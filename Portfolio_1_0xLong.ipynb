# %% [markdown]
# <a href="https://colab.research.google.com/github/minh-nguyen-mn/Quanta-Portfolio/blob/main/Portfolio_1_0xLong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# QUANTA FELLOWSHIP — WEEK 1
# FULL ROBUSTNESS + NO LOOKAHEAD (V1.2 FINAL)
# Author: Minh Nguyen
# =========================================================

# =========================
# CONFIG
# =========================

POLYGON_API_KEY = "REMOVED_API_KEY"

ETF_UNIVERSE = [
    "AAXJ",
    "ACWI",
    "ACWX",
    "AGG",
    "AGQ",
    "AIA",
    "AOA",
    "AOM",
    "AOR",
    "BAB",
    "BIL",
    "BIV",
    "BLV",
    "BND",
    "BSV",
    "BWX",
    "CGW",
    "CMF",
    "CQQQ",
    "CWB",
    "CWI",
    "DBC",
    "DEM",
    "DES",
    "DGS",
    "DHS",
    "DIA",
    "DLN",
    "DLS",
    "DON",
    "DSI",
    "DTD",
    "DVY",
    "DXJ",
    "EDV",
    "EEM",
    "EFA",
    "EFG",
    "EFV",
    "EMB",
    "EPI",
    "EPP",
    "EPS",
    # "EQWL",
    "EWA",
    "EWC",
    "EWG",
    "EWJ",
    "EWL",
    "EWP",
    "EWS",
    "EWT",
    "EWU",
    "EWW",
    "EWY",
    "EWZ",
    "EXI",
    "EZU",
    "FAS",
    "FBT",
    "FDL",
    "FDN",
    "FEX",
    "FEZ",
    "FGD",
    "FIW",
    "FNX",
    "FPX",
    "FTA",
    "FTC",
    "FTCS",
    "FVD",
    "FXH",
    "FXI",
    "FXL",
    "FXO",
    "FXR",
    "FXU",
    "FYX",
    "GDX",
    "GDXJ",
    "GLD",
    # "GOVI",
    "GRID",
    "GSG",
    "GSY",
    "GVI",
    "HEDJ",
    "HYD",
    "HYG",
    "IAI",
    "IAU",
    "IBB",
    "ICF",
    "ICLN",
    "IDU",
    "IDV",
    "IEF",
    "IEI",
    "IEV",
    "IGF",
    # "IGIB",
    # "IGLB",
    "IGM",
    "IGOV",
    # "IGSB",
    "IGV",
    "IHI",
    "IJH",
    "IJJ",
    "IJK",
    "IJR",
    "IJS",
    "IJT",
    # "ILCB",
    # "ILCG",
    # "ILCV",
    "ILF",
    # "IMCB",
    # "IMCG",
    "IOO",
    "ITA",
    "ITB",
    "ITM",
    "ITOT",
    "IUSG",
    "IUSV",
    "IVE",
    "IVV",
    "IVW",
    "IWB",
    "IWC",
    "IWD",
    "IWF",
    "IWL",
    "IWM",
    "IWN",
    "IWO",
    "IWP",
    "IWR",
    "IWS",
    "IWV",
    "IWX",
    "IWY",
    "IXC",
    "IXJ",
    "IXN",
    "IYC",
    "IYE",
    "IYF",
    "IYG",
    "IYH",
    "IYJ",
    "IYK",
    "IYR",
    "IYW",
    "IYY",
    "JNK",
    "KBE",
    "KRE",
    "LQD",
    "MBB",
    "MDY",
    "MDYG",
    "MDYV",
    "MGC",
    "MGK",
    "MGV",
    "MINT",
    "MUB",
    "MUNI",
    "NLR",
    "NYF",
    "OEF",
    "ONEQ",
    "PCY",
    "PDP",
    "PEY",
    "PFF",
    "PGX",
    "PHO",
    "PID",
    "PKW",
    "PPA",
    "PRF",
    "PRFZ",
    "PWB",
    "PWV",
    "PWZ",
    "PXF",
    "PXH",
    "PZA",
    "QLD",
    "QQEW",
    "QQQ",
    "QQXT",
    "QTEC",
    "ROM",
    "RPG",
    "RPV",
    "RSP",
    # "RSPT",
    "RWJ",
    "RWK",
    "RWL",
    "RWO",
    "RWR",
    "SCHA",
    "SCHB",
    "SCHF",
    "SCHG",
    "SCHV",
    "SCHX",
    "SCZ",
    "SDY",
    "SGOL",
    "SH",
    "SHM",
    "SHV",
    "SHY",
    "SIVR",
    "SLV",
    "SLYG",
    "SLYV",
    "SMH",
    "SOXX",
    "SPAB",
    # "SPDW",
    # "SPEM",
    "SPHQ",
    # "SPIB",
    # "SPIP",
    # "SPLB",
    # "SPLG",
    # "SPMB",
    "SPMD",
    # "SPSB",
    # "SPTI",
    # "SPTL",
    # "SPTM",
    "SPXL",
    "SPY",
    "SPYG",
    "SPYV",
    "SSO",
    "SUB",
    # "SUSA",
    "TECL",
    "TFI",
    "TIP",
    "TLH",
    "TLT",
    "TMF",
    "TNA",
    "UPRO",
    "USD",
    # "USIG",
    "USO",
    # "USRT",
    "UYG",
    "VAW",
    "VB",
    "VBK",
    "VBR",
    "VCIT",
    "VCLT",
    "VCR",
    "VCSH",
    "VDC",
    "VDE",
    "VEA",
    "VEU",
    "VFH",
    "VGIT",
    "VGK",
    "VGLT",
    "VGSH",
    "VGT",
    "VHT",
    "VIG",
    "VIS",
    "VMBS",
    "VNQ",
    "VO",
    "VOE",
    "VOT",
    "VOX",
    "VPL",
    "VPU",
    "VSS",
    "VT",
    "VTI",
    "VTV",
    "VUG",
    "VV",
    "VWO",
    "VXF",
    "VYM",
    # "WTV",
    "XBI",
    "XHB",
    "XLB",
    "XLE",
    "XLF",
    "XLG",
    "XLI",
    "XLK",
    "XLP",
    "XLU",
    "XLV",
    "XLY",
    "XME",
    # "XMHQ",
    # "XMMO",
    # "XNTK",
    "XOP",
    "XSD",
    # "XSMO",
    "YINN",
    "ZROZ"
]

BOND = ["AGG", "BAB", "BIL", "BIV", "BLV", "BND", "BSV", "BWX", "CMF", "CWB", "EDV", "EMB", "GOVI", "GSY", "GVI", "HYD", "HYG", "IEF", "IEI", "IGIB", "IGLB", "IGOV", "IGSB", "ITM", "JNK", "LQD", "MBB", "MINT", "MUB", "MUNI", "NYF", "PCY", "PWZ", "PZA", "SHM", "SHV", "SHY", "SPAB", "SPIB", "SPIP", "SPLB", "SPMB", "SPSB", "SPTI", "SPTL", "SUB", "TFI", "TIP", "TLH", "TLT", "TMF", "USIG", "VCIT", "VCLT", "VCSH", "VGIT", "VGLT", "VGSH", "VMBS", "ZROZ"]

# =========================
# SIGNAL 1  -- PICKED
# =========================
# # Maximize full sharpe
IGV', 'VEU', 'VTV', 'DTD', 'IWD', 'CWB', 'BIV', 'IYF', 'VEA', 'MUNI', 'VTI', 'VGSH', 'EWJ', 'EFG', 'IYJ', 'EEM', 'IWY', 'IWF', 'FXI', 'MBB', 'TFI', 'AOA', 'IVE', 'BIL', 'SDY', 'VAW', 'VO', 'SPY', 'EWZ', 'TMF', 'DLN', 'IUSG', 'VNQ', 'SH', 'FIW', 'SPXL', 'VCLT']
# ETF_UNIVERSE = ['EWT', 'CMF', 'RWJ', 'PXH', 'GVI', 'ROM', 'TNA', 'QLD', 'USO', 'FYX', 'TECL', 'GRID', 'IJS', 'BWX', 'VB', 'QQQ', 'IDU', 'HEDJ', 'SCZ', 'EWG', 'EWU', 'EWS', 'VBR', 'EXI', 'ICLN', 'IGOV', 'TIP', 'XLU', 'CQQQ', 'FEZ', 'IJR', 'IWM', 'EZU', 'FVD', 'IOO', 'PRFZ', 'BLV', 'SH', 'DHS', 'VBK', 'XSD', 'VGLT', 'TLH', 'EPS', 'SLYV', 'FTA', 'DON', 'MUB', 'ITM', 'SLYG', 'SPYG', 'LQD', 'BND', 'PKW', 'VMBS', 'VXF', 'XLY', 'EDV', 'PGX', 'IEV', 'PWB', 'AOM', 'AGG', 'FNX', 'VCR', 'AIA', 'ACWX', 'DLS', 'VT', 'PZA', 'ACWI', 'IYW', 'MDYG', 'VSS', 'RWL', 'SCHA', 'XLK', 'DES', 'VIS', 'IWR', 'EFA', 'IEF', 'IJT', 'BIV', 'VGSH', 'PCY', 'TFI', 'SMH', 'QQXT', 'SCHF', 'IJK', 'MUNI', 'SPAB', 'BIL']
# ETF_UNIVERSE = ['EWT', 'CMF', 'CQQQ', 'PXH', 'RWJ', 'GVI', 'GRID', 'QLD', 'EWS', 'BWX', 'SH', 'QQQ', 'USO', 'VGLT', 'EWU', 'IGOV', 'SCZ', 'FYX', 'EXI', 'TIP', 'IJS', 'HEDJ', 'VB', 'FEZ', 'EDV', 'IDU', 'BLV', 'VBR', 'AIA', 'XLK', 'FVD', 'TLH', 'EZU', 'ITM', 'LQD', 'MUB', 'EWG', 'IOO', 'VMBS', 'XSD', 'BND', 'EPS', 'DHS', 'AGG', 'AOM', 'PGX', 'TNA', 'VBK', 'IWM', 'PWB', 'VGSH', 'PZA', 'PRFZ', 'TFI', 'BIV', 'BIL', 'SPAB', 'MUNI', 'PKW', 'ACWX']
# ETF_UNIVERSE = ['EWT', 'CMF', 'PXH', 'CQQQ', 'QLD', 'SH', 'QQQ', 'GVI', 'RWJ', 'BWX', 'EWS', 'IGOV', 'VGLT', 'TIP', 'GRID', 'BLV', 'MUB', 'EWU', 'FEZ', 'ITM', 'XSD', 'LQD', 'EPS', 'VMBS', 'EXI', 'EDV', 'BND', 'TLH', 'EZU', 'SCZ', 'VGSH', 'AGG', 'VB', 'IOO', 'MUNI', 'FVD', 'BIL']
# ETF_UNIVERSE = ['EWT', 'CMF', 'SH', 'CQQQ', 'EWS', 'PXH', 'VB', 'EPS', 'RWJ', 'GVI', 'BWX', 'TIP', 'BLV', 'VMBS', 'IOO', 'QQQ', 'MUB', 'ITM', 'LQD', 'FVD', 'VGLT', 'IGOV', 'EWU', 'BND', 'VGSH']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'CMF', 'SH', 'EPS', 'EWU', 'PXH', 'GVI', 'VGLT', 'VB', 'IOO', 'BLV', 'FVD', 'BWX', 'TIP', 'ITM', 'MUB', 'LQD', 'VMBS', 'BND', 'EWS']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'SH', 'CMF', 'GVI', 'EPS', 'FVD', 'IOO', 'VGLT', 'EWU', 'VB', 'BWX', 'MUB', 'TIP', 'ITM', 'VMBS', 'BND', 'LQD']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'SH', 'CMF', 'GVI', 'EWU', 'IOO', 'FVD', 'VGLT', 'EPS', 'BND', 'MUB', 'TIP', 'VMBS', 'LQD']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'SH', 'EPS', 'CMF', 'GVI', 'FVD', 'VGLT', 'IOO', 'MUB', 'LQD', 'TIP', 'BND']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'EPS', 'FVD', 'SH', 'IOO', 'GVI', 'CMF', 'VGLT', 'MUB', 'LQD']

# # Maximize train+val sharpe
# ETF_UNIVERSE = ['IAU', 'TECL', 'ROM', 'TNA', 'USD', 'UPRO', 'EWT', 'QLD', 'XLU', 'EFA', 'EWZ', 'IGM', 'VOX', 'QQQ', 'IGV', 'CMF', 'XSD', 'VAW', 'RPV', 'IDU', 'SCZ', 'VPU', 'IYW', 'QQEW', 'DLS', 'FDN', 'PCY', 'FGD', 'IYF', 'IWO', 'FYX', 'XLF', 'XLK', 'USO', 'PXH', 'XOP', 'EWJ', 'QTEC', 'ITA', 'IWR', 'IXN', 'BWX', 'EPI', 'SMH', 'FTA', 'EWU', 'EWW', 'EXI', 'IWS', 'GRID', 'XLB', 'IWP', 'VB', 'RWL', 'IWD', 'SPMD', 'IYK', 'FXO', 'DON', 'EPS', 'EWG', 'XME', 'VEA', 'PWB', 'VBR', 'HEDJ', 'FTC', 'VT', 'EZU', 'PWV', 'AOR', 'MDYV', 'IVW', 'AAXJ', 'TMF', 'VGT', 'MDY', 'AOA', 'VWO', 'VCR', 'XLY', 'SLYG', 'IVV', 'ACWI', 'EFV', 'DGS', 'IVE', 'DSI', 'KRE', 'PRF', 'IEF', 'QQXT', 'IWB', 'MGC', 'RSP', 'SLYV', 'IYJ', 'DXJ', 'MDYG', 'BSV', 'MUNI', 'FTCS', 'IJT', 'DTD', 'PHO', 'SPHQ', 'SHM', 'VGK', 'CWI', 'VCLT', 'IWM', 'FXU', 'EPP', 'EDV', 'VTI', 'PPA', 'VTV', 'IOO', 'VOT', 'SPYG', 'FXL', 'IJH', 'IWV', 'XHB', 'FVD', 'ICF', 'VDC', 'IYY', 'PRFZ', 'ACWX', 'PID', 'SH', 'IGOV', 'SCHF', 'SPYV', 'VMBS', 'VXF', 'VGLT', 'EWA', 'BND', 'SPXL', 'VBK', 'SPY', 'XLI', 'PKW', 'VV', 'SCHA', 'FIW', 'EEM', 'IEI', 'IGF', 'IJJ', 'VOE', 'DVY', 'EWP', 'BLV', 'VPL', 'ICLN', 'PWZ', 'SSO', 'MGK', 'BIL', 'MBB', 'SOXX', 'ITM', 'TLH']
 'FXH', 'XLB', 'EWS', 'MUB', 'IVW', 'PPA', 'ILF', 'IWM', 'XOP', 'MGC', 'FXU', 'FNX', 'BLV', 'PHO', 'MBB', 'PRFZ', 'PXF', 'SOXX', 'PID', 'PWV', 'XLI', 'GVI', 'ICF', 'MGK', 'VSS', 'ACWX', 'XHB', 'XME', 'XLF', 'FXL', 'BSV', 'DES', 'VOT', 'DHS', 'VIS', 'CQQQ', 'VWO', 'IJT', 'VPL', 'SPHQ', 'PDP', 'EFV', 'RSP', 'PGX', 'PKW', 'EWA', 'EWC', 'VGLT', 'DGS', 'VGSH', 'VXF', 'VBK', 'VDC', 'DSI', 'UYG', 'LQD', 'MDYG', 'VDE', 'SPAB', 'TLH', 'TLT', 'TIP', 'SPYG', 'FGD', 'SHM', 'SLYG', 'RWO', 'DXJ', 'SIVR', 'SCHA', 'SPYV', 'SLYV', 'EPI', 'UPRO', 'EPP', 'PZA']
# ETF_UNIVERSE = ['EWT', 'ROM', 'TNA', 'TECL', 'USO', 'QLD', 'USD', 'XLU', 'QQQ', 'IDU', 'SCZ', 'FYX', 'EFA', 'GRID', 'XSD', 'IGM', 'BWX', 'VB', 'HEDJ', 'XLK', 'EXI', 'EWU', 'DLS', 'VPU', 'PCY', 'FTA', 'IYW', 'RPV', 'QQEW', 'IWR', 'DON', 'EPS', 'EZU', 'RWL', 'PWB', 'QTEC', 'IWS', 'VT', 'XLY', 'IXN', 'VCR', 'ACWI', 'SH', 'QQXT', 'AAXJ', 'IWP', 'MDYV', 'BND', 'IEF', 'VMBS', 'FTC', 'SCHF', 'MUNI', 'PRF', 'MDY', 'FTCS', 'BIL', 'EWJ', 'IWO', 'FXO', 'EWG', 'EDV', 'PXH', 'SMH', 'IGOV', 'EWZ', 'IWV', 'CWI', 'IWD', 'VOX', 'VGT', 'VBR', 'IYF', 'VEA', 'VTI', 'VGK', 'DVY', 'IYJ', 'IVE', 'VTV', 'IJH', 'IVV', 'AOA', 'BIV', 'IYY', 'DTD', 'FIW', 'AGG', 'VCLT', 'IAU', 'FEZ', 'AOM', 'RWJ', 'AIA', 'AOR', 'FDN', 'CMF', 'VAW', 'IGV', 'KRE', 'IWN', 'SPMD', 'TFI', 'IWB', 'FEX', 'IYH', 'ITA', 'ICLN', 'FVD', 'IYC', 'IYK', 'IJK', 'IEV', 'EWP', 'EWW', 'IOO', 'FXR', 'IEI', 'IGF', 'IJJ', 'IJR', 'IJS', 'ITM', 'FXH', 'XLB', 'EWS', 'MUB', 'IVW', 'PPA', 'ILF', 'IWM', 'XOP', 'MGC', 'FXU', 'FNX', 'BLV', 'PHO', 'MBB', 'PRFZ', 'PXF', 'SOXX', 'PID', 'PWV', 'XLI', 'GVI', 'ICF', 'MGK', 'VSS', 'ACWX', 'XHB', 'XME', 'XLF', 'FXL', 'BSV', 'DES', 'VOT', 'DHS', 'VIS', 'CQQQ', 'VWO', 'IJT', 'VPL', 'SPHQ', 'PDP', 'EFV', 'RSP', 'PGX', 'PKW', 'EWA', 'EWC', 'VGLT', 'DGS', 'VGSH', 'VXF', 'VBK', 'VDC', 'DSI', 'UYG', 'LQD', 'MDYG', 'VDE', 'SPAB', 'TLH', 'TLT', 'TIP', 'SPYG', 'FGD', 'SHM', 'SLYG', 'RWO', 'DXJ', 'SIVR', 'SCHA', 'SPYV', 'SLYV', 'EPI', 'UPRO', 'EPP', 'PZA']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'SCZ', 'SH', 'HEDJ', 'BWX', 'PCY', 'EPS', 'RWL', 'MUNI', 'VMBS', 'IDU', 'ACWI']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'EPS', 'RWL', 'BWX', 'SCZ', 'MUNI', 'VMBS', 'ACWI', 'HEDJ', 'SH', 'PCY']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'EPS', 'RWL', 'SCZ', 'BWX', 'HEDJ', 'VMBS', 'MUNI']
# ETF_UNIVERSE = ['EWT', 'QQQ', 'BWX', 'SCZ', 'VMBS', 'MUNI', 'HEDJ', 'EPS']
# ETF_UNIVERSE = ['QQQ', 'EWT', 'BWX', 'SCZ', 'EPS', 'VMBS', 'MUNI', 'HEDJ']

# # Maximize (0.5 train sharpe + 0.5 val sharpe)
# ETF_UNIVERSE = ['TECL', 'IAU', 'ROM', 'TNA', 'EWT', 'USD', 'QLD', 'CMF', 'XLU', 'EFA', 'EWZ', 'QQQ', 'UPRO', 'IGM', 'PXH', 'FYX', 'XSD', 'IDU', 'SCZ', 'USO', 'IYW', 'VB', 'IGV', 'EWU', 'VAW', 'BWX', 'XLK', 'VPU', 'DLS', 'EXI', 'VOX', 'RPV', 'VBR', 'GRID', 'IWO', 'QQEW', 'IWR', 'FTA', 'QTEC', 'SMH', 'IYF', 'EZU', 'IXN', 'PCY', 'DON', 'HEDJ', 'EWG', 'XLF', 'IWS', 'EWJ', 'RWL', 'ICLN', 'IWP', 'EPS', 'IJS', 'PWB', 'VT', 'IWM', 'IWD', 'XLY', 'VCR', 'SLYG', 'SLYV', 'FGD', 'FXO', 'VEA', 'PRFZ', 'MDYV', 'MDY', 'EDV', 'IOO', 'FTC', 'IYK', 'IJT', 'XLB', 'ACWI', 'VBK', 'AAXJ', 'TMF', 'BLV', 'VGT', 'CQQQ', 'SPMD', 'VXF', 'FVD', 'PRF', 'AOR', 'VGLT', 'SPYG', 'VGK', 'IVW', 'QQXT', 'MDYG', 'AOA', 'TLH', 'IEF', 'IVE', 'IVV', 'PWV', 'EWP', 'IJR', 'CWI', 'XLI', 'ACWX', 'IJH', 'PKW', 'IYJ', 'IYY', 'DTD', 'SCHA', 'IWV', 'FDN', 'VTV', 'IJJ', 'ITA', 'VTI', 'EWW', 'EFV', 'MUNI', 'FTCS', 'SCHF', 'VWO', 'DSI', 'IGOV', 'DGS', 'BND', 'IWB', 'IEV', 'BSV', 'VMBS', 'XME', 'VCLT', 'FAS', 'RSP', 'SHM', 'VIS', 'FEZ', 'MGC', 'VPL', 'EEM', 'SH', 'DHS', 'PID', 'IJK', 'ITM', 'SPY', 'FEX', 'SPHQ', 'DXJ', 'FIW', 'FXH', 'PDP', 'VV', 'VO', 'IYR', 'PWZ', 'IEI', 'BIL', 'TIP', 'VOT', 'MBB', 'FXU', 'PHO', 'SSO', 'VOE', 'TLT', 'EPP']
# ETF_UNIVERSE = ['QQQ', 'XLU', 'FDN', 'SH', 'IYK', 'ITA', 'PCY', 'DLS', 'PWV', 'BSV', 'IGV', 'MUNI', 'IDU', 'VMBS', 'AOA', 'FTCS', 'BIL']

# # Maximize train+val sharpe + blind sharpe
# ETF_UNIVERSE = ['TECL', 'ROM', 'QLD', 'IAU', 'UPRO', 'IYK', 'KRE', 'IYW', 'QQQ', 'SPXL', 'TNA', 'XLK', 'IGM', 'GRID', 'SSO', 'IVW', 'XLU', 'SPYG', 'VDC', 'IXN', 'VGT', 'MGK', 'QTEC', 'EPI', 'DSI', 'ICLN', 'MGC', 'IGF', 'BWX', 'FXO', 'ACWI', 'VT', 'QQEW', 'AOA', 'IDU', 'CMF', 'AOR', 'VV', 'EPS', 'IVV', 'VPU', 'SOXX', 'SPY', 'SMH', 'IWV', 'IWP', 'EWP', 'IYY', 'XLB', 'PWB', 'IWB', 'VEA', 'PXH', 'IOO', 'IGOV', 'FXL', 'VTI', 'XHB', 'XSD', 'EXI', 'IWS', 'VGK', 'VWO', 'AAXJ', 'FTA', 'RWL', 'SLYG', 'ITA', 'MDY', 'VXF', 'DXJ', 'VB', 'MUNI', 'PID', 'EFV', 'EZU', 'MDYG', 'FTC', 'FXU', 'SPHQ', 'VCR', 'VOT', 'SHM', 'SCHF', 'PRFZ', 'SLYV', 'DGS', 'IWM', 'EEM', 'ACWX', 'PKW', 'DVY', 'SCHA', 'IJH', 'PWZ', 'ITM']
# ETF_UNIVERSE = ['ROM', 'TECL', 'QLD', 'IGOV', 'IYK', 'XLU', 'GRID', 'IYW', 'QQQ', 'IDU', 'IVW', 'BWX', 'SPYG', 'XLK', 'AOR', 'ACWI', 'SSO', 'AOA', 'UPRO', 'MGK', 'VPU', 'VT', 'CMF', 'DSI', 'IGM', 'VEA', 'SPXL', 'ITA', 'MGC', 'VGT', 'VV', 'SPY', 'IWV', 'EPS', 'IVV', 'FXO', 'IYY', 'IWB', 'IXN', 'IOO']
# ETF_UNIVERSE = ['XLU', 'IYK', 'GRID', 'IDU', 'ROM', 'AOR', 'QQQ', 'BWX', 'IGOV', 'VT', 'AOA', 'ACWI', 'CMF', 'IVW', 'VPU', 'SPYG']
# ETF_UNIVERSE = ['GRID', 'XLU', 'IYK', 'QQQ', 'ACWI', 'IVW', 'VT', 'CMF', 'BWX'] # best
# ETF_UNIVERSE = ['QQQ', 'XLU', 'GRID', 'VT', 'IYK', 'CMF']
# ETF_UNIVERSE = ['QQQ', 'XLU', 'GRID', 'VT', 'CMF']
# ETF_UNIVERSE = ['QQQ', 'GRID', 'XLU', 'VT', 'CMF']

# # Maximize train sharpe + blind sharpe
# ETF_UNIVERSE = ['IAU', 'ROM', 'TECL', 'QLD', 'UPRO', 'KRE', 'IYK', 'IYW', 'QQQ', 'EPI', 'IGM', 'TNA', 'XLK', 'XLU', 'IVW', 'SSO', 'VDC', 'IXN', 'GRID', 'VGT', 'MGK', 'QTEC', 'MGC', 'DSI', 'IGF', 'FXO', 'QQEW', 'VT', 'AOA', 'BW
# ETF_UNIVERSE = ['IGF', 'QLD', 'XLU', 'IYK', 'IYW', 'BWX', 'SCHG', 'GRID', 'HYG', 'EWC', 'AOR', 'XLG', 'AOA', 'ACWI', 'CMF']
# ETF_UNIVERSE = ['IGF', 'GRID', 'AOR', 'XLU', 'QLD', 'IYW', 'HYG', 'AOA', 'IYK', 'ACWI', 'EWC', 'CMF', 'BWX', 'XLG', 'SCHG']

# # Maximize train sharpe + val sharpe + blind sharpe
# # ETF_UNIVERSE = ['TECL', 'ROM', 'QLD', 'TNA', 'IYW', 'QQQ', 'CMF', 'XLK', 'IGM', 'XLU', 'GRID', 'IXN', 'QTEC', 'BWX', 'VGT', 'IDU', 'PXH', 'VT', 'QQEW', 'ACWI', 'FXO', 'VPU', 'EPS', 'SMH', 'AOA', 'XSD', 'IWP', 'PWB', 'EXI', 'IVV', 'VB', 'IWV', 'IYY', 'VEA', 'FTA', 'SPY', 'IWS', 'EZU', 'IGOV', 'RWL', 'VGK', 'VTI', 'MDY', 'AAXJ', 'VCR', 'MUNI', 'FTC', 'IJH', 'EEM']
# # ETF_UNIVERSE = ['QLD', 'XLU', 'GRID', 'BWX', 'IGOV', 'IDU', 'QQQ', 'ACWI', 'VT', 'XLK', 'EPS', 'IWP']
# # ETF_UNIVERSE = ['XLU', 'IDU', 'QQQ']
# # ETF_UNIVERSE = ['QQQ']
# # Neutral
# ETF_UNIVERSE = ['TECL', 'ROM', 'QLD', 'TNA', 'IYW', 'QQQ', 'CMF', 'XLK', 'IGM', 'XLU', 'GRID', 'IXN', 'QTEC', 'BWX', 'VGT', 'IDU', 'PXH', 'VT', 'QQEW', 'ACWI', 'FXO', 'VPU', 'EPS', 'SMH', 'AOA', 'XSD', 'IWP', 'PWB', 'EXI', 'IVV', 'VB', 'IWV', 'IYY', 'VEA', 'FTA', 'SPY', 'IWS', 'EZU', 'IGOV', 'RWL', 'VGK', 'VTI', 'MDY', 'AAXJ', 'VCR', 'MUNI', 'FTC', 'IJH', 'EEM', 'AGG', 'YINN', 'ACWX', 'AOR', 'VWO', 'AIA', 'VXF', 'EDV', 'EFA', 'EFG', 'EFV', 'EPP', 'EPI', 'EWC', 'EWA', 'VIS', 'FAS', 'EWZ', 'EWW', 'EWU', 'FDL', 'FEX', 'DXJ', 'EWP', 'EWS', 'EWT', 'FYX', 'FXL', 'FXI', 'FXU', 'FXR', 'FVD', 'FXH', 'FTCS', 'FPX', 'FNX', 'FDN', 'DVY', 'FEZ', 'IEI', 'FGD', 'FIW', 'IEF', 'IAI', 'ICLN', 'ICF', 'IAU', 'GLD', 'GDXJ', 'ITM', 'ITB', 'ITA', 'HYG', 'HEDJ', 'GVI', 'CWI', 'DEM', 'CWB', 'CQQQ', 'EWJ', 'EWG', 'CGW', 'AOM', 'DLS', 'DLN', 'DIA', 'DHS', 'DGS', 'DES', 'BIL', 'DON', 'IWF', 'IWL', 'IWM', 'IWN', 'IWO', 'IWR', 'IEV', 'IGF', 'IJR', 'IGV', 'IJK', 'IJJ', 'IJS', 'IOO', 'ILF', 'IJT', 'IYC', 'IYF', 'IYH', 'IYJ
GK', 'MGC', 'MDYV', 'NLR', 'MDYG', 'MBB', 'KRE', 'LQD', 'KBE', 'PXF', 'PWZ', 'PWV', 'PCY', 'ONEQ', 'PPA', 'PKW', 'PID', 'PHO', 'PGX', 'PDP', 'VCLT', 'IVE', 'SCHX', 'VDE', 'IUSG', 'SCHA', 'RWO', 'XLI', 'SCHG', 'XLG', 'SCZ', 'SCHF', 'RPG', 'QQXT', 'RWJ', 'UYG', 'TIP', 'USO', 'USD', 'UPRO', 'TLT', 'RSP', 'RPV', 'TFI', 'SPYG', 'TLH', 'SPYV', 'SPXL', 'SPMD', 'SSO', 'SPHQ', 'VTV', 'VOT', 'SPAB', 'SOXX', 'SLYV', 'SLYG', 'SIVR', 'PZA', 'VAW', 'XHB', 'BSV', 'XLF', 'SGOL', 'BIV', 'VV', 'VUG', 'VMBS', 'BLV', 'VSS', 'VPL', 'VOX', 'VOE', 'DSI', 'DTD', 'XOP', 'XME', 'XLB', 'BND', 'XLY', 'XLV', 'XLP']

# =========================
# SIGNAL 2? -- BAD
# =========================
# # Maximize 0.4/0.6 train/val
# ETF_UNIVERSE = ['PZA', 'TNA', 'FAS', 'ROM', 'EWZ', 'USD', 'SLV', 'FXI', 'EEM', 'ILF', 'SDY', 'AGQ', 'EWP', 'EWJ', 'FGD', 'VWO', 'EFA', 'IYG', 'ONEQ', 'GDX', 'SH', 'IDV', 'EWG', 'IWN', 'SIVR', 'SSO', 'FXR', 'EWC', 'AIA', 'XLB', 'XLG', 'EFV', 'IGF', 'IJR', 'IYR', 'VOX', 'FVD', 'FEZ', 'EWU', 'FNX', 'PDP', 'GSG', 'CWI', 'PXH', 'PXF', 'VEU', 'PGX', 'VIS', 'PHO', 'GRID', 'HEDJ', 'VAW', 'TMF', 'VBR', 'EFG', 'EZU', 'HYG', 'EWT', 'EXI', 'FXU', 'ACWX', 'DGS', 'DBC', 'DSI', 'VEA', 'GLD', 'VV', 'PID', 'VSS', 'ITB', 'ACWI', 'SCHF', 'XLF', 'VFH', 'VPL', 'FYX', 'EPP', 'XBI', 'VT', 'FEX', 'PWZ', 'EPS', 'TECL', 'FTA', 'VB', 'PWV', 'XHB', 'DEM', 'VO', 'IJJ', 'RWL', 'IOO', 'FTC', 'EDV', 'VOE', 'SCZ', 'DVY', 'VTV', 'AGG', 'RWK', 'AAXJ', 'RSP', 'PKW', 'GSY', 'TIP', 'FXH', 'VYM', 'VGK', 'IWX', 'IWL', 'DHS', 'ZROZ', 'IWS', 'VXF', 'EMB', 'VBK', 'MDYV', 'IUSV', 'SCHV', 'IAI', 'PCY', 'SPYV', 'SLYV', 'IUSG', 'JNK', 'IVE', 'IWD', 'VIG', 'MDYG', 'DON', 'CMF', 'FTCS', 'DTD', 'MBB', 'SPHQ', 'BWX', 'MGV', 'IJH', 'IGOV', 'RPG', 'VOT', 'DLN', 'BIL', 'FXL', 'SHV', 'SLYG', 'VMBS']
# ETF_UNIVERSE = ['PZA', 'EWZ', 'TMF', 'EWJ', 'FXI', 'SH', 'SDY', 'EEM', 'EFA', 'ILF', 'VIS', 'FGD', 'ONEQ', 'EFV', 'FVD', 'PHO', 'IDV', 'CWI', 'EWC', 'VEU', 'VOX', 'EWG', 'VWO', 'XLG', 'PDP', 'XLB', 'IWN', 'EWU', 'GSG', 'HYG', 'VAW', 'EWP', 'EFG', 'AIA', 'IGF', 'PGX', 'IYG', 'EXI', 'GRID', 'IJR', 'EPS', 'ACWX', 'VEA', 'PXH', 'FTA', 'FXR', 'FEX', 'SCHF', 'VB', 'VPL', 'PID', 'ACWI', 'RWL', 'VSS', 'PWV', 'VO', 'FTC', 'SLV', 'VT', 'VV', 'HEDJ', 'DBC', 'VOE', 'RWK', 'VTV', 'IJJ', 'EDV', 'IWX', 'PKW', 'VBK', 'IOO', 'VYM', 'ITB', 'VXF', 'DHS', 'SLYV', 'IWL', 'GLD', 'DON', 'PWZ', 'RSP', 'DVY', 'VFH', 'SCZ', 'FYX', 'DTD', 'SCHV', 'AAXJ', 'IWS', 'FXH', 'DLN', 'DGS', 'VOT', 'VIG', 'MDYG', 'MDYV', 'IVE', 'JNK', 'IWD', 'SPYV', 'IJH', 'RPG', 'AGG', 'GSY', 'IUSV', 'FXU', 'EMB', 'IUSG', 'BWX', 'DSI', 'IGOV', 'MGV', 'SLYG', 'PXF', 'PCY', 'FTCS', 'SIVR', 'DEM', 'VBR', 'SPHQ', 'MBB', 'XLF', 'BIL', 'SHV']
# ETF_UNIVERSE = ['PZA', 'ILF', 'EWZ', 'EWP', 'EWJ', 'PDP', 'SDY', 'FGD', 'FXI', 'EFA', 'EEM', 'EDV', 'VIS', 'EFV', 'GSG', 'EWG', 'IDV', 'EWC', 'EWU', 'PHO', 'CWI', 'DBC', 'ONEQ', 'VEU', 'XLB', 'HYG', 'PGX', 'SLYV', 'VOX', 'VWO', 'XLG', 'PXH', 'IGF', 'AIA', 'EFG', 'ITB', 'VAW', 'HEDJ', 'IWN', 'EXI', 'GRID', 'PWZ', 'SCHF', 'IJR', 'VPL', 'ACWX', 'VEA', 'RWL', 'FVD', 'BWX', 'IGOV', 'GSY', 'EPS', 'VSS', 'FTA', 'AGG', 'SIVR', 'FEX', 'ACWI', 'PID', 'PWV', 'IYG', 'VB', 'IJJ', 'MBB', 'XLF', 'FTC', 'VOE', 'VO', 'BIL', 'EMB', 'SHV', 'JNK']
# ETF_UNIVERSE = ['PZA', 'EWP', 'EWJ', 'PDP', 'EDV', 'ITB', 'FGD', 'SDY', 'EFA', 'GSG', 'EFV', 'EWU', 'VIS', 'IDV', 'CWI', 'EWG', 'EWC', 'EEM', 'DBC', 'VEU', 'HYG', 'HEDJ', 'SLYV', 'PHO', 'PGX', 'XLG', 'PXH', 'XLB', 'VAW', 'EXI', 'GRID', 'EFG', 'VOX', 'VEA', 'PID', 'ACWX', 'IJJ', 'SCHF', 'IGF', 'FXI', 'ONEQ', 'VPL', 'VB', 'VSS', 'ACWI', 'PWZ', 'AGG', 'FTA', 'IGOV', 'RWL', 'VO', 'BWX', 'FEX', 'SIVR', 'PWV', 'IWN', 'VOE', 'EPS', 'AIA', 'JNK', 'BIL', 'MBB']
# ETF_UNIVERSE = ['SIVR', 'EWJ', 'ITB', 'FXI', 'PZA', 'EWP', 'PDP', 'SLYV', 'FGD', 'EEM', 'GRID', 'PXH', 'HEDJ', 'EFA', 'IDV', 'SDY', 'GSG', 'EFV', 'VEU', 'CWI', 'IJJ', 'EWU', 'HYG', 'PGX', 'SCHF', 'EWC', 'EXI', 'VSS', 'PWZ', 'DBC', 'AGG', 'IGOV', 'EDV', 'MBB', 'EFG', 'AIA', 'BWX', 'VEA', 'BIL', 'IGF']
# ETF_UNIVERSE = ['SIVR', 'ITB', 'EWJ', 'FXI', 'PZA', 'EWP', 'EEM', 'EFA', 'FGD', 'PDP', 'GRID', 'HEDJ', 'IDV', 'PXH', 'GSG', 'SLYV', 'EFV', 'CWI', 'VEU', 'SDY', 'PGX', 'HYG', 'EWU', 'PWZ', 'EXI', 'AGG', 'MBB', 'IGOV', 'SCHF', 'BIL']
# ETF_UNIVERSE = ['PZA', 'EWJ', 'ITB', 'SIVR', 'EEM', 'FGD', 'FXI', 'EWP', 'IDV', 'GRID', 'GSG', 'EFA', 'HEDJ', 'PDP', 'PXH', 'PGX', 'SLYV', 'HYG', 'EFV', 'CWI', 'VEU', 'PWZ', 'EXI', 'SDY', 'EWU', 'AGG', 'SCHF', 'MBB', 'IGOV', 'BIL']

# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['PZA', 'TNA', 'ROM', 'FAS', 'AGQ', 'EWZ', 'USD', 'SLV', 'FXI', 'EEM', 'EWP', 'GDX', 'SDY', 'ILF', 'EWJ', 'FGD', 'VWO', 'SH', 'SIVR', 'EFA', 'IYG', 'ONEQ', 'IDV', 'EWG', 'IWN', 'AIA', 'EWC', 'FXR', 'EFV', 'IGF', 'XLB', 'VOX', 'XLG', 'IYR', 'EWU', 'FEZ', 'FVD', 'PXH', 'IJR', 'GSG', 'GRID', 'HEDJ', 'CWI', 'PXF', 'VEU', 'FNX', 'ITB', 'PDP', 'SSO', 'PGX', 'VIS', 'EFG', 'EZU', 'PHO', 'VAW', 'DGS', 'EXI', 'VBR', 'ACWX', 'VEA', 'PID', 'HYG', 'VSS', 'FXU', 'ACWI', 'EPP', 'DBC', 'SCHF', 'VT', 'DSI', 'EWT', 'IJJ', 'DEM', 'XBI', 'VV', 'VPL', 'IOO', 'VFH', 'PWV', 'FEX', 'SCZ', 'EPS', 'FTA', 'FYX', 'VB', 'XHB', 'VO', 'GLD', 'RWL', 'PWZ', 'FTC', 'RSP', 'VGK', 'AAXJ', 'VOE', 'VTV', 'DVY', 'FXH', 'XLF', 'RWK', 'IAI', 'PKW', 'AGG', 'VYM', 'IWX', 'DHS', 'GSY', 'IWS', 'IWL', 'VIG', 'IXC', 'MDYV', 'EMB', 'SCHV', 'IUSV', 'PCY', 'XLE', 'TIP', 'SPYV', 'IWD', 'IYF', 'DON', 'IEV', 'IJS', 'CMF', 'JNK', 'IVE', 'SLYV', 'IUSG
# ETF_UNIVERSE = ['PZA', 'EDV', 'EWP', 'EWJ', 'PDP', 'FGD', 'SDY', 'GSG', 'EFA', 'EFV', 'EWU', 'HEDJ', 'EWG', 'IDV', 'CWI', 'VOX', 'DBC', 'EWC', 'VIS', 'VEU', 'HYG', 'PXH', 'SLYV', 'PGX', 'VAW', 'EXI', 'XLB', 'EFG', 'PHO', 'PID', 'VEA', 'SCHF', 'EEM', 'XLE', 'IJJ', 'ACWX', 'XLG', 'VSS', 'VB', 'IGF', 'ACWI', 'VPL', 'PWZ', 'AGG', 'IGOV', 'BWX', 'ONEQ', 'RWL', 'RSP', 'FTA', 'CMF', 'IXC', 'VT', 'FEX', 'IOO', 'JNK', 'PWV', 'BIL', 'MBB']
# ETF_UNIVERSE = ['EWP', 'EWJ', 'PZA', 'EEM', 'HEDJ', 'PXH', 'PDP', 'FGD', 'EFA', 'IDV', 'GSG', 'SLYV', 'EFV', 'SDY', 'EWU', 'XLE', 'VEU', 'CWI', 'IJJ', 'IXC', 'VSS', 'SCHF', 'HYG', 'PGX', 'CMF', 'DBC', 'EWC', 'PWZ', 'AGG', 'MBB', 'EXI', 'EFG', 'ACWX', 'VEA', 'VOX', 'IGOV', 'IGF', 'BWX', 'RSP', 'BIL', 'FEX']
# ETF_UNIVERSE = ['PZA', 'EWP', 'EWJ', 'EEM', 'FGD', 'HEDJ', 'IDV', 'EFA', 'PXH', 'GSG', 'PDP', 'EFV', 'EWU', 'VEU', 'PGX', 'CWI', 'HYG', 'SLYV', 'SDY', 'CMF', 'VSS', 'SCHF', 'PWZ', 'AGG', 'MBB', 'IGF', 'BIL']
# ETF_UNIVERSE = ['PZA', 'HEDJ', 'EWJ', 'FGD', 'GSG', 'EWP', 'PXH', 'IDV', 'EFA', 'EEM', 'EFV', 'EWU', 'PGX', 'CMF', 'HYG', 'CWI', 'VEU', 'SCHF', 'IGF', 'VSS', 'MBB', 'PWZ', 'BIL']
# ETF_UNIVERSE = ['PZA', 'HEDJ', 'PXH', 'FGD', 'EWJ', 'GSG', 'CMF', 'IDV', 'EWP', 'EFA', 'PGX', 'HYG', 'EEM', 'MBB', 'BIL']
# ETF_UNIVERSE = ['HEDJ', 'PZA', 'FGD', 'GSG', 'PXH', 'EWJ', 'CMF', 'IDV', 'PGX', 'HYG', 'EFA', 'BIL', 'MBB']
# ETF_UNIVERSE = ['HEDJ', 'PZA', 'FGD', 'GSG', 'IDV', 'PXH', 'CMF', 'PGX', 'EWJ', 'EFA', 'BIL', 'MBB']
# ETF_UNIVERSE = ['HEDJ', 'PZA', 'FGD', 'GSG', 'CMF', 'IDV', 'PXH', 'PGX', 'EWJ', 'EFA', 'BIL', 'MBB']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['PZA', 'SSO', 'EWJ', 'ILF', 'FXI', 'FXL', 'PDP', 'SDY', 'FGD', 'EDV', 'EFA', 'GSG', 'ZROZ', 'EWG', 'EEM', 'EFV', 'IYG', 'SLYV', 'VIS', 'DBC', 'EWC', 'EWU', 'IDV', 'AIA', 'PHO', 'CWI', 'XLB', 'ONEQ', 'HYG', 'VEU', 'PGX', 'VOX', 'XLG', 'VWO', 'IGF', 'EFG', 'PXH', 'EXI', 'PWZ', 'RWL', 'VAW', 'SH', 'IWN', 'VPL', 'VEA', 'ACWX', 'SCHF', 'FEX', 'FTA', 'EPS', 'BWX', 'PWV', 'AGG', 'IJR', 'PID', 'ACWI', 'IGOV', 'VSS', 'VB', 'VOE', 'FXU', 'FTC', 'HEDJ', 'GRID', 'IJJ', 'VO', 'MBB', 'BIL', 'SHV', 'XLF']
# ETF_UNIVERSE = ['SSO', 'PDP', 'PZA', 'EWJ', 'SLYV', 'SH', 'EDV', 'FXL', 'FGD', 'SDY', 'ZROZ', 'CWI', 'FXI', 'EFV', 'VEU', 'EFA', 'GSG', 'VIS', 'EWU', 'EWG', 'HYG', 'EPS', 'DBC', 'SCHF', 'PHO', 'EWC', 'VSS', 'XLG', 'PWZ', 'EXI', 'FEX', 'VOX', 'VAW', 'PGX', 'AGG', 'XLB', 'EFG', 'RWL', 'FTA', 'IGOV', 'BWX', 'VEA', 'VB', 'HEDJ', 'VPL', 'ACWX', 'ONEQ', 'IJJ', 'PID', 'MBB', 'PWV', 'FTC', 'VO', 'VOE', 'IDV', 'ACWI', 'SHV', 'BIL']
# ETF_UNIVERSE = ['SSO', 'FXI', 'EWJ', 'EFA', 'PDP', 'SLYV', 'FXL', 'SH', 'EDV', 'FGD', 'XLG', 'EWG', 'SDY', 'PZA', 'IDV', 'EFV', 'CWI', 'GSG', 'VEU', 'HYG', 'EWC', 'SCHF', 'EWU', 'DBC', 'PWZ', 'VSS', 'VIS', 'EPS', 'EXI', 'XLB', 'AGG', 'FEX', 'PGX', 'PHO', 'EFG', 'BWX', 'VPL', 'IGOV', 'FTC', 'FTA', 'MBB', 'ZROZ', 'PWV', 'VEA', 'BIL', 'SHV', 'IJJ']
# ETF_UNIVERSE = ['SSO', 'FXI', 'EWJ', 'EFA', 'PDP', 'SLYV', 'FXL', 'SH', 'EDV', 'FGD', 'XLG', 'EWG', 'SDY', 'PZA', 'IDV', 'EFV', 'CWI', 'GSG', 'VEU', 'HYG', 'EWC', 'SCHF', 'EWU', 'DBC', 'PWZ', 'VSS', 'VIS', 'EPS', 'EXI', 'XLB', 'AGG', 'FEX', 'PGX', 'PHO', 'EFG', 'BWX', 'VPL', 'IGOV', 'FTC', 'FTA', 'MBB', 'ZROZ', 'PWV', 'VEA', 'BIL', 'SHV', 'IJJ']
# ETF_UNIVERSE = ['SSO', 'FXI', 'EWJ', 'EFA', 'PDP', 'SLYV', 'FXL', 'SH', 'XLG', 'PZA', 'EDV', 'SDY', 'CWI', 'GSG', 'EFV', 'VEU', 'EWG', 'HYG', 'FGD', 'SCHF', 'VSS', 'DBC', 'PWZ', 'EXI', 'EWC', 'EWU', 'VIS', 'IDV', 'EPS', 'AGG', 'FEX', 'PHO', 'XLB', 'FTA', 'EFG', 'VEA', 'BWX', 'IGOV', 'FTC', 'PGX', 'MBB', 'VPL', 'ZROZ', 'BIL', 'SHV']
# ETF_UNIVERSE = ['SSO', 'FXI', 'EWJ', 'EFA', 'PDP', 'SLYV', 'FXL', 'SH', 'XLG', 'EDV', 'PZA', 'SDY', 'GSG', 'CWI', 'EFV', 'VEU', 'HYG', 'FGD', 'EWG', 'SCHF', 'VSS', 'DBC', 'PWZ', 'EXI', 'VIS', 'IDV', 'EPS', 'EWU', 'AGG', 'FEX', 'EWC', 'FTA', 'PHO', 'EFG', 'VEA', 'BWX', 'XLB', 'VPL', 'IGOV', 'FTC', 'PGX', 'ZROZ', 'MBB', 'BIL', 'SHV']

# =========================
# SIGNAL 8 -- PICKED
# =========================
# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['IAU', 'SPAB', 'AGQ', 'TMF', 'UYG', 'GDX', 'XOP', 'PZA', 'RWK', 'RWJ', 'QLD', 'EWT', 'IYE', 'FAS', 'FNX', 'SMH', 'TECL', 'XSD', 'XLE', 'SIVR', 'SHM', 'VDE', 'EDV', 'SPMD', 'GRID', 'FXU', 'IEF', 'XLY', 'DXJ', 'IOO', 'FXL', 'FTA', 'PRF', 'IYH', 'BWX', 'QTEC', 'IJH', 'AGG', 'IXJ', 'QQQ', 'XLK', 'EXI', 'XLV', 'BAB', 'EFA', 'TLT', 'CWI', 'IYW', 'IWR', 'EWS', 'PWB', 'ITM', 'IJJ', 'ROM', 'VIS', 'VHT', 'VCR', 'ICF', 'GLD', 'AIA', 'MGK', 'PHO', 'IEV', 'CMF', 'BND', 'SPYG', 'ICLN', 'MBB', 'IHI', 'SLV', 'NYF', 'QQXT', 'SGOL', 'PXH', 'EFG', 'DBC', 'TLH', 'FTC', 'PDP', 'EWC', 'IEI', 'PCY', 'IWY', 'VGIT', 'EWA', 'DSI', 'SPYV', 'VO', 'VGK', 'IWP', 'VUG', 'VEA', 'VMBS', 'IGOV', 'SOXX', 'YINN', 'KRE', 'DEM', 'SPHQ', 'OEF', 'PWZ', 'FPX', 'VBR', 'MDYV', 'FGD', 'BSV', 'DTD', 'SCHG', 'PPA', 'IVV', 'FTCS', 'VGLT', 'IVW', 'FYX', 'FXI', 'DON', 'EWJ', 'AOA', 'XLB', 'VTV', 'DVY', 'GSY', 'SSO', 'DLN', 'PRFZ', 'IWD', 'IUSG', 'VYM', 'VXF', 'VOE', 'IYJ', 'KBE', 'PEY', 'FXR', 'IJR', 'XLF', 'VFH', 'ACWX', 'VOX', 'DIA', 'VEU', 'USD', 'IWS', 'IUSV', 'AOM', 'SCHV', 'VGSH', 'MUNI', 'XLG', 'SCHB']
# ETF_UNIVERSE = ['SPAB', 'IAU', 'AGQ', 'PZA', 'GDX', 'BWX', 'RWJ', 'SHM', 'SPMD', 'RWK', 'DXJ', 'XOP', 'XSD', 'SMH', 'GRID', 'IEF', 'UYG', 'FXU', 'AGG', 'TECL', 'IYH', 'QLD', 'FNX', 'IXJ', 'IOO', 'IYE', 'XLY', 'SIVR', 'ITM', 'FXL', 'PRF
# ETF_UNIVERSE = ['XSD', 'SHM', 'FXU', 'IEF', 'PWZ', 'AGG', 'XLV', 'AIA', 'VGIT', 'MBB', 'SMH', 'IYE', 'BSV', 'VMBS', 'ITM', 'IEI', 'BWX', 'IXJ']
# ETF_UNIVERSE = ['SHM', 'XSD', 'FXU', 'AIA', 'IEF', 'XLV', 'PWZ', 'AGG', 'VGIT', 'MBB', 'IXJ', 'VMBS', 'BSV', 'ITM', 'IEI', 'IYE']
# ETF_UNIVERSE = ['XSD', 'SHM', 'FXU', 'IEF', 'AIA', 'PWZ', 'XLV', 'AGG', 'IXJ', 'VGIT', 'MBB', 'BSV', 'VMBS', 'IEI', 'ITM']
# ETF_UNIVERSE = ['XSD', 'IEF', 'SHM', 'FXU', 'PWZ', 'AGG', 'VGIT', 'XLV', 'MBB', 'AIA', 'VMBS', 'BSV', 'ITM', 'IEI']
# ETF_UNIVERSE = ['XSD', 'IEF', 'FXU', 'SHM', 'PWZ', 'AGG', 'VGIT', 'MBB', 'AIA', 'VMBS', 'BSV', 'IEI', 'ITM']
# ETF_UNIVERSE = ['XSD', 'PWZ', 'AGG', 'IEF', 'FXU', 'VGIT', 'MBB', 'SHM', 'VMBS', 'BSV', 'IEI', 'ITM', 'AIA']

# # Maximize 0.6/0.4 train/val
# ETF_UNIVERSE = ['IAU', 'SPAB', 'TMF', 'AGQ', 'GDX', 'EWT', 'PZA', 'UYG', 'FAS', 'FNX', 'RWK', 'XOP', 'QLD', 'SHM', 'IYE', 'RWJ', 'XLE', 'SMH', 'IOO', 'SIVR', 'EDV', 'FTA', 'IEF', 'DXJ', 'XSD', 'SPMD', 'TECL', 'FXU', 'FXL', 'XLY', 'VDE', 'TLT', 'PRF', 'IJH', 'BAB', 'EXI', 'EFA', 'AGG', 'IXJ', 'GLD', 'CWI', 'GRID', 'DBC', 'IWR', 'EWA', 'IEV', 'ICF', 'QTEC', 'XLV', 'AIA', 'BWX', 'VIS', 'QQQ', 'VCR', 'QQXT', 'IJJ', 'VHT', 'YINN', 'IYH', 'EWS', 'MGK', 'TLH', 'PXH', 'XLK', 'PCY', 'VGK', 'DEM', 'EWC', 'PWB', 'CMF', 'IYW', 'BND', 'NYF', 'VEA', 'SGOL', 'MBB', 'VO', 'IEI', 'FTC', 'EFG', 'IWP', 'SPYG', 'KRE', 'AOA', 'FXI', 'FPX', 'IHI', 'PHO', 'PDP', 'SH', 'DSI', 'SPYV', 'IWY', 'PRFZ', 'VGIT', 'FGD', 'ITM', 'VMBS', 'SPHQ', 'OEF', 'VUG', 'PWZ', 'BSV', 'SLV', 'ICLN', 'SSO', 'MDYV', 'VBR', 'IWD', 'DTD', 'EWJ', 'IVV', 'ACWX', 'PEY', 'FTCS', 'VTV', 'IVW', 'GSY', 'DON', 'BLV', 'VXF', 'SCHG', 'FYX', 'EZU', 'VYM', 'PPA', 'VEU', 'IYJ', 'IGOV', 'IJR', 'IWS', 'XLG', 'DVY', 'XLB', 'IUSG', 'SOXX', 'DLN', 'VGLT', 'SCHB', 'VOX', 'VV', 'VOE', 'ROM', 'DIA', 'IUSV', 'VGSH']
# ETF_UNIVERSE = ['SPAB', 'IAU', 'GDX', 'AGQ', 'PZA', 'TMF', 'SPMD', 'DXJ', 'SHM', 'IEF', 'FNX', 'FXU', 'RWJ', 'RWK', 'AGG', 'EWT', 'IOO', 'XSD', 'UYG', 'SMH', 'IXJ', 'BWX', 'FTA', 'FXL', 'XOP', 'TECL', 'XLY', 'PRF', 'GLD', 'AIA', 'BAB', 'QLD', 'SIVR', 'GRID', 'SGOL', 'DBC', 'EXI', 'VHT', 'MBB', 'QQQ', 'CMF', 'IYH', 'PCY', 'IEI', 'BND', 'FAS', 'QQXT', 'XLV', 'NYF', 'EFA', 'PWZ', 'BSV', 'XLE', 'IJH', 'TLT', 'ITM', 'VMBS', 'QTEC', 'SPYG', 'VGIT', 'VCR', 'IYE', 'IWR', 'SPHQ', 'CWI', 'EWS', 'SPYV', 'TLH', 'IEV', 'MGK', 'AOA', 'IHI', 'IGOV', 'FTC', 'VGSH', 'GSY']
# ETF_UNIVERSE = ['IAU', 'SPAB', 'EWT', 'AIA', 'SHM', 'SPMD', 'GDX', 'IEF', 'TMF', 'FXU', 'AGG', 'IXJ', 'DXJ', 'BWX', 'XSD', 'IOO', 'AGQ', 'BAB', 'UYG', 'PRF', 'EFA', 'SGOL', 'GLD', 'TECL', 'IWR', 'BSV', 'SMH', 'IEI', 'RWK', 'IHI', 'MBB', 'CMF', 'PWZ', 'FNX', 'VGIT', 'XLV', 'BND', 'VMBS', 'ITM', 'IJH', 'VHT', 'SPYG', 'RWJ', 'FXL', 'NYF', 'DBC', 'TLH', 'VGSH']
# ETF_UNIVERSE = ['SPAB', 'UYG', 'AIA', 'DXJ', 'XSD', 'IAU', 'IXJ', 'FXU', 'SHM', 'TMF', 'IEF', 'EWT', 'AGQ', 'AGG', 'SPMD', 'SMH', 'IOO', 'PRF', 'PWZ', 'BWX', 'IWR', 'VGIT', 'GDX', 'MBB', 'IEI', 'VMBS', 'NYF', 'XLV', 'BSV', 'ITM', 'IJH', 'SPYG', 'EFA', 'RWJ', 'BND', 'TECL', 'VHT', 'IHI', 'RWK', 'SGOL', 'VGSH', 'TLH', 'CMF']
# ETF_UNIVERSE = ['UYG', 'IAU', 'AIA', 'XSD', 'SHM', 'SMH', 'FXU', 'AGQ', 'IXJ', 'DXJ', 'IEF', 'EWT', 'AGG', 'TMF', 'PRF', 'SPMD', 'IWR', 'PWZ', 'BWX', 'IOO', 'GDX', 'XLV', 'IJH', 'SPAB', 'VGIT', 'MBB', 'RWJ', 'IEI', 'VMBS', 'BSV', 'NYF', 'ITM', 'EFA', 'SPYG', 'BND', 'SGOL', 'VHT', 'VGSH', 'IHI', 'RWK']
# ETF_UNIVERSE = ['XSD', 'SMH', 'AIA', 'UYG', 'SHM', 'IAU', 'AGQ', 'IXJ', 'FXU', 'IEF', 'TMF', 'DXJ', 'AGG', 'EWT', 'PRF', 'SPMD', 'BWX', 'IWR', 'XLV', 'IOO', 'PWZ', 'IEI', 'VGIT', 'MBB', 'SPYG', 'VMBS', 'NYF', 'IJH', 'RWJ', 'BSV', 'GDX', 'ITM', 'IHI', 'VHT', 'EFA', 'BND', 'RWK', 'VGSH']
# ETF_UNIVERSE = ['XSD', 'AIA', 'SHM', 'SMH', 'AGQ', 'IXJ', 'XLV', 'FXU', 'IEF', 'AGG', 'UYG', 'TMF', 'DXJ', 'IOO', 'IWR', 'GDX', 'EWT', 'PRF', 'PWZ', 'BWX', 'IJH', 'SPMD', 'MBB', 'IEI', 'VGIT', 'NYF', 'VMBS', 'BSV', 'SPYG', 'ITM', 'EFA', 'VHT', 'RWK', 'BND', 'VGSH', 'IHI']
# ETF_UNIVERSE = ['SHM', 'XSD', 'AIA', 'GDX', 'SMH', 'AGQ', 'IXJ', 'FXU', 'XLV', 'AGG', 'IEF', 'TMF', 'PWZ', 'IWR', 'NYF', 'IOO', 'IEI', 'MBB', 'VMBS', 'IJH', 'PRF', 'VGIT', 'BSV', 'DXJ', 'BWX', 'ITM', 'SPYG', 'VHT', 'VGSH']
# ETF_UNIVERSE = ['SHM', 'AIA', 'XSD', 'FXU', 'IEF', 'XLV', 'IWR', 'AGG', 'PWZ', 'NYF', 'SMH', 'IOO', 'IJH', 'IXJ', 'PRF', 'SPYG', 'TMF', 'VGIT', 'IEI', 'VMBS', 'MBB', 'BSV', 'ITM', 'VGSH']
# ETF_UNIVERSE = ['SHM', 'XSD', 'AIA', 'IEF', 'XLV', 'FXU', 'PWZ', 'AGG', 'NYF', 'VGIT', 'MBB', 'IJH', 'VMBS', 'BSV', 'IEI', 'VGSH', 'SPYG']
# ETF_UNIVERSE = ['IJH', 'XSD', 'SHM', 'IEF', 'AGG', 'NYF', 'PWZ', 'FXU', 'AIA', 'VGIT', 'MBB', 'VMBS', 'BSV', 'SPYG', 'IEI', 'XLV', 'VGSH']

# # # Maximize 0.65/0.35 train/val
# ETF_UNIVERSE = ['IAU', 'SPAB', 'TMF', 'AGQ', 'GDX', 'EWT', 'PZA', 'FNX', 'FAS', 'UYG', 'RWK', 'SHM', 'QLD', 'XOP', 'XLE', 'FTA', 'IOO', 'IYE', 'IEF', 'DXJ', 'EDV', 'RWJ', 'SPMD', 'SMH', 'SIVR', 'FXL', 'FXU', 'TLT', 'XSD', 'BAB', 'XLY', 'EFA', 'IJH', 'EXI', 'PRF', 'GLD', 'TECL', 'VDE', 'AGG', 'EWA', 'IXJ', 'DBC', 'CWI', 'IEV', 'ICF', 'AIA', 'IWR', 'QQXT', 'YINN', 'VIS', 'XLV', 'SH', 'VCR', 'IJJ', 'QTEC', 'TLH', 'BWX', 'GRID', 'DEM', 'PCY', 'VGK', 'VHT', 'QQQ', 'PXH', 'MGK', 'EWS', 'EWC', 'VEA', 'VO', 'CMF', 'NYF', 'SGOL', 'AOA', 'BND', 'FXI', 'IEI', 'IWP', 'PWB', 'XLK', 'IYH', 'KRE', 'MBB', 'FTC', 'FPX', 'IYW', 'EFG', 'PRFZ', 'SPYG', 
# ETF_UNIVERSE = ['SPAB', 'AIA', 'FXI', 'UYG', 'IXJ', 'TMF', 'FXU', 'SHM', 'AGQ', 'DXJ', 'XSD', 'EWT', 'SPMD', 'IEF', 'SMH', 'AGG', 'IOO', 'PRF', 'XLV', 'PWZ', 'IWR', 'IJH', 'VHT', 'NYF', 'VGIT', 'BSV', 'BWX', 'EFA', 'IEI', 'SPYG', 'MBB', 'TECL', 'IAU', 'ITM', 'VMBS', 'GDX', 'BND', 'SGOL', 'RWJ']
# ETF_UNIVERSE = ['AIA', 'TMF', 'UYG', 'FXI', 'AGQ', 'SHM', 'IAU', 'SMH', 'IEF', 'IXJ', 'XSD', 'FXU', 'SPMD', 'AGG', 'DXJ', 'PRF', 'EWT', 'IOO', 'PWZ', 'XLV', 'IJH', 'IWR', 'NYF', 'IEI', 'VGIT', 'BWX', 'MBB', 'BSV', 'VMBS', 'GDX', 'EFA', 'RWJ', 'SPYG', 'VHT', 'ITM', 'BND']
# ETF_UNIVERSE = ['AIA', 'FXI', 'SHM', 'AGQ', 'XSD', 'TMF', 'XLV', 'SMH', 'IXJ', 'IEF', 'FXU', 'UYG', 'AGG', 'IOO', 'DXJ', 'PWZ', 'SPMD', 'IJH', 'PRF', 'IWR', 'NYF', 'IEI', 'VGIT', 'VHT', 'MBB', 'EWT', 'BWX', 'BSV', 'SPYG', 'VMBS', 'ITM', 'GDX', 'EFA', 'BND']
# ETF_UNIVERSE = ['SHM', 'AIA', 'TMF', 'AGQ', 'XLV', 'FXU', 'XSD', 'IEF', 'FXI', 'IXJ', 'AGG', 'SMH', 'GDX', 'PWZ', 'NYF', 'IOO', 'IJH', 'IEI', 'IWR', 'PRF', 'VGIT', 'MBB', 'VMBS', 'VHT', 'BSV', 'SPMD', 'DXJ', 'SPYG']
# ETF_UNIVERSE = ['SHM', 'XSD', 'IEF', 'FXU', 'XLV', 'AGG', 'FXI', 'AIA', 'SMH', 'NYF', 'IWR', 'PWZ', 'IOO', 'TMF', 'AGQ', 'IJH', 'IXJ', 'PRF', 'SPYG', 'VGIT', 'VMBS', 'IEI', 'MBB', 'SPMD', 'GDX', 'VHT', 'BSV']
# ETF_UNIVERSE = ['SHM', 'XSD', 'FXU', 'XLV', 'SMH', 'IEF', 'FXI', 'AGG', 'AIA', 'NYF', 'IJH', 'PWZ', 'TMF', 'IOO', 'IWR', 'IXJ', 'VGIT', 'SPYG', 'PRF', 'VMBS', 'MBB', 'IEI', 'VHT', 'SPMD', 'BSV']
# ETF_UNIVERSE = ['SHM', 'XSD', 'IEF', 'FXU', 'NYF', 'AGG', 'XLV', 'PWZ', 'AIA', 'SMH', 'TMF', 'IJH', 'VGIT', 'FXI', 'VMBS', 'MBB', 'SPYG', 'IWR', 'BSV', 'IXJ', 'IEI']
# ETF_UNIVERSE = ['SHM', 'XSD', 'XLV', 'FXI', 'FXU', 'IEF', 'IJH', 'PWZ', 'AGG', 'NYF', 'IXJ', 'AIA', 'VGIT', 'SPYG', 'VMBS', 'IWR', 'MBB', 'TMF', 'BSV']
# # best
# # TRAIN+VAL SHARPE: 1.2180258248432354
# # TRAIN SHARPE: 1.2442379495206295
# # VAL SHARPE: 1.1636433210712214
# # BLIND SHARPE: 0.5937777636562553
# ETF_UNIVERSE = ['SHM', 'XSD', 'FXI', 'FXU', 'IXJ', 'IJH', 'XLV', 'NYF', 'IEF', 'PWZ', 'AGG', 'SPYG', 'VGIT', 'IWR', 'AIA', 'VMBS', 'MBB', 'BSV']
# # best
# # TRAIN+VAL SHARPE: 1.2039078651932278
# # TRAIN SHARPE: 1.1934072852529656
# # VAL SHARPE: 1.2359178640273902
# # BLIND SHARPE: 0.6308944464996529
# ETF_UNIVERSE = ['SHM', 'XSD', 'IEF', 'FXU', 'NYF', 'AGG', 'XLV', 'PWZ', 'FXI', 'IXJ', 'VGIT', 'IJH', 'SPYG', 'VMBS', 'MBB', 'BSV']
# ETF_UNIVERSE = ['FXI', 'SHM', 'IEF', 'FXU', 'IJH', 'NYF', 'XLV', 'AGG', 'XSD', 'IXJ', 'PWZ', 'VGIT', 'VMBS', 'MBB', 'SPYG', 'BSV']

# # Maximize 0.7/0.3 train/val
# ETF_UNIVERSE = ['IAU', 'SPAB', 'TMF', 'EWT', 'AGQ', 'GDX', 'PZA', 'FNX', 'FAS', 'UYG', 'RWK', 'SHM', 'QLD', 'FTA', 'IOO', 'XLE', 'IEF', 'DXJ', 'XOP', 'EDV', 'TLT', 'SPMD', 'IYE', 'FXL', 'FXU', 'GLD', 'BAB', 'SIVR', 'EFA', 'RWJ', 'EWA', 'EXI', 'SMH', 'IJH', 'SH', 'DBC', 'PRF', 'XLY', 'XSD', 'AGG', 'CWI', 'IXJ', 'IEV', 'VDE', 'ICF', 'YINN', 'AIA', 'QQXT', 'IWR', 'TECL', 'VIS', 'VCR', 'DEM', 'TLH', 'IJJ', 'VGK', 'PCY', 'XLV', 'PXH', 'VHT', 'EWC', 'VEA', 'QTEC', 'MGK', 'BWX', 'AOA', 'EWS', 'QQQ', 'FXI', 'VO', 'IEI', 'IWP', 'SGOL', 'GRID', 'NYF', 'CMF', 'KRE', 'FPX', 'BND', 'FTC', 'PRFZ', 'MBB', 'EFG', 'PWB', 'EZU', 'XLK', 'IYW', 'FGD', 'BLV', 'SPYG', 'SSO', 'DSI', 'IWD', 'IYH', 'PDP', 'ACWX', 'OEF', 'PEY', 'SPHQ', 'SPYV', 'IHI', 'BSV', 'VMBS', 'IWY', 'EWJ', 'VGIT', 'PWZ', 'VXF', 'VUG', 'XLG', 'MDYV', 'VTV', 'PHO', 'GSY', 'DTD', 'VEU', 'VBR', 'IVV', 'IWS', 'VYM', 'FTCS', 'IJR', 'IVW', 'DON', 'EWG', 'NLR', 'IYJ', 'EFV', 'FYX', 'SCHB', 'VV', 'PXF', 'HEDJ', 'SCHG', 'IUSG', 'DVY', 'IJK', 'PPA', 'VOX', 'IYR', 'VNQ', 'DLN', 'XLB', 'VGSH']
# ETF_UNIVERSE = ['IAU', 'SPAB', 'PZA', 'TMF', 'GDX', 'AGQ', 'SPMD', 'DXJ', 'FNX', 'SHM', 'EWT', 'IEF', 'RWK', 'FXU', 'AGG', 'FTA', 'IOO', 'GLD', 'IXJ', 'DBC', 'FXL', 'RWJ', 'FAS', 'XSD', 'AIA', 'SIVR', 'BAB', 'QQXT', 'EXI', 'PCY', 'TECL', 'SGOL', 'PRF', 'SMH', 'BWX', 'UYG', 'TLT', 'QLD', 'AOA', 'VHT', 'QQQ', 'IEI', 'XLY', 'EFA', 'CMF', 'MBB', 'IJH', 'PWZ', 'BND', 'NYF', 'XOP', 'BSV', 'VMBS', 'XLV', 'GRID', 'YINN', 'TLH', 'VGK', 'IEV', 'SPHQ', 'SPYG', 'CWI', 'IWR', 'FXI', 'EWA', 'VCR', 'VGIT', 'MGK', 'SPYV', 'XLE', 'IYH', 'MDYV', 'EWS', 'GSY', 'DEM', 'QTEC']
# ETF_UNIVERSE = ['IAU', 'SPAB', 'TMF', 'EWT', 'SPMD', 'SHM', 'IEF', 'GDX', 'AIA', 'DXJ', 'FXU', 'AGG', 'IXJ', 'IOO', 'FXI', 'GLD', 'PRF', 'AGQ', 'BAB', 'EFA', 'FTA', 'XSD', 'DBC', 'BWX', 'RWK', 'IWR', 'SGOL', 'IEI', 'XLV', 'BSV', 'TECL', 'PWZ', 'IJH', 'TLH', 'TLT', 'MBB', 'CMF', 'BND', 'VHT', 'FXL', 'EXI', 'IEV', 'VGIT', 'UYG', 'EWA', 'NYF', 'SPHQ', 'PCY', 'AOA', 'VMBS', 'QQXT', 'SPYG', 'CWI', 'DEM', 'VGK']
# ETF_UNIVERSE = ['EWT', 'AIA', 'DXJ', 'TMF', 'SPMD', 'IXJ', 'FXI', 'AGQ', 'SHM', 'IEF', 'UYG', 'FXU', 'GDX', 'SPAB', 'AGG', 'XSD', 'PRF', 'TECL', 'IOO', 'IAU', 'GLD', 'PWZ', 'BAB', 'DBC', 'BWX', 'NYF', 'IWR', 'XLV', 'BSV', 'SGOL', 'EFA', 'SPYG', 'IEI', 'VGIT', 'IJH', 'FXL', 'MBB', 'IEV', 'RWK', 'BND', 'EXI', 'TLH', 'VMBS', 'SPHQ', 'FTA', 'VHT', 'CMF', 'VGK', 'CWI']
# ETF_UNIVERSE = ['TMF', 'AIA', 'EWT', 'IXJ', 'DXJ', 'IEF', 'SPMD', 'FXU', 'AGQ', 'UYG', 'FXI', 'SHM', 'AGG', 'XSD', 'PRF', 'IOO', 'GDX', 'TECL', 'DBC', 'SPAB', 'PWZ', 'NYF', 'IWR', 'BAB', 'BWX', 'FXL', 'IJH', 'IAU', 'BSV', 'IEI', 'VGIT', 'EFA', 'MBB', 'TLH', 'GLD', 'RWK', 'SPYG', 'IEV', 'SGOL', 'VMBS', 'EXI', 'BND', 'CWI', 'XLV', 'VGK', 'FTA', 'SPHQ']
# ETF_UNIVERSE = ['TMF', 'AIA', 'IXJ', 'SPMD', 'EWT', 'DXJ', 'IEF', 'AGQ', 'FXI', 'UYG', 'FXU', 'SHM', 'AGG', 'XSD', 'PRF', 'IOO', 'TECL', 'GDX', 'PWZ', 'IAU', 'NYF', 'IWR', 'DBC', 'XLV', 'IJH', 'BWX', 'FXL', 'IEI', 'BSV', 'VGIT', 'EFA', 'TLH', 'SPYG', 'MBB', 'RWK', 'VMBS', 'IEV', 'BAB', 'CWI', 'BND', 'EXI', 'SGOL', 'FTA', 'GLD', 'SPHQ', 'VGK']
# ETF_UNIVERSE = ['TMF', 'IXJ', 'AIA', 'SPMD', 'DXJ', 'IEF', 'XLV', 'AGQ', 'AGG', 'EWT', 'FXU', 'FXI', 'IOO', 'SHM', 'GDX', 'PRF', 'XSD', 'TECL', 'PWZ', 'IJH', 'NYF', 'BAB', 'DBC', 'BSV', 'BWX', 'IEI', 'VGIT', 'UYG', 'IWR', 'MBB', 'TLH', 'VMBS', 'FTA', 'EFA', 'BND', 'RWK', 'SPYG', 'FXL', 'IEV', 'SPHQ', 'SGOL', 'CWI', 'GLD']
# ETF_UNIVERSE = ['TMF', 'AIA', 'IXJ', 'IEF', 'AGG', 'SHM', 'DXJ', 'SPMD', 'XLV', 'FXU', 'IOO', 'GDX', 'AGQ', 'FXI', 'DBC', 'PWZ', 'NYF', 'GLD', 'PRF', 'EWT', 'BSV', 'VGIT', 'IEI', 'VMBS', 'XSD', 'MBB', 'TECL', 'BND']
# ETF_UNIVERSE = ['IXJ', 'AIA', 'IOO', 'TMF', 'IEF', 'FXI', 'AGG', 'FXU', 'SPMD', 'TECL', 'DXJ', 'PRF', 'SHM', 'NYF', 'PWZ', 'XSD', 'EWT', 'XLV', 'VGIT', 'IEI', 'VMBS', 'BSV', 'MBB']
# ETF_UNIVERSE = ['SHM', 'AIA', 'TMF', 'XSD', 'IEF', 'IXJ', 'IOO', 'AGG', 'FXI', 'PWZ', 'NYF', 'FXU', 'PRF', 'TECL', 'XLV', 'VGIT', 'IEI', 'VMBS', 'MBB', 'BSV']
# ETF_UNIVERSE = ['SHM', 'IEF', 'XSD', 'AIA', 'FXI', 'AGG', 'IXJ', 'TMF', 'PWZ', 'NYF', 'FXU', 'IOO', 'VGIT', 'PRF', 'VMBS', 'BSV', 'TECL', 'MBB']
# ETF_UNIVERSE = ['IOO', 'SHM', 'FXI', 'AIA', 'TMF', 'FXU', 'IEF', 'XSD', 'NYF', 'AGG', 'IXJ', 'PWZ', 'PRF', 'VGIT', 'TECL', 'VMBS', 'BSV', 'MBB']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['IAU', 'SPAB', 'TMF', 'EWT', 'GDX', 'AGQ', 'FNX', 'FAS', 'PZA', 'RWK', 'UYG', 'SHM', 'FTA', 'IOO', 'IEF', 'QLD', 'SH', 'DXJ', 'XLE', 'TLT', 'EDV', 'SPMD', 'GLD', 'EWA', 'BAB', 'EFA', 'XOP', 'DBC', 'FXL', 'FXU', 'EXI', 'IJH', 'IYE', 'SIVR', 'PRF', 'YINN', 'CWI', 'XLY', 'AGG', 'IEV', 'IXJ', 'SMH', 'ICF', 'AIA', 'RWJ', 'QQXT', 'XSD', 'IWR', 'DEM', 'VIS', 'VDE', 'VGK', 'TL
# ETF_UNIVERSE = ['TMF', 'DXJ', 'GLD', 'IXJ', 'AIA', 'IEF', 'SHM', 'AGG', 'SPMD', 'GDX', 'FXU', 'IOO', 'FNX', 'DBC', 'EWT', 'PRF', 'FXI', 'PWZ', 'NYF', 'BAB', 'AGQ', 'BSV', 'FTA', 'TECL', 'IEI', 'AOA', 'IJH', 'VMBS', 'VGIT', 'SGOL', 'XSD', 'MBB', 'XLV', 'IWR', 'SPHQ']
# ETF_UNIVERSE = ['TMF', 'AIA', 'IEF', 'IOO', 'SHM', 'IXJ', 'SPMD', 'FXI', 'AGG', 'DXJ', 'FXU', 'GLD', 'PRF', 'NYF', 'XSD', 'XLV', 'IJH', 'TECL', 'PWZ', 'GDX', 'IWR', 'IEI', 'FTA', 'BSV', 'VGIT', 'VMBS', 'SPHQ', 'AOA']
# ETF_UNIVERSE = ['TMF', 'IEF', 'AIA', 'SHM', 'FXI', 'GLD', 'AGG', 'IXJ', 'FXU', 'IOO', 'PWZ', 'NYF', 'TECL', 'XLV', 'XSD', 'SPMD', 'DXJ', 'BSV', 'IWR', 'PRF', 'GDX', 'IEI', 'VGIT', 'VMBS', 'SPHQ']
# ETF_UNIVERSE = ['IXJ', 'TMF', 'AIA', 'IEF', 'AGG', 'SHM', 'FXI', 'GLD', 'FXU', 'XSD', 'PWZ', 'NYF', 'IOO', 'DXJ', 'TECL', 'PRF', 'XLV', 'SPMD', 'VGIT', 'IWR', 'VMBS', 'IEI', 'BSV', 'GDX']
# ETF_UNIVERSE = ['IXJ', 'TMF', 'AIA', 'IEF', 'AGG', 'FXI', 'SHM', 'XSD', 'FXU', 'GLD', 'PWZ', 'IOO', 'NYF', 'TECL', 'DXJ', 'PRF', 'XLV', 'VGIT', 'SPMD', 'VMBS', 'IWR', 'IEI', 'BSV']
# ETF_UNIVERSE = ['GLD', 'IXJ', 'SHM', 'AIA', 'IEF', 'AGG', 'TMF', 'XSD', 'PWZ', 'FXU', 'FXI', 'NYF', 'TECL', 'IOO', 'XLV', 'VGIT', 'DXJ', 'PRF', 'VMBS', 'BSV', 'IEI']
# ETF_UNIVERSE = ['GLD', 'IEF', 'IXJ', 'AIA', 'AGG', 'TMF', 'SHM', 'FXI', 'PWZ', 'FXU', 'IOO', 'NYF', 'XSD', 'TECL', 'PRF', 'VGIT', 'BSV', 'VMBS', 'IEI']
# ETF_UNIVERSE = ['GLD', 'IOO', 'AIA', 'AGG', 'TMF', 'IXJ', 'IEF', 'FXI', 'FXU', 'PWZ', 'NYF', 'XSD', 'SHM', 'TECL', 'VGIT', 'BSV', 'VMBS']
# ETF_UNIVERSE = ['FXI', 'GLD', 'IOO', 'IXJ', 'TMF', 'FXU', 'AGG', 'IEF', 'AIA', 'NYF', 'PWZ', 'XSD', 'TECL', 'VGIT', 'SHM', 'BSV', 'VMBS']

'PFF', 'EWP', 'TIP', 'GRID', 'GSY', 'IVW', 'LQD', 'IWM', 'VGT', 'FXU', 'MDYG', 'FXH', 'IJT', 'TNA', 'VAW', 'DTD', 'RWL', 'VNQ', 'SCHA', 'AOR', 'MBB', 'MUB', 'PKW', 'HYG', 'CGW', 'MINT', 'BND', 'IYJ', 'IEI', 'QQXT', 'JNK', 'HEDJ', 'SHV', 'IUSG', 'VOT', 'EWS', 'XLI']
# ETF_UNIVERSE = ['PZA', 'GDX', 'EWL', 'FNX', 'EWJ', 'XBI', 'XLP', 'FYX', 'XLV', 'VDC', 'IYH', 'IXC', 'IYK', 'KBE', 'FXL', 'KRE', 'EWY', 'IDU', 'SOXX', 'FPX', 'IWF', 'XLB', 'FBT', 'EPI', 'FTA', 'HYD', 'VCIT', 'VPU', 'IBB', 'DES', 'XLU', 'VHT', 'ILF', 'XME', 'DEM', 'RWO', 'SCHG', 'TIP', 'GSY', 'VOX', 'QQQ', 'SLYG', 'XLG', 'PFF', 'EWU', 'RWR', 'LQD', 'EFA', 'QLD', 'MDYV', 'RWK', 'DXJ', 'FXR', 'MINT', 'FVD', 'IGM', 'ITB', 'SHV', 'MUB', 'MBB', 'MGK', 'FDL', 'AAXJ', 'GVI']
# ETF_UNIVERSE = ['GDX', 'PZA', 'EWL', 'FNX', 'XBI', 'EWJ', 'XLP', 'VDC', 'FYX', 'XLV', 'IXC', 'IYK', 'IYH', 'VCIT', 'HYD', 'FXL', 'IDU', 'TIP', 'XLU', 'VPU', 'GSY', 'LQD', 'EWY', 'IBB', 'SOXX', 'KBE', 'MINT', 'MUB', 'FBT', 'SHV', 'SLYG', 'EPI', 'MBB']
# # best
# ETF_UNIVERSE = ['GDX', 'EWL', 'PZA', 'XLP', 'EWJ', 'FNX', 'VDC', 'IYK', 'XBI', 'VCIT', 'IXC', 'FXL', 'HYD', 'KBE', 'GSY', 'TIP', 'IDU', 'FYX', 'IYH', 'XLV', 'MUB', 'MINT', 'XLU', 'LQD', 'MBB']
# ETF_UNIVERSE = ['GDX', 'EWL', 'XBI', 'XLP', 'EWJ', 'PZA', 'FNX', 'VDC', 'FXL', 'VCIT', 'IXC', 'IYK', 'HYD', 'IDU', 'GSY', 'MINT', 'MUB', 'TIP', 'LQD']
# ETF_UNIVERSE = ['GDX', 'EWL', 'XBI', 'XLP', 'FNX', 'PZA', 'VDC', 'FXL', 'VCIT', 'EWJ', 'HYD', 'IXC', 'IDU', 'IYK', 'GSY', 'TIP', 'MUB', 'MINT', 'LQD']

# # Maximize 0.65/0.35 train/val
# ETF_UNIVERSE = ['PZA', 'EWL', 'GDX', 'FNX', 'EWJ', 'KBE', 'ITB', 'XHB', 'IXC', 'KRE', 'XBI', 'XLV', 'FYX', 'USD', 'IYH', 'ILF', 'EWY', 'EWW', 'XLP', 'QLD', 'FXL', 'XLB', 'IWF', 'VDC', 'IXJ', 'IYK', 'IWN', 'XME', 'XLG', 'IDU', 'FTA', 'FPX', 'RWR', 'FBT', 'IGM', 'EFA', 'GLD
# # best
# # TRAIN+VAL SHARPE: 1.3710969400952402
# # TRAIN SHARPE: 1.3835915844580597
# # VAL SHARPE: 1.4131346629771133
# # BLIND SHARPE: 0.5662239901485779
# ETF_UNIVERSE = ['GDX', 'EWL', 'XBI', 'XLP', 'FNX', 'PZA', 'EWJ', 'VDC', 'FXL', 'VCIT', 'IYK', 'GSY', 'HYD', 'MUB', 'IDU', 'MINT']
# ETF_UNIVERSE = ['GDX', 'EWL', 'FNX', 'FXL', 'XLP', 'PZA', 'XBI', 'IDU', 'VDC', 'VCIT', 'IYK', 'EWJ', 'HYD', 'GSY', 'MINT']
# ETF_UNIVERSE = ['GDX', 'EWL', 'FNX', 'FXL', 'XLP', 'PZA', 'VDC', 'IDU', 'XBI', 'IYK', 'VCIT', 'EWJ', 'HYD', 'GSY', 'MINT']

# # Maximize 0.7/0.3 train/val
# ETF_UNIVERSE = ['PZA', 'EWL', 'FNX', 'GDX', 'EWJ', 'KBE', 'ITB', 'XHB', 'IXC', 'USD', 'KRE', 'XLV', 'FYX', 'XBI', 'IYH', 'QLD', 'ILF', 'EWW', 'EWY', 'IXJ', 'FXL', 'XLP', 'XLB', 'IWF', 'VDC', 'IYK', 'XLG', 'IWN', 'IDU', 'IGM', 'EFA', 'RWR', 'GLD', 'FTA', 'FPX', 'EZU', 'VGK', 'EWU', 'EPI', 'FBT', 'SOXX', 'RPV', 'VPU', 'IYG', 'GDXJ', 'RWO', 'ONEQ', 'FXO', 'YINN', 'DEM', 'FDL', 'XLK', 'VHT', 'FVD', 'DES', 'VIS', 'XME', 'XOP', 'XLU', 'SDY', 'BIV', 'VUG', 'QQQ', 'FXR', 'VOX', 'DXJ', 'RPG', 'XLF', 'IHI', 'RWK', 'SCHG', 'XLE', 'IGV', 'VDE', 'PWB', 'DVY', 'IYE', 'EWG', 'IWO', 'EWZ', 'VCIT', 'FDN', 'MGK', 'XSD', 'AAXJ', 'ITA', 'PXH', 'TMF', 'EFV', 'SGOL', 'DTD', 'HYD', 'RWL', 'GVI', 'SLYG', 'IEV', 'PFF', 'FXH', 'SLV', 'VCR', 'IBB', 'EWP', 'GSY', 'VGT', 'MDYV', 'PXF', 'GRID', 'IVW', 'XLI', 'FXU', 'TIP', 'SLYV', 'LQD', 'CGW', 'IYJ', 'AOR', 'IWM', 'PKW', 'MBB', 'MUB', 'CMF', 'HEDJ', 'SCHA', 'MDYG', 'MINT', 'QQXT', 'IEI', 'BND', 'HYG', 'SHV', 'BWX', 'VOT', 'VCLT', 'IUSG', 'QQEW']
# ETF_UNIVERSE = ['BIV', 'USO', 'XBI', 'EPI', 'ICLN', 'SIVR', 'EWT', 'EWZ', 'IGV', 'VYM', 'XHB', 'CQQQ', 'ITB', 'XLY', 'PFF', 'UPRO', 'BAB', 'XOP', 'IGM', 'FXI', 'IXC', 'SGOL', 'IJS', 'IBB', 'PID', 'SLYV', 'IYC', 'VOX', 'IAI', 'VNQ', 'IWY', 'IJJ', 'DXJ', 'RWJ', 'VBR', 'IYJ', 'ICF', 'XME', 'VBK', 'ITOT', 'PPA', 'IYW', 'VOT', 'XLK', 'SCHA', 'IWM', 'IWO', 'FTCS', 'VB', 'MDYV', 'PKW', 'IYF', 'IJK', 'MUNI', 'NLR', 'IWN', 'SCHB', 'SCHX', 'AGQ', 'ONEQ', 'IWC', 'VOE', 'VSS']
# ETF_UNIVERSE = ['BIV', 'USO', 'XBI', 'PFF', 'CQQQ', 'EPI', 'ICLN', 'SIVR', 'IGV', 'EWT', 'XHB', 'XLY', 'SGOL', 'UPRO', 'VYM', 'IAI', 'IGM', 'SLYV', 'ITB', 'IBB', 'IWY', 'IJS', 'ITOT', 'IYC', 'FTCS', 'MDYV', 'EWZ', 'MUNI', 'IJJ']
# ETF_UNIVERSE = ['BIV', 'PFF', 'CQQQ', 'SIVR', 'IGV', 'ICLN', 'XBI', 'EPI', 'XLY', 'USO', 'VYM', 'IGM', 'IJS', 'SGOL', 'SLYV', 'IBB', 'MUNI', 'IWY', 'ITOT', 'XHB']
# ETF_UNIVERSE = ['BIV', 'CQQQ', 'SIVR', 'PFF', 'ICLN', 'IGV', 'EPI', 'USO', 'XLY', 'SGOL', 'XBI', 'SLYV', 'MUNI', 'IGM', 'ITOT']
# ETF_UNIVERSE = ['BIV', 'PFF', 'CQQQ', 'SIVR', 'EPI', 'IGV', 'ICLN', 'SGOL', 'XLY', 'SLYV', 'IGM', 'MUNI', 'ITOT']
# ETF_UNIVERSE = ['BIV', 'CQQQ', 'PFF', 'SIVR', 'SLYV', 'EPI', 'MUNI']
# ETF_UNIVERSE = ['BIV', 'PFF', 'CQQQ', 'SIVR', 'MUNI']
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'BIV', 'MUNI']
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'MUNI']

# # Maximize 0.8/0.2 train/val
# ETF_UNIVERSE = ['BIV', 'USO', 'IAU', 'EWZ', 'ITB', 'XBI', 'ICLN', 'FAS', 'XHB', 'EPI', 'IAI', 'IGV', 'XOP', 'EWT', 'AGQ', 'IGM', 'SIVR', 'TNA', 'SH', 'XLY', 'UYG', 'IXC', 'CQQQ', 'IJS', 'QLD', 'PFF', 'VYM', 'SGOL', 'IYJ', 'IBB', 'XLK', 'IYW', 'VBR', 'IJJ', 'IYF', 'IWM', 'IWC', 'PID', 'IYC', 'VBK', 'XME', 'IWO', 'VCR', 'VB', 'ILF', 'FXI', 'FBT', 'IJK', 'VNQ', 'RPV', 'GDXJ', 'ROM', 'RWJ', 'UPRO', 'DXJ', 'VIS', 'SLYV', 'VDE', 'VOT', 'VOE', 'IWY', 'XSD', 'PHO', 'PKW', 'ONEQ', 'ICF', 'PPA', 'RS
# ETF_UNIVERSE = ['BIV', 'XBI', 'PFF', 'SIVR', 'USO', 'EPI', 'IGV', 'CQQQ', 'VYM', 'SGOL', 'ICLN', 'XLY', 'UPRO', 'EWT', 'XHB', 'IBB', 'IAI', 'IGM', 'SLYV', 'IJS', 'IWY', 'ITB', 'IYC', 'ITOT', 'FTCS', 'MUNI', 'EWZ', 'MDYV', 'VSS', 'VOT', 'SCHA']
# ETF_UNIVERSE = ['BIV', 'PFF', 'IGV', 'SIVR', 'XBI', 'CQQQ', 'ICLN', 'XLY', 'EPI', 'IBB', 'IGM', 'SGOL', 'IJS', 'SLYV', 'IWY', 'ITOT', 'FTCS', 'MUNI']
# ETF_UNIVERSE = ['BIV', 'PFF', 'CQQQ', 'SIVR', 'IGV', 'EPI', 'SLYV', 'IGM', 'FTCS', 'ITOT', 'SGOL', 'MUNI']
# # best
# TRAIN+VAL SHARPE: 1.0815959468044547
# TRAIN SHARPE: 1.161135187142187
# VAL SHARPE: 1.0076076740208875
# BLIND SHARPE: -0.058703638789350684
# ETF_UNIVERSE = ['PFF', 'BIV', 'CQQQ', 'SIVR', 'SLYV', 'MUNI', 'FTCS', 'ITOT']
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'SIVR', 'BIV', 'MUNI', 'ITOT', 'FTCS']
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'SIVR', 'BIV', 'MUNI', 'ITOT', 'FTCS']

# # Maximize 0.9/0.1 train/val
# ETF_UNIVERSE = ['BIV', 'IAU', 'USO', 'FAS', 'EWZ', 'ITB', 'XBI', 'IAI', 'XHB', 'TNA', 'ICLN', 'EPI', 'IGV', 'IGM', 'EWT', 'XOP', 'AGQ', 'UYG', 'XLY', 'SIVR', 'SH', 'IJS', 'VYM', 'PFF', 'IXC', 'IYJ', 'XLK', 'SGOL', 'IBB', 'QLD', 'FBT', 'IWM', 'IYF', 'CQQQ', 'IYW', 'PID', 'VBR', 'IWC', 'VB', 'VBK', 'IJJ', 'IJK', 'FXI', 'IYC', 'XME', 'ILF', 'VCR', 'IWO', 'VNQ', 'DXJ', 'RPV', 'ICF', 'VIS', 'GDXJ', 'ROM', 'VOT', 'XSD', 'PHO', 'RWJ', 'UPRO', 'PKW', 'IJT', 'VOE', 'SLYV', 'IWY', 'ONEQ', 'IWR', 'RSP', 'VXF', 'IJH', 'BAB', 'VO', 'NLR', 'VOX', 'EWP', 'PPA', 'YINN', 'XLF', 'XLI', 'DON', 'FYX', 'FIW', 'IWN', 'QQEW', 'MDY', 'DHS', 'PRF', 'XLG', 'FPX', 'SCHA', 'USD', 'FDL', 'EFV', 'DEM', 'IVV', 'PGX', 'VDE', 'EWJ', 'SSO', 'RPG', 'ITA', 'FXR', 'VSS', 'IYH', 'IYR', 'SCHX', 'SCHB', 'IWL', 'IVW', 'DLS', 'IYK', 'SCZ', 'VEA', 'SCHF', 'SLYG', 'MDYV', 'IYE', 'IWV', 'MGK', 'FTCS', 'ITOT', 'IWF', 'VAW', 'DIA', 'DLN', 'XLP', 'RWL', 'KRE', 'CWI', 'EXI', 'IEI', 'EPS', 'VFH', 'IWS', 'IYG', 'SOXX', 'IWB', 'MUNI', 'EFG', 'TLH', 'QTEC', 'TECL', 'VDC', 'FXL', 'VWO', 'MGV', 'IXN', 'ACWX', 'IEF', 'VV', 'SPY', 'RWK', 'VUG', 'GRID']
# ETF_UNIVERSE = ['BIV', 'XBI', 'EWT', 'EPI', 'EWZ', 'VYM', 'USO', 'XHB', 'SIVR', 'ITB', 'IGV', 'PFF', 'XLY', 'ICLN', 'IGM', 'IBB', 'PID', 'CQQQ', 'SGOL', 'VNQ', 'IJS', 'FAS', 'BAB', 'SLYV', 'IAI', 'UPRO', 'DXJ', 'FXI', 'IYC', 'VOX', 'XLK', 'IWY', 'IYJ', 'RWJ', 'NLR', 'IYW', 'FBT', 'IJJ', 'IJK', 'IXC', 'TNA', 'VBR', 'IWM', 'VB', 'AGQ', 'PKW', 'ICF', 'ITOT', 'VBK', 'FTCS', 'SCHA', 'SLYG', 'IWC', 'IYF', 'MUNI', 'VOT', 'VSS', 'IWL', 'IWO', 'SOXX', 'PPA', 'SCHF', 'SCHX', 'MDYV', 'SCHB', 'FDL', 'RPV']
# ETF_UNIVERSE = ['BIV', 'XBI', 'PFF', 'EPI', 'SIVR', 'IGV', 'EWT', 'XLY', 'SGOL', 'VYM', 'CQQQ', 'UPRO', 'IGM', 'ICLN', 'IAI', 'IBB', 'XHB', 'SLYV', 'USO', 'IJS', 'IWY', 'EWZ', 'FTCS', 'IYC', 'ITOT', 'MUNI', 'ITB', 'VSS', 'NLR', 'VOT', 'FAS', 'MDYV', 'XLK']
# ETF_UNIVERSE = ['BIV', 'PFF', 'IGV', 'XBI', 'SIVR', 'CQQQ', 'EPI', 'ICLN', 'IBB', 'XLY', 'SGOL', 'IGM', 'IJS', 'SLYV', 'IWY', 'FTCS', 'ITOT', 'VYM', 'MUNI', 'EWZ']
# ETF_UNIVERSE = ['BIV', 'PFF', 'CQQQ', 'SIVR', 'IGM', 'IGV', 'EPI', 'XLY', 'ICLN', 'SLYV', 'FTCS', 'IWY', 'ITOT', 'SGOL', 'VYM', 'MUNI', 'IJS']
# ETF_UNIVERSE = ['BIV', 'CQQQ', 'PFF', 'SIVR', 'EPI', 'IGV', 'SLYV', 'FTCS', 'MUNI', 'SGOL', 'ITOT']
# ETF_UNIVERSE = ['BIV', 'PFF', 'CQQQ', 'SIVR', 'FTCS', 'MUNI', 'SGOL', 'ITOT']
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'SIVR', 'BIV', 'FTCS', 'MUNI', 'ITOT']
# # # best
# # TRAIN+VAL SHARPE: 1.0981708403563168
# # TRAIN SHARPE: 1.202453964001961
# # VAL SHARPE: 0.9571108748692132
# # BLIND SHARPE: -0.016012241457986107
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'SIVR', 'BIV', 'MUNI', 'FTCS', 'ITOT']
# ETF_UNIVERSE = ['PFF', 'CQQQ', 'SIVR', 'BIV', 'MUNI', 'FTCS', 'ITOT']

# =========================
# SIGNAL ENTROPY - PICKED
# =========================
# =========================
# SIGNAL KURTOSIS -- PENDING
# =========================
# # Maximize 0.4/0.6 train/val
# ETF_UNIVERSE = ['EWY', 'EWT', 'IAU', 'ITB', 'UYG', 'AIA', 'GSG', 'ICLN', 'SH', 'TECL', 'DBC', 'SOXX', 'KRE', 'XHB', 'EWP', 'ROM', 'EWL', 'EWG', 'XLF', 'XSD', 'ONEQ', 'VFH', 'EZU', 'EFA', 'IYF', 'DGS', 'PZA', 'QQQ', 'USD', 'IXN', 'DEM', 'XBI', 'IYG', 'XLE', 'PEY', 'IGM', 'RPV', 'FEZ', 'FXI', 'RWO', 'EWA', 'FDN', 'EWZ', 'HEDJ', 'IXC', 'VCLT', 'PXH', 'IWN', 'RWL', 'XLG', 'QLD', 'XLK', 'EPI', 'FVD', 'BWX', 'GDX', 'IYW', 'SPMD', 'FXO', 'PGX', 'DON', 'IHI', 'RWK', 'PXF', 'FXU', 'IGF', 'ILF', 'BLV', 'SDY', 'VCR', 'EWS', 'EWJ', 'EFG', 'FBT', 'MGV', 'QTEC', 'FXL', 'FNX', 'IGV', 'CWI', 'SCHF', 'IEV', 'DVY', 'AAXJ', 'VNQ', 'VGT', 'VTV', 'DLN', 'IUSG', 'PWB', 'QQEW', 'IVW', 'EPP', 'RWJ', 'BND', 'TIP', 'DHS', 'VEA', 'EEM', 'IWD', 'MINT', 'VDC', 'IOO', 'VCIT', 'IWS', 'AOA', 'IWX', 'EWW', 'YINN', 'FTC', 'IYE', 'FGD', 'BAB', 'ITM', 'GDXJ', 'ACWX', 'IBB', 'MUNI', 'GSY', 'MUB', 'IDU', 'AGG', 'PRF', 'NYF', 'PWZ', 'SCHB', 'VGSH', 'VCSH', 'MBB', 'EDV', 'SUB', 'VDE', 'SHM']
# ETF_UNIVERSE = ['EWY', 'EWT', 'SH', 'IAU', 'ICLN', 'GSG', 'DBC', 'SOXX', 'AIA', 'ITB', 'EWL', 'KRE', 'EWP', 'PZA', 'XHB', 'UYG', 'BWX', 'VCLT', 'XSD', 'ONEQ', 'QQQ', 'VFH', 'XLF', 'EWG', 'DGS', 'BLV', 'PGX', 'HEDJ', 'RWO', 'IYF', 'EFA', 'PEY', 'FXU', 'DEM', 'TIP', 'BND', 'XLG', 'FDN', 'SPMD', 'EZU', 'VCIT', 'MINT', 'TECL', 'FXO', 'IGF', 'ROM', 'IYG', 'IGM', 'XLE', 'MUNI', 'FEZ', 'GDX', 'RPV', 'DON', 'PXF', 'SCHF', 'ITM', 'VGSH', 'EDV', 'FVD', 'GSY', 'RWL', 'VCSH']
# ETF_UNIVERSE = ['SH', 'DBC', 'ICLN', 'EWT', 'GSG', 'SOXX', 'EWY', 'XSD', 'EWL', 'KRE', 'BWX', 'DGS', 'VCLT', 'FXU', 'DEM', 'QQQ', 'ITB', 'BND', 'PGX', 'ONEQ', 'FDN', 'BLV', 'HEDJ', 'TIP', 'GDX', 'EWG', 'EFA', 'VCIT', 'XLG', 'PEY', 'ROM', 'PZA', 'XLE', 'VGSH', 'MUNI', 'AIA']
# ETF_UNIVERSE = ['SH', 'ICLN', 'ITB', 'GSG', 'DBC', 'EWT', 'BWX', 'SOXX', 'EWL', 'EWY', 'VCLT', 'BND', 'FDN', 'DGS', 'EFA', 'TIP', 'QQQ', 'BLV', 'VCIT', 'HEDJ', 'DEM', 'PGX', 'XLG', 'XSD', 'FXU', 'VGSH', 'MUNI']
# ETF_UNIVERSE = ['SH', 'ICLN', 'EWY', 'EWT', 'BWX', 'EWL', 'GSG', 'QQQ', 'DBC', 'VCLT', 'SOXX', 'EFA', 'XLG', 'FDN', 'BND', 'TIP', 'HEDJ', 'DGS', 'PGX', 'VCIT', 'VGSH']
# ETF_UNIVERSE = ['SH', 'ICLN', 'SOXX', 'EWL', 'BWX', 'EWT', 'GSG', 'EWY', 'QQQ', 'DBC', 'FDN', 'VCLT', 'XLG', 'BND', 'TIP', 'HEDJ', 'EFA', 'VCIT', 'PGX']
# ETF_UNIVERSE = ['SH', 'ICLN', 'SOXX', 'EWT', 'BWX', 'EWY', 'QQQ', 'DBC', 'EWL', 'HEDJ', 'FDN', 'GSG', 'VCLT', 'BND', 'XLG', 'PGX', 'TIP', 'VCIT']
# ETF_UNIVERSE = ['SH', 'ICLN', 'SOXX', 'EWT', 'BWX', 'EWY', 'QQQ', 'EWL', 'HEDJ', 'XLG', 'DBC', 'VCLT', 'FDN', 'BND', 'GSG', 'TIP', 'PGX', 'VCIT']

# # Maximize 0.45/0.55 train/val
# ETF_UNIVERSE = ['EWY', 'IAU', 'EWT', 'ITB', 'UYG', 'ICLN', 'GSG', 'XHB', 'AIA', 'SH', 'TECL', 'EWP', 'KRE', 'SOXX', 'EWL', 'EWG', 'DBC', 'VFH', 'XLF', 'ROM', 'ONEQ', 'EZU', 'IYF', 'EFA', 'PZA', 'RPV', 'XBI', 'IYG', 'XSD', 'RWO', 'IXN', 'QQQ', 'DGS', 'FEZ', 'XLE', 'FXI', 'IGM', 'DEM', 'PEY', 'IXC', 'HEDJ', 'USD', 'EWA', 'RWL', 'XLG', 'EPI', 'RWK', 'FVD', 'FDN', 'IWN', 'VCLT', 'SPMD', 'EWZ', 'PXH', 'PGX', 'FXO', 'XLK', 'DON', 'BWX', 'IYW', 'IGF', 'EWS', 'PXF', 'FBT', 'BLV', 'VNQ', 'IHI', 'MGV', 'FNX', 'FXU', 'EWJ', 'VCR', 'GDX', 'SDY', 'AAXJ', 'QTEC', 'QLD', 'VTV', 'EFG', 'DVY', 'VGT', 'DHS', 'RWJ', 'SCHF', 'IEV', 'DLN', 'QQEW', 'IGV', 'ILF', 'IUSG', 'FXL', 'YINN', 'IVW', 'TIP', 'PWB', 'CWI', 'EDV', 'BND', 'FGD', 'IWS', 'IWX', 'VDC', 'IWD', 'VEA', 'MINT', 'AOA', 'VCIT', 'EPP', 'BAB', 'IOO', 'ITM', 'EEM', 'MUNI', 'FTC', 'IYE', 'PRF', 'MUB', 'IBB', 'NYF', 'AGG', 'GSY', 'ACWX', 'PWZ', 'IDU', 'SCHB', 'VT', 'VCSH', 'VGSH', 'SUB', 'MBB', 'PFF']
# ETF_UNIVERSE = ['EWY', 'SH', 'IAU', 'EWT', 'ICLN', 'GSG', 'SOXX', 'DBC', 'ITB', 'EWL', 'EWP', 'KRE', 'AIA', 'UYG', 'VFH', 'PZA', 'XHB', 'ONEQ', 'XLF', 'VCLT', 'BWX', 'HEDJ', 'EWG', 'QQQ', 'PGX', 'IYF', 'RWO', 'BLV', 'XSD', 'EFA', 'DGS', 'SPMD', 'XLG', 'RPV', 'XBI', 'EZU', 'TIP', 'EDV', 'TECL', 'PEY', 'FXU', 'IYG', 'BND', 'DEM', 'FXO', 'IGF', 'MINT', 'VCIT', 'FDN', 'FEZ', 'DON', 'XLE', 'FVD', 'GDX', 'MUNI', 'RWL', 'SCHF', 'IGM', 'ITM', 'VGSH', 'PXF', 'VCSH']
# ETF_UNIVERSE = ['SH', 'EWT', 'DBC', 'ICLN', 'GSG', 'SOXX', 'EWY', 'EWL', 'XSD', 'BWX', 'KRE', 'DGS', 'VCLT', 'ONEQ', 'QQQ', 'ITB', 'DEM', 'PGX', 'EWG', 'FXU', 'HEDJ', 'BLV', 'FDN', 'GDX', 'XLG', 'EFA', 'BND', 'TIP', 'VCIT', 'XLE', 'PEY', 'AIA', 'XHB', 'VGSH', 'MUNI']
# ETF_UNIVERSE = ['SH', 'ICLN', 'GSG', 'SOXX', 'DBC', 'EWL', 'BWX', 'EWT', 'EWY', 'EFA', 'VCLT', 'QQQ', 'FDN', 'ONEQ', 'XLG', 'EWG', 'BND', 'DGS', 'BLV', 'TIP', 'HEDJ', 'PGX', 'DEM', 'FXU', 'VCIT', 'VGSH', 'MUNI']
# ETF_UNIVERSE = ['SH', 'ICLN', 'GSG', 'SOXX', 'EWL', 'EWY', 'BWX', 'DBC', 'VCLT', 'QQQ', 'BND', 'XLG', 'TIP', 'HEDJ', 'EFA', 'FDN', 'EWT', 'VCIT', 'VGSH']
# ETF_UNIVERSE = ['ICLN', 'SH', 'SOXX', 'EWL', 'BWX', 'QQQ', 'GSG', 'EWY', 'XLG', 'EWT', 'FDN', 'VCLT', 'HEDJ', 'BND', 'EFA', 'TIP', 'DBC', 'VCIT']
# ETF_UNIVERSE = ['ICLN', 'SH', 'SOXX', 'BWX', 'EWL', 'QQQ', 'EWT', 'EWY', 'XLG', 'HEDJ', 'GSG', 'FDN', 'VCLT', 'BND', 'DBC', 'EFA', 'TIP', 'VCIT']

# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['SH', 'ICLN', 'SOXX', 'GSG', 'DBC', 'ONEQ', 'EWL', 'BWX', 'HEDJ', 'PGX', 'QQQ', 'VCLT', 'BLV', 'RWO', 'EDV', 'KRE', 'FXU', 'XLF', 'EWP', 'XLG', 'VFH', 'BND', 'TIP', 'EWG', 'FVD', 'RPV', 'EFA', 'VCIT', 'FDN', 'DGS', 'MUNI', 'VGSH']
# ETF_UNIVERSE = ['SH', 'SOXX', 'ICLN', 'ONEQ', 'GSG', 'DBC', 'EWL', 'HEDJ', 'QQQ', 'BWX', 'PGX', 'DGS', 'VCLT', 'EDV', 'TIP', 'RPV', 'BND', 'FXU', 'RWO', 'XLG', 'BLV', 'KRE', 'VGSH', 'VCIT']
# # TRAIN+VAL SHARPE: 1.1871929631237659
# # TRAIN SHARPE: 1.2373684307749708
# # VAL SHARPE: 1.082269158230024
# # BLIND SHARPE: 0.1329153140271622
# ETF_UNIVERSE = ['SH', 'SOXX', 'ONEQ', 'ICLN', 'EWL', 'QQQ', 'HEDJ', 'GSG', 'BWX', 'XLG', 'DGS', 'RWO', 'VCLT', 'BND', 'TIP', 'EDV', 'PGX', 'VGSH']
# ETF_UNIVERSE = ['SH', 'SOXX', 'ONEQ', 'GSG', 'ICLN', 'EWL', 'QQQ', 'BWX', 'HEDJ', 'DGS', 'TIP', 'XLG', 'VCLT', 'BND', 'RWO', 'VGSH', 'PGX']
# # TRAIN+VAL SHARPE: 1.1484040433972613
# # TRAIN SHARPE: 1.0785680640708473
# # VAL SHARPE: 1.3148686571528538
# # BLIND SHARPE: 0.28756420679184386
# ETF_UNIVERSE = ['SH', 'SOXX', 'GSG', 'EWL', 'ONEQ', 'BWX', 'ICLN', 'QQQ', 'HEDJ', 'XLG', 'DGS', 'VCLT', 'TIP', 'BND']
# ETF_UNIVERSE = ['SH', 'SOXX', 'GSG', 'ICLN', 'ONEQ', 'EWL', 'HEDJ', 'QQQ', 'BWX', 'XLG', 'DGS', 'BND', 'VCLT', 'TIP']

# # Maximize 0.525/0.475 train/val
# ETF_UNIVERSE = ['IAU', 'EWY', 'EWT', 'ITB', 'UYG', 'XHB', 'ICLN', 'GSG', 'VFH', 'EWP', 'EWG', 'EWL', 'XLF', 'KRE', 'SH', 'IYF', 'SOXX', 'ONEQ', 'TECL', 'AIA', 'EZU', 'RPV', 'EFA', 'PZA', 'DBC', 'XBI', 'IYG', 'RWO', 'ROM', 'FEZ', 'FXI', 'IXC', 'IXN', 'RWK', 'QQQ', 'XLE', 'RWL', 'EPI', 'HEDJ', 'IGM', 'FVD', 'DGS', 'XLG', 'PEY', 'XSD', 'EWA', 'VNQ', 'SPMD', 'DEM', 'IWN', 'PGX', 'FBT', 'FXO', 'EWS', 'EDV', 'DON', 'FNX', 'VCLT', 'MGV', 'IGF', 'FDN', 'IYW', 'AAXJ', 'BLV', 'EWJ', 'XLK', 'PXF', 'BWX', 'DHS', 'PXH', 'YINN', 'VCR', 'VTV', 'RWJ', 'USO', 'USD', 'FGD', 'QTEC', 'EWZ', 'DVY', 'FXU', 'VGT', 'SDY', 'IHI', 'QQEW', 'IWS', 'DLN', 'IWX', 'EFG', 'SCHF', 'TIP', 'IEV', 'IUSG
# # TRAIN+VAL SHARPE: 1.1961616111580027
# # TRAIN SHARPE: 1.1372104748517777
# # VAL SHARPE: 1.3283172393983553
# # BLIND SHARPE: 0.2356578027156815
# ETF_UNIVERSE = ['SH', 'SOXX', 'ONEQ', 'GSG', 'ICLN', 'EWL', 'HEDJ', 'QQQ', 'BWX', 'RWO', 'TIP', 'DGS', 'XLG', 'BND', 'VCLT', 'VGSH']
# ETF_UNIVERSE = ['SH', 'SOXX', 'GSG', 'EWL', 'ONEQ', 'HEDJ', 'BWX', 'ICLN', 'QQQ', 'XLG', 'DGS', 'VCLT', 'TIP', 'BND', 'RWO']
# # TRAIN+VAL SHARPE: 1.1484040433972615
# # TRAIN SHARPE: 1.0785680640708473
# # VAL SHARPE: 1.3148686571528543
# # BLIND SHARPE: 0.2875642067918441
# ETF_UNIVERSE = ['SH', 'SOXX', 'GSG', 'ONEQ', 'EWL', 'HEDJ', 'BWX', 'ICLN', 'QQQ', 'XLG', 'DGS', 'BND', 'TIP', 'VCLT']
# ETF_UNIVERSE = ['SH', 'SOXX', 'GSG', 'ONEQ', 'ICLN', 'EWL', 'HEDJ', 'QQQ', 'BWX', 'XLG', 'DGS', 'BND', 'VCLT', 'TIP']

# # Maximize 0.55/0.45 train/val
# ETF_UNIVERSE = ['IAU', 'EWY', 'EWT', 'ITB', 'UYG', 'XHB', 'ICLN', 'GSG', 'VFH', 'EWP', 'XLF', 'EWG', 'EWL', 'KRE', 'IYF', 'ONEQ', 'SH', 'EZU', 'RPV', 'SOXX', 'TECL', 'EFA', 'AIA', 'PZA', 'XBI', 'IYG', 'RWO', 'DBC', 'ROM', 'IXC', 'FEZ', 'RWK', 'FXI', 'IXN', 'RWL', 'QQQ', 'XLE', 'EPI', 'FVD', 'HEDJ', 'XLG', 'IGM', 'VNQ', 'PEY', 'DGS', 'EDV', 'EWA', 'SPMD', 'FBT', 'PGX', 'EWS', 'IWN', 'XSD', 'FNX', 'FXO', 'USO', 'DON', 'DEM', 'MGV', 'IGF', 'AAXJ', 'VCLT', 'YINN', 'EWJ', 'DHS', 'BLV', 'IYW', 'PXF', 'FDN', 'RWJ', 'XLK', 'VTV', 'BWX', 'FGD', 'VCR', 'PXH', 'QTEC', 'DVY', 'VGT', 'SDY', 'FXU', 'IWS', 'IHI', 'QQEW', 'USD', 'IWX', 'EWZ', 'DLN', 'SCHF', 'EFG', 'TIP', 'VDC', 'IEV', 'IUSG', 'BAB', 'IVW', 'BND', 'IWD', 'VT', 'PRF', 'IGV', 'AOA', 'MINT', 'PWB', 'ZROZ', 'ITM', 'GDX', 'FXL', 'VCIT', 'MUB', 'NYF', 'MUNI', 'PFF', 'DTD', 'PWZ', 'IOO', 'TMF', 'VEA', 'AGG', 'HYD', 'VIS', 'GRID', 'SCHG', 'CWI', 'VCSH', 'SUB', 'VGSH', 'IYE', 'SCHB', 'MBB', 'GSY']
# ETF_UNIVERSE = ['IAU', 'SH', 'ICLN', 'EWY', 'EWT', 'SOXX', 'ITB', 'VFH', 'XHB', 'GSG', 'EWP', 'EWL', 'UYG', 'ONEQ', 'KRE', 'XLF', 'RWO', 'IYF', 'RPV', 'PZA', 'HEDJ', 'PGX', 'XBI', 'TECL', 'EWG', 'DBC', 'QQQ', 'EDV', 'EFA', 'AIA', 'XLG', 'IYG', 'BWX', 'VCLT', 'BLV', 'EZU', 'IGF', 'FBT', 'FXU', 'RWL', 'VNQ', 'SPMD', 'FVD', 'TIP', 'FXO', 'RWK', 'BND', 'DGS', 'MINT', 'IWX', 'IXC', 'EPI', 'MGV', 'XSD', 'SCHF', 'VCIT', 'PEY', 'DON', 'FEZ', 'IUSG', 'MUNI', 'AAXJ', 'NYF', 'ITM', 'MUB', 'VTV', 'VGSH', 'DEM', 'VCSH', 'SUB']
# ETF_UNIVERSE = ['SH', 'ICLN', 'SOXX', 'EWY', 'ONEQ', 'GSG', 'EWT', 'EWL', 'DBC', 'KRE', 'XLG', 'QQQ', 'TECL', 'ITB', 'EWG', 'PGX', 'BWX', 'HEDJ', 'VCLT', 'XSD', 'BLV', 'EDV', 'EFA', 'DGS', 'EWP', 'RPV', 'FXU', 'RWO', 'DEM', 'TIP', 'BND', 'IXC', 'VFH', 'XHB', 'VCIT', 'XBI', 'IUSG', 'FVD', 'XLF', 'MINT', 'AIA', 'SCHF', 'IGF', 'MUNI', 'VGSH']
# ETF_UNIVERSE = ['SH', 'ICLN', 'SOXX', 'ONEQ', 'GSG', 'EWL', 'DBC', 'PGX', 'RWO', 'HEDJ', 'KRE', 'EDV', 'QQQ', 'BWX', 'RPV', 'XBI', 'VFH', 'EWP', 'XLF', 'XLG', 'VCLT', 'BLV', 'EWG', 'FVD', 'TIP', 'EFA', 'BND', 'FXU', 'VCIT', 'IGF', 'MUNI', 'VGSH']
# ETF_UNIVERSE = ['SH', 'SOXX', 'ONEQ', 'ICLN', 'GSG', 'HEDJ', 'EWL', 'QQQ', 'DBC', 'XBI', 'PGX', 'EDV', 'BWX', 'RPV', 'VCLT', 'XLG', 'TIP', 'RWO', 'FXU', 'BND', 'BLV', 'EWP', 'VGSH', 'VCIT']
# # TRAIN+VAL SHARPE: 1.1961357270093365
# # TRAIN SHARPE: 1.304211357136677
# # VAL SHARPE: 0.974552131140751
# # BLIND SHARPE: -0.048523617972140276
# ETF_UNIVERSE = ['SH', 'SOXX', 'ONEQ', 'ICLN', 'HEDJ', 'QQQ', 'EWL', 'XLG', 'GSG', 'BWX', 'EDV', 'RWO', 'XBI', 'VCLT', 'TIP', 'BND', 'PGX', 'FXU', 'VGSH']
# # TRAIN+VAL SHARPE: 1.1950119701020994
# # TRAIN SHARPE: 1.1726897756878336
# # VAL SHARPE: 1.2450001495057414
# # BLIND SHARPE: 0.3390780176695093
# ETF_UNIVERSE = ['SOXX', 'SH', 'ONEQ', 'GSG', 'ICLN', 'EWL', 'HEDJ', 'QQQ', 'BWX', 'XLG', 'RWO', 'PGX', 'VCLT', 'TIP', 'BND', 'FXU', 'VGSH']
# # TRAIN+VAL SHARPE: 1.164861255902961
# # TRAIN SHARPE: 1.1307014115911544
# # VAL SHARPE: 1.2565042159368096
# # BLIND SHARPE: 0.2448093816408022
# ETF_UNIVERSE = ['SOXX', 'SH', 'ONEQ', 'EWL', 'GSG', 'HEDJ', 'BWX', 'QQQ', 'XLG', 'ICLN', 'VCLT', 'BND', 'TIP']
# ETF_UNIVERSE = ['SOXX', 'SH', 'ONEQ', 'EWL', 'GSG', 'HEDJ', 'QQQ', 'ICLN', 'XLG', 'BWX', 'BND', 'VCLT', 'TIP']

# # Maximize 0.575/0.425 train/val
# ETF_UNIVERSE = ['IAU', 'EWY', 'ITB', 'EWT', 'UYG', 'XHB', 'ICLN', 'VFH', 'GSG', 'EWP', 'XLF', 'EWG', 'EWL', 'IYF', 'ONEQ', 'KRE', 'RPV', 'EZU', 'SH', 'EFA', 'SOXX', 'PZA', 'TECL', 'XBI', 'IYG', 'RWO', 'AIA', 'DBC', 'IXC', 'RWK', 'ROM', 'FEZ', 'FXI', 'RWL', 'IXN', 'EPI', 'XLE', 'FVD', 'QQQ', 'XLG', 'VNQ', 'HEDJ', 'EDV', 'USO', 'IGM', 'PEY', 'SPMD', 'FBT', 'EWA', 'EWS', 'PGX', 'FNX', 'DGS', 'FXO', 'IWN', 'MGV', 'DON', 'YINN', 'AAXJ', 'IGF', 'DHS', 'DEM', 'XSD', 'EWJ', 'FGD', 'BLV', 'VCLT', 'RWJ', 'IYW', 'VTV', 'PXF', 'VCR', 'XLK', 'BWX', 'FDN', 'QTEC', 'DVY', 'VGT', 'PXH', 'IWS', 'IWX', 'SDY', 'QQEW', 'FXU', 'DLN', 'IHI', 'VDC', 'SCHF', 'TIP', 'EFG', 'EWZ', 'BAB', 'IUSG', 'IEV', 'USD', 'VT', 'IVW', 'BND', 'PRF', 'IWD', 'ZROZ', 'TMF', 'AOA', 'MINT', 'IGV', 'ITM', 'PWB', 'VIS', 'MUB', 'NYF', 'PFF', 'DTD', 'VCIT', 'MUNI', 'PWZ', 'FXL', 'GRID', 'AGG', 'HYD', 'GDX', 'IOO', 'SCHG', 'VCSH', 'SUB', 'VEA', 'VGSH']
# ETF_UNIVERSE = ['IAU', 'SH', 'ICLN', 'EWY', 'EWT', 'SOXX', 'VFH', 'EWP', 'ITB', 'XHB', 'GSG', 'EWL', 'ONEQ', 'UYG', 'XLF', 'KRE', 'RWO', 'RPV', 'IYF', 'XBI', 'PGX', 'HEDJ', 'AIA', 'EDV', 'TECL', 'PZA', 'EWG', 'EFA', 'QQQ', 'DBC', 'XLG', 'IYG', 'BWX', 'VCLT', 'BLV', 'EZU', 'IGF', 'FBT', 'EPI', 'VNQ', 'FVD', 'RWL', 'TIP', 'IXC', 'RWK', 'FXU', 'IWX', 'MINT', 'SPMD', 'BND', 'MGV', 'FXO', 'SCHF', 'AAXJ', 'VCIT', 'DON', 'DGS', 'XSD', 'NYF', 'IUSG', 'MUNI', 'FEZ', 'PEY', 'MUB', 'XLE', 'VTV', 'VGSH', 'ITM', 'VCSH', 'SUB']
# # TRAIN+VAL SHARPE: 0.8102442969864179
# # TRAIN SHARPE: 0.7340107854995234
# # VAL SHARPE: 0.9616441130042378
# # BLIND SHARPE: -0.09423294977518906
# ETF_UNIVERSE = ['CQQQ', 'EWW', 'FDN', 'IXC', 'XLP', 'XLU']
# # TRAIN+VAL SHARPE: 0.849959861374688
# # TRAIN SHARPE: 0.8226750612595677
# # VAL SHARPE: 0.9066964641047085
# # BLIND SHARPE: -0.18859394261902823
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'FDN', 'XLP', 'IXC']
# # TRAIN+VAL SHARPE: 0.7475916571108004
# # TRAIN SHARPE: 0.8825038552942142
# # VAL SHARPE: 0.4631949525692322
# # BLIND SHARPE: 0.027415273789150825
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'FDN', 'XLP']
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'FDN', 'XLP']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['SPMD', 'BIV', 'EWY', 'EWW', 'TNA', 'IXC', 'FNX', 'AOM', 'EWC', 'XLE', 'XLK', 'RWR', 'EWZ', 'ROM', 'KBE', 'XLI', 'ICF', 'QLD', 'TECL', 'IWN', 'IYE', 'DES', 'IWC', 'VDE', 'IXN', 'FDN', 'IBB', 'UPRO', 'CQQQ', 'ITA', 'IJT', 'IJK', 'IJR', 'XLU', 'IYR', 'MDY', 'VBK', 'IGV', 'IJH', 'AAXJ', 'XME', 'RPV', 'GDX', 'VXF', 'PHO', 'XLB', 'SSO', 'ILF', 'IHI', 'IWP', 'IWO', 'XLY', 'IYK', 'SCHA', 'QQQ', 'CGW', 'IWM', 'RPG', 'QQEW', 'VIS', 'VGT', 'IWS', 'IYC', 'IYJ', 'VTI', 'EWS', 'ICLN', 'IGM', 'RWK', 'VUG', 'DHS', 'VB', 'XLP', 'EWT', 'MGK', 'VBR', 'VAW', 'FDL', 'IWB', 'RWO', 'FTC', 'FIW', 'SGOL', 'IWR', 'DVY', 'USD', 'SPXL', 'IWY', 'VNQ', 'IYW', 'PRFZ', 'IVE', 'SCHG', 'EWJ', 'XBI', 'VOE', 'PFF', 'IWD', 'IJJ', 'VO', 'FPX', 'XOP', 'SCHX', 'IYG', 'IWV', 'VDC', 'FAS', 'VHT', 'IDU', 'MDYG', 'EFV', 'ONEQ', 'DLN', 'SDY', 'XLV', 'FVD', 'DTD', 'IUSG', 'VYM', 'EWG', 'IWF', 'QTEC', 'KRE', 'FTCS', 'IVV', 'XHB', 'VPU', 'SPY', 'PDP', 'ITOT', 'TIP', 'CWB', 'PRF', 'DON', 'IVW', 'SCHB', 'RSP', 'FXH', 'VOX', 'SMH', 'VTV', 'FBT', 'PPA', 'IYY', 'EWP', 'NLR', 'CWI', 'SPHQ', 'IUSV', 'IJS', 'RWL', 'DIA', 'FYX', 'MGC', 'SOXX', 'SPYG', 'SCHV', 'FXL', 'FXU', 'HEDJ', 'IWL']
# ETF_UNIVERSE = ['EWY', 'SPMD', 'CQQQ', 'GDX', 'EWT', 'EWW', 'IXC', 'XLU', 'RWR', 'IBB', 'TNA', 'SMH', 'ITA', 'EWZ', 'USD', 'XLK', 'ICF', 'HEDJ', 'XLP', 'ICLN', 'EWS', 'AAXJ', 'EWJ', 'EWC', 'FBT', 'TECL', 'IWC', 'XLB', 'ROM', 'XLI', 'CWB', 'PHO', 'IXN', 'RPG', 'BIV', 'IYK', 'XLE', 'IHI', 'UPRO', 'SCHA', 'QQQ', 'IGV', 'DES', 'IJK', 'XOP', 'MDY', 'VAW', 'IJT', 'RWO', 'SOXX', 'KBE', 'XLV', 'IWN', 'VDE', 'FDL', 'VNQ', 'IYC', 'XME', 'IYR', 'VGT', 'VBK', 'IJH', 'VIS', 'MGK', 'DHS', 'IUSG', 'IWP', 'SCHG', 'IWY', 'VXF', 'IJR', 'RPV', 'FTCS', 'QLD', 'QQEW']
# ETF_UNIVERSE = ['EWY', 'EWW', 'IBB', 'XLU', 'TNA', 'CQQQ', 'SPMD', 'GDX', 'BIV', 'IXC', 'EWT', 'XLK', 'ITA', 'KBE', 'RWR', 'IWC', 'TECL', 'XLI', 'EWC', 'HEDJ', 'SCHA', 'XLB', 'ICLN', 'MDY', 'CWB', 'FBT', 'IHI', 'QQQ', 'RPG', 'XLP', 'PHO', 'AAXJ', 'IYK', 'RWO', 'IJK', 'IWY', 'IUSG', 'ROM', 'IJT', 'FDL']
# ETF_UNIVERSE = ['EWY', 'SPMD', 'EWW', 'XLU', 'IXC', 'RWR', 'TNA', 'EWC', 'CQQQ', 'XLK', 'ITA', 'XLI', 'TECL', 'IBB', 'KBE', 'BIV', 'SCHA', 'QQQ', 'IWC', 'IWY', 'XLB']
# ETF_UNIVERSE = ['SPMD', 'EWW', 'EWY', 'TNA', 'XLU', 'IXC', 'XLK', 'XLI', 'CQQQ', 'TECL', 'KBE', 'EWC', 'SCHA', 'ITA', 'IWY', 'QQQ']
# ETF_UNIVERSE = ['EWW', 'TNA', 'EWY', 'CQQQ', 'XLU', 'KBE', 'XLK', 'EWC', 'IXC', 'XLI', 'SCHA', 'IWY', 'QQQ']
# ETF_UNIVERSE = ['EWW', 'TNA', 'CQQQ', 'EWY', 'XLK', 'XLU', 'KBE', 'QQQ', 'EWC', 'SCHA', 'IWY', 'XLI']
# ETF_UNIVERSE = ['EWW', 'TNA', 'CQQQ', 'EWY', 'XLK', 'SCHA', 'XLU', 'QQQ', 'IWY', 'EWC']
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'TNA', 'EWY', 'XLU', 'XLK', 'SCHA', 'IWY']
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'EWY', 'XLK', 'SCHA', 'IWY']
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'SCHA', 'IWY']
# ETF_UNIVERSE = ['EWW', 'CQQQ', 'SCHA', 'IWY']

# =========================
# SIGNAL GAP -- PENDING
# =========================
# # Maximize 0.4/0.6 train/val
# ETF_UNIVERSE = ['GDX', 'TECL', 'EWT', 'USD', 'VPU', 'FNX', 'VYM', 'EWS', 'MDYV', 'IWY', 'VMBS', 'VCR', 'PCY', 'UPRO', 'GDXJ', 'IDU', 'CWB', 'XLU', 'DBC', 'IUSG', 'SCHG', 'IVW', 'VCSH', 'IBB', 'PEY', 'CGW', 'SHV', 'IWL', 'SPHQ', 'FVD', 'SPYG', 'SHY', 'BIL']
# # TRAIN+VAL SHARPE: 1.0577215429367217
# # TRAIN SHARPE: 1.0669956314809113
# # VAL SHARPE: 1.0426155667532084
# # BLIND SHARPE: 0.6995445375042634
# ETF_UNIVERSE = ['TECL', 'GDX', 'EWS', 'EWT', 'USD', 'VPU', 'IWY', 'MDYV', 'VYM', 'UPRO', 'VMBS', 'PCY', 'CWB', 'FNX', 'VCR', 'IUSG', 'IDU', 'SCHG', 'IVW', 'XLU', 'VCSH', 'FVD', 'IWL', 'SPHQ', 'SHV', 'SHY', 'BIL']
# ETF_UNIVERSE = ['GDX', 'TECL', 'EWT', 'EWS', 'VPU', 'PCY', 'VMBS', 'MDYV', 'IWY', 'IDU', 'VYM', 'XLU', 'SHV', 'SHY', 'VCSH', 'IUSG', 'CWB', 'BIL']
# # TRAIN+VAL SHARPE: 0.9520961640297868
# # TRAIN SHARPE: 0.8558557000119456
# # VAL SHARPE: 1.1358538762817245
# # BLIND SHARPE: 0.5277989431632729
# ETF_UNIVERSE = ['GDX', 'TECL', 'EWT', 'IWY', 'VPU', 'VMBS', 'IDU', 'PCY', 'EWS', 'VYM', 'XLU', 'MDYV', 'SHV', 'SHY', 'IUSG', 'BIL']
# ETF_UNIVERSE = ['GDX', 'TECL', 'IWY', 'EWT', 'VPU', 'EWS', 'VMBS', 'IDU', 'MDYV', 'VYM', 'XLU', 'PCY', 'SHV', 'SHY', 'BIL', 'IUSG']

# # Maximize 0.45/0.55 train/val
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'FNX', 'UPRO', 'QLD', 'ROM', 'VPU', 'EWT', 'EWS', 'VYM', 'SSO', 'XOP', 'GDXJ', 'XLE', 'IBB', 'SPXL', 'IDU', 'IYE', 'IXC', 'XLU', 'AOM', 'PEY', 'EWW', 'IVW', 'VCR', 'EWY', 'IWY', 'XLK', 'FAS', 'BWX', 'SCHG', 'VUG', 'EWC', 'FVD', 'IUSG', 'IWF', 'DVY', 'IYH', 'SPYG', 'QQQ', 'PDP', 'CWB', 'ONEQ', 'EPP', 'RWR', 'IWN', 'SPHQ', 'MDYV', 'QQEW', 'IHI', 'PHO', 'MGK', 'XLP', 'FIW', 'VNQ', 'IWL', 'CGW', 'IJR', 'VV', 'IJJ', 'XBI', 'VOE', 'VDC', 'FXL', 'EFA', 'PZA', 'SPMD', 'EWP', 'IJH', 'MGC', 'IJK', 'VWO', 'SCHX', 'IYW', 'MD
# # TRAIN+VAL SHARPE: 1.1529758650956374
# # TRAIN SHARPE: 1.2437656194602267
# # VAL SHARPE: 0.9840505469991314
# # BLIND SHARPE: 0.6695568914196092
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'FNX', 'EWS', 'GDXJ', 'EWT', 'VPU', 'VYM', 'DBC', 'MDYV', 'VCR', 'UPRO', 'CWB', 'VMBS', 'IWY', 'IDU', 'BWX', 'XLE', 'FVD', 'PCY', 'IHI', 'SPHQ', 'SCHG', 'IUSG', 'VCSH', 'GSG', 'EWJ', 'SHY', 'SUB', 'EWW', 'BIL', 'SHV', 'IYH', 'IWL', 'SPYG', 'PEY']
# # TRAIN+VAL SHARPE: 1.1519765665055655
# # TRAIN SHARPE: 1.2214170502074648
# # VAL SHARPE: 1.0213671981148185
# # BLIND SHARPE: 0.7169362728034139
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'VPU', 'EWT', 'EWS', 'VYM', 'FNX', 'VMBS', 'UPRO', 'DBC', 'CWB', 'BWX', 'MDYV', 'IWY', 'IDU', 'IUSG', 'VCR', 'SPHQ', 'SUB', 'SHY', 'SCHG', 'SHV', 'VCSH', 'BIL', 'PCY']
# # TRAIN+VAL SHARPE: 1.1086623220081673
# # TRAIN SHARPE: 1.1450128337566037
# # VAL SHARPE: 1.0423754662875497
# # BLIND SHARPE: 0.6064622296819493
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'EWT', 'VPU', 'EWS', 'VYM', 'IDU', 'VMBS', 'BWX', 'SUB', 'SHY', 'MDYV', 'VCR', 'IWY', 'SHV', 'BIL', 'VCSH', 'CWB', 'IUSG']
# ETF_UNIVERSE = ['GDX', 'TECL', 'VPU', 'BWX', 'VMBS', 'USD', 'SUB', 'IWY', 'VYM', 'EWS', 'SHY', 'IDU', 'MDYV', 'EWT', 'SHV', 'BIL', 'VCSH']
# ETF_UNIVERSE = ['GDX', 'TECL', 'VPU', 'BWX', 'USD', 'VMBS', 'VYM', 'SUB', 'IWY', 'SHY', 'IDU', 'MDYV', 'SHV', 'BIL', 'VCSH']
# # TRAIN+VAL SHARPE: 0.9556037262134124
# # TRAIN SHARPE: 0.9349623741348068
# # VAL SHARPE: 1.0020457048349531
# # BLIND SHARPE: 0.6829649954937835
# ETF_UNIVERSE = ['GDX', 'TECL', 'VYM', 'USD', 'BWX', 'VMBS', 'SUB', 'SHY', 'MDYV', 'IWY', 'SHV', 'VPU', 'BIL']
# ETF_UNIVERSE = ['GDX', 'TECL', 'VYM', 'VPU', 'BWX', 'USD', 'VMBS', 'SHY', 'SUB', 'IWY', 'SHV', 'MDYV', 'BIL']

# # Maximize 0.6/0.4 train/val
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'FNX', 'EWT', 'EWS', 'VPU', 'VYM', 'GDXJ', 'DBC', 'MDYV', 'VCR', 'CWB', 'EWW', 'UPRO', 'VMBS', 'IDU', 'IHI', 'BWX', 'IWY', 'PCY', 'FVD', 'EWJ', 'SPHQ', 'BIV', 'SHY', 'IWN', 'IUSG', 'SCHG', 'SUB', 'GSG', 'VCSH', 'IYH', 'BIL', 'SHV']
# # TRAIN+VAL SHARPE: 1.1766022658914925
# # TRAIN SHARPE: 1.2645480045479351
# # VAL SHARPE: 1.0075061055881587
# # BLIND SHARPE: 0.6693868738673178
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'VPU', 'EWT', 'FNX', 'VYM', 'IDU', 'DBC', 'EWS', 'VMBS', 'BWX', 'CWB', 'MDYV', 'UPRO', 'IWY', 'IUSG', 'VCR', 'SUB', 'SPHQ', 'SHY', 'PCY', 'SCHG', 'SHV', 'VCSH', 'BIL', 'IWN']
# # TRAIN+VAL SHARPE: 1.1536739601459425
# # TRAIN SHARPE: 1.2273836995388612
# # VAL SHARPE: 1.014589628181214
# # BLIND SHARPE: 0.6774230076130994
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'EWT', 'VPU', 'EWS', 'VYM', 'VMBS', 'BWX', 'SUB', 'IDU', 'SHY', 'MDYV', 'CWB', 'DBC', 'SPHQ', 'SHV', 'VCSH', 'IUSG', 'BIL', 'IWY', 'VCR']
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'VPU', 'BWX', 'VYM', 'VMBS', 'EWS', 'SUB', 'EWT', 'SHY', 'MDYV', 'IWY', 'SHV', 'CWB', 'SPHQ', 'IDU', 'BIL', 'VCSH']
# # TRAIN+VAL SHARPE: 0.9992267508231268
# # TRAIN SHARPE: 0.9945782190036127
# # VAL SHARPE: 1.0103263858044949
# # BLIND SHARPE: 0.7507177052803833
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'BWX', 'VYM', 'VMBS', 'VPU', 'SUB', 'IWY', 'SHY', 'MDYV', 'SHV', 'EWT', 'BIL', 'VCSH', 'SPHQ']
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'VPU', 'VYM', 'BWX', 'VMBS', 'SUB', 'IWY', 'SHY', 'MDYV', 'SHV', 'BIL', 'VCSH']
# # TRAIN+VAL SHARPE: 0.9556037262134124
# # TRAIN SHARPE: 0.934962374134807
# # VAL SHARPE: 1.0020457048349531
# # BLIND SHARPE: 0.6829649954937835
# ETF_UNIVERSE = ['GDX', 'TECL', 'VYM', 'USD', 'BWX', 'VPU', 'VMBS', 'SHY', 'SUB', 'MDYV', 'IWY', 'SHV', 'BIL']
# ETF_UNIVERSE = ['GDX', 'TECL', 'VYM', 'USD', 'BWX', 'VPU', 'VMBS', 'SHY', 'SUB', 'IWY', 'MDYV', 'SHV', 'BIL']

# # Maximize 0.65/0.35 train/val
# ETF_UNIVERSE = ['GDX', 'USD', 'FNX', 'TECL', 'VYM', 'EWT', 'UPRO', 'EWS', 'VPU', 'AOM', 'EWY', 'SSO', 'QLD', 'ROM', 'VCR', 'XLE', 'EWW', 'XOP', 'GDXJ', 'PZA', 'IWN', 'IDU', 'SPMD', 'SPXL', 'IYE', 'PEY', 'IHI', 'VNQ', 'FVD', 'DVY', 'IBB', 'IXC', 'IYH', 'EPP', 'IJR', 'EEM', 'IVW', 'EWC', '
# ETF_UNIVERSE = ['GDX', 'USD', 'FNX', 'TECL', 'VYM', 'EWT', 'EWS', 'GDXJ', 'VPU', 'AOM', 'UPRO', 'EWY', 'MDYV', 'EWW', 'DBC', 'VCR', 'GRID', 'CWB', 'FVD', 'IDU', 'SSO', 'VMBS', 'QLD', 'SPXL', 'DVY', 'IYH', 'GSG', 'SPHQ', 'IWY', 'SCHG', 'IUSG', 'BWX', 'EWJ', 'IHI', 'IWN', 'PEY', 'PCY', 'ROM', 'BIV', 'SPYG', 'SUB', 'IVW', 'DSI', 'MDYG', 'PDP', 'SHY', 'VCSH', 'FTC', 'QQEW', 'VDC', 'IYK', 'JNK', 'ITOT', 'RWR', 'IWL', 'BIL', 'QQQ', 'SHV', 'EPP', 'FPX', 'VOE', 'XLP', 'VUG']
# # TRAIN+VAL SHARPE: 1.157619466441541
# # TRAIN SHARPE: 1.2869646336203613
# # VAL SHARPE: 0.9046024936492081
# # BLIND SHARPE: 0.6904124933308678
# ETF_UNIVERSE = ['GDX', 'USD', 'FNX', 'TECL', 'EWT', 'VPU', 'VYM', 'EWS', 'DBC', 'MDYV', 'CWB', 'UPRO', 'IDU', 'VCR', 'GDXJ', 'VMBS', 'GSG', 'IHI', 'PCY', 'FVD', 'BWX', 'IWY', 'GRID', 'IWN', 'SPHQ', 'EWJ', 'IUSG', 'SCHG', 'SUB', 'SHY', 'BIV', 'EWW', 'IYH', 'VCSH', 'DVY', 'PEY', 'BIL', 'SHV', 'MDYG', 'SPYG']
# # TRAIN+VAL SHARPE: 1.1790216048547029
# # TRAIN SHARPE: 1.2828976008058728
# # VAL SHARPE: 0.9774466875682319
# # BLIND SHARPE: 0.6560875663967389
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'EWT', 'FNX', 'VPU', 'DBC', 'EWS', 'VYM', 'UPRO', 'CWB', 'MDYV', 'VMBS', 'BWX', 'IDU', 'SUB', 'VCR', 'IUSG', 'SPHQ', 'IWY', 'GRID', 'SHY', 'SCHG', 'PCY', 'SHV', 'VCSH', 'BIL', 'IWN']
# # TRAIN+VAL SHARPE: 1.1697400394565962
# # TRAIN SHARPE: 1.2937116466702099
# # VAL SHARPE: 0.9349808683858585
# # BLIND SHARPE: 0.6785324285844915
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'EWT', 'EWS', 'VYM', 'VPU', 'VMBS', 'SUB', 'BWX', 'CWB', 'SHY', 'MDYV', 'UPRO', 'SPHQ', 'IDU', 'IUSG', 'IWN', 'SHV', 'DBC', 'VCR', 'VCSH', 'BIL', 'GRID', 'IWY']
# # TRAIN+VAL SHARPE: 1.124496329901146
# # TRAIN SHARPE: 1.203998915273363
# # VAL SHARPE: 0.9796324663197605
# # BLIND SHARPE: 0.7723689850150709
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'EWS', 'BWX', 'VYM', 'VPU', 'SUB', 'VMBS', 'EWT', 'CWB', 'SHY', 'MDYV', 'UPRO', 'SPHQ', 'SHV', 'IUSG', 'IWY', 'VCSH', 'BIL', 'VCR']
', 'QQXT', 'SPY', 'IJK', 'FEZ', 'VEA', 'FXO', 'VCSH', 'SHY', 'SCHA', 'SIVR', 'PRF', 'RPV', 'XLV', 'SUB', 'XHB', 'AGQ', 'IUSV', 'BSV', 'AGG', 'IVV', 'JNK', 'IGOV', 'VO', 'RPG', 'IJT', 'GSY', 'SCHV', 'IWB', 'BIL', 'FDN', 'XLP', 'RWO', 'SHV', 'VSS', 'GLD', 'IEF', 'PHO', 'RWL', 'EFV', 'EPS', 'IEV']
# ETF_UNIVERSE = ['GDX', 'FNX', 'USD', 'TECL', 'VYM', 'EWT', 'EWS', 'VPU', 'UPRO', 'AOM', 'EWY', 'EWW', 'DBC', 'VCR', 'MDYV', 'FVD', 'CWB', 'GRID', 'IDU', 'GDXJ', 'SPXL', 'SSO', 'PCY', 'DVY', 'VMBS', 'IYH', 'SPHQ', 'GSG', 'BWX', 'IHI', 'SCHG', 'IWN', 'IUSG', 'PEY', 'IWY', 'BIV', 'SPYG', 'QLD', 'ROM', 'SUB', 'QQEW', 'MDYG', 'EWJ', 'SHY', 'IVW', 'VCSH', 'FTC', 'DSI', 'VDC', 'ITOT', 'SLYG', 'IYK', 'PDP', 'BIL', 'JNK', 'IJR', 'IWL', 'SHV', 'RWR', 'XOP', 'VOE']
# # TRAIN+VAL SHARPE: 1.1627466336497359
# # TRAIN SHARPE: 1.3149029281802576
# # VAL SHARPE: 0.8635118001732927
# # BLIND SHARPE: 0.7596459902242741
# ETF_UNIVERSE = ['GDX', 'USD', 'FNX', 'TECL', 'EWT', 'VYM', 'VPU', 'EWS', 'DBC', 'MDYV', 'CWB', 'UPRO', 'GSG', 'GRID', 'IDU', 'PCY', 'VMBS', 'VCR', 'IHI', 'BWX', 'FVD', 'EWY', 'SPHQ', 'SUB', 'SHY', 'EWW', 'DVY', 'EWJ', 'IWY', 'IYH', 'IUSG', 'SCHG', 'IWN', 'VCSH', 'GDXJ', 'BIL', 'PEY', 'SHV', 'IYK', 'BIV']
# # TRAIN+VAL SHARPE: 1.1790216048547029
# # TRAIN SHARPE: 1.282897600805873
# # VAL SHARPE: 0.9774466875682319
# # BLIND SHARPE: 0.6560875663967388
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'FNX', 'EWT', 'DBC', 'VPU', 'VYM', 'CWB', 'MDYV', 'EWS', 'UPRO', 'GRID', 'VMBS', 'BWX', 'IDU', 'SUB', 'PCY', 'SPHQ', 'IUSG', 'SHY', 'IWY', 'SCHG', 'VCR', 'IWN', 'VCSH', 'SHV', 'BIL']
# # TRAIN+VAL SHARPE: 1.2012626207863153
# # TRAIN SHARPE: 1.3482356874899584
# # VAL SHARPE: 0.9193268661448445
# # BLIND SHARPE: 0.7025704840859617
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'EWT', 'VYM', 'EWS', 'VPU', 'SUB', 'VMBS', 'BWX', 'CWB', 'SHY', 'IWN', 'MDYV', 'UPRO', 'GRID', 'SPHQ', 'DBC', 'SHV', 'IUSG', 'VCR', 'VCSH', 'BIL']
# # TRAIN+VAL SHARPE: 1.141781139883037
# # TRAIN SHARPE: 1.2522403375097668
# # VAL SHARPE: 0.9324442076125042
# # BLIND SHARPE: 0.7442980404622347
# ETF_UNIVERSE = ['GDX', 'TECL', 'USD', 'EWS', 'VPU', 'VYM', 'BWX', 'SUB', 'VMBS', 'EWT', 'CWB', 'SHY', 'SPHQ', 'UPRO', 'MDYV', 'GRID', 'DBC', 'SHV', 'IUSG', 'VCSH', 'BIL']
# # TRAIN+VAL SHARPE: 1.0041512098910546
# # TRAIN SHARPE: 1.0547427318857385
# # VAL SHARPE: 0.9096978243808044
# # BLIND SHARPE: 0.7943759557861985
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'VYM', 'VPU', 'BWX', 'SUB', 'VMBS', 'UPRO', 'EWT', 'SHY', 'CWB', 'MDYV', 'SPHQ', 'SHV', 'GRID', 'IUSG', 'VCSH', 'BIL']
# # TRAIN+VAL SHARPE: 0.9702696080029299
# # TRAIN SHARPE: 1.0004513749575954
# # VAL SHARPE: 0.9247025994118829
# # BLIND SHARPE: 0.8480846716081029
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'VYM', 'BWX', 'VMBS', 'SUB', 'UPRO', 'VPU', 'SHY', 'MDYV', 'CWB', 'SPHQ', 'SHV', 'IUSG', 'VCSH', 'BIL']
# # TRAIN+VAL SHARPE: 0.9632219567030699
# # TRAIN SHARPE: 1.0105745549645724
# # VAL SHARPE: 0.8869336026783278
# # BLIND SHARPE: 0.9943641871002155
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'VYM', 'BWX', 'VMBS', 'SUB', 'SHY', 'UPRO', 'MDYV', 'SHV', 'SPHQ', 'CWB', 'VCSH', 'BIL']
# ETF_UNIVERSE = ['USD', 'TECL', 'VYM', 'GDX', 'BWX', 'VMBS', 'SUB', 'SHY', 'UPRO', 'MDYV', 'SHV', 'SPHQ', 'CWB', 'VCSH', 'BIL']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['GDX', 'USD', 'FNX', 'TECL', 'VYM', 'EWT', 'EWS', 'UPRO', 'EWY', 'AOM', 'VPU', 'SSO', 'PZA', 'VCR', 'IWN', 'SPMD', 'QLD', 'EWW', 'IHI', 'VNQ', 'ROM', 'DVY', 'EEM', 'XLE', 'FVD', 'IJR', 'EPP', 'IYH', 'PEY', 'IDU', 'BIV', 'GDXJ', 'XOP', 'RWR', 'IYE', 'EWC', 'EFA', 'SPXL', 'GRID', 'XBI', 'EWP', 'IJS', 'CWB', 'QQEW', 'VBR', 'VWO', 'DES', 'BWX', 'DBC', 'IVW', 'IXC', 'IBB', 'SCHG', 'VOE', 'VUG', 'MDYV', 'EWU', 'IYK', 'FXR', 'TNA', 'IJJ', 'ONEQ', 'EWJ', 'SPHQ', 'IWY', 'PCY', 'PDP', 'IYC', 'FTC', 'GSG', 'VV', 'IWS', 'IJH', 'VGK', 'PXH', 'SLYV', 'IUSG', 'SPYG', 'EWA', 'DSI', 'MGC', 'FAS', 'SOXX', 'FXL', 'SLYG', 'XLK', 'VMBS', 'AGQ', 'IVE', 'VHT', 'VTV', 'FPX', 'VDC', 'IWR', 'FEZ', 'MDYG', 'VTI', 'MDY', 'PRFZ', 'IEI', 'SIVR', 'FXO', 'PPA', 'SCHB', 'RPV', 'SCHX', 'QQQ', 'SCHA', 'ITOT', 'QQXT', 'SHY', 'SPY', 'GLD', 'VEA', 'IWF', 'SUB', 'IWL', 'XHB', 'PRF', 'XLV', 'VCSH', 'JNK', 'IJK', 'AGG', 'IUSV', 'IJT', 'BSV', 'EFV', 'XLU', 'VO', 'FDN', 'SCHV', 'IEF', 'IEV', 'IGOV', 'VSS', 'GSY', 'RWO', 'AAXJ', 'BIL', 'IVV', 'ITA', 'SHV', 'RPG', 'BLV', 'IWB']
# ETF_UNIVERSE = ['GDX', 'FNX', 'USD', 'TECL', 'VYM', 'EWT', 'VPU', 'EWS', 'AOM', 'UPRO', 'EWY', 'DBC', 'GRID', 'MDYV', 'EWW', 'FVD', 'VCR', 'CWB', 'IDU', 'IHI', 'DVY', 'VMBS', 'IWN', 'IYH', 'SPXL', 'GSG', 'SSO', 'SPHQ', 'PCY', 'BWX', 'GDXJ', 'SCHG', 'PEY', 'BIV', 'IUSG', 'IWY', 'SUB', 'VDC', 'SPYG', 'QQEW', 'SHY', 'MDYG', 'SLYG', 'EWJ', 'VCSH', 'FTC', 'JNK', 'ITOT', 'IJR', 'FXR', 'SLYV', 'BIL', 'DSI', 'IYK', 'SHV', 'IEI', 'PDP', 'XOP', 'EEM']
# # TRAIN+VAL SHARPE: 1.1693806628918224
# # TRAIN SHARPE: 1.2975397860132367
# # VAL SHARPE: 0.9232128750788586
# # BLIND SHARPE: 0.7947602121519961
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'FNX', 'VYM', 'EWT', 'EWS', 'VPU', 'DBC', 'MDYV', 'GRID', 'UPRO', 'CWB', 'VCR', 'BWX', 'VMBS', 'SPHQ', 'SUB', 'IDU', 'FVD', 'PCY', 'GSG', 'SHY', 'IUSG', 'DVY', 'SCHG', 'GDXJ', 'IWY', 'EWJ', 'EWW', 'VCSH', 'IHI', 'BIL', 'SHV', 'IYH', 'EWY']
# # TRAIN+VAL SHARPE: 1.2228723174708798
# # TRAIN SHARPE: 1.3517668064372925
# # VAL SHARPE: 0.974694861081702
# # BLIND SHARPE: 0.694761175191338
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'EWT', 'FNX', 'VPU', 'DBC', 'VYM', 'CWB', 'MDYV', 'GRID', 'UPRO', 'BWX', 'VMBS', 'SUB', 'EWS', 'SHY', 'VCR', 'SPHQ', 'IUSG', 'SCHG', 'DVY', 'SHV', 'PCY', 'VCSH', 'BIL', 'FVD', 'IWY']
# # TRAIN+VAL SHARPE: 1.1459482432692598
# # TRAIN SHARPE: 1.2576764967585465
# # VAL SHARPE: 0.9380530748816682
# # BLIND SHARPE: 0.7265728500563202
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 'EWS', 'EWT', 'VPU', 'VYM', 'SUB', 'VMBS', 'DBC', 'BWX', 'CWB', 'MDYV', 'GRID', 'SHY', 'SPHQ', 'FVD', 'UPRO', 'SHV', 'VCSH', 'IUSG', 'BIL']
# ETF_UNIVERSE = ['GDX', 'USD', 'TECL', 
## best
# ETF_UNIVERSE = ['AAXJ', 'TECL', 'SH', 'VOX', 'FNX', 'PXH', 'MGK', 'GLD', 'RPV', 'EWP', 'HYD', 'PPA', 'DEM', 'PHO', 'FXI', 'EFV', 'DBC', 'SLV', 'HYG', 'EWS', 'SHY', 'BIV', 'FXL', 'MUNI', 'VCIT', 'VCSH', 'VMBS', 'XSD', 'SPYG']
## best
# ETF_UNIVERSE = ['AAXJ', 'TECL', 'SH', 'VOX', 'GLD', 'FNX', 'RPV', 'MGK', 'PXH', 'HYD', 'EWP', 'PPA', 'PHO', 'DEM', 'SLV', 'FXI', 'EFV', 'DBC', 'FXL', 'SHY', 'HYG', 'MUNI', 'VCIT', 'VCSH', 'VMBS', 'EWS', 'BIV']
# ## best
# # TRAIN+VAL SHARPE: 1.291965215458406
# # TRAIN SHARPE: 1.434348172278585
# # VAL SHARPE: 0.98504112649159
# # BLIND SHARPE: -0.08189828612848446
# ETF_UNIVERSE = ['AAXJ', 'TECL', 'VOX', 'SH', 'PHO', 'GLD', 'FNX', 'MGK', 'RPV', 'PXH', 'HYD', 'PPA', 'EWP', 'FXL', 'SLV', 'DEM', 'SHY', 'FXI', 'DBC', 'MUNI', 'HYG', 'EFV', 'VCIT', 'VCSH', 'VMBS']
# ETF_UNIVERSE = ['AAXJ', 'VOX', 'TECL', 'SH', 'GLD', 'PHO', 'RPV', 'MGK', 'PXH', 'EWP', 'HYD', 'PPA', 'FNX', 'FXL', 'SLV', 'DEM', 'EFV', 'MUNI', 'DBC', 'SHY', 'VCIT', 'HYG', 'VCSH', 'FXI', 'VMBS']

# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['TECL', 'AGQ', 'AAXJ', 'FXH', 'IDU', 'PHO', 'XLU', 'PZA', 'VPU', 'FBT', 'QTEC', 'AOM', 'CQQQ', 'VOX', 'SIVR', 'SOXX', 'GLD', 'SLV', 'SPXL', 'VCR', 'UPRO', 'VT', 'RWO', 'SSO', 'SH', 'SPYG', 'XLV', 'XHB', 'FXR', 'SMH', 'EWZ', 'XSD', 'IJR', 'CWB', 'PPA', 'IVW', 'EWP', 'IUSG', 'ICLN', 'OEF', 'SPHQ', 'QQXT', 'XLK', 'PWB', 'RPV', 'FTCS', 'DSI', 'HYD', 'EWS', 'IGV', 'VSS', 'AOR', 'ILF', 'ROM', 'IWL', 'CGW', 'FXI', 'AIA', 'VDE', 'VV', 'VUG', 'SCHV', 'IVV', 'QQEW', 'XLB', 'VHT', 'EXI', 'ONEQ', 'IWY', 'PDP', 'SCHG', 'DBC', 'SCHB', 'PRF', 'VTV', 'VAW', 'PGX', 'SPY', 'IXN', 'MDYG', 'FPX', 'IYK', 'VGT', 'ITA', 'SCHX', 'AOA', 'IWO', 'SGOL', 'GRID', 'IWX', 'GDXJ', 'RPG', 'ACWX', 'DIA', 'EFA', 'SPYV', 'EFV', 'MGK', 'TNA', 'VIG', 'IYR', 'FDL', 'IWD', 'VOT', 'IYY', 
# ETF_UNIVERSE = ['XLU', 'BIV', 'EWY', 'VPU', 'AOM', 'VAW', 'CMF', 'ITM', 'IHI', 'GLD', 'XLE', 'FEX', 'DBC', 'ITA', 'VDC', 'PPA', 'IWB', 'VGLT', 'QQXT', 'SLYV', 'XOP', 'FVD', 'CWB', 'EMB', 'VIG', 'SPHQ', 'BWX', 'DXJ', 'IGOV', 'XME', 'VCLT', 'VGIT', 'VOT', 'IYJ', 'VYM', 'FTC', 'VHT', 'VMBS', 'HYD', 'IDU', 'VCIT', 'KBE', 'SHM', 'ITB', 'SGOL', 'SHV', 'ITOT', 'PWZ', 'EWA', 'PWB', 'VCSH', 'BIL']
# ETF_UNIVERSE = ['XLU', 'EWY', 'BIV', 'VAW', 'VPU', 'GLD', 'CMF', 'ITM', 'AOM', 'DBC', 'PPA', 'VGLT', 'VDC', 'SLYV', 'FEX', 'IWB', 'ITA', 'IHI', 'EMB', 'CWB', 'KBE', 'IGOV', 'VGIT', 'FVD', 'VYM', 'SPHQ', 'VCLT', 'BWX', 'VIG', 'DXJ', 'VHT', 'VOT', 'XLE', 'VMBS', 'QQXT', 'SGOL', 'VCIT', 'HYD', 'SHM', 'IYJ', 'PWZ', 'SHV', 'PWB', 'VCSH', 'BIL']
# # TRAIN+VAL SHARPE: 1.3732855254544156
# # TRAIN SHARPE: 1.2912069162237143
# # VAL SHARPE: 1.5936457085064717
# # BLIND SHARPE: 0.2214092999351672
# ETF_UNIVERSE = ['XLU', 'BIV', 'VAW', 'CMF', 'VPU', 'ITM', 'EWY', 'XLE', 'FEX', 'AOM', 'DBC', 'VGLT', 'SLYV', 'VDC', 'PPA', 'QQXT', 'EMB', 'ITA', 'IHI', 'VYM', 'DXJ', 'IGOV', 'CWB', 'VGIT', 'SPHQ', 'VOT', 'GLD', 'BWX', 'IWB', 'VCLT', 'VMBS', 'KBE', 'SGOL', 'FVD', 'HYD', 'VCIT', 'PWZ', 'SHV', 'PWB', 'VCSH', 'VHT', 'BIL', 'VIG']
# # # TRAIN+VAL SHARPE: 1.383677867379166
# # # TRAIN SHARPE: 1.3208551505584483
# # # VAL SHARPE: 1.5688798328030396
# # # BLIND SHARPE: 0.22381005092167938
# ETF_UNIVERSE = ['XLU', 'VAW', 'BIV', 'VPU', 'CMF', 'EWY', 'ITM', 'XLE', 'DBC', 'FEX', 'AOM', 'VGLT', 'PPA', 'ITA', 'SLYV', 'VYM', 'VDC', 'EMB', 'IGOV', 'SPHQ', 'IHI', 'IWB', 'VOT', 'DXJ', 'VGIT', 'CWB', 'QQXT', 'BWX', 'PWB', 'FVD', 'VMBS', 'VCLT', 'SGOL', 'HYD', 'PWZ', 'VHT', 'VCIT', 'SHV', 'KBE', 'VCSH', 'BIL']
# ETF_UNIVERSE = ['XLU', 'EWY', 'VAW', 'VPU', 'CMF', 'XLE', 'BIV', 'ITM', 'DBC', 'PPA', 'AOM', 'VGLT', 'SLYV', 'ITA', 'IWB', 'VDC', 'VYM', 'VOT', 'SPHQ', 'FEX', 'EMB', 'IGOV', 'PWB', 'CWB', 'DXJ', 'VGIT', 'SGOL', 'FVD', 'VHT', 'IHI', 'VMBS', 'KBE', 'BWX', 'HYD', 'VCLT', 'VCIT', 'SHV', 'VCSH', 'BIL']
# ETF_UNIVERSE = ['XLU', 'EWY', 'BIV', 'GLD', 'AOM', 'CMF', 'ITM', 'VAW', 'VPU', 'XLE', 'DBC', 'DXJ', 'VDC', 'SLYV', 'FEX', 'KBE', 'CWB', 'VGLT', 'VYM', 'PPA', 'EMB', 'IHI', 'FVD', 'SPHQ', 'ITA', 'IGOV', 'IWB', 'VHT', 'VGIT', 'BWX', 'VCLT', 'QQXT', 'HYD', 'VMBS', 'FTC', 'VOT', 'VCIT', 'PWZ', 'ITOT', 'DHS', 'SHV', 'VIG', 'VCSH', 'SGOL', 'MBB', 'XOP', 'BIL']
# # ## best
# # # TRAIN+VAL SHARPE: 1.4525584358065136
# # # TRAIN SHARPE: 1.4626283242058093
# # # VAL SHARPE: 1.4412768403654865
# # # BLIND SHARPE: 0.37590342759239087
# ETF_UNIVERSE = ['XLU', 'EWY', 'VAW', 'GLD', 'ITM', 'CMF', 'BIV', 'VPU', 'VYM', 'AOM', 'VDC', 'DXJ', 'XLE', 'SLYV', 'ITA', 'DBC', 'PPA', 'VGLT', 'CWB', 'IWB', 'VHT', 'EMB', 'IHI', 'FVD', 'SPHQ', 'FEX', 'QQXT', 'IGOV', 'VGIT', 'KBE', 'VOT', 'BWX', 'VCLT', 'HYD', 'VMBS', 'PWZ', 'ITOT', 'VCIT', 'FTC', 'XOP', 'SHV', 'VCSH', 'MBB', 'SGOL', 'BIL']
# ETF_UNIVERSE = ['XLU', 'EWY', 'VAW', 'CMF', 'BIV', 'ITM', 'GLD', 'VPU', 'FEX', 'VYM', 'ITA', 'AOM', 'PPA', 'DBC', 'DXJ', 'SLYV', 'VDC', 'VGLT', 'CWB', 'XLE', 'EMB', 'SPHQ', 'FVD', 'VHT', 'IWB', 'QQXT', 'KBE', 'IGOV', 'FTC', 'VGIT', 'IHI', 'BWX', 'HYD', 'VMBS', 'VCLT', 'VOT', 'PWZ', 'ITOT', 'VCIT', 'SHV', 'SGOL', 'VCSH', 'BIL']
# ETF_UNIVERSE = ['XLU', 'XLE', 'EWY', 'VAW', 'BIV', 'CMF', 'ITM', 'VPU', 'DBC', 'VYM', 'AOM', 'DXJ', 'SLYV', 'VDC', 'FEX', 'VGLT', 'ITA', 'GLD', 'PPA', 'CWB', 'EMB', 'IWB', 'SPHQ', 'IGOV', 'VGIT', 'VHT', 'BWX', 'FVD', 'KBE', 'VMBS', 'QQXT', 'HYD', 'IHI', 'VCLT', 'VOT', 'VCIT', 'SHV', 'PWZ', 'ITOT', 'SGOL', 'FTC', 'VCSH', 'BIL']

# # Maximize 0.85/0.15 train/val
GC', 'TIP', 'FEZ', 'PFF', 'VEU', 'IEV', 'EWL', 'IGF', 'PXF', 'PDP', 'EWU', 'SIVR', 'ITM', 'IEF', 'EWC', 'EPP', 'PWZ', 'YINN', 'EWT', 'IEI', 'NYF', 'IYH', 'MUNI', 'EWP', 'NLR', 'FXI', 'VCIT', 'MDYV', 'SUB', 'SHM', 'VMBS', 'VWO', 'SHY', 'IOO', 'PID', 'XLB', 'ILF', 'VGK', 'VCLT']
# ETF_UNIVERSE = ['FXU', 'SPMD', 'SH', 'BAB', 'EPI', 'EWY', 'AIA', 'CQQQ', 'RWL', 'VSS', 'DGS', 'DBC', 'PFF', 'GLD', 'PZA', 'ITB', 'RWK', 'EDV', 'SCZ', 'ITM', 'TLT', 'EWG', 'IGOV', 'GRID', 'VOX', 'SLV', 'SCHF', 'PWZ', 'IDV', 'DLS', 'PXH', 'TIP', 'NYF', 'SHM', 'IEF', 'MUNI', 'IGF', 'VCIT', 'CWI', 'SUB', 'PXF', 'VMBS', 'SHY']
# ETF_UNIVERSE = ['BAB', 'SH', 'RWL', 'SPMD', 'TLT', 'ITB', 'EWY', 'EPI', 'AIA', 'PFF', 'FXU', 'SCZ', 'DGS', 'DBC', 'VSS', 'EDV', 'IGOV', 'CQQQ', 'GLD', 'IDV', 'SHM', 'VOX', 'EWG', 'TIP', 'PWZ', 'CWI', 'NYF', 'DLS', 'MUNI', 'SUB', 'VMBS']
# ## best
# # # TRAIN+VAL SHARPE: 1.1572464865699577
# # # TRAIN SHARPE: 1.1281185985557582
# # # VAL SHARPE: 1.230341540619356
# # # BLIND SHARPE: 0.6908562157620807
# ETF_UNIVERSE = ['BAB', 'ITB', 'SH', 'RWL', 'SPMD', 'EWY', 'SCZ', 'DBC', 'VSS', 'TLT', 'EPI', 'AIA', 'CQQQ', 'VOX', 'DGS', 'PFF', 'FXU', 'IGOV', 'GLD', 'EDV', 'TIP', 'SHM', 'PWZ', 'DLS', 'NYF', 'MUNI', 'VMBS', 'SUB']
# ETF_UNIVERSE = ['BAB', 'ITB', 'EWY', 'RWL', 'SH', 'SPMD', 'AIA', 'EPI', 'SCZ', 'VOX', 'DBC', 'DGS', 'DLS', 'PFF', 'FXU', 'VSS', 'TLT', 'CQQQ', 'IGOV', 'TIP', 'GLD', 'SHM', 'PWZ', 'NYF', 'MUNI', 'EDV', 'VMBS', 'SUB']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['EWS', 'SPMD', 'ICF', 'PPA', 'XLU', 'EWY', 'FXU', 'EPI', 'ITA', 'BAB', 'AIA', 'ITB', 'PZA', 'VOX', 'EWG', 'EWU', 'EPP', 'SLV', 'DBC', 'FXI', 'IEV', 'RWL', 'UYG', 'XLK', 'IDU', 'XHB', 'CWI', 'IWN', 'EWT', 'GLD', 'EWA', 'FTA', 'EFG', 'IDV', 'DLS', 'CQQQ', 'YINN', 'EZU', 'VEU', 'IJR', 'EWP', 'FEZ', 'IOO', 'XLG', 'VWO', 'EWC', 'DGS', 'EDV', 'PF
# ETF_UNIVERSE = ['BAB', 'SH', 'SPMD', 'EWY', 'FXU', 'EPI', 'ITB', 'RWL', 'PFF', 'AIA', 'TLT', 'VSS', 'DGS', 'SCZ', 'DBC', 'CQQQ', 'GLD', 'RWK', 'IDV', 'IGOV', 'VOX', 'EDV', 'CWI', 'SHM', 'EWG', 'PWZ', 'XLU', 'PXH', 'IGF', 'NYF', 'DLS', 'ITM', 'MUNI', 'SCHF', 'SUB', 'VMBS', 'EMB', 'PXF', 'TIP']
# # ## best
# # TRAIN+VAL SHARPE: 1.1430438151928415
# # TRAIN SHARPE: 1.0742635110920054
# # VAL SHARPE: 1.3175251242817807
# # BLIND SHARPE: 0.6711854610764261
# ETF_UNIVERSE = ['BAB', 'ITB', 'SPMD', 'RWL', 'SH', 'EWY', 'EPI', 'SCZ', 'PFF', 'DBC', 'VSS', 'DGS', 'AIA', 'FXU', 'GLD', 'XLU', 'VOX', 'TLT', 'CQQQ', 'RWK', 'SHM', 'IGOV', 'PWZ', 'CWI', 'IGF', 'IDV', 'DLS', 'NYF', 'PXH', 'MUNI', 'EDV', 'TIP', 'SUB', 'VMBS', 'ITM']
# ETF_UNIVERSE = ['BAB', 'ITB', 'EWY', 'RWL', 'SPMD', 'XLU', 'SH', 'EPI', 'PFF', 'SCZ', 'VSS', 'AIA', 'FXU', 'DGS', 'DBC', 'VOX', 'RWK', 'GLD', 'IDV', 'TLT', 'CWI', 'PWZ', 'IGOV', 'CQQQ', 'SHM', 'DLS', 'IGF', 'PXH', 'NYF', 'TIP', 'MUNI', 'SUB', 'VMBS', 'ITM', 'EDV']

# # Maximize 0.775/0.225 train/val
# ETF_UNIVERSE = ['SPMD', 'EWY', 'BAB', 'ITB', 'PFF', 'SH', 'FXU', 'EPI', 'AIA', 'TLT', 'RWL', 'VSS', 'DGS', 'DLS', 'IDV', 'RWK', 'DBC', 'SCZ', 'EWG', 'IGOV', 'FTA', 'CQQQ', 'SHM', 'PWZ', 'SCHF', 'NYF', 'IEF', 'PXH', 'EDV', 'PXF', 'MUNI', 'EMB', 'SUB', 'VMBS', 'SHY', 'IGF', 'GRID']
# ETF_UNIVERSE = ['BAB', 'ITB', 'SPMD', 'PFF', 'RWL', 'SH', 'EPI', 'EWY', 'DBC', 'AIA', 'FXU', 'VSS', 'TLT', 'DLS', 'SCZ', 'IGOV', 'DGS', 'SHM', 'RWK', 'PWZ', 'EMB', 'NYF', 'IDV', 'SHY', 'SUB', 'VMBS', 'MUNI']
# ETF_UNIVERSE = ['BAB', 'ITB', 'SH', 'RWL', 'SCZ', 'PFF', 'AIA', 'DBC', 'EPI', 'SPMD', 'VSS', 'DLS', 'DGS', 'FXU', 'TLT', 'IDV', 'IGOV', 'RWK', 'SHM', 'PWZ', 'NYF', 'MUNI', 'EMB', 'SHY', 'VMBS', 'SUB']
# ETF_UNIVERSE = ['BAB', 'ITB', 'SH', 'AIA', 'RWL', 'EPI', 'SCZ', 'PFF', 'DBC', 'SPMD', 'DLS', 'IDV', 'VSS', 'IGOV', 'FXU', 'DGS', 'RWK', 'PWZ', 'EMB', 'MUNI', 'NYF', 'VMBS', 'SHM', 'SHY', 'SUB']
G', 'FEZ', 'TIP', 'PXF', 'FIW', 'IEV', 'VEU', 'IGF', 'EWP', 'PWZ', 'FXO', 'FTC', 'RPG', 'EPP', 'FXI', 'XLK', 'NYF', 'IOO', 'FEX', 'ILF', 'VAW', 'IEF', 'XLG', 'NLR', 'EWT', 'SUB', 'MGV', 'USO', 'MUNI', 'SHM', 'SHY', 'IYH', 'EWC', 'VMBS', 'VCIT', 'EMB', 'VWO', 'PID', 'VDE', 'SIVR', 'VEA', 'VGK']
# ETF_UNIVERSE = ['SPMD', 'SH', 'FXU', 'BAB', 'EPI', 'VSS', 'AIA', 'ITB', 'RWL', 'PZA', 'DGS', 'EWY', 'PFF', 'TLT', 'RWK', 'DBC', 'SCHF', 'CQQQ', 'EWG', 'SCZ', 'IGOV', 'XLU', 'GLD', 'GRID', 'YINN', 'EDV', 'FTA', 'IDV', 'PWZ', 'FXR', 'PXH', 'SHM', 'SLV', 'NYF', 'FXH', 'IGF', 'MDYV', 'IEF', 'EMB', 'TIP', 'MUNI', 'VMBS', 'SUB', 'DLS', 'SHY', 'VCIT', 'PXF', 'MGC', 'EWP']
# # best
# ETF_UNIVERSE = ['SPMD', 'EWY', 'BAB', 'ITB', 'PFF', 'SH', 'FXU', 'EPI', 'AIA', 'TLT', 'RWL', 'VSS', 'DGS', 'DLS', 'IDV', 'RWK', 'DBC', 'SCZ', 'EWG', 'IGOV', 'FTA', 'CQQQ', 'SHM', 'PWZ', 'SCHF', 'NYF', 'IEF', 'PXH', 'EDV', 'PXF', 'MUNI', 'EMB', 'SUB', 'VMBS', 'SHY', 'IGF', 'GRID']
# ETF_UNIVERSE = ['BAB', 'ITB', 'SPMD', 'PFF', 'RWL', 'SH', 'EPI', 'DBC', 'EWY', 'AIA', 'VSS', 'FXU', 'TLT', 'DLS', 'RWK', 'IGOV', 'DGS', 'SHM', 'SCZ', 'PWZ', 'EMB', 'NYF', 'IDV', 'SHY', 'SUB', 'VMBS', 'MUNI']
# ETF_UNIVERSE = ['BAB', 'ITB', 'SH', 'RWL', 'SCZ', 'PFF', 'AIA', 'SPMD', 'DBC', 'EPI', 'VSS', 'TLT', 'DLS', 'RWK', 'IDV', 'DGS', 'IGOV', 'FXU', 'SHM', 'PWZ', 'EMB', 'NYF', 'SHY', 'MUNI', 'VMBS', 'SUB']
# ETF_UNIVERSE = ['BAB', 'ITB', 'SH', 'AIA', 'RWL', 'EPI', 'PFF', 'SCZ', 'DBC', 'SPMD', 'DLS', 'IDV', 'VSS', 'IGOV', 'RWK', 'FXU', 'DGS', 'PWZ', 'EMB', 'NYF', 'MUNI', 'VMBS', 'SHM', 'SHY', 'SUB', 'TLT']

# =========================
# SIGNAL SPIKE -- PICKED
# =========================
# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['IGOV', 'IDU', 'DGS', 'DEM', 'SH', 'BWX', 'SCHF', 'TFI', 'EFA', 'EWT', 'PWB', 'IBB', 'FGD', 'MUB', 'SMH', 'AIA', 'DTD', 'XLY', 'EFV', 'SPMD', 'PID', 'FBT']
# ETF_UNIVERSE = ['IGOV', 'DEM', 'IDU', 'SH', 'DGS', 'SMH', 'BWX', 'PWB', 'SCHF', 'TFI', 'EFA', 'FGD', 'EFV', 'EWT', 'MUB', 'DTD', 'FBT', 'IBB']
# ETF_UNIVERSE = ['DEM', 'DGS', 'IGOV', 'SH', 'IDU', 'BWX', 'PWB', 'SCHF', 'EWT', 'EFV', 'TFI', 'FGD', 'IBB', 'MUB', 'DTD']
# # TRAIN+VAL SHARPE: 0.9965241621870922
# # TRAIN SHARPE: 0.8835337897625645
# # VAL SHARPE: 1.3186339693912421
# # BLIND SHARPE: 1.1868285825286626
# ETF_UNIVERSE = ['IDU', 'DEM', 'SH', 'IGOV', 'BWX', 'DGS', 'SCHF', 'EFV', 'PWB', 'TFI', 'DTD', 'MUB']
# ETF_UNIVERSE = ['IDU', 'IGOV', 'SH', 'DEM', 'DGS', 'SCHF', 'DTD', 'BWX', 'EFV', 'TFI', 'PWB', 'MUB']

# # Maximize 0.45/0.55 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'YINN', 'ICLN', 'SMH', 'AOM', 'EWT', 'DEM', 'EWP', 'TMF', 'IDU', 'QQXT', 'EFA', 'PXF', 'EWC', 'IGOV', 'SCHF', 'EFV', 'IBB', 'PHO', 'FIW', 'AIA', 'SCZ', 'RPV', 'IXN', 'DGS', 'SIVR', 'PZA', 'PID', 'BAB', 'FGD', 'EWZ', 'IGM', 'VAW', 'FBT', 'XLK', 'SOXX', 'EDV', 'BWX', 'PWB', 'FDL', 'SPMD', 'IEV', 'IDV', 'IXJ', 'VPU', 'XLB', 'DTD', 'FPX', 'GRID', 'XSD', 'IWC', 'TFI', 'ITA', 'EXI', 'ROM', 'IWS', 'MUB', 'FDN', 'IOO', 'VNQ', 'ICF', 'DES', 'KBE', 'XLF', 'EWS', 'SHY', 'ZROZ', 'XLY', 'DVY', 'EEM', 'USD', 'IEI', 'VEA', 'VGT', 'DIA', 'FXH', 'IWD', 'EWL', 'PCY', 'TECL', 'IHI', 'QQEW', 'EWG', 'VOX', 'PWV', 'VIG', 'IYG', 'SHM', 'VGK', 'IGV', 'RWR', 'BLV', 'CMF', 'DLN', 'XLU', 'VSS', 'SH', 'GSG', 'AOR', 'VTI', 'FNX', 'XLP', 'VO', 'PDP', 'EPI', 'PRF', 'EZU', 'PPA', 'XBI', 'IWX', 'IYH', 'DLS', 'QTEC', 'XLE', 'VCIT', 'RSP', 'RWL', 'VV', 'FXO', 'IUSV', 'VXF', 'FEZ', 'FXR', 'SPHQ', 'IJR', 'PKW', 'FXL', 'IWV', 'FVD', 'SCHB', 'QQQ', 'PFF', 'BIV', 'SCHV', 'GVI', 'SCHA', 'NYF', 'VTV', 'ACWX', 'UPRO', 'SPYV', 'DXJ', 'MDY', 'ITM', 'IWN', 'VBK', 'VGLT']
# ETF_UNIVERSE = ['IGOV', 'DEM', 'DGS', 'IDU', 'BWX', 'SH', 'EFV', 'SCHF', 'EWT', 'IXJ', 'TFI', 'FGD', 'DTD', 'MUB', 'SCZ']
# # TRAIN+VAL SHARPE: 0.965176929678481
# # TRAIN SHARPE: 0.8571012372711907
# # VAL SHARPE: 1.304043331596031
# # BLIND SHARPE: 0.7973844469078554
# ETF_UNIVERSE = ['IDU', 'IGOV', 'SH', 'DEM', 'EFV', 'BWX', 'IXJ', 'DGS', 'TFI', 'SCHF', 'MUB', 'DTD']
# ETF_UNIVERSE = ['IDU', 'IGOV', 'SH', 'DEM', 'SCHF', 'DGS', 'DTD', 'BWX', 'IXJ', 'TFI', 'EFV', 'MUB']

# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'AOM', 'SMH', 'YINN', 'ICLN', 'EWT', 'EWP', 'QQXT', 'DEM', 'TMF', 'IDU', 'EWC', 'EFA', 'PXF', 'FIW', 'PZA', 'RPV', 'PHO', 'IXN', 'IGOV', 'SCHF', 'EFV', 'SCZ', 'AIA', 'SIVR', 'IBB', 'BAB', 'VAW', 'PID', 'DGS', 'FGD', 'EDV', 'IGM', 'XLK', 'FDL', 'SPMD', 'FBT', 'EWZ', 'FPX', 'XLB', 'GRID', 'IXJ', 'IDV', 'SOXX', 'BWX', 'VPU', 'PWB', 'DTD', 'TFI', 'IWC', 'IEV', 'ITA', 'XSD', 'EXI', 'KBE', 'IWS', 'MUB', 'VNQ', 'IOO', 'ICF', 'FDN', 'DES', 'XLY', 'EEM', 'DVY', 'IHI', 'SHY', 'EWL', 'XLF', 'IEI', 'ZROZ', 'SHM', 'DIA', 'EWS', 'XLE', 'RWR', 'FXH', 'VGT', 'ROM', 'PCY', 'IWD', 'EWG', 'GSG', 'PDP', 'CMF', 'SH', 'VSS', 'PWV', 'FNX', 'QQEW', 'IYG', 'VEA', 'IGV', 'TECL', 'VIG', 'VOX', 'AOR', 'IJR', 'VGK', 'VO', 'DLN', 'VTI', 'BLV', 'XLP', 'PPA', 'FXL', 'FXR', 'EPI', 'RWL', 'PRF', 'VCIT', 'RSP', 'DLS', 'EZU', 'XBI', 'VXF', 'XLU', 'VV', 'IWX', 'IUSV', 'USD', 'QTEC', 'PFF', 'IYH', 'IYJ', 'SCHA', 'MDY', 'PKW', 'FVD', 'DBC', 'VGLT', 'FEZ', 'SPHQ', 'NYF', 'MDYV', 'GVI', 'SCHV', 'IWV', 'IWN', 'VBR', 'SPYV', 'SCHB', 'QQQ', 'VTV', 'BIV', 'FXO', 'IJJ', 'EPS']
# ETF_UNIVERSE = ['AAXJ', 'ICLN', 'YINN', 'AOM', 'SMH', 'IGOV', 'EWT', 'SPMD', 'DEM', 'IDU', 'EWC', 'PID', 'TMF', 'AIA', 'IBB', 'SCHF', 'FIW', 'PHO', 'QQXT', 'DGS', 'PXF', 'BWX', 'EWP', 'RPV', 'FGD', 'TFI', 'EDV', 'SH', 'SCZ', 'EFA', '
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'DGS', 'IDU', 'EWT', 'SCHF', 'BWX', 'IBB', 'FGD', 'PWB', 'TFI', 'IXJ', 'MUB', 'DTD']
# ETF_UNIVERSE = ['DEM', 'IDU', 'SH', 'IGOV', 'SCHF', 'BWX', 'DGS', 'TFI', 'IXJ', 'DTD', 'FGD', 'MUB']
# # TRAIN+VAL SHARPE: 0.9285085547664567
# # TRAIN SHARPE: 0.8109349643803828
# # VAL SHARPE: 1.3080990108757256
# # BLIND SHARPE: 0.776058403244168
# ETF_UNIVERSE = ['IDU', 'SH', 'IGOV', 'DEM', 'SCHF', 'BWX', 'DGS', 'TFI', 'DTD', 'MUB', 'IXJ']
# ETF_UNIVERSE = ['IDU', 'IGOV', 'SH', 'DEM', 'SCHF', 'DTD', 'BWX', 'TFI', 'DGS', 'MUB', 'IXJ']

# # Maximize 0.55/0.45 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'AOM', 'SMH', 'YINN', 'ICLN', 'EWP', 'QQXT', 'EWT', 'DEM', 'TMF', 'IDU', 'PZA', 'EWC', 'FIW', 'RPV', 'EFA', 'PHO', 'PXF', 'IXN', 'BAB', 'EDV', 'VAW', 'SCZ', 'SIVR', 'AIA', 'IGOV', 'SCHF', 'EFV', 'PID', 'IBB', 'FDL', 'FGD', 'SPMD', 'IGM', 'XLK', 'DGS', 'FPX', 'XLB', 'GRID', 'FBT', 'TFI', 'IXJ', 'DTD', 'VPU', 'IWC', 'ITA', 'IDV', 'KBE', 'EWZ', 'XSD', 'PWB', 'XLE', 'EXI', 'BWX', 'IWS', 'MUB', 'VNQ', 'SOXX', 'IEV', 'IHI', 'ICF', 'SHM', 'IOO', 'EWL', 'EEM', 'FDN', 'DVY', 'XLY', 'PDP', 'RWR', 'DES', 'IEI', 'GSG', 'SHY', 'IJR', 'DIA', 'FNX', 'XLF', 'PCY', 'SH', 'FXH', 'EWG', 'ZROZ', 'CMF', 'IWD', 'VSS', 'VGT', 'FXL', 'FXR', 'EWS', 'IYG', 'PWV', 'IGV', 'QQEW', 'VO', 'PPA', 'AOR', 'VIG', 'VTI', 'RWL', 'TECL', 'IYJ', 'VEA', 'DLN', 'XLP', 'VCIT', 'EPI', 'VOX', 'DBC', 'VGK', 'ROM', 'RSP', 'VXF', 'BLV', 'PRF', 'DLS', 'MDYV', 'MDY', 'EZU', 'XBI', 'VV', 'VGLT', 'IUSV', 'PFF', 'SCHA', 'IJJ', 'VBR', 'FVD', 'IWX', 'PKW', 'EPS', 'NYF', 'KRE', 'IWN', 'GVI', 'QTEC', 'SCHV', 'SPYV', 'FYX', 'SPHQ', 'IWV', 'FEZ', 'IYH', 'XLU', 'MDYG', 'GSY']
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'IDU', 'DGS', 'SCHF', 'SMH', 'BWX', 'EWT', 'TFI', 'IXJ', 'FGD', 'FBT', 'MUB', 'EFV', 'AIA', 'FDL', 'DTD', 'PHO', 'XLY']
# ETF_UNIVERSE = ['DEM', 'SH', 'IGOV', 'IDU', 'SMH', 'SCHF', 'IXJ', 'TFI', 'DGS', 'FDL', 'MUB', 'BWX', 'FGD', 'EFV', 'DTD', 'XLY', 'PHO']
# ETF_UNIVERSE = ['DEM', 'SH', 'IGOV', 'IDU', 'DGS', 'SCHF', 'TFI', 'SMH', 'MUB', 'IXJ', 'FDL', 'FGD', 'EFV', 'BWX', 'DTD', 'PHO']
# # # TRAIN+VAL SHARPE: 1.0529534479901266
# # # TRAIN SHARPE: 1.0476250527358177
# # # VAL SHARPE: 1.0910809805074713
# # # BLIND SHARPE: 0.7389509199611162
# ETF_UNIVERSE = ['DEM', 'SH', 'IDU', 'IGOV', 'DGS', 'SCHF', 'TFI', 'EFV', 'MUB', 'FDL', 'FGD', 'IXJ', 'BWX', 'DTD', 'PHO']
# ETF_UNIVERSE = ['DEM', 'SH', 'IDU', 'IGOV', 'SCHF', 'DGS', 'TFI', 'MUB', 'IXJ', 'BWX', 'FDL', 'PHO', 'EFV']
# ETF_UNIVERSE = ['SH', 'IDU', 'IGOV', 'DEM', 'SCHF', 'DGS', 'FDL', 'TFI', 'EFV', 'IXJ', 'MUB', 'BWX']
# ETF_UNIVERSE = ['IDU', 'SH', 'IGOV', 'DEM', 'SCHF', 'EFV', 'FDL', 'DGS', 'TFI', 'IXJ', 'MUB', 'BWX']

# # Maximize 0.575/0.425 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'AOM', 'SMH', 'ICLN', 'YINN', 'EWP', 'QQXT', 'EWT', 'PZA', 'DEM', 'TMF', 'IDU', 'EWC', 'FIW', 'RPV', 'EFA', 'PHO', 'PXF', 'IXN', 'EDV', 'BAB', 'VAW', 'SIVR', 'SCZ', 'AIA', 'SCHF', 'IGOV', 'EFV', 'FDL', 'PID', 'SPMD', 'FGD', 'IBB', 'XLK', 'IGM', 'FPX', 'DGS', 'GRID', 'XLB', 'XLE', 'TFI', 'KBE', 'IXJ', 'DTD', 'ITA', 'IWC', 'VPU', 'FBT', 'IDV', 'EXI', 'XSD', 'IWS', 'MUB', 'VNQ', 'PWB', 'IHI', 'BWX', 'EWZ', 'SHM', 'PDP', 'EWL', 'ICF', 'RWR', 'IOO', 'SOXX', 'EEM', 'IJR', 'IEV', 'DVY', 'XLY', 'FDN', 'GSG', 'IEI', 'DES', 'FNX', 'FXL', 'SHY', 'DIA', 'SH', 'FXR', 'CMF', 'VSS', 'PCY', 'XLF', 'EWG', 'FXH', 'IWD', 'VGT', 'ZROZ', 'IYG', 'VO', 'IGV', 'PWV', 'IYJ', 'EWS', 'PPA
# ETF_UNIVERSE = ['SPMD', 'SMH', 'IGOV', 'EFA', 'DEM', 'EWT', 'IDU', 'IGM', 'DGS', 'PHO', 'SCHF', 'AIA', 'BWX', 'PID', 'FGD', 'TFI', 'SH', 'EWC', 'QQXT', 'PXF', 'SCZ', 'FIW', 'MUB', 'AOM', 'IBB', 'SOXX', 'XLY', 'FBT', 'DTD', 'RPV', 'IXJ', 'FPX', 'FDL', 'XLK', 'EFV', 'EXI', 'GRID', 'VPU', 'VAW', 'XLB', 'XLP']
# ETF_UNIVERSE = ['IGOV', 'SMH', 'EWT', 'DEM', 'IDU', 'SH', 'EFA', 'DGS', 'TFI', 'PHO', 'SCHF', 'SPMD', 'IGM', 'MUB', 'AIA', 'BWX', 'IBB', 'FGD', 'FDL', 'XLY', 'EWC', 'PID', 'DTD', 'RPV', 'IXJ', 'SCZ', 'FPX', 'FIW']
# ETF_UNIVERSE = ['IGOV', 'SMH', 'DEM', 'IDU', 'SH', 'SCHF', 'EWT', 'TFI', 'EFA', 'DGS', 'PHO', 'BWX', 'MUB', 'FGD', 'FDL', 'SPMD', 'DTD', 'IXJ', 'SCZ', 'XLY', 'RPV', 'IBB', 'PID']
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'IDU', 'SMH', 'DGS', 'SCHF', 'TFI', 'EWT', 'BWX', 'IXJ', 'EFA', 'PHO', 'MUB', 'FGD', 'SCZ', 'DTD', 'FDL', 'IBB']
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'DGS', 'IDU', 'EWT', 'BWX', 'SCHF', 'FGD', 'IBB', 'TFI', 'IXJ', 'PHO', 'SCZ', 'MUB', 'DTD', 'FDL']
# ETF_UNIVERSE = ['DEM', 'IDU', 'SH', 'IGOV', 'PHO', 'IXJ', 'SCHF', 'TFI', 'FDL', 'BWX', 'MUB', 'DGS', 'DTD', 'FGD', 'SCZ']
# ETF_UNIVERSE = ['SH', 'IDU', 'DEM', 'IGOV', 'PHO', 'TFI', 'IXJ', 'SCHF', 'DGS', 'MUB', 'BWX', 'FDL']
# ETF_UNIVERSE = ['SH', 'IGOV', 'IDU', 'SCHF', 'DEM', 'PHO', 'TFI', 'FDL', 'MUB', 'IXJ', 'DGS', 'BWX']

# # Maximize 0.6/0.4 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'AOM', 'SMH', 'EWP', 'ICLN', 'YINN', 'QQXT', 'EWT', 'PZA', 'TMF', 'EWC', 'IDU', 'DEM', 'FIW', 'RPV', 'PHO', 'EFA', 'EDV', 'IXN', 'PXF', 'VAW', 'BAB', 'SIVR', 'SCZ', 'AIA', 'FDL', 'SCHF', 'EFV', 'IGOV', 'SPMD', 'PID', 'FGD', 'FPX', 'XLK', 'IBB', 'XLE', 'IGM', 'GRID', 'XLB', 'TFI', 'KBE', 'DGS', 'ITA', 'DTD', 'IWC', 'IXJ', 'VPU', 'IDV', 'EXI', 'IWS', 'IHI', 'VNQ', 'MUB', 'FBT', 'XSD', 'SHM', 'PDP', 'IJR', 'RWR', 'EWL', 'PWB', 'BWX', 'ICF', 'GSG', 'EEM', 'IOO', 'DVY', 'EWZ', 'XLY', 'FXL', 'FNX', 'FDN', 'IEI', 'IEV', 'SOXX', 'DES', 
# ETF_UNIVERSE = ['SMH', 'IGOV', 'SPMD', 'EWT', 'DEM', 'IDU', 'EFA', 'SH', 'FBT', 'ICLN', 'SCHF', 'PHO', 'DGS', 'IGM', 'PID', 'RPV', 'FGD', 'BWX', 'YINN', 'AIA', 'FIW', 'TFI', 'PXF', 'IXJ', 'FPX', 'MUB', 'FDL', 'SCZ', 'EWC', 'DTD', 'SOXX', 'GRID', 'QQXT', 'EFV', 'XLY', 'EDV', 'XLK', 'EXI', 'XLF', 'ITA', 'IXN', 'VCIT', 'PCY']
# ## best
# ETF_UNIVERSE = ['SMH', 'SPMD', 'EWT', 'DEM', 'IGOV', 'EFA', 'IDU', 'FBT', 'DGS', 'SCHF', 'PHO', 'FGD', 'SH', 'AIA', 'RPV', 'PID', 'PXF', 'TFI', 'QQXT', 'FIW', 'SCZ', 'FDL', 'MUB', 'IXJ', 'DTD', 'BWX', 'FPX', 'IGM', 'SOXX', 'XLY', 'XLF', 'EFV', 'IXN', 'GRID', 'EXI', 'EWC', 'XLK', 'PCY', 'ITA']
# ## best
# ETF_UNIVERSE = ['IGOV', 'SMH', 'SPMD', 'SH', 'EWT', 'IDU', 'DEM', 'TFI', 'DGS', 'EFA', 'SCHF', 'MUB', 'PHO', 'FDL', 'FGD', 'AIA', 'XLY', 'FBT', 'RPV', 'SOXX', 'BWX', 'PID', 'IXJ', 'DTD', 'FPX', 'FIW']
# ## best
# ETF_UNIVERSE = ['IGOV', 'DEM', 'SH', 'SMH', 'IDU', 'DGS', 'SCHF', 'TFI', 'EWT', 'IXJ', 'SPMD', 'FGD', 'BWX', 'PHO', 'MUB', 'FDL', 'DTD', 'PID', 'AIA', 'FBT', 'XLY']
# # TRAIN+VAL SHARPE: 1.0850915452604193
# # TRAIN SHARPE: 1.1080418408670003
# # VAL SHARPE: 1.047255155973688
# # BLIND SHARPE: 0.8403687823381559
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'IDU', 'SMH', 'SCHF', 'IXJ', 'TFI', 'DGS', 'FDL', 'FGD', 'MUB', 'BWX', 'PHO', 'XLY', 'DTD', 'EWT', 'AIA', 'FBT']
# # best
# # TRAIN+VAL SHARPE: 1.085358291991003
# # TRAIN SHARPE: 1.117228607696369
# # VAL SHARPE: 1.0260659326087171
# # BLIND SHARPE: 0.9872078938002137
# ETF_UNIVERSE = ['DEM', 'SH', 'IGOV', 'IDU', 'SMH', 'IXJ', 'SCHF', 'TFI', 'FDL', 'MUB', 'FGD', 'PHO', 'BWX', 'DGS', 'XLY', 'DTD']
# ETF_UNIVERSE = ['DEM', 'SH', 'IDU', 'IGOV', 'SMH', 'SCHF', 'DGS', 'TFI', 'MUB', 'IXJ', 'FGD', 'FDL', 'PHO', 'DTD', 'BWX']
# # TRAIN+VAL SHARPE: 1.060373884858876
# # TRAIN SHARPE: 1.0635360927954265
# # VAL SHARPE: 1.0802365587007101
# # BLIND SHARPE: 0.7129917201954902
# ETF_UNIVERSE = ['SPMD', 'AAXJ', 'SMH', 'EWT', 'EDV', 'IDU', 'AOM', 'EWC', 'IGOV', 'FIW', 'QQXT', 'DEM', 'RPV', 'PHO', 'PXF', 'EFA', 'SH', 'FDL', 'AIA', 'FBT', 'GRID', 'SCHF', 'FGD', 'EWP', 'VPU', 'FPX', 'SCZ', 'TFI', 'PID', 'DTD', 'DGS', 'KBE', 'MUB', 'IGM', 'PDP', 'IXJ', 'ITA', 'XLY', 'VAW', 'CMF', 'EFV', 'EXI', 'XLK', 'VNQ', 'XLP', 'SOXX', 'IXN', 'PCY', 'IWS', 'FNX', 'DVY', 'VSS', 'FXH', 'XLF', 'BWX', 'IOO', 'PFF', 'VCIT', 'IHI']
# ETF_UNIVERSE = ['SMH', 'EWT', 'IGOV', 'SPMD', 'IDU', 'DEM', 'PHO', 'EFA', 'EWC', 'IGM', 'FBT', 'AIA', 'DGS', 'FIW', 'SH', 'PID', 'RPV', 'SCHF', 'FDL', 'EDV', 'TFI', 'FGD', 'FPX', 'XLY', 'IXJ', 'PXF', 'DTD', 'SCZ', 'VPU', 'MUB', 'ITA', 'XLK', 'QQXT', 'EFV', 'AOM', 'GRID', 'SOXX', 'EXI', 'VNQ', 'IXN', 'BWX', 'PDP', 'XLP', 'IOO', 'PCY', 'IWS', 'DVY', 'FNX', 'VAW', 'FXH']
# ETF_UNIVERSE = ['SMH', 'IGOV', 'EWT', 'SPMD', 'SH', 'IDU', 'TFI', 'PHO', 'DEM', 'SCHF', 'RPV', 'EWC', 'EFA', 'DGS', 'MUB', 'FDL', 'XLY', 'AIA', 'IGM', 'PID', 'FGD', 'FBT', 'FPX', 'IXJ', 'DTD', 'GRID', 'ITA', 'FIW', 'SOXX', 'SCZ', 'XLK', 'VPU', 'EXI', 'PXF']
# ETF_UNIVERSE = ['SMH', 'IGOV', 'EWT', 'DEM', 'TFI', 'SH', 'XLY', 'EFA', 'FDL', 'DGS', 'PHO', 'SCHF', 'RPV', 'MUB', 'FGD', 'AIA', 'DTD', 'FBT', 'IDU', 'PID', 'FPX', 'ITA', 'IXJ']
# # TRAIN+VAL SHARPE: 1.1167266497754058
# # TRAIN SHARPE: 1.1797119062162693
# # VAL SHARPE: 0.9747935006387634
# # BLIND SHARPE: 0.9827376342284587
# ETF_UNIVERSE = ['IGOV', 'DEM', 'SH', 'SMH', 'TFI', 'DGS', 'IDU', 'IXJ', 'FGD', 'EWT', 'SCHF', 'MUB', 'PHO', 'FDL', 'AIA', 'XLY', 'FBT', 'DTD', 'FPX']
# # TRAIN+VAL SHARPE: 1.1254099982769843
# # TRAIN SHARPE: 1.2013909874644264
# # VAL SHARPE: 0.9507356350425938
# # BLIND SHARPE: 0.7170859840853114
# ETF_UNIVERSE = ['IGOV', 'SH', 'DEM', 'SMH', 'TFI', 'FDL', 'IDU', 'IXJ', 'SCHF', 'PHO', 'DGS', 'MUB', 'FGD', 'XLY', 'EWT', 'DTD', 'AIA']
# ETF_UNIVERSE = ['IGOV', 'SH', 'SMH', 'DEM', 'FDL', 'IXJ', 'TFI', 'IDU', 'SCHF', 'MUB', 'PHO', 'XLY', 'DGS', 'FGD', 'DTD']
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'SMH', 'IDU', 'FDL', 'TFI', 'DGS', 'SCHF', 'PHO', 'MUB', 'IXJ', 'FGD', 'DTD']
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'FDL', 'IDU', 'DGS', 'SCHF', 'TFI', 'PHO', 'FGD', 'MUB', 'DTD', 'IXJ']
# ETF_UNIVERSE = ['SH', 'IGOV', 'DEM', 'IDU', 'PHO', 'FDL', 'TFI', 'SCHF', 'IXJ', 'MUB', 'DGS', 'DTD']
# ETF_UNIVERSE = ['IGOV', 'SH', 'DEM', 'IDU', 'SCHF', 'FDL', 'PHO', 'TFI', 'IXJ', 'MUB', 'DTD', 'DGS']

# # Maximize 0.65/0.35 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'AOM', 'SMH', 'EWP', 'QQXT', 'ICLN', 'YINN', 'EWT', 'PZA', 'FIW', 'EWC', 'TMF', 'IDU', 'RPV', 'DEM', 'EDV', 'PHO', 'EFA', 'VAW', 'IXN', 'BAB', 'PXF', 'SIVR', 'FDL', 'SCZ', 'XLE', 'SPMD', 'AIA', 'PID', 'SCHF', 'EFV', 'FPX', 'IGOV', 'FGD', 'GRID', 'XLK', 'XLB', 'KBE', 'IGM', 'TFI', 'ITA', 'IBB', 'IJR', 'PDP', 'IWC', 'DTD', 'IHI', 'SHM', 'IXJ', 'VPU', 'VNQ', 'IWS', 'RWR', 'MUB', 'EXI', 'EWL', 'FXL', 'IDV', 'DGS', 'XSD', 'GSG', 'FXR', 'FNX', 'EEM', 'ICF', 'FBT', 'DVY', 'XLY', 'IOO', 'IEI', 'PWB', 'SH', 'IYJ', 'DBC', 'BWX', 'FDN', 'VSS', 'CMF', 'DIA', 'DES', 'EWG', 'SHY', 'PCY', 'MDYV', 'FXH', 'IEV', 'IWD', 'VO', 'PPA', 'EWZ', 'KRE', 'VGT', 'SOXX', 'XLF', 'RWL', 'IYG', 'IJJ', 'IGV', 'XME', 'VXF', 'ZROZ', 'MDY', 'PWV', 'VCIT', 'VGLT', 'AOR', 'VBR', 'FYX', 'RSP', 'EPI', 'QQEW', 'VTI', 'EPS', 'XLP', 'PFF', 'DLS', 'PRF', 'EWS', 'SCHA', 'VIG', 'DLN', 'SLYG', 'IUSV', 'VV', 'IWN', 'BLV', 'VGK', 'EZU', 'FVD', 'XBI', 'TECL', 'MDYG', 'NYF', 'VOX', 'PKW', 'RWK', 'USO', 'VWO', 'GVI', 'VEA', 'GSY', 'IVE', 'SPYV', 'SCHV', 'SUB', 'PGX']
# ETF_UNIVERSE = ['SMH', 'EWT', 'IGOV', 'DEM', 'EFA', 'FBT', 'FIW', 'IDU', 'SH', 'DGS', 'PHO', 'TFI', 'SCHF', 'AIA', 'EDV', 'FDL', 'RPV', 'FGD', 'XLY', 'QQXT', 'FPX', 'PID', 'EWC', 'SPMD', 'IGM', 'DTD', 'IXJ', 'SCZ', 'ITA', 'IHI', 'MUB', 'PXF', 'VPU', 'GRID', 'XLK', 'PDP', 'IXN', 'EFV', 'EXI', 'PCY', 'CMF', 'VCIT', 'SOXX', 'IWS', 'KBE', 'XLP']
# # TRAIN+VAL SHARPE: 1.1205273784296566
# # TRAIN SHARPE: 1.2596596065277965
# # VAL SHARPE: 0.7849330161769447
# # BLIND SHARPE: 1.3992462990197363
# ETF_UNIVERSE = ['SMH', 'IGOV', 'EWT', 'SH', 'FBT', 'TFI', 'DEM', 'FDL', 'DGS', 'XLY', 'SCHF', 'FIW', 'EFA', 'PDP', 'PHO', 'FGD', 'EDV', 'RPV', 'FPX', 'GRID', 'IXJ', 'MUB', 'AIA', 'EWC', 'DTD', 'IDU', 'PID', 'SPMD', 'VCIT', 'ITA', 'VPU', 'PCY', 'IHI', 'CMF', 'SOXX', 'IGM']
# ETF_UNIVERSE = ['SMH', 'DEM', 'IGOV', 'SH', 'EWT', 'FBT', 'SCHF', 'FDL', 'TFI', 'FIW', 'DGS', 'RPV', 'XLY', 'PHO', 'FGD', 'IXJ', 'EFA', 'GRID', 'PDP', 'DTD', 'IDU', 'EDV', 'PID', 'MUB', 'FPX', 'PCY', 'AIA', 'VPU', 'VCIT', 'SPMD']
# ETF_UNIVERSE = ['SMH', 'IGOV', 'DEM', 'SH', 'FBT', 'EWT', 'IXJ', 'SCHF', 'FDL', 'TFI', 'DGS', 'PHO', 'FGD', 'EFA', 'RPV', 'DTD', 'FPX', 'GRID', 'EDV', 'FIW', 'XLY', 'PID', 'MUB', 'IDU']
# ETF_UNIVERSE = ['IGOV', 'SH', 'SMH', 'DEM', 'EWT', 'TFI', 'FBT', 'SCHF', 'FDL', 'PHO', 'IXJ', 'DGS', 'MUB', 'RPV', 'FGD', 'DTD', 'IDU', 'XLY', 'FPX']
# # TRAIN+VAL SHARPE: 1.1177710947061492
# # TRAIN SHARPE: 1.199893397897611
# # VAL SHARPE: 0.9269093643564428
# # BLIND SHARPE: 0.6561511748756729
# ETF_UNIVERSE = ['DEM', 'IGOV', 'SH', 'SMH', 'TFI', 'IDU', 'PHO', 'IXJ', 'SCHF', 'EWT', 'FDL', 'DGS', 'MUB', 'FGD', 'DTD', 'XLY']
# ETF_UNIVERSE = ['SH', 'DEM', 'IGOV', 'SMH', 'FDL', 'IDU', 'TFI', 'IXJ', 'PHO', 'SCHF', 'MUB', 'DTD', 'DGS', 'XLY', 'FGD', 'EWT']

# # Maximize 0.7/0.3 train/val
# ETF_UNIVERSE = ['SH', 'IGOV', 'DEM', 'TFI', 'FDL', 'PHO', 'IDU', 'SCHF', 'IXJ', 'RPV', 'EWT', 'DTD', 'MUB', 'FGD', 'FPX', 'PDP', 'GRID', 'DGS', 'FBT', 'FIW', 'PID']
# ETF_UNIVERSE = ['IGOV', 'SH', 'IDU', 'IXJ', 'DEM', 'TFI', 'PHO', 'FDL', 'SCHF', 'RPV', 'DTD', 'FPX', 'PID', 'MUB', 'FGD', 'DGS', 'PDP', 'GRID']
# ETF_UNIVERSE = ['SH', 'IGOV', 'DEM', 'IDU', 'TFI', 'IXJ', 'PHO', 'SCHF', 'FDL', 'MUB', 'RPV', 'FPX', 'DGS', 'DTD', 'GRID']
# ETF_UNIVERSE = ['SH', 'IGOV', 'DEM', 'IDU', 'SCHF', 'PHO', 'TFI', 'IXJ', 'FDL', 'MUB', 'RPV', 'DTD', 'FPX', 'DGS']
# ETF_UNIVERSE = ['SH', 'IGOV', 'DEM', 'IDU', 'PHO', 'SCHF', 'TFI', 'MUB', 'IXJ', 'FDL', 'RPV', 'DTD', 'DGS', 'FPX']


# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['AAXJ', 'SPAB', 'AOM', 'SMH', 'EWP', 'QQXT', 'PZA', 'ICLN', 'EWT', 'FIW', 'EWC', 'YINN', 'RPV', 'EDV', 'TMF', 'IDU', 'XLE', 'PHO', 'VAW', 'DEM', 'BAB', 'IXN', 'FDL', 'EFA', 'SPMD', 'PXF', 'SIVR', 'SCZ', 'FPX', 'IJR', 'KBE', 'GRID', 'PDP', 'AIA', 'PID', 'XME', 'XLB', 'SHM', 'IHI', 'FXL', 'TFI', 'XLK', 'FGD', 'RWR', 'SCHF', 'EFV', 'ITA', 'IGOV', 'FXR', 'IWC', 'GSG', 'DTD', 'VNQ', 'EWL', 'IGM', 'DBC', 'IWS', 'MUB', 'IYJ', 'FNX', 'IXJ', 'EXI', 'VPU', 'EEM', 'XSD', 'KRE', 'SH', 'MDYV', 'IDV', 'ICF', 'DVY', 'XLY', 'IBB', 'IEI', 'VSS', 'CMF', 'IOO', 'IJJ', 'FYX', 'DIA', 'FDN', 'EWG', 'PPA', 'MDY', 'VO', 'DES', 'VBR', 'VGLT', 'PCY', 'DGS', 'RWL', 'VXF', 'EPS', 'SHY', 'FXH', 'SLYG', 'PWB', 'IWD', 'FBT', 'VCIT', 'BWX', 'IYG', 'USO', 'IGV', 'RSP', 'VGT', 'VWO', 'AOR', 'SLV', 'PFF', 'EPI', 'PWV', 'XLF', 'SCHA', 'VTI', 'ZROZ', 'DLS', 'XLP', 'IWN', 'PRF', 'IEV', 'QQEW', 'RWK', 'MDYG', 'IUSV', 'VV', 'IVE', 'PGX', 'FVD', 'XOP', 'NYF', 'SUB', 'VIG', 'DLN', 'SOXX', 'GSY', 'PKW', 'EZU', 'XBI', 'GVI', 'HYD', 'SPYV', 'BLV', 'JNK', 'EWS', 'EWZ', 'MUNI', 'SCHV']
# ETF_UNIVERSE = ['AAXJ', 'AOM', 'SMH', 'SPMD', 'YINN', 'EDV', 'QQXT', 'EWC', 'EWP', 'EWT', 'ICLN', 'IDU', 'FIW', 'RPV', 'IGOV', 'TMF', 'PHO', 'FDL', 'SH', 'DEM', 'PZA', 'PDP', 'SIVR', 'GRID', 'AIA', 'TFI', 'VAW', 'IXN', 'FXR', 'SCZ', 'MUB', 'FGD', 'PXF', 'SCHF', 'FPX', 'VPU', 'PID', 'BAB', 'KBE', 'ITA', 'XLE', 'DTD', 'EFA', 'IHI', 'FNX', 'CMF', 'PCY', 'IXJ', 'XLY', 'BWX', 'EWL', 'VGLT', 'FXL', 'SHM', 'SLYG', 'DVY', 'EXI', 'IWS', 'XLP', 'VSS', 'XLK', 'MDYV', 'VNQ', 'IGM', 'VCIT', 'DGS', 'RWL', 'AOR', 'HYD', 'FBT', 'IWC', 'IJR', 'IYJ', 'EFV', 'IUSV', 'PFF', 'DIA', 'ZROZ', 'GSY', 'FXH']
# ETF_UNIVERSE = ['SMH', 'EDV', 'EWT', 'EWC', 'IDU', 'QQXT', 'FIW', 'RPV', 'SPMD', 'PHO', 'DEM', 'FDL', 'EFA', 'KBE', 'AOM', 'IGOV', 'PZA', 'AIA', 'PXF', 'FPX', 'IGM', 'PDP', 'IHI', 'FBT', 'SCZ', 'PID', 'VAW', 'FGD', 'GRID', 'XLY', 'VPU', 'DTD', 'SCHF', 'IJR', 'DGS', 'ITA', 'XLK', 'EWP', 'IWS', 'EXI', 'VNQ', 'TFI', 'IXJ', 'SH', 'IYJ', 'IXN', 'DVY', 'MUB', 'DIA', 'EFV', 'VSS', 'TMF', 'IWC', 'FXH', 'RWL', 'SLYG', 'PCY', 'MDYV', 'SHM', 'PFF', 'FXL', 'BAB', 'XLP', 'EWL', 'VCIT']
# ETF_UNIVERSE = ['SMH', 'EWC', 'EWT', 'FIW', 'EDV', 'FDL', 'RPV', 'IGOV', 'SH', 'SLYG', 'TFI', 'PHO', 'DEM', 'PDP', 'TMF', 'IDU', 'GRID', 'FBT', 'SCHF', 'XLY', 'QQXT', 'FPX', 'KBE', 'PXF', 'PID', 'FGD', 'IGM', 'ITA', 'MUB', 'DTD', 'SHM', 'VAW', 'AIA', 'SCZ', 'DGS', 'VPU', 'XLK', 'IXJ', 'BAB', 'EFA', 'IHI', 'VSS', 'EXI', 'VCIT', 'PCY', 'IWS', 'MDYV', 'IXN']
# # TRAIN+VAL SHARPE: 1.1171731683882977
# # TRAIN SHARPE: 1.3692849542761667
# # VAL SHARPE: 0.49312722420732485
# # BLIND SHARPE: 0.8386628284531741
# ETF_UNIVERSE = ['SMH', 'SH', 'FDL', 'EWT', 'IGOV', 'TFI', 'FIW', 'PDP', 'XLY', 'FBT', 'EWC', 'RPV', 'EDV', 'PHO', 'DEM', 'SLYG', 'GRID', 'SCHF', 'DGS', 'EFA', 'FPX', 'MUB', 'IHI', 'FGD', 'SHM', 'DTD', 'VCIT', 'IXJ', 'ITA', 'VPU', 'PID', 'KBE']
# ETF_UNIVERSE = ['SMH', 'SH', 'DEM', 'IGOV', 'FIW', 'TFI', 'FDL', 'SCHF', 'VPU', 'RPV', 'EWT', 'PHO', 'GRID', 'PDP', 'EDV', 'MUB', 'FBT', 'IHI', 'DGS', 'FGD', 'DTD', 'IXJ', 'FPX', 'VCIT', 'XLY', 'SHM', 'PID']
# # TRAIN+VAL SHARPE: 1.1355394794802316
# # TRAIN SHARPE: 1.346392558422455
# # VAL SHARPE: 0.6330612847866611
# # BLIND SHARPE: 1.2421845065713686
# ETF_UNIVERSE = ['SMH', 'SH', 'DEM', 'IGOV', 'FDL', 'EWT', 'TFI', 'PHO', 'FIW', 'SCHF', 'VPU', 'GRID', 'IHI', 'RPV', 'XLY', 'EDV', 'IXJ', 'FBT', 'MUB', 'FGD', 'DTD', 'PDP', 'FPX', 'DGS', 'VCIT']
# # TRAIN+VAL SHARPE: 1.096383671841225
# # TRAIN SHARPE: 1.269911040994614
# # VAL SHARPE: 0.6816772777870155
# # BLIND SHARPE: 1.2403027388341565
# ETF_UNIVERSE = ['SMH', 'SH', 'IGOV', 'TFI', 'PHO', 'DEM', 'FDL', 'EWT', 'SCHF', 'FIW', 'IXJ', 'RPV', 'VPU', 'GRID', 'MUB', 'XLY', 'DTD', 'PDP', 'FGD', 'FPX']
# # TRAIN+VAL SHARPE: 1.0850592971627375
# # TRAIN SHARPE: 1.2358689019683524
# # VAL SHARPE: 0.7237803166754373
# # BLIND SHARPE: 1.3144461659226307
# ETF_UNIVERSE = ['SMH', 'SH', 'IGOV', 'TFI', 'DEM', 'EWT', 'FDL', 'PHO', 'SCHF', 'IXJ', 'MUB', 'XLY', 'DTD', 'VPU', 'FGD', 'RPV', 'PDP', 'FPX']
# # TRAIN+VAL SHARPE: 1.0883294401534642
# # TRAIN SHARPE: 1.2216905417890964
# # VAL SHARPE: 0.7675187743900513
# # BLIND SHARPE: 1.1456249345168918
# ETF_UNIVERSE = ['SMH', 'DEM', 'SH', 'IGOV', 'TFI', 'PHO', 'EWT', 'FDL', 'SCHF', 'MUB', 'IXJ', 'XLY', 'DTD', 'FPX', 'FGD', 'RPV', 'VPU']
# ETF_UNIVERSE = ['DEM', 'SMH', 'SH', 'IGOV', 'TFI', 'EWT', 'PHO', 'FDL', 'SCHF', 'MUB', 'IXJ', 'XLY', 'FPX', 'DTD', 'RPV', 'FGD', 'VPU']

# =========================
# SIGNAL BURSTINESS -- PICKED
# =========================
# # Maximize 0.35/0.65 train/val
# ETF_UNIVERSE = ['AIA', 'IAU', 'XSD', 'EWY', 'EWT', 'YINN', 'XHB', 'EWZ', 'IGV', 'VPU', 'ITB', 'FNX', 'FDN', 'TECL', 'DVY', 'EPP', 'DHS', 'ICLN', 'IYF', 'IYC', 'FIW', 'FPX', 'UYG', 'EWS', 'RWK', 'XLF', 'FVD', 'VUG', 'RWL', 'RWJ', 'UPRO', 'IDU', 'SLYV', 'VGT', 'XLU', 'AAXJ', 'SCZ', 'BIV', 'SPMD', 'IWY', 
# # best
# # TRAIN+VAL SHARPE: 1.0795390094873185
# # TRAIN SHARPE: 1.0997746451244323
# # VAL SHARPE: 1.042510827673166
# # BLIND SHARPE: 1.3785725079925573
# ETF_UNIVERSE = ['VPU', 'SH', 'XSD', 'IGV', 'FDN', 'FPX', 'EPP', 'IYC', 'VUG', 'AIA', 'VCLT', 'GLD', 'BWX', 'FVD', 'RWL', 'EDV', 'IGOV', 'DVY', 'IWY', 'HEDJ', 'SHM', 'FNX', 'GSY', 'BIL', 'SHY']
# ETF_UNIVERSE = ['IGV', 'VPU', 'SH', 'FPX', 'FDN', 'XSD', 'VUG', 'EPP', 'IYC', 'EDV', 'GLD', 'VCLT', 'FVD', 'BWX', 'DVY', 'IGOV', 'RWL', 'FNX', 'GSY', 'AIA', 'SHM', 'BIL']
# ETF_UNIVERSE = ['FPX', 'SH', 'IGV', 'FDN', 'VPU', 'EPP', 'XSD', 'VUG', 'EDV', 'GLD', 'IYC', 'FVD', 'BWX', 'VCLT', 'SHM', 'IGOV', 'AIA', 'DVY', 'GSY', 'BIL']
# ETF_UNIVERSE = ['SH', 'FPX', 'VPU', 'FDN', 'GLD', 'EDV', 'IGV', 'VUG', 'EPP', 'XSD', 'FVD', 'BWX', 'IYC', 'VCLT', 'SHM', 'DVY', 'AIA', 'IGOV', 'GSY', 'BIL']

# # # Maximize 0.45/0.55 train/val
# ETF_UNIVERSE = ['IAU', 'AIA', 'XSD', 'XHB', 'FNX', 'ITB', 'YINN', 'IGV', 'DVY', 'EWZ', 'ICLN', 'EWY', 'DHS', 'VPU', 'EWT', 'FDN', 'IYF', 'TECL', 'RWK', 'XLF', 'RWL', 'UYG', 'FIW', 'EPP', 'EWS', 'IYC', 'SPMD', 'IDU', 'FVD', 'BIV', 'AAXJ', 'USO', 'VUG', 'EDV', 'FPX', 'IYR', 'PGX', 'VGT', 'UPRO', 'RWJ', 'EWL', 'SLYV', 'VCR', 'XLU', 'SCZ', 'VDE', 'GLD', 'XLY', 'FGD', 'SMH', 'VT', 'XBI', 'PZA', 'TLT', 'EFA', 'XLG', 'VFH', 'IWY', 'IVW', 'KRE', 'XLP', 'EWA', 'XLK', 'FDL', 'VCLT', 'BWX', 'HEDJ', 'SPYG', 'EXI', 'EZU', 'IJS', 'IYW', 'MGV', 'RPV', 'FEZ', 'IUSG', 'EWU', 'SHM', 'VTV', 'MDYV', 'PEY', 'VBR', 'IGOV', 'FXI', 'PXH', 'VEA', 'IXN', 'EWP', 'VIG', 'VNQ', 'SCHG', 'ACWI', 'IWF', 'IEV', 'DXJ', 'BLV', 'ZROZ', 'BAB', 'IVV', 'IWD', 'AOR', 'GSG', 'DGS', 'IGF', 'SH', 'IYG', 'VTI', 'SDY', 'FXL', 'SCHX', 'SCHF', 'EPI', 'VGK', 'FXR', 'FYX', 'SOXX', 'GSY', 'IWS', 'OEF', 'XME', 'IWC', 'EFV', 'ITM', 'VV', 'NYF', 'SHY', 'EWC', 'BSV', 'DLN', 'HYD', 'AOA', 'VYM', 'IYY', 'IWL', 'IVE', 'BIL', 'DEM', 'FEX', 'SUB', 'LQD']
# ETF_UNIVERSE = ['IGV', 'EDV', 'DHS', 'RWL', 'FPX', 'FDN', 'DVY', 'VPU', 'FVD', 'XSD', 'EPP', 'VUG', 'FNX', 'SH', 'RWK', 'AIA', 'SHM', 'PGX', 'VGT', 'ICLN', 'BWX', 'VCLT', 'SLYV', 'IGOV', 'IWY', 'IYC', 'FIW', 'EWL', 'XLP', 'IVW', 'BIV', 'HEDJ', 'GLD', 'XBI', 'BIL', 'YINN']
# # # best
# # TRAIN+VAL SHARPE: 1.1940481667463931
# # TRAIN SHARPE: 1.2850205352922761
# # VAL SHARPE: 1.0013595345076325
# # BLIND SHARPE: 1.2786351254661885
# ETF_UNIVERSE = ['IGV', 'EDV', 'EPP', 'VPU', 'FDN', 'FVD', 'DHS', 'RWL', 'XSD', 'FPX', 'VUG', 'SH', 'DVY', 'PGX', 'RWK', 'VCLT', 'EWL', 'SHM', 'VGT', 'BWX', 'GLD', 'SLYV', 'FNX', 'IGOV', 'IWY', 'XLP', 'IVW', 'FIW', 'IYC', 'HEDJ', 'BIV', 'BIL']
# ETF_UNIVERSE = ['XSD', 'IGV', 'EPP', 'EDV', 'SH', 'VPU', 'FDN', 'DHS', 'DVY', 'FVD', 'FPX', 'RWL', 'BWX', 'VUG', 'EWL', 'VCLT', 'BIV', 'SHM', 'IGOV', 'PGX', 'SLYV', 'FIW', 'HEDJ', 'BIL', 'RWK', 'GLD', 'IYC']
# ETF_UNIVERSE = ['XSD', 'IGV', 'EDV', 'SH', 'FDN', 'EPP', 'FPX', 'VPU', 'VUG', 'DHS', 'FVD', 'BWX', 'RWL', 'VCLT', 'GLD', 'EWL', 'DVY', 'IGOV', 'IYC', 'SHM', 'BIV', 'PGX', 'BIL']
# # TRAIN+VAL SHARPE: 1.0833754437009973
# # TRAIN SHARPE: 1.062526458366024
# # VAL SHARPE: 1.1399547169962132
# # BLIND SHARPE: 1.1024780712208349
# ETF_UNIVERSE = ['XSD', 'EDV', 'SH', 'FDN', 'IGV', 'FPX', 'VPU', 'EPP', 'RWL', 'VUG', 'BWX', 'GLD', 'VCLT', 'FVD', 'DVY', 'DHS', 'IGOV', 'BIV', 'SHM', 'EWL', 'IYC', 'BIL']
# ETF_UNIVERSE = ['XSD', 'SH', 'IGV', 'EDV', 'FDN', 'FPX', 'EPP', 'VPU', 'RWL', 'DVY', 'BWX', 'VUG', 'FVD', 'GLD', 'VCLT', 'IGOV', 'DHS', 'IYC', 'EWL', 'SHM', 'BIV', 'BIL']

# # # Maximize 0.55/0.45 train/val
# ETF_UNIVERSE = ['IAU', 'FNX', 'AIA', 'XHB', 'ITB', 'ICLN', 'DVY', 'DHS', 'IGV', 'XSD', 'YINN', 'RWK', 'IYF', 'XLF', 'RWL', 'EWZ', 'VPU', 'SPMD', 'UYG', 'FDN', 'USO', 'BIV', 'AAXJ', 'TECL', 'IDU', 'EDV', 'FIW', 'EWS', 'IYR', 'FVD', 'IYC', 'EWT', 'PGX', 'EWY', 'VCR', 'TLT', 'VFH', 'EWL', 'XBI', 'VDE', 'KRE', 'EPP', 'VUG', 'PZA', 'XLY', 'VGT', 'VT', 'GLD', 'XLG', 'FGD', 'FDL', 'SMH', 'SCZ', 
# ETF_UNIVERSE = ['EDV', 'VPU', 'IGV', 'DVY', 'RWL', 'SH', 'DHS', 'FVD', 'FDN', 'RWK', 'VUG', 'FPX', 'BWX', 'AAXJ', 'XSD', 'SHM', 'EWL', 'SLYV', 'IGOV', 'VCLT', 'EPP', 'PGX', 'BIL', 'VGT']
# ETF_UNIVERSE = ['EDV', 'VPU', 'IGV', 'SH', 'FDN', 'DHS', 'RWL', 'DVY', 'FVD', 'FPX', 'VUG', 'BWX', 'RWK', 'XSD', 'SHM', 'SLYV', 'IGOV', 'AAXJ', 'EWL', 'VCLT', 'PGX', 'VGT', 'BIL']
# ETF_UNIVERSE = ['VPU', 'EDV', 'IGV', 'FVD', 'SH', 'DVY', 'RWL', 'FDN', 'VUG', 'DHS', 'FPX', 'VGT', 'BWX', 'SHM', 'XSD', 'RWK', 'AAXJ', 'IGOV', 'VCLT', 'SLYV', 'EWL', 'BIL']
# ETF_UNIVERSE = ['VPU', 'EDV', 'IGV', 'DVY', 'FVD', 'SH', 'DHS', 'FPX', 'VUG', 'RWL', 'FDN', 'SHM', 'BWX', 'VGT', 'RWK', 'AAXJ', 'IGOV', 'XSD', 'SLYV', 'EWL', 'BIL']
# ETF_UNIVERSE = ['VPU', 'EDV', 'DVY', 'IGV', 'FVD', 'FPX', 'SH', 'RWL', 'DHS', 'VUG', 'FDN', 'BWX', 'VGT', 'RWK', 'SHM', 'IGOV', 'AAXJ', 'XSD', 'SLYV', 'BIL']
# ETF_UNIVERSE = ['EDV', 'VPU', 'IGV', 'FVD', 'DVY', 'VUG', 'SH', 'FPX', 'VGT', 'RWL', 'SHM', 'DHS', 'FDN', 'BWX', 'IGOV', 'RWK', 'AAXJ', 'XSD', 'BIL']
# ETF_UNIVERSE = ['EDV', 'VPU', 'IGV', 'FVD', 'DVY', 'SH', 'VUG', 'FPX', 'VGT', 'RWL', 'SHM', 'BWX', 'DHS', 'FDN', 'IGOV', 'RWK', 'AAXJ', 'BIL']
# ETF_UNIVERSE = ['VPU', 'EDV', 'IGV', 'FVD', 'VUG', 'VGT', 'SH', 'DVY', 'FPX', 'RWL', 'SHM', 'BWX', 'DHS', 'IGOV', 'FDN', 'RWK', 'AAXJ', 'BIL']

# =========================
# SIGNAL SIGNED VOLUME AGREEMENT -- PICKED
# =========================
# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['IAU', 'UPRO', 'TECL', 'PZA', 'VDE', 'FTA', 'XOP', 'FXL', 'IYR', 'SPXL', 'FNX', 'IGV', 'PID', 'ROM', 'VBK', 'SPMD', 'VCR', 'ITA', 'RWL', 'IYE', 'GSG', 'XSD', 'XLK', 'SMH', 'TNA', 'VBR', 'PDP', 'MDY', 'EWT', 'BAB', 'GDXJ', 'VGT', 'RWO', 'RWJ', 'IWP', 'XHB', 'SCHB', 'RWR', 'IWC', 'IJS', 'QQEW', 'IWS', 'QQQ', 'ICF', 'IGM', 'RSP', 'XLP', 'IWN', 'VYM', 'FTCS', 'IAI', 'IBB', 'SPY', 'FXO', 'AGQ', 'KRE', 'QQXT', 'XLY', 
# ETF_UNIVERSE = ['FTA', 'FXL', 'PZA', 'VBK', 'GSG', 'SPMD', 'VDE', 'PID', 'TECL', 'CMF', 'RWL', 'IGV', 'SHM', 'XSD', 'MDY', 'TIP', 'PDP', 'XLP', 'UPRO', 'GDXJ', 'VCR', 'ITA', 'BLV', 'XOP', 'BND', 'FTCS', 'SCHB', 'EMB', 'VCIT', 'MUB', 'ITM', 'TFI', 'PWZ', 'IGM', 'GVI', 'VCSH', 'AOR', 'NYF', 'IWC', 'BSV', 'SPHQ', 'SPYV', 'SHV']
# # best
# # TRAIN+VAL SHARPE: 1.4516648723758816
# # TRAIN SHARPE: 1.4691088702298263
# # VAL SHARPE: 1.4252079178826962
# # BLIND SHARPE: 0.34293862121843377
# ETF_UNIVERSE = ['VBK', 'FTA', 'FXL', 'GSG', 'IGV', 'MDY', 'SPMD', 'PID', 'RWL', 'UPRO', 'XLP', 'VCR', 'XOP', 'XSD', 'GDXJ', 'VDE', 'TIP', 'PDP', 'CMF', 'SHM', 'IGM', 'TECL', 'BLV', 'BND', 'FTCS', 'EMB', 'VCIT', 'MUB', 'SCHB', 'ITA', 'ITM', 'GVI', 'TFI', 'PWZ', 'BSV', 'VCSH', 'NYF', 'PZA', 'SPHQ', 'SHV', 'AOR']
# ETF_UNIVERSE = ['FTA', 'VBK', 'FXL', 'GSG', 'IGV', 'PID', 'SPMD', 'RWL', 'MDY', 'XSD', 'GDXJ', 'UPRO', 'VCR', 'XLP', 'XOP', 'PDP', 'SHM', 'TIP', 'VDE', 'CMF', 'IGM', 'PZA', 'BLV', 'BND', 'FTCS', 'EMB', 'TECL', 'VCIT', 'MUB', 'ITM', 'SCHB', 'GVI', 'ITA', 'TFI', 'PWZ', 'BSV', 'VCSH', 'NYF', 'SHV', 'SPHQ']
# ETF_UNIVERSE = ['FTA', 'VBK', 'FXL', 'GSG', 'IGV', 'SPMD', 'PID', 'MDY', 'RWL', 'XSD', 'UPRO', 'VCR', 'GDXJ', 'XLP', 'PDP', 'SHM', 'XOP', 'TIP', 'CMF', 'VDE', 'IGM', 'PZA', 'BND', 'BLV', 'TECL', 'FTCS', 'EMB', 'VCIT', 'ITM', 'MUB', 'SCHB', 'ITA', 'GVI', 'TFI', 'PWZ', 'BSV', 'VCSH', 'NYF', 'SHV', 'SPHQ']

# # Maximize 0.7/0.3 train/val
# ETF_UNIVERSE = ['IAU', 'PZA', 'SPMD', 'IGV', 'VBK', 'FXL', 'UPRO', 'IYR', 'GSG', 'FTA', 'VDE', 'TECL', 'IYE', 'IWC', 'SPXL', 'FAS', 'VCR', 'RWJ', 'TNA', 'PID', 'FNX', 'IYG', 'BAB', 'RWL', 'MDY', 'IAI', 'IBB', 'XHB', 'FXO', 'PDP', 'AGQ', 'XOP', 'ICF', 'XLK', 'SMH', 'ITA', 'QQEW', 'RSP', 'EWT', 'XLP', 'IWP', 'VGT', 'IYK', 'VYM', 'IXN', 'IGM', 'FEX', 'IWN', 'XSD', 'SCHB',
# ETF_UNIVERSE = ['SPMD', 'PZA', 'FTA', 'GSG', 'FXL', 'VBK', 'TECL', 'IGV', 'VDE', 'SHM', 'XSD', 'CMF', 'IWC', 'MDY', 'ITA', 'XLP', 'IBB', 'UPRO', 'SCHB', 'TIP', 'VDC', 'HEDJ', 'AOR', 'PDP', 'IWN', 'SPYV', 'SPXL', 'FTCS', 'MUB', 'VCR', 'PWZ', 'NYF', 'BLV', 'TFI', 'BND', 'EMB', 'IEF', 'VYM', 'MGC', 'PID', 'VCIT', 'ITM', 'SPHQ', 'VCSH', 'VGT', 'IUSV', 'SPYG', 'GDXJ', 'IYR', 'BSV', 'GVI', 'SHV', 'SHY', 'FXO']
# ETF_UNIVERSE = ['FTA', 'GSG', 'VBK', 'SPMD', 'FXL', 'PZA', 'MDY', 'SHM', 'TECL', 'CMF', 'IWC', 'IBB', 'TIP', 'IGV', 'UPRO', 'XLP', 'HEDJ', 'ITA', 'FXO', 'AOR', 'VCR', 'PID', 'PDP', 'VDC', 'SCHB', 'NYF', 'XSD', 'MUB', 'FTCS', 'VDE', 'IEF', 'PWZ', 'BLV', 'GDXJ', 'TFI', 'SPYV', 'BND', 'VYM', 'EMB', 'VCIT', 'ITM', 'MGC', 'VCSH', 'SPXL', 'SPYG', 'BSV', 'GVI', 'SHV', 'IUSV']
# ETF_UNIVERSE = ['FTA', 'GSG', 'VBK', 'SPMD', 'FXL', 'MDY', 'PZA', 'IBB', 'SHM', 'IGV', 'TECL', 'CMF', 'UPRO', 'TIP', 'XLP', 'XSD', 'VDC', 'HEDJ', 'VYM', 'IWC', 'PDP', 'VCR', 'ITA', 'PID', 'SCHB', 'AOR', 'VDE', 'MUB', 'NYF', 'FTCS', 'FXO', 'PWZ', 'BLV', 'BND', 'TFI', 'SPYV', 'EMB', 'VCIT', 'ITM', 'VCSH', 'SPYG', 'BSV', 'IEF', 'MGC', 'SHV', 'GVI', 'SPXL']
# ETF_UNIVERSE = ['FTA', 'GSG', 'SPMD', 'VBK', 'FXL', 'MDY', 'SHM', 'TECL', 'IBB', 'IGV', 'PZA', 'CMF', 'UPRO', 'TIP', 'XLP', 'VDC', 'HEDJ', 'XSD', 'VCR', 'VYM', 'ITA', 'PDP', 'IWC', 'PID', 'SCHB', 'AOR', 'MUB', 'NYF', 'FTCS', 'FXO', 'VDE', 'BLV', 'PWZ', 'BND', 'TFI', 'SPYV', 'SPXL', 'VCIT', 'ITM', 'VCSH', 'EMB', 'MGC', 'SPYG', 'BSV', 'SHV', 'GVI', 'IEF']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['IAU', 'PZA', 'SPMD', 'VBK', 'IGV', 'FXL', 'GSG', 'IYR', 'UPRO', 'FAS', 'IYE', 'FTA', 'IWC', 'IYG', 'VDE', 'TECL', 'RWJ', 'TNA', 'SPXL', 'BAB', 'VCR', 'IAI', 'IBB', 'FXO', 'MDY', 'PID', 'FNX', 'XHB', 'AGQ', 'RWL', 'PDP', 'ICF', 'XLK', 'RSP', 'QQEW', 'SMH
# ETF_UNIVERSE = ['VBK', 'GSG', 'FTA', 'FXL', 'SPMD', 'SHM', 'IBB', 'PZA', 'MDY', 'TECL', 'IWC', 'UPRO', 'CMF', 'MGC', 'XLP', 'FXO', 'IGV', 'TIP', 'HEDJ', 'VDC', 'PDP', 'XHB', 'SCHB', 'VDE', 'AOR', 'MUB', 'SPXL', 'NYF', 'VCR', 'BLV', 'SPYG', 'QQEW', 'PWZ', 'SPYV', 'FTCS', 'XSD', 'VCSH', 'IEF', 'TFI', 'VCIT', 'BND', 'EMB', 'ITA', 'BSV', 'SHV', 'GVI', 'IUSV']
# ETF_UNIVERSE = ['VBK', 'GSG', 'FTA', 'SPMD', 'FXL', 'IBB', 'MDY', 'SHM', 'IGV', 'UPRO', 'CMF', 'TECL', 'TIP', 'XLP', 'IWC', 'HEDJ', 'VDC', 'QQEW', 'XHB', 'PDP', 'FXO', 'AOR', 'VCR', 'SCHB', 'MUB', 'NYF', 'MGC', 'XSD', 'ITA', 'VDE', 'BLV', 'PZA', 'SPYG', 'SPXL', 'PWZ', 'SPYV', 'IEF', 'FTCS', 'VCSH', 'TFI', 'BND', 'VCIT', 'EMB', 'BSV', 'SHV', 'GVI', 'IUSV']

# =========================
# SIGNAL CONFLICT -- PICKED
# =========================
# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['AGQ', 'AIA', 'SLV', 'SIVR', 'EWW', 'DXJ', 'ILF', 'EWZ', 'PXH', 'CQQQ', 'NLR', 'GRID', 'TECL', 'VWO', 'AOM', 'VPL', 'VFH', 'EPP', 'EWS', 'EXI', 'EWY', 'IAI', 'SSO', 'IHI', 'VT', 'IOO', 'PZA', 'EWU', 'DEM', 'GLD', 'VAW', 'EWP', 'PDP', 'IDV', 'IWR', 'ITM', 'VV', 'UYG', 'EWT', 'VTI', 'IYW', 'ICLN', 'VCR', 'AOR', 'DSI', 'SPY', 'EZU', 'VEA', 'EWL', 'IYK', 'IXJ', 'EWG', 'VGK', 'EPI', 'XLF', 'QLD', 'XLP', 'ACWX', 'IVW', 'SCHF', 'IYF', 'SCHG', 'IVV', 'PGX', 'VO', 'BAB', 'XLU', 'ONEQ', 'IYJ', 'IYY', 'VHT', 'VEU', 'IYH', 'PPA', 'PFF', 'SCZ', 'MGK', 'RWR', 'CWI', 'SPYG', 'XBI', 'FXR', 'PCY', 'IWL', 'TFI', 'EPS', 'FDN', 'VUG', 'CGW', 'IWP', 'VPU', 'OEF', 'RPG', 'GVI', 'IVE', 'MGV', 'IJJ', 'HYG', 'MGC', 'ZROZ', 'IWD', 'HYD', 'AAXJ', 'NYF', 'DLS', 'GSY', 'IWV', 'TLH', 'DLN', 'IWY', 'VIS', 'IYG', 'FNX', 'SHM', 'VGT', 'IUSG', 'GDXJ', 'IWM',
# ETF_UNIVERSE = ['CQQQ', 'AGQ', 'AOR', 'IWR', 'XLP', 'GVI', 'HYG', 'ITM', 'PGX', 'NYF', 'GSY', 'SHY', 'TLH', 'QQXT', 'SPY', 'VGSH', 'SHV', 'BIL', 'ICLN', 'MBB']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'AGQ', 'GSY', 'GVI', 'NYF', 'ITM', 'PGX', 'IWR', 'HYG', 'TLH', 'SHY', 'XLP', 'VGSH', 'SHV', 'MBB', 'BIL']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'IWR', 'GVI', 'GSY', 'TLH', 'NYF', 'HYG', 'ITM', 'PGX', 'SHY', 'XLP', 'VGSH', 'SHV', 'BIL', 'MBB']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'NYF', 'GSY', 'ITM', 'SHY', 'HYG', 'TLH', 'VGSH', 'SHV', 'BIL', 'MBB']
# # TRAIN+VAL SHARPE: 0.9285663310703817
# # TRAIN SHARPE: 0.7558290578438656
# # VAL SHARPE: 1.3112328271469573
# # BLIND SHARPE: -0.2118098709913912
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'HYG', 'NYF', 'ITM', 'GSY', 'SHY', 'VGSH', 'SHV', 'BIL']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'NYF', 'GSY', 'HYG', 'ITM', 'SHY', 'VGSH', 'SHV', 'BIL']

# # Maximize 0.55/0.45 train/val
# ETF_UNIVERSE = ['AGQ', 'AIA', 'SLV', 'DXJ', 'EWW', 'SIVR', 'ILF', 'EWZ', 'PXH', 'CQQQ', 'VWO', 'NLR', 'GRID', 'TECL', 'AOM', 'VPL', 'EWY', 'IHI', 'SSO', 'EWS', 'VFH', 'EPP', 'IAI', 'IOO', 'PZA', 'EWU', 'ITM', 'VT', 'IWR', 'EXI', 'EWT', 'VV', 'VTI', 'GLD', 'DEM', 'UYG', 'PDP', 'VCR', 'ICLN', 'IDV', 'VAW', 'IXJ', 'IYK', 'SPY', 'EWG', 'QLD', 'DSI', 'IYW', 'SCHF', 'AOR', 'XLP', 'IYJ', 'IYF', 'EWP', 'EWL', 'XLF', 'VGK', 'IVV', 'IVW', 'RWR', 'VEA', 'IYY', 'VO', 'SCHG', 'ACWX', 'XLU', 'CWI', 'EZU', 'PGX', 'EPI', 'PCY', 'VHT', 'VEU', 'ONEQ', 'BAB', 'XBI', 'PFF', 'FDN', 'MGK', 'PPA', 'SCZ', 'IYH', 'SPYG', 'VUG', 'VPU', 'IWD', 'IWL', 'OEF', 'TFI', 'FTA', 'IJJ', 'VNQ', 'CGW', 'IVE', 'MGV', 'EPS', 'IWP', 'HYG', 'GVI', 'IGF', 'HYD', 'NYF', 'DLN', 'RPG', 'ZROZ', 'IWV', 'MGC', 'FVD', 'GSY', 'SHM', 'EEM', 'TL
# ETF_UNIVERSE = ['CQQQ', 'AGQ', 'TECL', 'AOR', 'XLP', 'ITM', 'IWR', 'EWW', 'SPY', 'IHI', 'HYG', 'QQXT', 'PGX', 'IYH', 'IVW', 'GVI', 'VPL', 'GSY', 'NYF', 'XLU', 'HYD', 'SLV', 'TFI', 'TLH', 'SHY', 'JNK', 'SHV', 'MBB', 'FDN', 'BIL', 'BSV', 'VGSH', 'VCSH']
# ETF_UNIVERSE = ['CQQQ', 'TECL', 'IWR', 'AOR', 'XLP', 'AGQ', 'SPY', 'IHI', 'HYG', 'ITM', 'PGX', 'GVI', 'QQXT', 'IVW', 'NYF', 'XLU', 'GSY', 'FDN', 'IYH', 'HYD', 'TLH', 'SHY', 'TFI', 'SHV', 'BSV', 'BIL', 'JNK', 'MBB', 'VGSH', 'VCSH']
# ETF_UNIVERSE = ['CQQQ', 'IWR', 'AOR', 'XLP', 'ITM', 'HYG', 'GVI', 'PGX', 'QQXT', 'GSY', 'NYF', 'AGQ', 'TFI', 'TLH', 'XLU', 'SHY', 'BSV', 'TECL', 'SHV', 'MBB', 'BIL', 'VGSH']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'IWR', 'GSY', 'ITM', 'XLP', 'GVI', 'HYG', 'TFI', 'PGX', 'NYF', 'SHY', 'TLH', 'TECL', 'QQXT', 'XLU', 'BSV', 'SHV', 'MBB', 'BIL', 'VGSH']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'IWR', 'ITM', 'GSY', 'GVI', 'HYG', 'PGX', 'XLP', 'TFI', 'SHY', 'NYF', 'TLH', 'BSV', 'MBB', 'SHV', 'VGSH', 'BIL']
# # TRAIN+VAL SHARPE: 1.0388102162994288
# # TRAIN SHARPE: 1.0170838438096452
# # VAL SHARPE: 1.1273272104285559
# # BLIND SHARPE: -0.04396518638068364
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'TFI', 'GVI', 'ITM', 'GSY', 'SHY', 'NYF', 'HYG', 'PGX', 'SHV', 'TLH', 'VGSH', 'BSV', 'BIL', 'MBB']
# # TRAIN+VAL SHARPE: 0.961644103732109
# # TRAIN SHARPE: 0.8887980180333818
# # VAL SHARPE: 1.1720774751418173
# # BLIND SHARPE: -0.1796759150233972
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'TFI', 'HYG', 'ITM', 'SHY', 'NYF', 'GSY', 'PGX', 'SHV', 'VGSH', 'BIL', 'BSV']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'TFI', 'HYG', 'SHY', 'GSY', 'ITM', 'NYF', 'PGX', 'VGSH', 'SHV', 'BIL', 'BSV']

# # Maximize 0.6/0.4 train/val
# ETF_UNIVERSE = ['CQQQ', 'QQXT', 'IWR', 'AOR', 'HYG', 'ITM', 'TECL', 'TLH', 'XLP', 'GVI', 'NYF', 'TFI', 'GSY', 'SHY', 'PGX', 'IHI', 'BND', 'BSV', 'VCIT', 'SHV', 'MBB', 'VGSH', 'BIL', 'VCSH']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'ITM', 'HYG', 'GVI', 'QQXT', 'TFI', 'NYF', 'TLH', 'SHY', 'XLP', 'PGX', 'GSY', 'BND', 'IWR', 'VCIT', 'BSV', 'MBB', 'SHV', 'BIL', 'VGSH', 'VCSH']
# ## best
# # TRAIN+VAL SHARPE: 1.0522845870860582
# # TRAIN SHARPE: 1.0371878096433715
# # VAL SHARPE: 1.1267630938570556
# # BLIND SHARPE: 0.00802429081560227
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'ITM', 'TFI', 'HYG', 'NYF', 'GSY', 'SHY', 'PGX', 'TLH', 'SHV', 'BSV', 'MBB', 'VGSH', 'BIL', 'BND', 'VCSH']
# TRAIN+VAL SHARPE: 1.038810216299429
# TRAIN SHARPE: 1.0170838438096452
# VAL SHARPE: 1.1273272104285559
# BLIND SHARPE: -0.0439651863806836
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'HYG', 'TFI', 'ITM', 'SHY', 'NYF', 'PGX', 'GSY', 'TLH', 'SHV', 'BIL', 'VGSH', 'BSV', 'MBB']
# # TRAIN+VAL SHARPE: 0.9500345373368065
# # TRAIN SHARPE: 0.8678680682374191
# # VAL SHARPE: 1.1901683457599674
# # BLIND SHARPE: -0.14975279586032084
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'TFI', 'HYG', 'ITM', 'SHY', 'NYF', 'GSY', 'PGX', 'SHV', 'VGSH', 'BSV', 'BIL', 'MBB']
# ETF_UNIVERSE = ['CQQQ', 'AOR', 'GVI', 'TFI', 'HYG', 'ITM', 'SHY', 'NYF', 'GSY', 'PGX', 'VGSH', 'SHV', 'BIL', 'BSV', 'MBB']

# # Maximize 0.625/0.375 train/val
# ETF_UNIVERSE = ['AGQ', 'AIA', 'DXJ', 'EWW', 'SLV', 'ILF', 'PXH', 'SIVR', 'EWZ', 'CQQQ', 'VWO', 'AOM', 'GRID', 'IHI', 'SSO', 'NLR', 'TECL', 'EWY', 'VPL', 'IOO', 'PZA', 'EWU', 'EWS', 'ITM', 'VFH', 'IWR', 'EPP', 'VTI', 'VV', 'IAI', 'VT', 'RWR', 'IYK', 'UYG', 'QLD', 'VCR', 'PDP', 'GLD', 'IXJ', 'EWT', 'SPY', 'EWG', 'ICLN', 'XLP', 'IDV', 'DSI', 'DEM', 'IVV', 'VNQ', 'IYF', 'IYW', 'VAW', 'SCHF', 'VO', 'IYY', 'IYJ', 'XLF', 'EWL', 'IVW', 'VGK', 'XLU', 'PCY', 'AOR', 'EWP', 'EXI', 'FDN', 'CWI', 'FTA', 'IWD', 'SCHG', 'PGX', 'XBI', 'VEU', 'ONEQ', 'SCZ', 'PFF', 'VHT', 'EZU', 'ACWX', 'VPU', 'IJJ', 'IGF', 'VUG', 'OEF', 'BAB', 'VEA
# ETF_UNIVERSE = ['ITB', 'GLD', 'USO', 'VO', 'TLT', 'RWJ', 'DBC', 'SPYV', 'XSD', 'SCHA', 'VSS', 'EMB', 'VGIT', 'SCHX', 'EFV', 'MUNI', 'ICLN', 'PWZ', 'PCY', 'PKW', 'BLV', 'VCSH', 'XBI', 'MINT']
# # TRAIN+VAL SHARPE: 1.4132170457799096
# # TRAIN SHARPE: 1.4096586980585057
# # VAL SHARPE: 1.4589421350645413
# # BLIND SHARPE: 0.1510609384309174
# ETF_UNIVERSE = ['GLD', 'ITB', 'USO', 'VO', 'TLT', 'RWJ', 'SPYV', 'VSS', 'ICLN', 'SCHA', 'EMB', 'XSD', 'VGIT', 'PKW', 'PCY', 'DBC', 'SCHX', 'MUNI', 'PWZ', 'EFV', 'BLV', 'VCSH', 'MINT']
# ETF_UNIVERSE = ['GLD', 'ITB', 'USO', 'VO', 'TLT', 'RWJ', 'SPYV', 'VSS', 'EMB', 'SCHA', 'ICLN', 'PKW', 'VGIT', 'XSD', 'PCY', 'MUNI', 'PWZ', 'SCHX', 'EFV', 'VCSH', 'BLV', 'DBC', 'MINT']

# # Maximize 0.8/0.2 train/val
# ETF_UNIVERSE = ['USO', 'ITB', 'ROM', 'AGQ', 'UPRO', 'RWJ', 'XHB', 'IWM', 'IHI', 'GLD', 'TLT', 'EWG', 'EEM', 'IJR', 'VO', 'BAB', 'PEY', 'EWY', 'EFV', 'ICF', 'VHT', 'XSD', 'FNX', 'ICLN', 'EWC', 'XBI', 'XLI', 'IYR', 'DBC', 'IVW', 'IYH', 'VPL', 'PKW', 'QLD', 'KRE', 'GSG', 'AIA', 'EFA', 'VSS', 'DEM', 'VXF', 'EDV', 'DGS', 'DVY', 'VOX', 'SCHA', 'PCY', 'VB', 'SPYV', 'RWK', 'IAI', 'XLY', 'FGD', 'FVD', 'FAS', 'FTA', 'EMB', 'RSP', 'SGOL', 'SCHX', 'EWW', 'XLV', 'VNQ', 'IWP', 'SPAB', 'FDL', 'QQEW', 'FXR', 'MDY', 'FXO', 'VGLT', 'PXF', 'IXC', 'EWZ', 'SMH', 'DIA', 'IWV', 'IBB', 'ITA', 'IEF', 'EWJ', 'FXH', 'EPS', 'KBE', 'IYJ', 'SOXX', 'VGT', 'SHM', 'EWU', 'BLV', 'IGV', 'FXL', 'VDC', 'SLYV', 'ZROZ', 'IYC', 'QQQ', 'QTEC', 'PGX', 'IWB', 'SCZ', 'USD', 'DXJ', 'PWZ', 'VEA', 'FYX', 'PWV', 'MDYG', 'EWL', 'IYY', 'HYG', 'FTC', 'VGK', 'VOE', 'MUNI', 'VGIT', 'IVV', 'ILF', 'ITOT', 'XLK', 'XLU', 'AOA', 'TECL', 'IJK', 'VOT', 'VWO', 'CQQQ', 'IWL', 'NYF', 'IJT', 'YINN', 'IJJ', 'PPA', 'HEDJ', 'IWC', 'CMF', 'VAW', 'RPG', 'GRID', 'SCHF', 'PRF', 'EPI', 'VCLT', 'HYD', 'VEU', 'MDYV', 'IWX', 'VCSH', 'MBB', 'VV', 'XLB', 'IWY', 'IUSV', 'VMBS', 'IOO', 'ACWI', 'RWL', 'MINT', 'SHV', 'GVI', 'MUB']
# ETF_UNIVERSE = ['ITB', 'USO', 'GLD', 'RWJ', 'TLT', 'VO', 'XLI', 'DBC', 'EMB', 'XSD', 'SPYV', 'SCHX', 'AGQ', 'XBI', 'VSS', 'EFV', 'ICLN', 'PCY', 'PKW', 'SCHA', 'PWZ', 'VGIT', 'HYG', 'MUNI', 'KRE', 'BLV', 'XHB', 'VOX', 'UPRO', 'DGS', 'VCSH', 'MBB', 'MINT']
# ETF_UNIVERSE = ['USO', 'GLD', 'ITB', 'RWJ', 'TLT', 'VO', 'DBC', 'XBI', 'XSD', 'SPYV', 'EMB', 'VSS', 'ICLN', 'EFV', 'SCHX', 'AGQ', 'SCHA', 'PCY', 'XHB', 'VGIT', 'VOX', 'PWZ', 'XLI', 'MUNI', 'PKW', 'BLV', 'DGS', 'HYG', 'VCSH', 'MBB', 'MINT']
# ETF_UNIVERSE = ['USO', 'GLD', 'ITB', 'TLT', 'RWJ', 'VO', 'DBC', 'SPYV', 'XBI', 'XSD', 'EMB', 'VSS', 'EFV', 'SCHX', 'VOX', 'ICLN', 'VGIT', 'XHB', 'SCHA', 'PCY', 'BLV', 'MUNI', 'PWZ', 'DGS', 'PKW', 'HYG', 'VCSH', 'XLI', 'MINT', 'MBB']
# ETF_UNIVERSE = ['USO', 'GLD', 'ITB', 'RWJ', 'TLT', 'VO', 'DBC', 'XBI', 'SPYV', 'EMB', 'VSS', 'XSD', 'EFV', 'SCHX', 'VGIT', 'ICLN', 'VOX', 'PCY', 'XHB', 'BLV', 'DGS', 'PWZ', 'MUNI', 'SCHA', 'PKW', 'VCSH', 'HYG', 'MBB', 'MINT']
# ETF_UNIVERSE = ['ITB', 'USO', 'GLD', 'RWJ', 'VO', 'TLT', 'DBC', 'ICLN', 'XSD', 'SPYV', 'XBI', 'EMB', 'VSS', 'SCHX', 'EFV', 'HYG', 'VGIT', 'XHB', 'PCY', 'BLV', 'SCHA', 'PKW', 'PWZ', 'MUNI', 'DGS', 'VCSH', 'VOX', 'MINT', 'MBB']

# =========================
# SIGNAL VOLUME CENTER OF MASS -- PENDING
# =========================
# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['RWR', 'CQQQ', 'PWV', 'XSD', 'GSG', 'XME', 'IYE', 'AGQ', 'SIVR', 'KRE', 'IWN', 'GLD', 'SPMD', 'GDXJ', 'SLV', 'IWM', 'SOXX', 'EWG', 'BAB', 'UYG', 'PXH', 'IXC', 'ITB', 'IWC', 'PDP', 'ZROZ', 'EWP', 'PRFZ', 'ILF', 'EDV', 'IWL', 'EWC', 'AIA', 'VTV', 'EWT', 'FXL', 'SCHV', 'CGW', 'HYG', 'SPYG', 'DBC', 'EWL', 'ROM', 'EFA', 'VXF', 'FTA', 'FXO', 'AOM', 'FTCS', 'IWX', 'IGOV', 'GRID', 'IYW', 'SPXL', 'VB', 'VCLT', 'SLYG', 'VT', 'SCHF', 'FEZ', 'KBE', 'RSP', 'SHM', 'IHI', 'IWO', 'AAXJ', 'PGX', 'FGD', 'AOR', 'SMH', 'IYY', 'PWZ', 'IDU', 'TLH', 'MGC', 'IAI', 'VCIT', 'PCY', 'IEV', 'DLN', 'VHT', 'VUG', 'MDY', 'IJS', 'DVY', 'IXN', 'MUNI', 'FXH', 'FVD', 'QTEC', 'IYH', 'ONEQ', 'NYF', 'VCR', 'ACWI', 'EXI', 'MDYG', 'MUB', 'ITOT', 'SPHQ', 'VAW', 'FBT', 'EMB', 'XLI', 'BWX', 'DEM', 'IVW', 'IJK', 'VMBS', 'TFI', 'IJH', 'XLB', 'TIP', 'DHS', 'BSV', 'ACWX', 'FXR', 'SUB', 'IYK', 'VGIT', 'VDC', 'RPG', 'IJT', 'VCSH', 'GVI', 'SH', 'BIL', 'SGOL', 'XLY', 'CWB', 'VGLT', 'SCHG', 'SHV', 'MINT']
# # TRAIN+VAL SHARPE: 1.5472456167173956
# # TRAIN SHARPE: 1.5274646450841152
# # VAL SHARPE: 1.647346781058316
# # BLIND SHARPE: 0.24821302813807325
# ETF_UNIVERSE = ['CQQQ', 'RWR', 'PWV', 'GSG', 'XSD', 'IYE', 'GLD', 'XME', 'BAB', 'AGQ', 'EDV', 'SPMD', 'SIVR', 'ZROZ', 'SH', 'IWN', 'IWM', 'SLV', 'PDP', 'IXC', 'IWL', 'IGOV', 'GRID', 'HYG', 'SCHV', 'VCLT', 'EWG', 'IWC', 'EWC', 'TLH', 'PXH', 'SHM', 'IWX', 'VCIT', 'CGW', 'DBC', 'SPYG', 'PWZ', 'MUNI', 'EWL', 'AAXJ', 'FXL', 'PGX', 'GDXJ', 'FTCS', 'EWP', 'VT', 'FXO', 'NYF', 'SLYG', 'SCHF', 'EWT', 'AOR', 'FGD', 'MUB', 'PCY', 'BWX', 'AIA', 'VMBS', 'BSV', 'VGIT', 'VTV', 'EMB', 'TFI', 'TIP', 'SUB', 'BIL', 'SHV']
# # TRAIN+VAL SHARPE: 1.5049130285698316
# # TRAIN SHARPE: 1.463633824809632
# # VAL SHARPE: 1.6963049264503953
# # BLIND SHARPE: 0.027264958101717883
# ETF_UNIVERSE = ['CQQQ', 'PWV', 'IYE', 'PXH', 'GSG', 'GLD', 'IWM', 'XSD', 'BAB', 'IWN', 'PDP', 'ZROZ', 'SCHV', 'IXC', 'SPMD', 'SPYG', 'IWL', 'VCLT', 'SHM', 'HYG', 'RWR', 'EWG', 'GRID', 'FXL', 'SIVR', 'EWC', 'EWP', 'VTV', 'TLH', 'SLYG', 'VCIT', 'FTCS', 'AGQ', 'VT', 'IWX', 'MUNI', 'SCHF', 'CGW', 'EWT', 'PWZ', 'IGOV', 'BSV', 'AOR', 'MUB', 'NYF', 'VGIT', 'FGD', 'BIL', 'VMBS', 'TFI', 'SHV']
# # TRAIN+VAL SHARPE: 1.5279368902972699
# # TRAIN SHARPE: 1.4278409748689553
# # VAL SHARPE: 1.84557063862168
# # BLIND SHARPE: -0.0723550717364114
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GSG', 'PXH', 'GLD', 'XSD', 'PWV', 'IWN', 'ZROZ', 'BAB', 'IWM', 'AGQ', 'PDP', 'SCHV', 'SIVR', 'SHM', 'VCLT', 'IXC', 'FXL', 'SPYG', 'HYG', 'TLH', 'VCIT', 'IWL', 'EWC', 'GRID', 'EWG', 'IWX', 'MUNI', 'SLYG', 'FTCS', 'PWZ', 'VT', 'SPMD', 'VGIT', 'VTV', 'EWT', 'MUB', 'CGW', 'BSV', 'AOR', 'EWP', 'NYF', 'BIL', 'SHV', 'VMBS']
# # TRAIN+VAL SHARPE: 1.5531779826093302
# # TRAIN SHARPE: 1.4832966132285161
# # VAL SHARPE: 1.820538831291439
# # BLIND SHARPE: -0.18070200282080506
# ETF_UNIVERSE = ['CQQQ', 'GSG', 'PWV', 'XSD', 'IYE', 'PXH', 'GLD', 'IWM', 'ZROZ', 'BAB', 'IWN', 'PDP', 'SCHV', 'SHM', 'VCLT', 'GRID', 'FXL', 'IXC', 'SPYG', 'SIVR', 'HYG', 'TLH', 'VT', 'AGQ', 'VCIT', 'IWL', 'EWT', 'MUNI', 'PWZ', 'EWG', 'IWX', 'MUB', 'SPMD', 'SLYG', 'FTCS', 'EWC', 'NYF', 'BSV', 'AOR', 'VGIT', 'BIL', 'VMBS', 'SHV']
# # TRAIN+VAL SHARPE: 1.5785745463626486
# # TRAIN SHARPE: 1.548927104061685
# # VAL SHARPE: 1.779704906645947
# # BLIND SHARPE: -0.2264121240613277
# ETF_UNIVERSE = ['CQQQ', 'GSG', 'IYE', 'PWV', 'PXH', 'GLD', 'IWM', 'XSD', 'ZROZ', 'BAB', 'PDP', 'EWG', 'SCHV', 'SHM', 'VCLT', 'IWN', 'HYG', 'GRID', 'IXC', 'TLH', 'SPYG', 'VT', 'EWT', 'VCIT', 'EWC', 'SIVR', 'FXL', 'IWL', 'MUNI', 'PWZ', 'MUB', 'SLYG', 'FTCS', 'NYF', 'BSV', 'IWX', 'VGIT', 'AOR', 'BIL', 'VMBS', 'SPMD', 'SHV']
# ETF_UNIVERSE = ['CQQQ', 'GSG', 'GLD', 'PWV', 'SIVR', 'PXH', 'IWM', 'XSD', 'IYE', 'ZROZ', 'BAB', 'EWG', 'PDP', 'SCHV', 'IXC', 'GRID', 'VCLT', 'SHM', 'HYG', 'IWN', 'TLH', 'SPYG', 'VCIT', 'VT', 'EWC', 'MUNI', 'EWT', 'PWZ', 'IWL', 'FXL', 'MUB', 'SLYG', 'NYF', 'BSV', 'VGIT', 'BIL', 'FTCS', 'AOR', 'VMBS', 'SHV']
# ETF_UNIVERSE = ['CQQQ', 'GSG', 'GLD', 'SIVR', 'PWV', 'IWM', 'IYE', 'PXH', 'ZROZ', 'XSD', 'BAB', 'SCHV', 'PDP', 'EWG', 'IXC', 'VCLT', 'GRID', 'IWN', 'SHM', 'HYG', 'SPYG', 'TLH', 'VCIT', 'VT', 'EWC', 'IWL', 'SLYG', 'MUNI', 'PWZ', 'FXL', 'MUB', 'EWT', 'AOR', 'BSV', 'NYF', 'FTCS', 'BIL', 'VGIT', 'VMBS', 'SHV']

# # Maximize 0.55/0.45 train/val
# ETF_UNIVERSE = ['RWR', 'CQQQ', 'PWV', 'XSD', 'GSG', 'XME', 'IYE', 'AGQ', 'SIVR', 'SPMD', 'IWN', 'KRE', 'GLD', 'SLV', 'GDXJ', 'IWM', 'BAB', 'EWG', 'SOXX', 'UYG', 'IWC', 'IXC', 'PXH', 'PDP', 'EDV', 'ZROZ', 'EWT', 'EWP', 'ITB', 'AIA', 'VTV', 'IWL', 'EWC', 'PRFZ', 'CGW', 'HYG', 'FXL', 'EFA', 'FXO', 'SCHV', 'ROM', 'EWL', 'ILF', 'AOM', 'VXF', 'SPYG', 'VB', 'VT', 'SPXL', 'DBC', 'KBE', 'FTA', 'IWX', 'IGOV', 'SCHF', 'FEZ', 'FTCS', 'IYW', 'GRID', 'SHM', 'VCLT', 'SLYG', 'IWO', 'PGX', 'FGD', 'IHI', 'IAI', 'AOR', 'RSP', 'IXN', 'PWZ', 'VAW', 'AAXJ', 'TLH', 'IJS', 'VCR', 'VCIT', 'PCY', 'MDY', 'QTEC', 'VUG', 'ONEQ', 'FVD', 'FXH', 'MGC', 'DVY', 'FBT', 'MDYG', 'IYH', 'IEV', 'EMB', 'DLN', 'MUNI', 'SMH', 'IDU', 'NYF', 'VHT', 'IYY', 'MUB', 'XLB', 'IVW', 'ACWI', 'ITOT', 'XLI', 'XOP', 'BWX', 'SPHQ', 'IJK', 'EXI', 'FXR', 'VMBS', 'TFI', 'DEM', 'IYK', 'IJH', 'JNK', 'IWS', 'DHS', 'SUB', 'BSV', 'RWO', 'RPG', 'VGLT', 'TIP', 'VCSH', 'GVI', 'FIW', 'VGIT', 'SGOL', 'BIL', 'MINT', 'PRF', 'SHV', 'XLY', 'VFH']
# # TRAIN+VAL SHARPE: 1.5139974258686981
# # TRAIN SHARPE: 1.530465469004567
# # VAL SHARPE: 1.5340312543029315
# # BLIND SHARPE: 0.2664987420403466
# ETF_UNIVERSE = ['CQQQ', 'RWR', 'PWV', 'GSG', 'XSD', 'IYE', 'GLD', 'BAB', 'SPMD', 'XME', 'EDV', 'AGQ', 'SIVR', 'ZROZ', 'IWN', 'IWM', 'SLV', 'PDP', 'IWL', 'IXC', 'IWC', 'HYG', 'VCLT', 'EWC', 'SCHV', 'TLH', 'EWG', 'SHM', 'IGOV', 'GDXJ', 'CGW', 'EWL', 'GRID', 'VT', 'EWT', 'PXH', 'IWX', 'VCIT', 'PWZ', 'SPYG', 'AAXJ', 'SCHF', 'FXL', 'MUNI', 'PGX', 'FTCS', 'FXO', 'SLYG', 'AOR', 'NYF', 'DBC', 'AIA', 'FGD', 'MUB', 'EMB', 'PCY', 'VMBS', 'VTV', 'EWP', 'BSV', 'SUB', 'TFI', 'BWX', 'JNK', 'VGIT', 'BIL', 'SHV', 'MINT']
# # TRAIN+VAL SHARPE: 1.5068430808511055
# # TRAIN SHARPE: 1.4992692609627933
# # VAL SHARPE: 1.612938015832162
# # BLIND SHARPE: 0.08540895930330278
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'PWV', 'GLD', 'PXH', 'GSG', 'BAB', 'XSD', 'IWM', 'ZROZ', 'PDP', 'IWN', 'RWR', 'SCHV', 'SPMD', 'SHM', 'VCLT', 'IXC', 'IWL', 'HYG', 'SPYG', 'SIVR', 'GRID', 'TLH', 'EWG', 'EWT', 'VT', 'FXL', 'EWC', 'SLYG', 'VCIT', 'EWP', 'FTCS', 'AGQ', 'MUNI', 'VTV', 'PWZ', 'EDV', 'SCHF', 'CGW', 'JNK', 'IWX', 'AOR', 'MUB', 'IGOV', 'BSV', 'IWC', 'VGIT', 'NYF', 'VMBS', 'TFI', 'BIL', 'SHV', 'EMB', 'MINT', 'SUB']
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'PWV', 'PXH', 'GSG', 'BAB', 'AGQ', 'XSD', 'ZROZ', 'IWM', 'PDP', 'SIVR', 'IWN', 'SCHV', 'SHM', 'SPYG', 'VCLT', 'HYG', 'TLH', 'SPMD', 'FXL', 'JNK', 'EDV', 'VT', 'IWL', 'VCIT', 'EWG', 'GRID', 'SLYG', 'MUNI', 'EWC', 'IWC', 'FTCS', 'PWZ', 'AOR', 'CGW', 'SCHF', 'EWT', 'MUB', 'BSV', 'VGIT', 'NYF', 'IXC', 'VMBS', 'EMB', 'BIL', 'VTV', 'SHV', 'MINT', 'SUB']
# ETF_UNIVERSE = ['CQQQ', 'PWV', 'GSG', 'GLD', 'IYE', 'XSD', 'IWM', 'BAB', 'ZROZ', 'PXH', 'PDP', 'SIVR', 'SCHV', 'SHM', 'VCLT', 'GRID', 'EDV', 'SPYG', 'AGQ', 'TLH', 'HYG', 'VT', 'IWL', 'VCIT', 'SPMD', 'FXL', 'JNK', 'EWT', 'MUNI', 'EWG', 'IWC', 'EWC', 'PWZ', 'SLYG', 'MUB', 'AOR', 'SCHF', 'IWN', 'FTCS', 'BSV', 'IXC', 'NYF', 'VGIT', 'EMB', 'VMBS', 'BIL', 'SHV', 'MINT', 'SUB']
# # TRAIN+VAL SHARPE: 1.572496110036905
# # TRAIN SHARPE: 1.5623828879245507
# # VAL SHARPE: 1.6903446974122585
# # BLIND SHARPE: 0.027750841706505925
# ETF_UNIVERSE = ['CQQQ', 'PWV', 'GLD', 'GSG', 'IWM', 'IYE', 'BAB', 'XSD', 'ZROZ', 'PXH', 'PDP', 'EDV', 'SHM', 'SCHV', 'SIVR', 'VCLT', 'EWG', 'SPYG', 'HYG', 'TLH', 'GRID', 'VT', 'AGQ', 'VCIT', 'IWL', 'EWC', 'JNK', 'SPMD', 'PWZ', 'FXL', 'MUNI', 'SLYG', 'MUB', 'EWT', 'SCHF', 'FTCS', 'AOR', 'IWC', 'BSV', 'IWN', 'EMB', 'NYF', 'VGIT', 'VMBS', 'BIL', 'MINT', 'SHV', 'SUB']
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'PWV', 'GLD', 'IWM', 'BAB', 'GSG', 'XSD', 'ZROZ', 'PXH', 'PDP', 'SCHV', 'SHM', 'EWG', 'EDV', 'VCLT', 'HYG', 'SPYG', 'SIVR', 'TLH', 'VT', 'GRID', 'AGQ', 'IWC', 'VCIT', 'FXL', 'IWL', 'EWC', 'JNK', 'SLYG', 'MUNI', 'PWZ', 'FTCS', 'MUB', 'SCHF', 'SPMD', 'AOR', 'BSV', 'EMB', 'NYF', 'VGIT', 'VMBS', 'BIL', 'EWT', 'MINT', 'SHV', 'SUB']
# # TRAIN+VAL SHARPE: 1.557653561698589
# # TRAIN SHARPE: 1.5350286195039013
# # VAL SHARPE: 1.714837430521985
# # BLIND SHARPE: 0.07836176272774983
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'PWV', 'IWM', 'BAB', 'GSG', 'PDP', 'ZROZ', 'XSD', 'PXH', 'EWG', 'SCHV', 'SHM', 'EDV', 'VCLT', 'SPYG', 'HYG', 'VT', 'SIVR', 'TLH', 'FXL', 'GRID', 'IWL', 'VCIT', 'JNK', 'SLYG', 'IWC', 'FTCS', 'SCHF', 'AGQ', 'MUNI', 'MUB', 'AOR', 'PWZ', 'SPMD', 'EMB', 'BSV', 'VGIT', 'NYF', 'VMBS', 'BIL', 'EWC', 'MINT', 'SHV', 'SUB']
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'PWV', 'IWM', 'EWG', 'GSG', 'PDP', 'ZROZ', 'PXH', 'XSD', 'BAB', 'SCHV', 'EDV', 'HYG', 'SHM', 'VCLT', 'SPYG', 'VT', 'TLH', 'GRID', 'FXL', 'IWL', 'VCIT', 'SIVR', 'JNK', 'IWC', 'SLYG', 'EWC', 'SCHF', 'MUNI', 'MUB', 'FTCS', 'PWZ', 'EMB', 'AOR', 'BSV', 'SPMD', 'VGIT', 'NYF', 'VMBS', 'BIL', 'AGQ', 'SHV', 'MINT', 'SUB']

# Maximize 0.6/0.4 train/val
# ETF_UNIVERSE = ['RWR', 'CQQQ', 'PWV', 'XSD', 'GSG', 'IYE', 'XME', 'AGQ', 'SPMD', 'IWN', 'GLD', 'SIVR', 'SLV', 'BAB', 'KRE', 'IWM', 'GDXJ', 'EWG', 'UYG', 'IWC', 'SOXX', 'EWT', 'EDV', 'IXC', 'PDP', 'PXH', 'ZROZ', 'CGW', 'VTV', 'AIA', 'EWP', 'HYG', 'EWC', 'IWL', 'FXO', 'EFA', 'ITB', 'VT', 'VB', 'AOM', 'FXL', 'ROM', 'VXF', 'EWL', 'KBE', 'PRFZ', 'SPXL', 'SCHV', 'SPYG', 'VAW', 'SHM', 'FEZ', 'SCHF', 'IWO', 'FTA', 'PGX', 'FGD', 'IWX', 'IXN', 'IGOV', 'IAI', 'DBC', 'VCLT', 'IHI', 'VCR', 'SLYG', 'XOP', 'IYW', 'FTCS', 'GRID', 'AOR', 'PWZ', 'TLH', 'IJS', 'ILF', 'FBT', 'QTEC', 'ONEQ', 'EMB', 'MDY', 'XLB', 'AAXJ', 'VCIT', 'VUG', 'MDYG', 'PCY', 'RSP', 'FVD', 'FXH', 'IYH', 'IVW', 'DVY', 'NYF', 'MUNI', 'MUB', 'MGC', 'DLN', 'IEV', 'JNK', 'IJK', 'VHT', 'XLI', 'IWS', 'FXR', 'IDU', 'SMH', 'ACWI', 'ITOT', 'RWO', 'IYK', 'TFI', 'BWX', 'VMBS', 'FIW', 'SPHQ', 'VGLT', 'DON', 'IJH', 'IYY', 'VFH', 'RPG', 'DHS', 'FPX', 'PRF', 'SUB', 'DEM', 'FYX', 'BSV', 'VCSH', 'GVI', 'EXI', 'SGOL', 'BIL', 'MINT', 'VGIT', 'SHV', 'TIP', 'VGSH']
# # TRAIN+VAL SHARPE: 1.5094543597911625
# # TRAIN SHARPE: 1.5583734192356227
# # VAL SHARPE: 1.4299821484391262
# # BLIND SHARPE: 0.28074089908143374
# ETF_UNIVERSE = ['CQQQ', 'RWR', 'PWV', 'XSD', 'IYE', 'GSG', 'GLD', 'BAB', 'SPMD', 'EDV', 'XME', 'AGQ', 'IWM', 'SIVR', 'ZROZ', 'IWN', 'SLV', 'PDP', 'EWT', 'IWC', 'IWL', 'HYG', 'VT', 'IXC', 'CGW', 'SHM', 'EWG', 'TLH', 'EWL', 'EWC', 'GDXJ', 'VCLT', 'IGOV', 'SCHV', 'GRID', 'SCHF', 'VCIT', 'PWZ', 'AAXJ', 'PGX', 'FXO', 'SPYG', 'IWX', 'FXL', 'EMB', 'PXH', 'FGD', 'MUNI', 'AOR', 'SLYG', 'AIA', 'FTCS', 'NYF', 'MUB', 'PCY', 'RWO', 'JNK', 'VTV', 'VMBS', 'TFI', 'SUB', 'BSV', 'EWP', 'VGLT', 'VAW', 'BIL', 'BWX', 'SHV', 'MINT', 'MDYG', 'VCSH', 'IXN', 'GVI']
# # TRAIN+VAL SHARPE: 1.5021657922372156
# # TRAIN SHARPE: 1.4881095730320353
# # VAL SHARPE: 1.6185010558887063
# # BLIND SHARPE: 0.045066207550490275
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'PWV', 'GLD', 'PXH', 'BAB', 'RWR', 'XSD', 'GSG', 'IWM', 'PDP', 'SPMD', 'ZROZ', 'IWN', 'SHM', 'HYG', 'SCHV', 'IWL', 'VCLT', 'VT', 'TLH', 'SPYG', 'EWP', 'SIVR', 'EWT', 'VCIT', 'SLYG', 'CGW', 'GRID', 'SCHF', 'PWZ', 'IWC', 'FXL', 'FTCS', 'AGQ', 'MUNI', 'EWG', 'JNK', 'IWX', 'IXC', 'EWC', 'AOR', 'EMB', 'IGOV', 'MUB', 'IXN', 'BSV', 'VTV', 'VMBS', 'TFI', 'NYF', 'FGD', 'BIL', 'SUB', 'SHV', 'GVI', 'MINT']
# # TRAIN+VAL SHARPE: 1.466665117267884
# # TRAIN SHARPE: 1.4271025240601183
# # VAL SHARPE: 1.6691165500624814
# # BLIND SHARPE: -0.11037367914439569
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'PXH', 'BAB', 'XSD', 'GSG', 'ZROZ', 'IWM', 'PWV', 'IWN', 'PDP', 'RWR', 'SPMD', 'SHM', 'AGQ', 'SIVR', 'VT', 'TLH', 'SCHV', 'HYG', 'VCLT', 'JNK', 'IWL', 'CGW', 'SPYG', 'VCIT', 'EWT', 'EWG', 'PWZ', 'FXL', 'MUNI', 'EWP', 'EMB', 'AOR', 'FTCS', 'IWX', 'MUB', 'SCHF', 'SLYG', 'EWC', 'VTV', 'BSV', 'NYF', 'VMBS', 'GRID', 'BIL', 'IXC', 'SHV', 'MINT', 'SUB']
# # TRAIN+VAL SHARPE: 1.5405374627457953
# # TRAIN SHARPE: 1.4968710327966255
# # VAL SHARPE: 1.727371361854183
# # BLIND SHARPE: -0.12958881252142404
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'XSD', 'BAB', 'IWN', 'PXH', 'GSG', 'IWM', 'ZROZ', 'PDP', 'SHM', 'VT', 'SCHV', 'EWT', 'HYG', 'TLH', 'PWV', 'VCLT', 'JNK', 'FXL', 'SPYG', 'SPMD', 'SIVR', 'AGQ', 'IWL', 'VCIT', 'EWC', 'EWG', 'PWZ', 'IXC', 'CGW', 'SLYG', 'MUNI', 'AOR', 'MUB', 'EMB', 'GRID', 'FTCS', 'SCHF', 'IWX', 'BSV', 'NYF', 'VMBS', 'BIL', 'SUB', 'VTV', 'SHV', 'MINT']
# # TRAIN+VAL SHARPE: 1.5669129233392731
# # TRAIN SHARPE: 1.5707966947131835
# # VAL SHARPE: 1.6754869557543894
# # BLIND SHARPE: -0.18875528160592175
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'XSD', 'GSG', 'IWM', 'BAB', 'PWV', 'PXH', 'EWT', 'ZROZ', 'PDP', 'VT', 'SHM', 'HYG', 'TLH', 'SCHV', 'VCLT', 'IXC', 'SPYG', 'JNK', 'GRID', 'SPMD', 'FXL', 'IWL', 'VCIT', 'EWG', 'PWZ', 'EWC', 'SIVR', 'EMB', 'MUNI', 'MUB', 'IWX', 'AOR', 'SLYG', 'SCHF', 'CGW', 'NYF', 'BSV', 'VMBS', 'IWN', 'FTCS', 'BIL', 'SUB', 'SHV', 'MINT']
# ETF_UNIVERSE = ['CQQQ', 'GLD', 'IYE', 'SIVR', 'XSD', 'GSG', 'PWV', 'IWM', 'BAB', 'PXH', 'ZROZ', 'PDP', 'EWT', 'SHM', 'VT', 'SCHV', 'HYG', 'TLH', 'VCLT', 'IXC', 'GRID', 'SPYG', 'JNK', 'EWG', 'VCIT', 'PWZ', 'IWL', 'MUNI', 'CGW', 'FXL', 'EWC', 'MUB', 'SPMD', 'SLYG', 'AOR', 'EMB', 'IWX', 'SCHF', 'BSV', 'NYF', 'VMBS', 'BIL', 'SHV', 'SUB', 'MINT']
# # best
# # TRAIN+VAL SHARPE: 1.5885158134581192
# # TRAIN SHARPE: 1.6312614383125938
# # VAL SHARPE: 1.5842956074803045
# # BLIND SHARPE: -0.14829192880686534
# ETF_UNIVERSE = ['CQQQ', 'GLD', 'SIVR', 'IYE', 'XSD', 'IWM', 'PWV', 'GSG', 'PDP', 'PXH', 'ZROZ', 'BAB', 'SHM', 'VT', 'EWT', 'SCHV', 'HYG', 'VCLT', 'EWG', 'SPYG', 'TLH', 'GRID', 'JNK', 'VCIT', 'FXL', 'SLYG', 'IWL', 'IWX', 'SPMD', 'PWZ', 'MUNI', 'MUB', 'CGW', 'SCHF', 'EWC', 'AOR', 'EMB', 'BSV', 'VMBS', 'NYF', 'BIL', 'SHV', 'SUB', 'MINT']
# # TRAIN+VAL SHARPE: 1.5792242462380222
# # TRAIN SHARPE: 1.6289650300902536
# # VAL SHARPE: 1.5633365163012527
# # BLIND SHARPE: -0.12309009086193079
# ETF_UNIVERSE = ['CQQQ', 'GLD', 'IYE', 'SIVR', 'XSD', 'IWM', 'BAB', 'PDP', 'PWV', 'GSG', 'PXH', 'ZROZ', 'EWG', 'SHM', 'SCHV', 'VT', 'EWT', 'HYG', 'VCLT', 'SPYG', 'TLH', 'FXL', 'GRID', 'JNK', 'VCIT', 'IWX', 'SLYG', 'IWL', 'PWZ', 'MUNI', 'SCHF', 'MUB', 'AOR', 'EMB', 'SPMD', 'CGW', 'BSV', 'VMBS', 'NYF', 'BIL', 'SHV', 'SUB', 'MINT']
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'SIVR', 'XSD', 'EWG', 'IWM', 'PDP', 'PWV', 'ZROZ', 'BAB', 'GSG', 'SCHV', 'VT', 'PXH', 'SHM', 'HYG', 'VCLT', 'EWT', 'SPYG', 'FXL', 'GRID', 'TLH', 'IWX', 'JNK', 'SLYG', 'VCIT', 'IWL', 'AOR', 'SCHF', 'CGW', 'MUNI', 'PWZ', 'MUB', 'SPMD', 'EMB', 'VMBS', 'BSV', 'NYF', 'BIL', 'SHV', 'SUB', 'MINT']

# # Maximize 0.65/0.35 train/val
# ETF_UNIVERSE = ['RWR', 'CQQQ', 'PWV', 'XSD', 'IYE', 'GSG', 'XME', 'AGQ', 'SPMD', 'GLD', 'IWN', 'BAB', 'SLV', 'IWM', 'SIVR', 'GDXJ', 'KRE', 'EWG', 'UYG', 'IWC', 'EWT', 'EDV', 'SOXX', 'PDP', 'IXC', 'CGW', 'HYG', 'VTV', 'VT', 'AIA', 'FXO', 'ZROZ', 'VB', 'EWC', 'PXH', 'EFA', 'IWL', 'AOM', 'KBE', 'EWP', 'VAW', 'VXF', 'ROM', 'EWL', 'XOP', 'SPXL', 'FXL', 'ITB', 'SHM', 'FEZ', 'IWO', 'SCHF', 'PGX', 'IXN', 'FGD', 'SPYG', 'IAI', 'VCR', 'SCHV', 'PRFZ', 'FBT', 'IHI', 'XLB', 'EMB', 'FTA', 'PWZ', 'IWX', 'QTEC', 'VCLT', 'AOR', 'ONEQ', 'IJS', 'IGOV', 'SLYG', 'TLH', 'MDYG', 'MDY', 'DBC', 'IYW', 'VUG', 'VCIT', 'IVW', 'GRID', 'FTCS', 'PCY', 'FVD', 'JNK', 'AAXJ', 'FXH', 'IYH', 'IWS', 'NYF', 'RWO', 'MUB', 'DON', 'RSP', 'DVY', 'FXR', 'IJK', 'MUNI', 'FYX', 'IYK', 'FIW', 'XLI', 'VFH', 'FPX', 'MGC', 'DLN', 'PRF', 'TFI', 'VGLT', 'IEV', 'VMBS', 'ITOT', 'ACWI', 'VHT', 'RPG', 'BWX', 'XLE', 'IJH', 'DHS', 'SUB', 'FDN', 'ILF', 'IDU', 'QQEW', 'SPHQ', 'BSV', 'SMH', 'GVI', 'VCSH', 'XLK', 'DEM', 'SGOL', 'EWJ', 'BIL', 'MINT', 'VIG', 'SHV', 'VGSH']
# # TRAIN+VAL SHARPE: 1.4858383904336256
# # TRAIN SHARPE: 1.5335543754686294
# # VAL SHARPE: 1.4066456293289784
# # BLIND SHARPE: 0.3218837630555467
# ETF_UNIVERSE = ['CQQQ', 'RWR', 'IYE', 'XSD', 'PWV', 'GSG', 'SPMD', 'GLD', 'BAB', 'EDV', 'XME', 'AGQ', 'IWM', 'SLV', 'IWN', 'EWT', 'ZROZ', 'SIVR', 'IWC', 'VT', 'PDP', 'IWL', 'HYG', 'GDXJ', 'SHM', 'CGW', 'IXC', 'EWG', 'EWL', 'TLH', 'EWC', 'SCHF', 'VCLT', 'PGX', 'FXO', 'EMB', 'PWZ', 'AAXJ', 'VCIT', 'SCHV', 'IGOV', 'SPYG', 'RWO', 'JNK', 'FGD', 'VAW', 'IWX', 'FXL', 'AOR', 'AIA', 'GRID', 'SLYG', 'MUNI', 'MUB', 'VTV', 'MDYG', 'NYF', 'PCY', 'FTCS', 'IXN', 'VMBS', 'TFI', 'PXH', 'VGLT', 'SUB', 'BSV', 'EWP', 'VCSH', 'GVI', 'BIL', 'MINT', 'SHV', 'BWX', 'VB']
# ETF_UNIVERSE = ['CQQQ', 'IYE', 'GLD', 'PWV', 'BAB', 'RWR', 'XSD', 'PXH', 'IWM', 'SPMD', 'PDP', 'GSG', 'ZROZ', 'SHM', 'IWN', 'HYG', 'VT', 'IWL', 'SCHV', 'EWT', 'TLH', 'VCLT', 'SPYG', 'CGW', 'IWC', 'EWP', 'VCIT', 'SCHF', 'PWZ', 'SLYG', 'SIVR', 'EMB', 'JNK', 'GRID', 'IWX', 'MUNI', 'FXL', 'EWC', 'AOR', 'FTCS', 'IXN', 'VTV', 'MUB', 'IGOV', 'TFI', 'VMBS', 'FGD', 'BSV', 'NYF', 'AGQ', 'SUB', 'BIL', 'EWG', 'GVI', 'SHV', 'IXC', 'MINT']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'BAB', 'XSD', 'PXH', 'ZROZ', 'SPMD', 'IWM', 'PDP', 'IWN', 'GSG', 'VT', 'SHM', 'RWR', 'HYG', 'EWT', 'TLH', 'CGW', 'JNK', 'VCLT', 'SCHV', 'PWV', 'IWL', 'SIVR', 'VCIT', 'SPYG', 'AGQ', 'PWZ', 'EMB', 'FXL', 'EWG', 'MUNI', 'SCHF', 'AOR', 'EWP', 'MUB', 'VTV', 'SLYG', 'IWX', 'FTCS', 'VMBS', 'EWC', 'BSV', 'NYF', 'FGD', 'BIL', 'TFI', 'SUB', 'SHV', 'MINT', 'GVI']
# # TRAIN+VAL SHARPE: 1.561377964491654
# # TRAIN SHARPE: 1.5308673235907488
# # VAL SHARPE: 1.7274219000430655
# # BLIND SHARPE: 0.10197924794278626
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'BAB', 'XSD', 'IWM', 'ZROZ', 'SHM', 'EWT', 'PXH', 'PDP', 'IWN', 'GSG', 'HYG', 'PWV', 'VT', 'SPMD', 'TLH', 'JNK', 'SCHV', 'FXL', 'VCLT', 'IWL', 'SPYG', 'EWG', 'VCIT', 'EMB', 'PWZ', 'CGW', 'SLYG', 'IWX', 'AOR', 'MUNI', 'EWC', 'MUB', 'SCHF', 'VTV', 'FTCS', 'FGD', 'BSV', 'AGQ', 'VMBS', 'EWP', 'NYF', 'BIL', 'SUB', 'SHV', 'MINT', 'GVI', 'TFI']
# # TRAIN+VAL SHARPE: 1.5413161800568491
# # TRAIN SHARPE: 1.5593953534947211
# # VAL SHARPE: 1.598905908774334
# # BLIND SHARPE: 0.04494042260730346
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'BAB', 'PWV', 'AGQ', 'IWM', 'GSG', 'ZROZ', 'EWT', 'SHM', 'VT', 'PDP', 'PXH', 'HYG', 'VCLT', 'TLH', 'SPMD', 'SCHV', 'JNK', 'IWL', 'FXL', 'SPYG', 'VCIT', 'EMB', 'EWG', 'PWZ', 'IWX', 'MUNI', 'MUB', 'SLYG', 'AOR', 'FTCS', 'SCHF', 'VMBS', 'BSV', 'CGW', 'BIL', 'FGD', 'SUB', 'NYF', 'SHV', 'MINT']
# # TRAIN+VAL SHARPE: 1.55136875907905
# # TRAIN SHARPE: 1.5694724216079412
# # VAL SHARPE: 1.6062933941392257
# # BLIND SHARPE: 0.03336999508172878
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'BAB', 'EWG', 'IWM', 'PDP', 'EWT', 'ZROZ', 'VT', 'SHM', 'HYG', 'AGQ', 'SCHV', 'VCLT', 'PWV', 'SPYG', 'TLH', 'FXL', 'IWX', 'IWL', 'GSG', 'CGW', 'JNK', 'SPMD', 'VCIT', 'PXH', 'EMB', 'SLYG', 'SCHF', 'PWZ', 'MUB', 'MUNI', 'AOR', 'FGD', 'FTCS', 'VMBS', 'BSV', 'BIL', 'SUB', 'SHV', 'MINT']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'BAB', 'IWM', 'EWG', 'PDP', 'VT', 'EWT', 'ZROZ', 'SHM', 'HYG', 'PWV', 'AGQ', 'SCHV', 'VCLT', 'SPYG', 'TLH', 'JNK', 'FXL', 'IWL', 'IWX', 'SPMD', 'GSG', 'PXH', 'EMB', 'CGW', 'VCIT', 'SLYG', 'PWZ', 'SCHF', 'MUB', 'MUNI', 'AOR', 'FTCS', 'VMBS', 'FGD', 'BSV', 'BIL', 'SUB', 'SHV', 'MINT']

# # Maximize 0.7/0.3 train/val
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'BAB', 'SIVR', 'SPMD', 'XSD', 'PXH', 'PWV', 'PDP', 'VT', 'SHM', 'IWM', 'ZROZ', 'HYG', 'GSG', 'CGW', 'JNK', 'TLH', 'EWT', 'IWL', 'SCHV', 'VCLT', 'VCIT', 'SPYG', 'EMB', 'IWN', 'PWZ', 'SCHF', 'RWR', 'IWC', 'RWO', 'SLYG', 'AOR', 'MUNI', 'EDV', 'FGD', 'VMBS', 'MUB', 'BSV', 'TFI', 'GRID', 'IWX', 'IGOV', 'GVI', 'EWG', 'BIL', 'SUB', 'FTCS', 'IXN', 'NYF', 'VGSH', 'MINT', 'SHV', 'VCSH', 'FXL']
# # TRAIN+VAL SHARPE: 1.5819052339183592
# # TRAIN SHARPE: 1.60834508005249
# # VAL SHARPE: 1.6542836657637063
# # BLIND SHARPE: 0.0631256020174545
# ETF_UNIVERSE = ['IYE', 'GLD', 'CQQQ', 'BAB', 'SIVR', 'IWM', 'PXH', 'PDP', 'SPMD', 'EWT', 'VT', 'CGW', 'HYG', 'XSD', 'PWV', 'SHM', 'IWC', 'ZROZ', 'TLH', 'JNK', 'SCHV', 'IWL', 'VCLT', 'SPYG', 'EWG', 'SCHF', 'VCIT', 'EMB', 'PWZ', 'AOR', 'FGD', 'SLYG', 'RWO', 'IWX', 'MUNI', 'FXL', 'MUB', 'VMBS', 'FTCS', 'GSG', 'BSV', 'EDV', 'TFI', 'NYF', 'BIL', 'GVI', 'SUB', 'SHV', 'MINT', 'VGSH', 'VCSH']
# # TRAIN+VAL SHARPE: 1.6237962995657498
# # TRAIN SHARPE: 1.6539166754253507
# # VAL SHARPE: 1.6885586333916953
# # BLIND SHARPE: -0.02302927315415661
# ETF_UNIVERSE = ['IYE', 'GLD', 'CQQQ', 'PWV', 'BAB', 'SIVR', 'XSD', 'PDP', 'IWM', 'VT', 'HYG', 'ZROZ', 'IWC', 'SHM', 'PXH', 'SPMD', 'EWT', 'SCHV', 'TLH', 'SPYG', 'IWL', 'VCLT', 'CGW', 'GSG', 'JNK', 'EWG', 'EMB', 'VCIT', 'SCHF', 'IWX', 'SLYG', 'AOR', 'FGD', 'PWZ', 'MUNI', 'FXL', 'MUB', 'VMBS', 'FTCS', 'BSV', 'BIL', 'TFI', 'SUB', 'SHV', 'GVI', 'MINT', 'VGSH']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'BAB', 'HYG', 'VT', 'EWT', 'PDP', 'ZROZ', 'EMB', 'SHM', 'TLH', 'IWL', 'VAW', 'SPYG', 'SCHV', 'SCHF', 'PWZ', 'VCLT', 'IWX', 'VCIT', 'VTV', 'AOR', 'SPMD', 'SLYG', 'JNK', 'MUB', 'RWO', 'MUNI', 'VMBS', 'IWM', 'TFI', 'MDYG', 'CGW', 'FGD', 'SUB', 'BIL', 'VCSH', 'GVI', 'SHV', 'VGSH', 'BSV', 'MINT']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'HYG', 'VT', 'EWT', 'PDP', 'VAW', 'ZROZ', 'EMB', 'IWL', 'TLH', 'SHM', 'SCHV', 'SPYG', 'SCHF', 'PWZ', 'VCLT', 'IWX', 'VCIT', 'BAB', 'VTV', 'AOR', 'SLYG', 'SPMD', 'JNK', 'MUB', 'IWM', 'MUNI', 'RWO', 'VMBS', 'MDYG', 'TFI', 'FGD', 'CGW', 'SUB', 'BIL', 'VCSH', 'SHV', 'GVI', 'VGSH', 'MINT']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'HYG', 'VT', 'PDP', 'EWT', 'VAW', 'ZROZ', 'TLH', 'EMB', 'IWL', 'SHM', 'SCHV', 'SPYG', 'SCHF', 'PWZ', 'VCLT', 'BAB', 'IWX', 'VCIT', 'AOR', 'VTV', 'SPMD', 'SLYG', 'JNK', 'MUB', 'RWO', 'FGD', 'MUNI', 'VMBS', 'IWM', 'TFI', 'MDYG', 'SUB', 'BIL', 'GVI', 'VCSH', 'SHV', 'VGSH', 'MINT']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'HYG', 'VT', 'PDP', 'TLH', 'EMB', 'ZROZ', 'SHM', 'IWL', 'IWM', 'SCHV', 'EWT', 'SPYG', 'SCHF', 'PWZ', 'VAW', 'VCLT', 'VCIT', 'IWX', 'AOR', 'SLYG', 'RWO', 'JNK', 'FGD', 'MUB', 'VTV', 'MUNI', 'VMBS', 'SPMD', 'TFI', 'GVI', 'SUB', 'VCSH', 'BIL', 'SHV', 'MDYG', 'VGSH', 'MINT']
# ETF_UNIVERSE = ['IYE', 'CQQQ', 'GLD', 'XSD', 'HYG', 'VT', 'PDP', 'VAW', 'IWM', 'EMB', 'TLH', 'ZROZ', 'IWL', 'SCHV', 'SHM', 'SCHF', 'SPYG', 'PWZ', 'VCLT', 'VCIT', 'AOR', 'IWX', 'EWT', 'SLYG', 'SPMD', 'JNK', 'MUB', 'FGD', 'MUNI', 'VMBS', 'RWO', 'TFI', 'GVI', 'SUB', 'MDYG', 'VCSH', 'BIL', 'SHV', 'VGSH', 'VTV', 'MINT']

# =========================
# SIGNAL PATH EFFICIENCY -- PICKED
# =========================
# # Maximize 0.5/0.5 train/val
# best
# TRAIN+VAL SHARPE: 1.0464576958507945
# TRAIN SHARPE: 1.0676110181428022
# VAL SHARPE: 1.0016201039791277
# BLIND SHARPE: 0.5920697735884933
# ETF_UNIVERSE = ['FXU', 'ICLN', 'IDU', 'XBI', 'SH', 'FXH', 'GDXJ', 'AAXJ', 'PCY', 'MUB', 'QQXT', 'XLP', 'XLG', 'TFI', 'IWY', 'XLK', 'IYK', 'CQQQ', 'SDY', 'VDC', 'BIL', 'VGSH', 'MGK', 'IEI']
# ETF_UNIVERSE = ['FXU', 'ICLN', 'IDU', 'FXH', 'AAXJ', 'GDXJ', 'SH', 'PCY', 'MUB', 'XBI', 'SDY', 'XLK', 'QQXT', 'XLG', 'IWY', 'TFI', 'XLP', 'IYK', 'MGK', 'VGSH', 'BIL', 'IEI', 'CQQQ']
# best
# TRAIN+VAL SHARPE: 1.0440380816681565
# TRAIN SHARPE: 1.061727460647171
# VAL SHARPE: 1.0086394138501997
# BLIND SHARPE: 0.580982460382187
# ETF_UNIVERSE = ['FXU', 'IDU', 'ICLN', 'SH', 'AAXJ', 'FXH', 'GDXJ', 'PCY', 'XBI', 'MUB', 'SDY', 'XLG', 'XLP', 'IWY', 'TFI', 'XLK', 'QQXT', 'IYK', 'VGSH', 'IEI', 'MGK', 'BIL', 'CQQQ']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['IAU', 'VDE', 'XLF', 'FNX', 'QQXT', 'VFH', 'EEM', 'IXC', 'SLV', 'FBT', 'VNQ', 'GDXJ', 'FXU', 'XBI', 'ICF', 'IYF', 'IDU', 'BIV', 'ICLN', 'FDL', 'XOP', 'GLD', 'RWL', 'ROM', 'FXH', 'DHS', 'XLK', 'SDY', 'SIVR', 'DVY', 'CQQQ', 'RWO', 'XLG', 'IWO', 'VGT', 'IHI', 'XLU', 'USD', 'AAXJ', 'IYE', 'EPI', 'FGD', 'PCY', 'EWC', 'IXN', 'BAB', 'IBB', 'IYK', 'TECL', 'ACWI', 'XLP', 'VCR', 'DTD', 'MGK', 'IYW', 'EPP', 'MUB', 'ONEQ', 'VPU', 'CGW', 'PEY', 'IYC', 'XLE', 'PGX', 'RPV', 'VDC', 'JNK', 'VIG', 'IWY', 'IGV', 'TFI', 'RPG', 'FXI', 'VT', 'IAI', 'XLY', 'PFF', 'SOXX', 'DIA', 'PKW', 'IYG', 'IWF', 'SGOL', 'VWO', 'AGQ', 'MGV', 'SH', 'DLN', 'PRF', 'FYX', 'BWX', 'VOX', 'VSS', 'ACWX', 'SCHG', 'QQQ', 'IWM', 'EWL', 'IVE', 'DXJ', 'FXR', 'BND', 'EWG', 'ITM', 'BLV', 'IGM', 'FEX', 'PXH', 'EWJ', 'SHM', 'VCIT', 'RWK', 'RWJ', 'VBK', 'BSV', 'SPHQ', 'EFA', 'VYM', 'PWV', 'SPYV', 'VUG', 'BIL', 'PHO', 'EWA', 'VEA', 'IVW', 'MDYV', 'DGS', 'PPA', 'IEI', 'VGSH', 'SUB', 'IWX', 'VCSH', 'FTCS', 'HEDJ', 'SMH', 'TLH', 'MINT']
# ETF_UNIVERSE = ['GDXJ', 'BIV', 'TECL', 'IAI', 'CGW', 'AOM', 'QQQ', 'XLP', 'OEF', 'EFA', 'BAB', 'KRE', 'FBT', 'CWB', 'VSS', 'XBI', 'IEF', 'FEZ', 'VDC', 'SDY', 'EPI', 'IWY', 'PFF', 'EWP', 'SHM', 'TFI', 'DHS', 'EMB', 'VHT', 'FDL', 'FXH', 'GSY', 'DLN', 'EWG', 'BLV', 'IWF', 'KBE', 'GLD', 'SUB', 'XLU', 'BSV', 'RWR', 'VPU', 'MUNI', 'MGK', 'VGSH', 'MINT', 'ACWX', 'VGIT']
# # best
# ETF_UNIVERSE = ['GDXJ', 'BIV', 'IAI', 'CGW', 'XLP', 'RWR', 'BAB', 'AOM', 'KRE', 'OEF', 'CWB', 'EFA', 'VDC', 'IEF', 'VSS', 'PFF', 'KBE', 'FDL', 'SDY', 'QQQ', 'GLD', 'EMB', 'FXH', 'VHT', 'EWP', 'DLN', 'XBI', 'DHS', 'TFI', 'BLV', 'GSY', 'SHM', 'MUNI', 'SUB', 'FBT', 'BSV', 'EPI', 'FEZ', 'MINT', 'VGSH', 'IWF']
# ETF_UNIVERSE = ['GDXJ', 'QQQ', 'BIV', 'CGW', 'BLV', 'XLP', 'IAI', 'OEF', 'RWR', 'BAB', 'AOM', 'CWB', 'IWF', 'EFA', 'IEF', 'PFF', 'VHT', 'GLD', 'VDC', 'MUNI', 'SUB', 'GSY', 'EMB', 'SHM', 'BSV', 'VGSH', 'TFI', 'MINT']
# ETF_UNIVERSE = ['GDXJ', 'IAI', 'BIV', 'EFA', 'QQQ', 'CWB', 'BAB', 'VHT', 'AOM', 'PFF', 'BLV', 'VDC', 'XLP', 'RWR', 'CGW', 'SUB', 'MUNI', 'GSY', 'OEF', 'IEF', 'MINT', 'TFI']
# ETF_UNIVERSE = ['GDXJ', 'IAI', 'QQQ', 'CWB', 'BIV', 'EFA', 'BAB', 'OEF', 'VHT', 'AOM', 'VDC', 'XLP', 'CGW', 'RWR', 'PFF', 'BLV', 'GSY', 'MUNI', 'SUB', 'TFI', 'MINT']
# ETF_UNIVERSE = ['GDXJ', 'IAI', 'QQQ', 'CWB', 'BIV', 'BAB', 'EFA', 'OEF', 'VHT', 'AOM', 'XLP', 'VDC', 'PFF', 'RWR', 'CGW', 'BLV', 'GSY', 'MUNI', 'SUB', 'TFI', 'MINT']

# # Maximize 0.6/0.4 train/val
# ETF_UNIVERSE = ['TECL', 'GDXJ', 'KRE', 'BIV', 'IAI', 'EWP', 'QQQ', 'FBT', 'SMH', 'CGW', 'OEF', 'AOM', 'EFA', 'XBI', 'XLP', 'UPRO', 'FEZ', 'IXC', 'KBE', 'BAB', 'RWR', 'FNX', 'SDY', 'MGK', 'DHS', 'IWF', 'EPI', 'ICF', 'ACWX', 'EWG', 'IWY', 'IWN', 'VSS', 'QQXT', 'IBB', 'DSI', 'IXN', 'SPXL', 'FDL', 'ONEQ', 'PEY', 'IEV', 'DLN', 'VDC', 'IJR', 'TNA', 'PWV', 'YINN', 'CWB', 'XLU', 'GLD', 'DIA', 'VTV', 'VPU', 'MGC', 'EWL', 'FXH', 'VHT',
# # best
# # TRAIN+VAL SHARPE: 1.1607498651113444
# # TRAIN SHARPE: 1.1740216363677691
# # VAL SHARPE: 1.165751174526206
# # BLIND SHARPE: 0.17817509436708348
# ETF_UNIVERSE = ['BIV', 'GDXJ', 'IAI', 'KRE', 'CGW', 'XLP', 'AOM', 'EFA', 'FDL', 'PWV', 'BAB', 'VPU', 'XBI', 'VSS', 'IEF', 'PFF', 'CWB', 'OEF', 'VDC', 'EWP', 'DHS', 'SDY', 'TFI', 'EPI', 'EMB', 'QQQ', 'DLN', 'BSV', 'GSY', 'SUB', 'VGSH', 'MINT', 'FXH', 'SPHQ']
# ETF_UNIVERSE = ['QQQ', 'GDXJ', 'BIV', 'CGW', 'XLP', 'IAI', 'OEF', 'AOM', 'BAB', 'IEF', 'KRE', 'CWB', 'EFA', 'FDL', 'XBI', 'VPU', 'VDC', 'VSS', 'SPHQ', 'TFI', 'SUB', 'PFF', 'EMB', 'GSY', 'BSV', 'PWV', 'VGSH', 'MINT', 'DHS']
# ETF_UNIVERSE = ['QQQ', 'BIV', 'GDXJ', 'XLP', 'IAI', 'CGW', 'AOM', 'OEF', 'BAB', 'EFA', 'CWB', 'FDL', 'VDC', 'IEF', 'VSS', 'PFF', 'DHS', 'KRE', 'PWV', 'TFI', 'XBI', 'SUB', 'BSV', 'SPHQ', 'VGSH', 'VPU', 'MINT', 'GSY']
# ETF_UNIVERSE = ['QQQ', 'BIV', 'XLP', 'GDXJ', 'CGW', 'AOM', 'IAI', 'OEF', 'BAB', 'CWB', 'EFA', 'FDL', 'VDC', 'VSS', 'XBI', 'IEF', 'PFF', 'DHS', 'PWV', 'TFI', 'SPHQ', 'KRE', 'SUB', 'BSV', 'VGSH', 'MINT', 'GSY']
# ETF_UNIVERSE = ['QQQ', 'BIV', 'CGW', 'XLP', 'OEF', 'IAI', 'AOM', 'GDXJ', 'EFA', 'CWB', 'BAB', 'FDL', 'VDC', 'PFF', 'VSS', 'KRE', 'IEF', 'PWV', 'XBI', 'DHS', 'TFI', 'SPHQ', 'BSV', 'SUB', 'GSY', 'VGSH', 'MINT']

# # Maximize 0.75/0.25 train/val
# ETF_UNIVERSE = ['BIV', 'SMH', 'KRE', 'EWP', 'IAI', 'AOM', 'FNX', 'DHS', 'EFA', 'CGW', 'ICF', 'FDL', 'SDY', 'YINN', 'FBT', 'GDXJ', 'BAB', 'TECL', 'XBI', 'EPI', 'PEY', 'OEF', 'DSI', 'RWR', 'PWV', 'IWN', 'ACWX', 'FEZ', 'IYF', 'GLD', 'XLP', 'UPRO', 'QQQ', 'IXC', 'VSS', 'QQXT', 'EWG', 'IJR', 'DLN', 'DIA', 'ONEQ', 'VTV', 'XLU', 'MGK', 'IWF', 'IWM', 'VPU', 'IEV', 'RPV', 'PRF', 'VDC', 'TNA', 'IXN', 'IBB', 'DTD', 'PW
# ETF_UNIVERSE = ['BIV', 'AOM', 'GDXJ', 'CGW', 'XBI', 'QQQ', 'XLP', 'FDL', 'VSS', 'PFF', 'EWP', 'IEF', 'PWV', 'CWB', 'IWY', 'IAI', 'SPHQ', 'EFA', 'TFI', 'SMH', 'GLD', 'KRE', 'GSY', 'VGLT', 'BSV', 'BAB', 'EMB', 'DIA', 'OEF', 'SHM', 'SUB', 'VDC', 'DSI', 'DHS', 'SDY', 'VGIT', 'NYF', 'MINT', 'VGSH']
# ETF_UNIVERSE = ['BIV', 'SMH', 'AOM', 'CGW', 'GLD', 'PFF', 'GDXJ', 'FDL', 'VSS', 'QQQ', 'KRE', 'XLP', 'XBI', 'PWV', 'CWB', 'EFA', 'IEF', 'EWP', 'IAI', 'SPHQ', 'TFI', 'BSV', 'GSY', 'SDY', 'DSI', 'DHS', 'SUB', 'SHM', 'VGLT', 'MINT', 'DIA', 'VGIT', 'VDC', 'VGSH', 'EMB']
# ETF_UNIVERSE = ['BIV', 'SMH', 'QQQ', 'CGW', 'AOM', 'GLD', 'PFF', 'XLP', 'GDXJ', 'FDL', 'VSS', 'XBI', 'IEF', 'PWV', 'KRE', 'CWB', 'IAI', 'SPHQ', 'DSI', 'GSY', 'BSV', 'EFA', 'TFI', 'DHS', 'SUB', 'EWP', 'SDY', 'EMB', 'SHM', 'VGLT', 'MINT', 'VGIT', 'VGSH']
# ETF_UNIVERSE = ['BIV', 'SMH', 'QQQ', 'CGW', 'PFF', 'AOM', 'GDXJ', 'XLP', 'GLD', 'FDL', 'VSS', 'PWV', 'IEF', 'CWB', 'XBI', 'EFA', 'KRE', 'SPHQ', 'IAI', 'DSI', 'DHS', 'GSY', 'TFI', 'BSV', 'SDY', 'SUB', 'EMB', 'MINT', 'VGIT', 'VGSH', 'VGLT']
# ETF_UNIVERSE = ['BIV', 'SMH', 'QQQ', 'AOM', 'FDL', 'CGW', 'PFF', 'PWV', 'XLP', 'EFA', 'VSS', 'GDXJ', 'IEF', 'CWB', 'IAI', 'DSI', 'DHS', 'XBI', 'SPHQ', 'GLD', 'GSY', 'SDY', 'KRE', 'BSV', 'TFI', 'SUB', 'MINT', 'VGLT', 'VGIT', 'VGSH']
# ETF_UNIVERSE = ['BIV', 'QQQ', 'AOM', 'SMH', 'FDL', 'PFF', 'VSS', 'CGW', 'EFA', 'PWV', 'XLP', 'IEF', 'CWB', 'XBI', 'GLD', 'DSI', 'DHS', 'SPHQ', 'GDXJ', 'SDY', 'GSY', 'IAI', 'BSV', 'TFI', 'KRE', 'SUB', 'VGLT', 'MINT', 'VGIT', 'VGSH']

# =========================
# SIGNAL AUTOCORR -- PICKED
# =========================
# # Maximize 0.5/0.5 train/val
# ETF_UNIVERSE = ['XBI', 'IGV', 'FPX', 'XME', 'RPV', 'SPMD', 'IJK', 'AOM', 'CQQQ', 'EWW', 'VCR', 'EWT', 'FXL', 'FBT', 'CGW', 'IBB', 'HYG', 'XLY', 'DES', 'IYH', 'ITA', 'YINN', 'KBE', 'IYC', 'VNQ', 'FNX', 'IWP', 'GDX', 'VXF', 'EWA', 'IAI', 'VBK', 'IXC', 'DEM', 'KRE', 'VHT', 'IWS', 'RSP', 'IYK', 'XLG', 'VIS', 'IJT', 'XLI', 
# ETF_UNIVERSE = ['XBI', 'IGV', 'FPX', 'CQQQ', 'SPMD', 'HYG', 'EWT', 'FXH', 'IJK', 'TFI', 'XLY', 'VCR', 'DEM', 'AOM', 'IYC', 'EWA', 'ITA', 'IYH', 'FBT', 'RPV', 'XLG', 'RSP', 'EPS', 'VNQ', 'GSY', 'QQEW', 'SOXX', 'MGC', 'SH', 'IWX', 'ONEQ', 'VTI', 'MINT', 'TIP', 'CWB', 'VTV', 'IJT', 'FTCS', 'RWL', 'IWD', 'IVW', 'VV', 'IWS', 'VIG', 'IYK', 'VPU', 'IYJ', 'IBB', 'DES', 'DIA', 'IWP', 'IXC', 'PWB', 'VGIT', 'IVE', 'SPY', 'IWV', 'IWR', 'PRF', 'BSV']
# ETF_UNIVERSE = ['XBI', 'IGV', 'CQQQ', 'FPX', 'RPV', 'SPMD', 'HYG', 'VCR', 'DEM', 'IJK', 'IYH', 'EWT', 'XLY', 'SH', 'TFI', 'FXH', 'EPS', 'ITA', 'IYC', 'AOM', 'GSY', 'SOXX', 'QQEW', 'ONEQ', 'IWX', 'FBT', 'MINT', 'RSP', 'XLG', 'MGC', 'FTCS', 'CWB', 'VTI', 'IXC']
# # # best
# # TRAIN+VAL SHARPE: 1.0383183952859834
# # TRAIN SHARPE: 1.0492959196690976
# # VAL SHARPE: 1.045794928666575
# # BLIND SHARPE: 0.7395142270892435
# ETF_UNIVERSE = ['XBI', 'IGV', 'CQQQ', 'ITA', 'FPX', 'DEM', 'XLY', 'RPV', 'IJK', 'VCR', 'SH', 'HYG', 'IYH', 'RSP', 'EPS', 'IYC', 'ONEQ', 'AOM', 'GSY', 'IWX', 'VTI', 'MINT', 'CWB', 'MGC', 'EWT', 'FTCS', 'SPMD']
# ETF_UNIVERSE = ['IGV', 'XBI', 'CQQQ', 'HYG', 'IJK', 'VCR', 'FPX', 'ITA', 'SH', 'XLY', 'IYH', 'RPV', 'IYC', 'GSY', 'ONEQ', 'EPS', 'AOM', 'DEM', 'RSP', 'IWX', 'MINT', 'VTI', 'FTCS', 'MGC']
# ETF_UNIVERSE = ['IGV', 'XBI', 'CQQQ', 'HYG', 'ITA', 'IJK', 'IYH', 'SH', 'VCR', 'XLY', 'DEM', 'EPS', 'GSY', 'IYC', 'IWX', 'FPX', 'RSP', 'ONEQ', 'MINT', 'RPV', 'AOM', 'VTI', 'FTCS']
# ETF_UNIVERSE = ['IGV', 'XBI', 'CQQQ', 'HYG', 'ITA', 'IJK', 'SH', 'IYH', 'VCR', 'XLY', 'DEM', 'EPS', 'GSY', 'IYC', 'IWX', 'FPX', 'MINT', 'ONEQ', 'RSP', 'RPV', 'AOM', 'VTI']
# ETF_UNIVERSE = ['IGV', 'XBI', 'CQQQ', 'HYG', 'ITA', 'IJK', 'SH', 'IYH', 'DEM', 'XLY', 'VCR', 'GSY', 'IYC', 'EPS', 'FPX', 'IWX', 'MINT', 'ONEQ', 'RSP', 'AOM', 'RPV', 'VTI']

# ETF_UNIVERSE = ['XBI', 'ITA', 'IGV', 'IYH', 'CQQQ', 'HYG', 'EPS', 'SOXX', 'XLY', 'DEM', 'IYC', 'RSP', 'VCR', 'DES', 'IWX', 'FBT', 'IBB', 'GSY', 'EWA', 'IJT', 'QQEW', 'IWP', 'PDP', 'FTCS', 'MINT', 'ONEQ', 'VV', 'VTI', 'TFI', 'MGC', 'QTEC', 'PEY', 'AOM']
# ETF_UNIVERSE = ['IGV', 'ITA', 'XBI', 'IYH', 'HYG', 'CQQQ', 'SOXX', 'EPS', 'DEM', 'XLY', 'QTEC', 'IYC', 'RSP', 'FBT', 'IWX', 'GSY', 'VCR', 'IBB', 'QQEW', 'IJT', 'DES', 'FTCS', 'MINT', 'PDP', 'TFI', 'IWP']
# ETF_UNIVERSE = ['CQQQ', 'IGV', 'HYG', 'XBI', 'ITA', 'IYH', 'SOXX', 'RSP', 'EPS', 'IBB', 'VCR', 'GSY', 'XLY', 'IYC', 'IWX', 'QTEC', 'FBT', 'DEM', 'FTCS', 'TFI', 'MINT']
# ETF_UNIVERSE = ['HYG', 'CQQQ', 'ITA', 'XBI', 'IYH', 'IBB', 'IGV', 'EPS', 'SOXX', 'RSP', 'IYC', 'FBT', 'IWX', 'GSY', 'VCR', 'DEM', 'XLY', 'TFI', 'QTEC', 'FTCS', 'MINT']
# ETF_UNIVERSE = ['HYG', 'CQQQ', 'ITA', 'XBI', 'IYH', 'IBB', 'IGV', 'EPS', 'SOXX', 'RSP', 'IYC', 'FBT', 'IWX', 'GSY', 'VCR', 'DEM', 'XLY', 'TFI', 'QTEC', 'FTCS', 'MINT']


# =========================
# TEST
# =========================

# ETF_UNIVERSE = ETF_UNIVERSE[:5]
# ETF_UNIVERSE = ETF_UNIVERSE[:6]
# ETF_UNIVERSE = ETF_UNIVERSE[:7]
# ETF_UNIVERSE = ETF_UNIVERSE[:8]
# ETF_UNIVERSE = ETF_UNIVERSE[:9]
# ETF_UNIVERSE = ETF_UNIVERSE[:10]
# ETF_UNIVERSE = ETF_UNIVERSE[:11]
# ETF_UNIVERSE = ETF_UNIVERSE[:12]
# ETF_UNIVERSE = ETF_UNIVERSE[:13]
# ETF_UNIVERSE = ETF_UNIVERSE[:14]
# ETF_UNIVERSE = ETF_UNIVERSE[:15] # 1.3816155312234528
# ETF_UNIVERSE = ETF_UNIVERSE[:20] # 1.4581661973741702
# ETF_UNIVERSE = ETF_UNIVERSE[:21] # 1.5050164810641276
# ETF_UNIVERSE = ETF_UNIVERSE[:22] # 1.5504382559196497
# ETF_UNIVERSE = ETF_UNIVERSE[:23] # 1.6303957159032645
# ETF_UNIVERSE = ETF_UNIVERSE[:24] # 1.6470394756880498
# ETF_UNIVERSE = ETF_UNIVERSE[:25] # 1.6204788091080229
# ETF_UNIVERSE = ETF_UNIVERSE[:26] # 1.6181462287785218
# ETF_UNIVERSE = ETF_UNIVERSE[:27] # 1.643269380534749
# ETF_UNIVERSE = ETF_UNIVERSE[:28] # 1.6938546920164046
# ETF_UNIVERSE = ETF_UNIVERSE[:29] # 1.6979770781751136
# ETF_UNIVERSE = ETF_UNIVERSE[:30] # 1.135467033526783
# ETF_UNIVERSE = ETF_UNIVERSE[:31] # 1.1309104955860128
# ETF_UNIVERSE = ETF_UNIVERSE[:32]
# ETF_UNIVERSE = ETF_UNIVERSE[:33]
# ETF_UNIVERSE = ETF_UNIVERSE[:34]
# ETF_UNIVERSE = ETF_UNIVERSE[:35]
# ETF_UNIVERSE = ETF_UNIVERSE[:36]
# ETF_UNIVERSE = ETF_UNIVERSE[:37]
# ETF_UNIVERSE = ETF_UNIVERSE[:38]
# ETF_UNIVERSE = ETF_UNIVERSE[:39]
# ETF_UNIVERSE = ETF_UNIVERSE[:40]
# ETF_UNIVERSE = ETF_UNIVERSE[:50]
# ETF_UNIVERSE = ETF_UNIVERSE[:60]
# ETF_UNIVERSE = ETF_UNIVERSE[:70]
# ETF_UNIVERSE = ETF_UNIVERSE[:80]
# ETF_UNIVERSE = ETF_UNIVERSE[:85]
# ETF_UNIVERSE = ETF_UNIVERSE[:90]
# ETF_UNIVERSE = ETF_UNIVERSE[:91]
# ETF_UNIVERSE = ETF_UNIVERSE[:92] # 1.175335243721979
# ETF_UNIVERSE = ETF_UNIVERSE[:93] # 1.1755104743389473
# ETF_UNIVERSE = ETF_UNIVERSE[:94] # 1.177900341573393
# ETF_UNIVERSE = ETF_UNIVERSE[:95] # 1.1741079512802084
# ETF_UNIVERSE = ETF_UNIVERSE[:100]
# ETF_UNIVERSE = ETF_UNIVERSE[:110]
# ETF_UNIVERSE = ETF_UNIVERSE[:120]

# ETF_UNIVERSE = [x for x in ETF_UNIVERSE if x not in BOND]

# import random
# ETF_UNIVERSE[:] = random.sample(ETF_UNIVERSE, 10)


TRAIN_START = "2000-01-01"
TRAIN_END   = "2015-12-31"
VAL_START   = "2016-01-01"
VAL_END     = "2021-12-31"
BLIND_START = "2022-01-01"
BLIND_END   = "2025-06-30"
SIGNAL_MAP = None


# =========================
# IMPORTS
# =========================

import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# =========================
# DATA LOADERS
# =========================

def fetch_etf(ticker):
    end = datetime.today().strftime("%Y-%m-%d")
    url = f"https://api.polygon.io/v2/aggs/ticker/{ticker}/range/1/day/{TRAIN_START}/{end}"
    params = {
        "adjusted": True,
        "sort": "asc",
        "limit": 50000,
        "apiKey": POLYGON_API_KEY
    }
    try:
        r = requests.get(url, params=params)
        r.raise_for_status()
        results = r.json().get("results")
        if not results: # Check if results list is empty or None
            print(f"Warning: No data found for {ticker} from Polygon API.")
            return None

        df = pd.DataFrame(results)
        df["Date"] = pd.to_datetime(df["t"], unit="ms")
        df = df.set_index("Date").sort_index()

        df = df.rename(columns={
            "o": "Open", "h": "High", "l": "Low",
            "c": "Close", "v": "Volume"
        })

        df["Returns"] = df["Close"].pct_change()
        return df[["Open", "High", "Low", "Close", "Volume", "Returns"]]
    except requests.exceptions.HTTPError as e:
        print(f"Error fetching data for {ticker}: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred while fetching data for {ticker}: {e}")
        return None

# =========================
# VIX LOADER (CACHED — LOAD ONCE ONLY)
# =========================

_VIX_CACHE = None   # global singleton

def fetch_vix(force_reload=False):
    """
    Loads VIX only once.
    Subsequent calls return cached copy.

    force_reload=True if you ever explicitly want refresh.
    """
    global _VIX_CACHE

    if _VIX_CACHE is not None and not force_reload:
        return _VIX_CACHE

    url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=VIXCLS"

    vix = pd.read_csv(url)
    vix.columns = [c.lower() for c in vix.columns]

    vix["observation_date"] = pd.to_datetime(vix["observation_date"])
    vix = vix.set_index("observation_date")["vixcls"]

    vix = vix.replace(".", np.nan).astype(float)
    vix.name = "VIX"

    _VIX_CACHE = vix   # cache

    return _VIX_CACHE


# =========================
# CORE OPERATORS
# =========================

def ts_rank(x, window):
    return x.rolling(window, min_periods=1).apply(
        lambda a: (a.argsort().argsort()[-1] + 1) / len(a), raw=True
    )

def ts_argmin(x, window):
    return x.rolling(window, min_periods=1).apply(np.argmin, raw=True)

def ts_mad(x, window):
    m = x.rolling(window, min_periods=1).mean()
    return (x - m).abs().rolling(window, min_periods=1).mean()

def ts_percentile(x, window, p):
    return x.rolling(window, min_periods=1).quantile(p)

def volatility(x, window):
    return x.rolling(window, min_periods=2).std()

def ts_mscore(x, window):
    ax = x.abs()
    s = ax.rolling(window, min_periods=1).sum()
    n = ax.rolling(window, min_periods=1).count()
    return ax * n / s

def scale_signal(x, cap=1.0):
    return x.replace({1.0: cap, -1.0: -1.0, 0.0: 0.0})

def apply_decay(signal, decay_days=5, mode="linear"):
    """
    Apply time decay to a signal.

    Parameters
    ----------
    signal : pd.Series
        Raw signal (e.g. -1, 0, +1)
    decay_days : int
        Number of days over which signal decays
    mode : str
        "linear" or "exponential"

    Returns
    -------
    pd.Series
        Decayed signal (point-in-time safe)
    """
    if decay_days <= 1:
        return signal

    if mode == "linear":
        weights = np.linspace(1.0, 0.0, decay_days)
    elif mode == "exponential":
        weights = np.exp(-np.arange(decay_days))
    else:
        raise ValueError("mode must be 'linear' or 'exponential'")

    weights = weights / weights.sum()

    return signal.rolling(
        window=decay_days,
        min_periods=1
    ).apply(lambda x: np.dot(x[::-1], weights[-len(x):]), raw=True)


# =========================
# SIGNAL REGISTRY (EXPLICIT)
# =========================

_SIGNAL_REGISTRY = []

def register_signal(fn):
    _SIGNAL_REGISTRY.append(fn)
    return fn

## TESTED
# Best: MUNI?, FDN?, QQQ
@register_signal
def signal_1(df, rank_window=189):
    x = df["Returns"].diff(2)
    x = ts_mad(x, 2)
    x = np.power(1.0 / x - 1.0, 0.5)
    x = ts_rank(x, rank_window) - 0.33
    # x = apply_decay(x, decay_days=5, mode="linear") # MUNI
    # x = x.rolling(5).mean()
    # return scale_signal(np.sign(x))
    return np.sign(x)
    # x = scale_signal(np.sign(x))
    # x = apply_decay(x, decay_days=5, mode="linear")
    # return x

# ## TESTED
# # Best: GDXJ
# @register_signal
# def signal_2(df, vol_win=126):
#     x = ts_percentile(df["Volume"], vol_win, 0.55)
#     # x = np.where(df["Returns"] < -0.028, x, 0)
#     # x = np.where(df["Returns"] < -0.1, x, 0)
#     x = np.where(df["Returns"] < -0.05, x, 0)
#     x = pd.Series(x, index=df.index)
#     x = volatility(x, vol_win)
#     x = ts_argmin(x, 252)
#     x = ts_rank(x, 21) - 0.5
#     # x = apply_decay(x, decay_days=5, mode="linear")
#     # return scale_signal(np.sign(x))
#     return -np.sign(x)

## TESTED
# Best: UPRO?, QQQ?, SHCB?
@register_signal
def signal_3(df, rank_window=189):
    x = np.sqrt(df["High"])
    x = volatility(x, 10)
    x = ts_mscore(1.0 / (x - 1.0), 4)
    x = ts_rank(x, rank_window) - 0.2
    # return scale_signal(np.sign(x))
    return np.sign(x)

# # # Best: BIL, SHV
# @register_signal
# def signal_4(df, mom=63, vol=21):
#     ret = df["Close"].pct_change(mom)
#     vol = df["Returns"].rolling(vol).std()
#     x = ret / vol
#     x = ts_rank(x, 252) - 0.5
#     # return scale_signal(np.sign(x))
#     # return -scale_signal(np.sign(x))
#     return -np.sign(x)

# ## TESTED
# # Best: BIL?
# # SPY SHARPE
# # Train: 0.07379135957493667
# # Val  : -0.11829372862784295
# @register_signal
# def signal_5(df, win=20):
#     rng = (df["High"] - df["Low"]) / df["Close"]
#     x = -ts_rank(rng, win)
#     x = ts_rank(x, 126) - 0.5
#     # return scale_signal(np.sign(x))
#     # return -scale_signal(np.sign(x))
#     return -np.sign(x)

# # Best: BIL, SHV
# # OPEN SHARPE NOT GOOD
# @register_signal
# def signal_6(df, mom=63, vol_win=21):
#     trend = df["Close"].pct_change(mom)
#     vol = ts_rank(df["Volume"], vol_win)
#     x = trend * vol
#     x = ts_rank(x, 252) - 0.5
#     # return scale_signal(np.sign(x))
#     # return -scale_signal(np.sign(x))
#     return -np.sign(x)

# # # Best: BIL, SHV-, VGSH-, VMBS-, BSV-
# # OPEN SHARPE NOT GOOD
# @register_signal
# def signal_7(df, ret_win=5, vol_win=21, decay_days=5):
#     ret = df["Returns"].rolling(ret_win).sum()
#     vol = df["Returns"].rolling(vol_win).std()
#     x = -ret / vol
#     x = ts_rank(x, 252) - 0.5

#     # x = apply_decay(x, decay_days=decay_days, mode="linear")
#     # return scale_signal(np.sign(x))
#     # x = scale_signal(np.sign(x))
#     x = np.sign(x)
#     # x = x.rolling(5).mean()
#     # x = apply_decay(x, decay_days=decay_days, mode="linear")
#     return x

# ## TESTED
# # WRONG
# @register_signal
# def signal_13(df, win=20):
#     skew = df["Returns"].rolling(win).skew()
#     x = -skew
#     x = ts_rank(x, 126) - 0.5
#     # return scale_signal(np.sign(x))
#     return -np.sign(x)

## TESTED
# NOT STRONG
@register_signal
def signal_8(df, win=20):
    gap = (df["Open"] - df["Close"].shift(1)) / df["Close"].shift(1)
    x = -gap
    x = ts_rank(x, win) - 0.5
    # x = apply_decay(x, decay_days=20, mode="linear")
    # return scale_signal(np.sign(x))
    return np.sign(x)

# # TESTED
# # WRONG
# @register_signal
# def signal_15(df, win=20):
#     up_days = (df["Returns"] > 0).rolling(win).mean()
#     x = up_days - 0.5
#     # return scale_signal(np.sign(x))
#     return np.sign(x)

## TESTED
# NOT STRONG
@register_signal
def signal_9(df, ret_win=21, vol_win=21):
    ret = df["Returns"].rolling(ret_win).sum()
    vol_chg = df["Returns"].rolling(vol_win).std().diff()
    x = ret * vol_chg
    x = ts_rank(x, 252) - 0.5
    # x = apply_decay(x, decay_days=20, mode="linear")
    # return -scale_signal(np.sign(x))
    return np.sign(x)

# # # Best: BIL, SHV, VGSH-, MINT-, SPYG-
# # OPEN SHARPE NOT GOOD
# # SPY NOT GOOD
# @register_signal
# def signal_10(df, win=20):
#     vwap = (df["Close"] * df["Volume"]).rolling(win).sum() / df["Volume"].rolling(win).sum()
#     dist = (df["Close"] - vwap) / vwap
#     x = -dist
#     x = ts_rank(x, 126) - 0.5

#     # x = apply_decay(x, decay_days=decay_days, mode="linear")
#     # return scale_signal(np.sign(x))
#     # x = scale_signal(np.sign(x))
#     x = np.sign(x)
#     # x = x.rolling(5).mean()
#     # x = apply_decay(x, decay_days=5, mode="linear")
#     return -x

# # Wrong
# @register_signal
# def signal_18(df, mom=63, vol_win=21):
#     trend = df["Close"].pct_change(mom)
#     vol = ts_rank(df["Returns"].rolling(vol_win).std(), 252)
#     x = trend * (1 - vol)
#     x = ts_rank(x, 252) - 0.5
#     return scale_signal(np.sign(x))



# def signal_6(df, vol_win=126):
#     x = ts_percentile(df["Volume"], vol_win, 0.55)
#     x = event(x, df["Returns"], -0.87, 2, 1)
#     x = volatility_fast(x, 126)
#     x = ts_argmin(x, 252)
#     x = ts_rank(x, 21) - 0.5
#     return scale_signal(-np.sign(x))

# # Best: VMBS?
# # OPEN SHARPE NOT GOOD
# @register_signal
# def signal_mr_1(df, win=5):
#     # 5-day return reversal
#     x = -df["Returns"].rolling(win).sum()
#     x = ts_rank(x, 252) - 0.5
#     # x = apply_decay(x, decay_days=5, mode="linear")
#     # return scale_signal(np.sign(x))
#     return np.sign(x)

# # NOT WORKING
# # OPEN SHARPE NOT GOOD
# @register_signal
# def signal_mr_2(df, win=10):
#     # Close-to-close exhaustion
#     ret = df["Close"].pct_change()
#     x = -ret.rolling(win).mean()
#     x = ts_rank(x, 126) - 0.5
#     # return scale_signal(np.sign(x))
#     return np.sign(x)

# # Best: ACWI, DXJ?, EWL?
# # OPEN SHARPE NOT GOOD
# @register_signal
# def signal_mr_3(df, win=3):
#     # Intraday range stretch
#     stretch = (df["Close"] - df["Open"]) / (df["High"] - df["Low"] + 1e-6)
#     x = -stretch.rolling(win).mean()
#     x = ts_rank(x, 126) - 0.5
#     # return scale_signal(np.sign(x))
#     return np.sign(x)

# SPY NOT GOOD
# TESTED
@register_signal
def signal_autocorr(df, win=42):
    """
    Detects serial correlation regime.
    Trendy assets -> long
    Mean reverting -> short
    """
    r = df["Returns"]

    ac = r.rolling(win).apply(
        lambda x: pd.Series(x).autocorr(lag=1),
        raw=False
    )

    return np.sign(ac)

# # OPEN NOT GOOD
# @register_signal
# def signal_drawdown_recovery(df, win=126):
#     """
#     Buy assets recovering from max drawdown.
#     Sell those still falling.
#     """
#     price = df["Close"]

#     peak = price.rolling(win).max()
#     dd = price / peak - 1

#     slope = dd.diff(5)   # recovery speed

#     x = ts_rank(slope, 252) - 0.5
#     return np.sign(x)

# POTENTIAL
# TESTED
@register_signal
def signal_entropy(df, win=40):
    """
    Lower entropy = more directional = trend friendly
    """
    r = df["Returns"]

    probs = (r > 0).rolling(win).mean()

    entropy = -(
        probs*np.log(probs+1e-9) +
        (1-probs)*np.log(1-probs+1e-9)
    )

    x = -ts_rank(entropy, 252) + 0.5
    return np.sign(x)

# ## TESTED
# @register_signal
# def signal_kurtosis(df, win=60):
#     kurt = df["Returns"].rolling(win).kurt()

#     x = -ts_rank(kurt, 252) + 0.5
#     return -np.sign(x)

# # POTENTIAL
# @register_signal
# def signal_convexity(df, win=20):
#     price = df["Close"]

#     accel = price.diff().diff()

#     x = ts_rank(accel, 252) - 0.5
#     return np.sign(x)

@register_signal
def signal_convexity_gap_adjusted(df, win=20):
    """
    Convexity + overnight gap structure.
    Better aligned with open execution.
    """

    gap = (df["Open"] - df["Close"].shift(1)) / df["Close"].shift(1)

    hist_price = df["Close"].shift(1)

    accel = hist_price.diff().diff()

    combo = accel + 0.5 * gap   # mix curvature + open info

    combo = combo.rolling(5).mean()

    x = ts_rank(combo, 252) - 0.5
    # x = apply_decay(x, decay_days=5, mode="linear")
    return -np.sign(x)

# ## TESTED -- NOT GOOD ENOUGH
# @register_signal
# def signal_time_underwater(df, win=126):
#     price = df["Close"]

#     peak = price.cummax()
#     underwater = (price < peak).astype(int)

#     tuw = underwater.rolling(win).sum()

#     x = -ts_rank(tuw, 252) + 0.5
#     return np.sign(x)

# # @register_signal
# # def signal_vol_asymmetry(df, win=40):
# #     r = df["Returns"]

# #     up = r.clip(lower=0).rolling(win).std()
# #     down = (-r.clip(upper=0)).rolling(win).std()

# #     asym = down - up

# #     x = -ts_rank(asym, 252) + 0.5
# #     return np.sign(x)

# # @register_signal
# # def signal_vol_cluster(df, win=40):
# #     r = df["Returns"]

# #     vol = r.abs()
# #     persistence = vol.rolling(win).corr(vol.shift(1))

# #     x = ts_rank(persistence, 252) - 0.5
# #     return np.sign(x)

# # @register_signal
# # def signal_trend_r2(df, win=40):
# #     price = df["Close"]

# #     def r2(x):
# #         t = np.arange(len(x))
# #         b = np.polyfit(t, x, 1)
# #         fit = np.polyval(b, t)
# #         ssr = ((x-fit)**2).sum()
# #         sst = ((x-x.mean())**2).sum()
# #         return 1 - ssr/sst

# #     r2_val = price.rolling(win).apply(r2, raw=False)

# #     x = ts_rank(r2_val, 252) - 0.5
# #     return np.sign(x)

## TESTED
@register_signal
def signal_run_length(df, win=40):
    r = np.sign(df["Returns"])

    run = (r != r.shift()).cumsum()
    streak = r.groupby(run).cumcount()

    avg_streak = streak.rolling(win).mean()

    x = -ts_rank(avg_streak, 252) + 0.5
    return np.sign(x)

# # @register_signal
# # def signal_return_quality(df, win=30):
# #     r = df["Returns"]
# #     vol = df["Volume"]

# #     quality = (r * vol).rolling(win).mean()

# #     x = ts_rank(quality, 252) - 0.5
# #     return np.sign(x)

# # @register_signal
# # def signal_round_anchor(df):
# #     price = df["Close"]

# #     anchor = (price/10).round()*10
# #     dist = (price-anchor)/anchor

# #     x = -ts_rank(np.abs(dist), 252) + 0.5
# #     return np.sign(x)

## TESTED
@register_signal
def signal_record_rate(df, win=120):
    price = df["Close"]

    rec_high = price == price.cummax()

    rate = rec_high.rolling(win).mean()

    x = ts_rank(rate, 252) - 0.5
    return np.sign(x)

# TESTED
@register_signal
def signal_time_since_volume_spike(df, win=60):
    vol = df["Volume"]

    spike = vol > vol.rolling(win).quantile(0.9)

    days = (~spike).cumsum() - (~spike).cumsum().where(spike).ffill().fillna(0)

    x = ts_rank(days, 252) - 0.5
    return np.sign(x)

## TESTED
@register_signal
def signal_return_iqr(df, win=40):
    r = df["Returns"]

    q75 = r.rolling(win).quantile(0.75)
    q25 = r.rolling(win).quantile(0.25)

    iqr = q75 - q25

    x = -ts_rank(iqr, 252) + 0.5
    return np.sign(x)

## TESTED
@register_signal
def signal_burstiness(df, win=40):
    r = df["Returns"].abs()

    mean = r.rolling(win).mean()
    std  = r.rolling(win).std()

    burst = std / (mean + 1e-9)

    x = -ts_rank(burst, 252) + 0.5
    return -np.sign(x)

## TESTED
## NOT GOOD GENERALIZATION
@register_signal
def signal_signed_volume_agreement(df, win=40):
    sign = np.sign(df["Returns"])
    vol = df["Volume"].pct_change()

    agree = (sign * vol > 0).astype(int)

    score = agree.rolling(win).mean()

    return -np.sign(score - 0.5)

# ## TESTED
# ## NOT GOOD GENERALIZATION
# @register_signal
# def signal_range_return_conflict(df, win=20):
#     r = df["Returns"]
#     rng = (df["High"] - df["Low"]) / df["Close"]

#     conflict = (r.abs() - rng).rolling(win).mean()

#     x = -ts_rank(conflict, 252) + 0.5
#     return -np.sign(x)

# ## TESTED
# ## NOT GOOD GENERALIZATION
# @register_signal
# def signal_price_volume_elasticity(df, win=30):
#     r = df["Returns"]
#     dv = df["Volume"].pct_change()

#     elas = (r / (dv.abs() + 1e-9)).rolling(win).mean()

#     x = ts_rank(elas, 252) - 0.5
#     return np.sign(x)

# ## TESTED
# # Not good generalization
# @register_signal
# def signal_volume_center_of_mass(df, win=30):
#     v = df["Volume"]

#     weights = np.arange(1, win+1)
#     com = v.rolling(win).apply(lambda x: (weights @ x) / x.sum(), raw=True)

#     x = ts_rank(com, 252) - 0.5
#     return np.sign(x)

## TESTED
@register_signal
def signal_path_efficiency(df, win=40):
    disp = (df["Close"] - df["Close"].shift(win)).abs()
    dist = df["Close"].diff().abs().rolling(win).sum()

    eff = disp / (dist + 1e-9)

    x = ts_rank(eff, 252) - 0.5
    return np.sign(x)

# ## TESTED
# @register_signal
# def signal_roughness(df, win=50):
#     r = df["Close"].diff().abs()

#     rough = r.rolling(win).sum() / (df["Close"].rolling(win).max() - df["Close"].rolling(win).min() + 1e-9)

#     x = -ts_rank(rough, 252) + 0.5
#     return np.sign(x)


# # TESTED
# @register_signal
# def signal_return_smoothness(df, win=40):

#     r = df["Returns"]

#     smooth = r.rolling(win).mean().abs()
#     noise  = r.abs().rolling(win).mean()

#     ratio = smooth / (noise + 1e-9)

#     x = ts_rank(ratio, 252) - 0.5

#     return np.sign(x)

# # TESTED
# @register_signal
# def signal_volume_shock(df, win=40):

#     v = df["Volume"]

#     shock = v / v.rolling(win).mean()

#     x = -ts_rank(shock, 252) + 0.5

#     return np.sign(x)

# TESTED
@register_signal
def signal_vol_of_vol(df, win=30):

    r = df["Returns"]

    vol = r.rolling(win).std()
    vov = vol.rolling(win).std()

    x = ts_rank(vov, 252) - 0.5

    return np.sign(x)

## TESTED
@register_signal
def signal_return_conviction(df, win=30):

    r = df["Returns"]

    intraday = (df["High"] - df["Low"]) / df["Close"]

    conviction = r.abs() / (intraday + 1e-9)

    x = ts_rank(conviction.rolling(win).mean(), 252) - 0.5

    return np.sign(x)

# ## TESTED
# @register_signal
# def signal_drift_stability(df, win=40):

#     r = df["Returns"]

#     drift = r.rolling(win).mean()
#     drift_vol = drift.rolling(win).std()

#     stability = drift / (drift_vol + 1e-9)

#     x = ts_rank(stability, 252) - 0.5

#     return np.sign(x)

## TESTED
@register_signal
def signal_price_volume_phase(df, win=40):

    r = df["Returns"]
    dv = df["Volume"].pct_change()

    phase = (r.shift(1) * dv).rolling(win).mean()

    x = ts_rank(phase, 252) - 0.5

    return -np.sign(x)

## TESTED
@register_signal
def signal_vol_compression_ratio(df, win=30):

    r = df["Returns"]

    short = r.rolling(10).std()
    long = r.rolling(win).std()

    ratio = short / (long + 1e-9)

    x = ts_rank(ratio, 252) - 0.5

    return np.sign(x)

## TESTED
@register_signal
def signal_liquidity_persistence(df, win=40):

    v = df["Volume"]

    shock = v / (v.rolling(win).mean() + 1e-9)

    persistence = shock.rolling(win).mean()

    x = ts_rank(persistence, 252) - 0.5

    return np.sign(x)

# ## TESTED
# @register_signal
# def signal_vol_drift_imbalance(df, win=40):

#     r = df["Returns"]

#     vol = r.rolling(win).std()
#     vol_drift = vol.diff()

#     drift = r.rolling(win).mean()

#     score = drift - vol_drift

#     x = ts_rank(score, 252) - 0.5
#     return np.sign(x)

# ## TESTED
# @register_signal
# def signal_direction_stability(df, win=40):

#     sign = np.sign(df["Returns"])

#     stability = sign.rolling(win).mean().abs()

#     x = ts_rank(stability, 252) - 0.5
#     return np.sign(x)

# =========================
# ETF → SIGNAL MAP
# =========================
SIGNAL_MAP = {
    # Good
    signal_1: ['ROM', 'XLU', 'QQQ', 'SH', 'FDN', 'PCY', 'TNA', 'IYK', 'GRID', 'ITA', 'IDU', 'XOP', 'IGOV', 'BSV', 'CMF', 'HEDJ', 'IGV', 'PXH', 'IWD', 'MUNI', 'VMBS', 'SCZ', 'MDYV', 'DLS', 'BWX', 'PWV', 'RWL', 'SPHQ', 'FTCS', 'BIL'],
    signal_entropy: ['TMF', 'DHS', 'XLV', 'IWC', 'XLK', 'IAI', 'VNQ', 'GDXJ', 'PCY', 'SIVR', 'VPL', 'PFF', 'BWX', 'KRE', 'FTCS', 'VOX', 'PID', 'SGOL', 'XLP', 'CQQQ', 'SPHQ', 'MUB', 'MBB', 'GSY', 'AOM', 'EWP', 'CWB', 'HYD', 'VSS', 'GRID', 'SUB', 'NYF', 'VGSH', 'ITOT', 'VCLT', 'MUNI', 'MINT', 'BIL', 'SHY'],
    signal_8: ['SHM', 'XSD', 'IEF', 'FXU', 'NYF', 'AGG', 'XLV', 'PWZ', 'FXI', 'IXJ', 'VGIT', 'IJH', 'SPYG', 'VMBS', 'MBB', 'BSV'],
    ## hurt a little
    signal_time_since_volume_spike: ['EEM', 'BIV', 'IJS', 'TLT', 'VBR', 'XBI', 'TECL', 'VDC', 'RWL', 'SH', 'VGLT', 'RWO', 'SDY', 'UPRO', 'FXO', 'VSS', 'EWU', 'FGD', 'IEI', 'SLYG', 'TIP', 'VXF', 'SCHX', 'SCHB', 'RWK', 'SCHG', 'CWB', 'VIS', 'QQQ', 'IUSG', 'IUSV', 'IEF', 'HEDJ', 'PWB', 'PHO', 'SCHV', 'PFF', 'SPY', 'AGG', 'FBT', 'VGSH', 'SHV', 'BIL'],
    ## hurt a little
    signal_autocorr: ['IGV', 'XBI', 'SH', 'IJK', 'ITA', 'HYG', 'IYH', 'CQQQ', 'VCR', 'GSY', 'FPX', 'IYC', 'IWX', 'MINT', 'XLY', 'EPS', 'RWL', 'VGIT'],
    # # hurt -- confirmed
    # signal_roughness: ['BIV', 'GDXJ', 'IAI', 'KRE', 'CGW', 'XLP', 'AOM', 'EFA', 'FDL', 'PWV', 'BAB', 'VPU', 'XBI', 'VSS', 'IEF', 'PFF', 'CWB', 'OEF', 'VDC', 'EWP', 'DHS', 'SDY', 'TFI', 'EPI', 'EMB', 'QQQ', 'DLN', 'BSV', 'GSY', 'SUB', 'VGSH', 'MINT', 'FXH', 'SPHQ'],
    signal_path_efficiency: ['FXU', 'ICLN', 'IDU', 'XBI', 'SH', 'FXH', 'GDXJ', 'AAXJ', 'PCY', 'MUB', 'QQXT', 'XLP', 'XLG', 'TFI', 'IWY', 'XLK', 'IYK', 'CQQQ', 'SDY', 'VDC', 'BIL', 'VGSH', 'MGK', 'IEI'],
    # Good
    signal_burstiness: ['IGV', 'EDV', 'EPP', 'VPU', 'FDN', 'FVD', 'DHS', 'RWL', 'XSD', 'FPX', 'VUG', 'SH', 'DVY', 'PGX', 'RWK', 'VCLT', 'EWL', 'SHM', 'VGT', 'BWX', 'GLD', 'SLYV', 'FNX', 'IGOV', 'IWY', 'XLP', 'IVW', 'FIW', 'IYC', 'HEDJ', 'BIV', 'BIL'],
    signal_signed_volume_agreement: ['VBK', 'FTA', 'FXL', 'GSG', 'IGV', 'MDY', 'SPMD', 'PID', 'RWL', 'UPRO', 'XLP', 'VCR', 'XOP', 'XSD', 'GDXJ', 'VDE', 'TIP', 'PDP', 'CMF', 'SHM', 'IGM', 'TECL', 'BLV', 'BND', 'FTCS', 'EMB', 'VCIT', 'MUB', 'SCHB', 'ITA', 'ITM', 'GVI', 'TFI', 'PWZ', 'BSV', 'VCSH', 'NYF', 'PZA', 'SPHQ', 'SHV', 'AOR'],
    # Good
    signal_9: ['GDX', 'EWL', 'XBI', 'XLP', 'FNX', 'PZA', 'EWJ', 'VDC', 'FXL', 'VCIT', 'IYK', 'GSY', 'HYD', 'MUB', 'IDU', 'MINT'],
    signal_run_length: ['XLU', 'EWY', 'VAW', 'GLD', 'ITM', 'CMF', 'BIV', 'VPU', 'VYM', 'AOM', 'VDC', 'DXJ', 'XLE', 'SLYV', 'ITA', 'DBC', 'PPA', 'VGLT', 'CWB', 'IWB', 'VHT', 'EMB', 'IHI', 'FVD', 'SPHQ', 'FEX', 'QQXT', 'IGOV', 'VGIT', 'KBE', 'VOT', 'BWX', 'VCLT', 'HYD', 'VMBS', 'PWZ', 'ITOT', 'VCIT', 'FTC', 'XOP', 'SHV', 'VCSH', 'MBB', 'SGOL', 'BIL'],
    # Good
    signal_record_rate: ['BAB', 'ITB', 'SH', 'RWL', 'SPMD', 'EWY', 'SCZ', 'DBC', 'VSS', 'TLT', 'EPI', 'AIA', 'CQQQ', 'VOX', 'DGS', 'PFF', 'FXU', 'IGOV', 'GLD', 'EDV', 'TIP', 'SHM', 'PWZ', 'DLS', 'NYF', 'MUNI', 'VMBS', 'SUB'],
    # Good
    signal_return_iqr: ['DEM', 'SH', 'IGOV', 'IDU', 'SMH', 'IXJ', 'SCHF', 'TFI', 'FDL', 'MUB', 'FGD', 'PHO', 'BWX', 'DGS', 'XLY', 'DTD'],
    # Good
    # signal_range_return_conflict: ['CQQQ', 'EWW', 'AGQ', 'XLP', 'PXH', 'ITM', 'AOR', 'QQXT', 'HYG', 'IWR', 'TECL', 'IHI', 'GRID', 'IYK', 'SPY', 'PGX', 'GVI', 'GSY', 'TLH', 'NYF', 'XLU', 'VPL', 'HYD', 'VCR', 'VT', 'SHY', 'MBB', 'SHV', 'BSV', 'BIL', 'VV', 'VCIT', 'TFI', 'BND', 'VGSH', 'VCSH', 'IVW'],
    # signal_price_volume_elasticity: ['GLD', 'ITB', 'USO', 'VO', 'TLT', 'RWJ', 'SPYV', 'VSS', 'ICLN', 'SCHA', 'EMB', 'XSD', 'VGIT', 'PKW', 'PCY', 'DBC', 'SCHX', 'MUNI', 'PWZ', 'EFV', 'BLV', 'VCSH', 'MINT'],
    # signal_volume_center_of_mass: ['IYE', 'GLD', 'CQQQ', 'PWV', 'BAB', 'SIVR', 'XSD', 'PDP', 'IWM', 'VT', 'HYG', 'ZROZ', 'IWC', 'SHM', 'PXH', 'SPMD', 'EWT', 'SCHV', 'TLH', 'SPYG', 'IWL', 'VCLT', 'CGW', 'GSG', 'JNK', 'EWG', 'EMB', 'VCIT', 'SCHF', 'IWX', 'SLYG', 'AOR', 'FGD', 'PWZ', 'MUNI', 'FXL', 'MUB', 'VMBS', 'FTCS', 'BSV', 'BIL', 'TFI', 'SUB', 'SHV', 'GVI', 'MINT', 'VGSH'],
    # signal_kurtosis: ['SOXX', 'SH', 'ONEQ', 'GSG', 'ICLN', 'EWL', 'HEDJ', 'QQQ', 'BWX', 'XLG', 'RWO', 'PGX', 'VCLT', 'TIP', 'BND', 'FXU', 'VGSH'],
    # Good
    signal_convexity_gap_adjusted: ['GDX', 'USD', 'TECL', 'EWT', 'FNX', 'VPU', 'DBC', 'VYM', 'CWB', 'MDYV', 'GRID', 'UPRO', 'BWX', 'VMBS', 'SUB', 'EWS', 'SHY', 'VCR', 'SPHQ', 'IUSG', 'SCHG', 'DVY', 'SHV', 'PCY', 'VCSH', 'BIL', 'FVD', 'IWY'],
    # signal_time_underwater: ['AAXJ', 'TECL', 'VOX', 'SH', 'PHO', 'GLD', 'FNX', 'MGK', 'RPV', 'PXH', 'HYD', 'PPA', 'EWP', 'FXL', 'SLV', 'DEM', 'SHY', 'FXI', 'DBC', 'MUNI', 'HYG', 'EFV', 'VCIT', 'VCSH', 'VMBS'],

    # signal_2: ['PZA', 'USD', 'SLV', 'PDP', 'EWJ', 'XLG', 'FXI', 'FGD', 'SSO', 'EDV', 'EFA', 'SH', 'ILF', 'ZROZ', 'PGX', 'GSG', 'HYG', 'EXI', 'EFV', 'FXR', 'FTA', 'IDV', 'SCHF', 'SLYV', 'RWK', 'PWZ', 'CWI', 'JNK', 'VEA', 'FEX', 'FIW', 'VT', 'ACWX', 'VEU', 'IWX', 'PEY', 'DBC', 'MGV', 'IGOV', 'AAXJ', 'PID', 'VOE', 'GRID', 'DON', 'BWX', 'IWL', 'EEM', 'BIL'],
    signal_3: ['FXU', 'SPAB', 'PZA', 'PGX', 'IAU', 'EWW', 'EWS', 'IXJ', 'IYC', 'ICF', 'XOP', 'HYG', 'IYH', 'SPXL', 'EWZ', 'AAXJ', 'HEDJ', 'CQQQ', 'MBB', 'VMBS', 'TIP', 'MUB', 'DGS', 'PFF', 'AGG', 'GSY', 'FXH', 'FXI', 'IYF', 'IVV', 'FXO', 'BLV', 'VIG', 'ITM', 'GVI', 'IYG', 'IAI', 'FTCS', 'SPY', 'IGV', 'SCHX', 'SCHB', 'DVY', 'VGT', 'FDL', 'IWO', 'IWL', 'FVD', 'VV', 'XLY', 'IWD', 'IEV', 'IVE', 'SDY', 'VHT'],

    # signal_13: ['AGQ', 'IBB', 'IXC', 'RWJ', 'BIV', 'EWJ', 'QQXT', 'RWO', 'RWK', 'SLYV', 'IJS', 'VCIT', 'FTA', 'PWZ', 'BWX', 'EMB', 'DON', 'EWW', 'TIP', 'CMF', 'PGX', 'USO', 'ITM'],
    # signal_15: ['SPMD', 'EPI', 'ICLN', 'USO', 'XBI', 'QQQ', 'IDV', 'GRID', 'IOO', 'FXH', 'VSS', 'IWC', 'TECL', 'RWK', 'DEM', 'MUNI', 'QTEC', 'JNK', 'EWW', 'IWY'],

    # signal_5: ['SLYV', 'SH', 'SHM', 'DBC', 'EWW', 'BAB', 'EWZ', 'DXJ', 'EMB', 'FXU', 'VGIT', 'PWZ', 'IXJ', 'GDX', 'FXR', 'RPV', 'IGOV', 'BIL', 'FDL', 'XOP', 'MBB', 'MUNI', 'EWS', 'NYF', 'XLP', 'BSV', 'IYR', 'VGSH', 'MUB', 'VCSH'],
    # signal_10: ['PFF', 'BIV', 'CQQQ', 'SIVR', 'SLYV', 'MUNI', 'FTCS', 'ITOT'],

    # signal_return_smoothness: ['GDXJ', 'SH', 'XBI', 'XLG', 'AAXJ', 'ICLN', 'XLP', 'IDU', 'IWY', 'IYW', 'FXU', 'FXH', 'VDC', 'XLF', 'VPU', 'PCY', 'MUB', 'TFI', 'IEI', 'RWL', 'EMB', 'QQXT', 'VGSH', 'BIL'],
    # signal_volume_shock: ['IYR', 'EZU', 'IDV', 'XLU', 'XLG', 'EWS', 'PZA', 'XME', 'MDYG', 'FTA', 'RSP', 'RWR', 'HEDJ', 'VPU', 'DSI', 'AGG', 'XLY', 'VUG', 'QQQ', 'XLV', 'IUSG', 'IWD', 'DES', 'VPL', 'VGLT', 'VGK', 'ITOT', 'VOT', 'VCIT', 'VIG', 'VSS', 'IVV', 'BSV', 'IYW', 'SHY', 'SGOL', 'SCHA', 'AAXJ', 'SCHX', 'SDY', 'SHV', 'TECL', 'VCSH', 'MINT', 'TLT', 'SUB'],
    signal_vol_of_vol: ['FBT', 'RWJ', 'PGX', 'FTA', 'SH', 'DBC', 'PWB', 'FXL', 'GLD', 'IVW', 'TIP', 'IEI', 'BWX', 'VT', 'VCLT', 'XLV', 'MINT', 'BIL'],
    signal_return_conviction: ['SIVR', 'EWJ', 'GRID', 'SH', 'JNK', 'ACWX', 'IYC', 'IXJ', 'SHM', 'FXU', 'CQQQ', 'TLH', 'VCSH', 'PGX', 'MUNI', 'SUB', 'XLG', 'TFI', 'SHY', 'VMBS', 'VGSH', 'SHV', 'MINT'],
    # signal_drift_stability: ['ICLN', 'XBI', 'IBB', 'EWT', 'EWP', 'FBT', 'GSG', 'DBC', 'DGS', 'EDV', 'KRE', 'GDXJ', 'EWC', 'KBE', 'DEM', 'PXH', 'EMB', 'EZU', 'AIA', 'DLS', 'VHT', 'CGW', 'BWX', 'NYF', 'VAW', 'IEI', 'CQQQ', 'XLV', 'PXF', 'IGOV', 'EWG', 'SCZ'],
    signal_price_volume_phase: ['SPAB', 'UPRO', 'PWV', 'TNA', 'SLV', 'AGQ', 'IWR', 'VB', 'EWW', 'FIW', 'IJJ', 'BIV', 'AAXJ', 'FAS', 'GLD', 'RPG', 'TLT', 'QTEC', 'PZA', 'CQQQ', 'HYD', 'PDP', 'EWZ', 'VDC', 'RWL', 'KRE', 'SCHX', 'XLG', 'FDN', 'AOR', 'VAW', 'QQQ', 'TECL', 'SMH', 'DES', 'QLD', 'XSD', 'MGC', 'IYH', 'IYC', 'EPI', 'IWC', 'IYK', 'RWJ', 'SOXX', 'BND', 'FBT', 'XLU', 'GSY', 'MUB', 'SHM', 'EFV', 'JNK', 'IJS', 'EFG', 'OEF', 'MUNI', 'SIVR', 'VDE', 'QQXT', 'CMF', 'MINT', 'RSP', 'VFH'],
    signal_vol_compression_ratio: ['FBT', 'PPA', 'XLG', 'SH', 'EWS', 'DXJ', 'XME', 'IYG', 'BIV', 'GLD', 'XLP', 'PWZ', 'TMF', 'BWX', 'SHM', 'VGK', 'SCZ', 'AAXJ', 'HYG', 'SGOL', 'NYF', 'IEV', 'GSY', 'MINT', 'SHV', 'BIL', 'VGIT', 'SUB', 'TLH', 'VMBS'],
    signal_liquidity_persistence: ['RWR', 'FTC', 'EPI', 'RWK', 'RWJ', 'EPS', 'IWN', 'RPV', 'EDV', 'DVY', 'EZU', 'SH', 'FXH', 'BAB', 'SOXX', 'DTD', 'GDXJ', 'UYG', 'SLYG', 'XLP', 'TLH', 'SPMD', 'LQD', 'OEF', 'CMF', 'VT', 'SHM', 'EWP', 'SPYG', 'QQXT', 'VCIT', 'NYF', 'VCLT', 'FEX', 'IGOV', 'MGV', 'IEF', 'VGLT', 'SHV', 'USO'],
    # signal_vol_drift_imbalance: ['XBI', 'DGS', 'ICLN', 'EWG', 'DBC', 'DEM', 'IGF', 'VPU', 'MDYV', 'SCZ', 'RWK', 'EMB', 'VOT'],
    # signal_direction_stability: ['BAB', 'XLK', 'GDXJ', 'PGX', 'UYG', 'PFF', 'IXC', 'XBI', 'VOX', 'XLV', 'PCY', 'FXO', 'ICLN', 'QQQ', 'FXR', 'FYX', 'IWM', 'FGD', 'PEY', 'EFA', 'TMF', 'FXL', 'EPI', 'RWR', 'VT', 'XLG', 'PXH', 'VNQ', 'ACWI', 'DHS', 'BWX', 'SPHQ', 'GLD', 'SCHA', 'GRID', 'EDV', 'SIVR', 'MDYV', 'MDYG', 'HEDJ', 'GSY', 'SPYV', 'TFI', 'IVE', 'MBB', 'NYF', 'FXU', 'TECL', 'MUB', 'SCHF', 'SPMD', 'SUB', 'VGSH', 'SGOL'],



}

# =========================
# LOAD DATA (CACHED + SAFE)
# =========================

ALWAYS_REQUIRED = ["SPY"]

# ---------------------------------
# Session cache (prevents API spam)
# ---------------------------------
# ---------------------------------
# Persistent session cache
# (survives cell reruns)
# ---------------------------------
try:
    _ETF_CACHE
except NameError:
    _ETF_CACHE = {}   # only created once per kernel


def load_price_data(trading_universe):
    """
    Cached deterministic loader.

    Guarantees:
        • each ETF fetched at most ONCE per session
        • no duplicate API calls
        • safe to rerun notebook cells
        • SPY always included
        • prints HIT / FETCH / FAIL
    """

    required = sorted(set(trading_universe) | set(ALWAYS_REQUIRED))

    data = {}
    hits = []
    fetched = []
    failed = []

    print("\nLoading ETF data...\n")

    for ticker in required:

        # =========================
        # CACHE HIT
        # =========================
        if ticker in _ETF_CACHE:
            data[ticker] = _ETF_CACHE[ticker]
            hits.append(ticker)
            continue

        # =========================
        # CACHE MISS → fetch once
        # =========================
        df = fetch_etf(ticker)

        if df is not None:
            _ETF_CACHE[ticker] = df
            data[ticker] = df
            fetched.append(ticker)
        else:
            failed.append(ticker)

    # =========================
    # Logging summary
    # =========================
    if hits:
        print(f"✓ Cache hits   ({len(hits)}): {hits}")

    if fetched:
        print(f"↓ Fetched new ({len(fetched)}): {fetched}")

    if failed:
        print(f"✗ Failed      ({len(failed)}): {failed}")

    print()

    return data

# =========================================
# BUILD ACTIVE TRADING UNIVERSE
# =========================================
# IMPORTANT:
#   Portfolio uses SIGNAL_MAP keys if present
#   Otherwise ETF_UNIVERSE
# =========================================

# if SIGNAL_MAP is not None and len(SIGNAL_MAP) > 0:
#     ACTIVE_UNIVERSE = list(SIGNAL_MAP.keys())
# else:
#     ACTIVE_UNIVERSE = list(ETF_UNIVERSE)
# -----------------------------------------
# Resolve active ETF universe automatically
# -----------------------------------------

if SIGNAL_MAP is not None and len(SIGNAL_MAP) > 0:

    first_key = next(iter(SIGNAL_MAP.keys()))

    if callable(first_key):
        # Mode 3 (signal → ETF)
        ACTIVE_UNIVERSE = sorted({
            etf for lst in SIGNAL_MAP.values() for etf in lst
        })
    else:
        # Mode 2 (ETF → signal)
        ACTIVE_UNIVERSE = list(SIGNAL_MAP.keys())

else:
    ACTIVE_UNIVERSE = list(ETF_UNIVERSE)



# =========================================
# LOAD EVERYTHING
# =========================================

price_data = load_price_data(ACTIVE_UNIVERSE)

# SPY safety (must exist for robustness tests)
if "SPY" not in price_data:
    raise RuntimeError("SPY failed to load — required for metrics/robustness.")

# VIX load (unchanged logic)
vix = fetch_vix()
print("VIX data loaded successfully.")


# =========================
# BACKTEST CORE
# =========================

def compute_pnl(position, returns, leverage_cap=None):
    """
    Single-asset PnL.

    clipping only applied if explicitly requested.
    """
    pos = position.copy()

    if leverage_cap is not None:
        pos = pos.clip(-1.0, leverage_cap)

    return pos.shift(1) * returns


def compute_open_pnl(position, df, leverage_cap=None):
    """
    Open-to-open PnL.

    For portfolio weights:
        leverage_cap=None  → no clipping

    For raw/single-asset:
        pass leverage_cap to enforce safety
    """

    pos = position.copy()

    if leverage_cap is not None:
        pos = pos.clip(-1.0, leverage_cap)

    return pos.shift(1) * df["Open"].pct_change()


# Moved the more robust sharpe function here
def sharpe(returns, ann_factor=252):
    returns = returns.dropna()
    if returns.std() == 0 or len(returns) < 20:
        return np.nan
    return np.sqrt(ann_factor) * returns.mean() / returns.std()


# CONTINUOUS EQUITY CURVE

def equity_curve(pnl_series):
    """
    Continuous cumulative return curve.
    NEVER resets across train/val/blind.

    pnl_series : daily pnl/returns

    Returns
    -------
    cumulative equity series
    """
    pnl_series = pnl_series.fillna(0)
    return (1 + pnl_series).cumprod()

# TURNOVER & MARGIN

def compute_turnover(position):
    """
    Daily portfolio turnover.

    Works for:
        Series  -> scalar per day
        DataFrame -> sums across assets
    """
    to = position.diff().abs().fillna(0)

    if isinstance(to, pd.DataFrame):
        return to.sum(axis=1)   # aggregate book turnover
    else:
        return to


def average_turnover(position):
    """
    Average daily turnover (% of book)
    """
    return 100 * compute_turnover(position).mean()

def compute_margin(pnl, position):
    """
    Margin = total PnL / total dollars traded
    Returned in basis points (bps)
    """
    dollars_traded = compute_turnover(position).sum()

    if dollars_traded == 0 or np.isnan(dollars_traded):
        return np.nan
    return 1e4 * pnl.sum() / dollars_traded


# ETF MARGINAL VALUE-ADD (Sharpe impact)

def compute_os_is_value_add(
    positions,
    returns_df,
    is_start,
    is_end,
    os_start,
    os_end
):
    """
    Marginal improvement in OS/IS Sharpe stability.

    score > 0  -> removing ETF improves robustness (closer to 1)
    score < 0  -> removing ETF hurts robustness

    Uses:
        IS = train + val
        OS = blind
        Requires both Sharpes > 0
    """

    pnl = positions.shift(1) * returns_df

    # ----- full portfolio -----
    full = pnl.sum(axis=1)

    is_full = sharpe(full.loc[is_start:is_end])
    os_full = sharpe(full.loc[os_start:os_end])

    if is_full <= 0 or os_full <= 0:
        return pd.Series(dtype=float)

    ratio_full = os_full / is_full
    stability_full = abs(ratio_full - 1)

    scores = {}

    for col in positions.columns:

        reduced = pnl.drop(columns=[col]).sum(axis=1)

        is_s = sharpe(reduced.loc[is_start:is_end])
        os_s = sharpe(reduced.loc[os_start:os_end])

        # enforce positive Sharpe
        if is_s <= 0 or os_s <= 0:
            scores[col] = -np.inf
            continue

        ratio_drop = os_s / is_s
        stability_drop = abs(ratio_drop - 1)

        # improvement if closer to 1
        scores[col] = stability_full - stability_drop

    return pd.Series(scores).sort_values(ascending=False)

def compute_train_val_value_add(
    positions,
    returns_df,
    train_start,
    train_end,
    val_start,
    val_end
):
    """
    Marginal contribution to portfolio quality.

    score > 0  -> ETF HELPS portfolio (removing hurts)
    score < 0  -> ETF HURTS portfolio (removing improves)

    Rules:
        • evaluate train + val Sharpe separately
        • no trade-offs allowed
        • only Pareto improvements count
    """

    pnl = positions.shift(1) * returns_df

    full = pnl.sum(axis=1)

    train_full = sharpe(full.loc[train_start:train_end])
    val_full   = sharpe(full.loc[val_start:val_end])

    scores = {}

    for col in positions.columns:

        reduced = pnl.drop(columns=[col]).sum(axis=1)

        train_s = sharpe(reduced.loc[train_start:train_end])
        val_s   = sharpe(reduced.loc[val_start:val_end])

        d_train = train_full - train_s
        d_val   = val_full - val_s

        # removal hurts both -> ETF helps
        if d_train >= 0 and d_val >= 0:
            scores[col] = d_train + d_val

        # removal helps both -> ETF hurts
        elif d_train <= 0 and d_val <= 0:
            scores[col] = d_train + d_val  # negative

        # trade-off → treat as neutral (or slight penalty)
        else:
            scores[col] = 0.0

    return pd.Series(scores).sort_values(ascending=False)

def compute_train_full_value_add(
    positions,
    returns_df,
    train_start,
    train_end
):
    """
    Marginal contribution using Train and Full Sharpe.

    score > 0  -> ETF HELPS portfolio (removing hurts)
    score < 0  -> ETF HURTS portfolio (removing helps)
    score = 0  -> trade-off / unclear

    Rules:
        • removal must hurt BOTH train and full to be positive
        • removal must help BOTH to be negative
        • trade-offs treated as neutral
    """

    pnl = positions.shift(1) * returns_df

    full_pnl = pnl.sum(axis=1)

    train_full = sharpe(full_pnl.loc[train_start:train_end])
    full_full  = sharpe(full_pnl)

    scores = {}

    for col in positions.columns:

        reduced = pnl.drop(columns=[col]).sum(axis=1)

        train_s = sharpe(reduced.loc[train_start:train_end])
        full_s  = sharpe(reduced)

        d_train = train_full - train_s
        d_full  = full_full  - full_s

        # removal hurts both → ETF helps
        if d_train >= 0 and d_full >= 0:
            scores[col] = d_train + d_full

        # removal helps both → ETF hurts
        elif d_train <= 0 and d_full <= 0:
            scores[col] = d_train + d_full  # negative

        # trade-off
        else:
            scores[col] = 0.0

    return pd.Series(scores).sort_values(ascending=False)

def compute_trainval_blind_value_add(
    positions,
    returns_df,
    is_start,
    is_end,      # train + val combined
    os_start,
    os_end       # blind only
):
    """
    Marginal contribution using:

        IS = train + val
        OS = blind

    score > 0  -> ETF HELPS portfolio (removal hurts both)
    score < 0  -> ETF HURTS portfolio (removal improves both)
    score = 0  -> trade-off / unclear
    """

    pnl = positions.shift(1) * returns_df

    full = pnl.sum(axis=1)

    is_full = sharpe(full.loc[is_start:is_end])
    os_full = sharpe(full.loc[os_start:os_end])

    scores = {}

    for col in positions.columns:

        reduced = pnl.drop(columns=[col]).sum(axis=1)

        is_s = sharpe(reduced.loc[is_start:is_end])
        os_s = sharpe(reduced.loc[os_start:os_end])

        d_is = is_full - is_s
        d_os = os_full - os_s

        # removal hurts both → ETF helps
        if d_is >= 0 and d_os >= 0:
            scores[col] = d_is + d_os

        # removal helps both → ETF hurts
        elif d_is <= 0 and d_os <= 0:
            scores[col] = d_is + d_os  # negative

        # trade-off
        else:
            scores[col] = 0.0

    return pd.Series(scores).sort_values(ascending=False)

def compute_train_val_blind_value_add(
    positions,
    returns_df,
    train_start,
    train_end,
    val_start,
    val_end,
    blind_start,
    blind_end
):
    """
    Marginal contribution using Train, Val, Blind Sharpe.

    score > 0  -> ETF HELPS portfolio (removal hurts all)
    score < 0  -> ETF HURTS portfolio (removal helps all)
    score = 0  -> trade-off / unclear

    Strict Pareto dominance across all 3 regimes.
    """

    pnl = positions.shift(1) * returns_df

    full = pnl.sum(axis=1)

    train_full = sharpe(full.loc[train_start:train_end])
    val_full   = sharpe(full.loc[val_start:val_end])
    blind_full = sharpe(full.loc[blind_start:blind_end])

    scores = {}

    for col in positions.columns:

        reduced = pnl.drop(columns=[col]).sum(axis=1)

        train_s = sharpe(reduced.loc[train_start:train_end])
        val_s   = sharpe(reduced.loc[val_start:val_end])
        blind_s = sharpe(reduced.loc[blind_start:blind_end])

        d_train = train_full - train_s
        d_val   = val_full   - val_s
        d_blind = blind_full - blind_s

        # removal hurts all → ETF helps
        if d_train >= 0 and d_val >= 0 and d_blind >= 0:
            scores[col] = d_train + d_val + d_blind

        # removal helps all → ETF hurts
        elif d_train <= 0 and d_val <= 0 and d_blind <= 0:
            scores[col] = d_train + d_val + d_blind

        # mixed → neutral
        else:
            scores[col] = 0.0

    return pd.Series(scores).sort_values(ascending=False)

def compute_train_val_weighted_value_add(
    positions,
    returns_df,
    train_start,
    train_end,
    val_start,
    val_end,
    w_train=0.5,
    w_val=0.5
):
    """
    Marginal ETF contribution using weighted Sharpe of Train + Val only.

    Blind is NOT used for scoring.

    score > 0  -> ETF helps portfolio
    score < 0  -> ETF hurts portfolio

    WeightedSharpe =
        w_train * Sharpe(train)
      + w_val   * Sharpe(val)
    """

    pnl = positions.shift(1) * returns_df

    full = pnl.sum(axis=1)

    def weighted_sharpe(series):
        s_train = sharpe(series.loc[train_start:train_end])
        s_val   = sharpe(series.loc[val_start:val_end])

        return w_train * s_train + w_val * s_val

    ws_full = weighted_sharpe(full)

    scores = {}

    for col in positions.columns:

        reduced = pnl.drop(columns=[col]).sum(axis=1)

        ws_drop = weighted_sharpe(reduced)

        scores[col] = ws_full - ws_drop

    return pd.Series(scores).sort_values(ascending=False)

def compute_value_add_scores(positions, returns_df):
    """
    Marginal Sharpe improvement from each ETF.

    > 0  -> helps portfolio
    < 0  -> hurts / redundant
    """

    full_pnl = (positions.shift(1) * returns_df).sum(axis=1)
    base_sharpe = sharpe(full_pnl)

    scores = {}

    for col in positions.columns:

        reduced_pos = positions.drop(columns=[col])
        reduced_ret = returns_df.drop(columns=[col])

        pnl = (reduced_pos.shift(1) * reduced_ret).sum(axis=1)

        scores[col] = base_sharpe - sharpe(pnl)

    return pd.Series(scores).sort_values(ascending=False)


def select_etfs_by_value_add(positions, returns_df, label="train"):
    """
    Compute value-add scores on ANY period slice.

    label:
        "train", "val", "train_val", "blind", "full"
    """

    scores = compute_value_add_scores(positions, returns_df)

    print(f"\n=== ETF VALUE-ADD SCORES ({label.upper()}) ===")
    print(scores.round(4))

    passed_etfs = scores[scores > 0].index.tolist()

    print("ETF_UNIVERSE = " + str(passed_etfs) + "\n")

    return scores, passed_etfs


def compute_portfolio_pnl_with_costs(
    positions,
    returns_df,
    cost_bps=0,
    leverage_cap=None
):
    """
    Cost-aware portfolio PnL.

    positions : DataFrame of weights
    returns_df : DataFrame of returns
    cost_bps : round-trip bps per 1.0 turnover

    Returns
    -------
    pnl_series

    IMPORTANT:
    Portfolio weights are already normalized by build_long_short_portfolio.
    Therefore NO clipping by default.
    """

    pos = positions.copy()

    if leverage_cap is not None:
        pos = pos.clip(-1.0, leverage_cap)

    # gross pnl (already correct + no lookahead)
    gross = (pos.shift(1) * returns_df).sum(axis=1)

    if cost_bps == 0:
        return gross

    turnover = compute_turnover(pos)

    cost = turnover * (cost_bps / 1e4)

    return gross - cost


def rescale_books(positions, long_target=1.0, short_target=1.0):
    """
    Proportionally rescales daily long/short books so that:

        sum(long weights)  = long_target
        sum(short weights) = -short_target

    Keeps relative weights unchanged.

    Works for ANY # of ETFs and ANY day.
    """

    pos = positions.copy()

    longs  = pos.clip(lower=0)
    shorts = pos.clip(upper=0)

    long_sum  = longs.sum(axis=1)
    short_sum = -shorts.sum(axis=1)

    long_scale  = np.where(long_sum  > 0, long_target  / long_sum,  0)
    short_scale = np.where(short_sum > 0, short_target / short_sum, 0)

    scaled = (
        longs.mul(long_scale, axis=0) +
        shorts.mul(short_scale, axis=0)
    )

    return scaled


# =========================
# PORTFOLIO CONSTRUCTION
# =========================

# SIGNAL / PORTFOLIO MODES

# ----- Combine mode (per ETF) -----
# How multiple signals inside ONE ETF are aggregated
# options:
#   "equal"        → simple average
#   "vote"         → sign majority vote
#   "rank"         → per-signal ranking
#   "zscore"       → per-signal zscore
COMBINE_MODE_OPTIONS = [
    "equal",
    "vote",
    "rank",
    "zscore",
]

COMBINE_MODE = "equal"


# ----- Portfolio mode (cross ETF) -----
# How capital is allocated ACROSS ETFs
# options:
#   "equal"        → equal weight
#   "rank"         → rank-based ensemble
#   "zscore"       → z-score aggregation
#   "vol_scaled"   → inverse volatility
#   "ic_weighted"  → rolling IC weighting (adaptive)
PORTFOLIO_MODE_OPTIONS = [
    "equal",
    "rank",
    "zscore",
    "vol_scaled",
    "ic_weighted",
]

PORTFOLIO_MODE = "equal"


def combine_signals(
    signals_df,
    mode=COMBINE_MODE,
    win=63
):
    """
    Combine multiple signals for ONE ETF into a discrete direction.
    Output is {-1, 0, +1}.
    """

    if signals_df.shape[1] == 1:
        raw = signals_df.iloc[:, 0]

    elif mode == "equal":
        raw = signals_df.mean(axis=1)

    elif mode == "vote":
        raw = np.sign(signals_df).sum(axis=1) # majority vote for discrete signals

    elif mode == "rank":
        ranked = (
            signals_df
            .rolling(win)
            .apply(lambda x: x.rank(pct=True).iloc[-1], raw=False)
        )
        raw = ranked.mean(axis=1) - 0.5

    elif mode == "zscore":
        mu = signals_df.rolling(win).mean()
        sigma = signals_df.rolling(win).std()
        z = (signals_df - mu) / sigma
        z = z.clip(-3, 3)
        raw = z.mean(axis=1)

    else:
        raise ValueError(f"Unknown combine_mode: {mode}")

    # DISCRETIZE
    direction = np.sign(raw)
    direction[raw.abs() < 1e-6] = 0

    return direction


# =========================
# PORTFOLIO CONSTRUCTION (CROSS ETF)
# =========================

def build_long_short_portfolio(
    signal_df,
    returns_df=None,
    portfolio_mode=PORTFOLIO_MODE,
    win=63,
    long_leverage=1.0,
    short_leverage=1.0
):
    """
    Build a daily long-short portfolio across ETFs.
    """

    positions = pd.DataFrame(0.0, index=signal_df.index, columns=signal_df.columns)

    for t in signal_df.index:
        sig = signal_df.loc[t]

        longs = sig[sig > 0].index
        shorts = sig[sig < 0].index

        if len(longs) == 0 and len(shorts) == 0:
            continue

        # -------------------------
        # RAW WEIGHTS
        # -------------------------

        if portfolio_mode == "equal":
            w_long = pd.Series(1.0, index=longs)
            w_short = pd.Series(1.0, index=shorts)

        elif portfolio_mode == "rank":
            ranks = signal_df.loc[:t].rank(axis=1, pct=True).iloc[-1]
            w_long = ranks.loc[longs]
            w_short = 1 - ranks.loc[shorts]

        elif portfolio_mode == "zscore":
            mu = signal_df.loc[:t].rolling(win).mean().iloc[-1]
            sd = signal_df.loc[:t].rolling(win).std().iloc[-1]
            z = (signal_df.loc[t] - mu) / sd
            w_long = z.loc[longs].clip(lower=0)
            w_short = (-z.loc[shorts]).clip(lower=0)

        elif portfolio_mode == "vol_scaled":
            vols = returns_df.loc[:t].rolling(win).std().iloc[-1]
            w_long = 1 / vols.loc[longs]
            w_short = 1 / vols.loc[shorts]

        elif portfolio_mode == "ic_weighted":
            ic = (
                signal_df
                .rolling(win)
                .corr(returns_df)
                .shift(1)
                .iloc[-1]
            )
            w_long = ic.loc[longs].clip(lower=0)
            w_short = (-ic.loc[shorts]).clip(lower=0)

        else:
            raise ValueError(f"Unknown portfolio_mode: {portfolio_mode}")

        # -------------------------
        # NORMALIZE BOOKS
        # -------------------------

        if len(w_long) > 0:
            w_long = w_long / w_long.sum() * long_leverage

        if len(w_short) > 0:
            w_short = w_short / w_short.sum() * short_leverage

        positions.loc[t, w_long.index] = w_long
        positions.loc[t, w_short.index] = -w_short

    return positions


# =========================
# MULTI-ETF ENGINE
# =========================

def run_period(
    start,
    end,
    price_data,
    signal_functions,
    combine_mode=COMBINE_MODE,
    portfolio_mode=PORTFOLIO_MODE,
    win=63,
    long_leverage=1.0,
    short_leverage=1.0,
    signal_map=None
):
    """
    3 modes:

    1) None
       → all signals on all ETFs

    2) {ETF : [signals]}
       → per-ETF signals

    3) {signal : [ETFs]}
       → per-signal portfolios averaged (NEW)
    """

    # ==============================
    # Detect map mode
    # ==============================

    if signal_map is None or len(signal_map) == 0:
        map_mode = "none"
    else:
        first_key = next(iter(signal_map.keys()))
        map_mode = "signal_to_etf" if callable(first_key) else "etf_to_signal"

    # =====================================================
    # MODE 3  (signal → ETF)
    # =====================================================

    if map_mode == "signal_to_etf":

        pnl_list = []
        pos_list = []

        # union of ETFs
        all_etfs = sorted({etf for lst in signal_map.values() for etf in lst})

        valid_etfs = [e for e in all_etfs if e in price_data]
        if len(valid_etfs) == 0:
            raise ValueError("No ETFs found in price_data for Mode 3")

        # master_index = price_data[valid_etfs[0]].loc[start:end].index

        returns_df = pd.DataFrame({
            etf: price_data[etf].loc[start:end]["Returns"]
            for etf in valid_etfs
        })

        master_index = returns_df.index

        # -----------------------------------------
        # build each signal portfolio independently
        # -----------------------------------------

        for signal_fn, etfs in signal_map.items():

            cols = [e for e in etfs if e in price_data]
            if len(cols) == 0:
                continue

            signal_df = pd.DataFrame({
                etf: signal_fn(price_data[etf].loc[start:end])
                for etf in cols
            }).reindex(master_index)

            pos = build_long_short_portfolio(
                signal_df,
                returns_df=returns_df[cols],
                portfolio_mode=portfolio_mode,
                win=win,
                long_leverage=long_leverage,
                short_leverage=short_leverage
            )

            pnl = compute_portfolio_pnl_with_costs(
                pos,
                returns_df[cols],
                cost_bps=0
            )

            pos_list.append(pos)
            pnl_list.append(pnl)

        if len(pnl_list) == 0:
            raise ValueError("All signals empty in Mode 3")

        n = len(pnl_list)

        positions = sum(
            p.reindex(columns=valid_etfs, fill_value=0)
            for p in pos_list
        ) / n

        pnl = sum(pnl_list) / n

        individual_etf_pnls = positions.shift(1) * returns_df

        return pnl, positions, returns_df, individual_etf_pnls


    # =====================================================
    # MODE 1 + MODE 2  (original logic)
    # =====================================================

    signal_matrix = {}
    returns_matrix = {}

    # -----------------------------------------
    # Resolve active ETF universe automatically
    # -----------------------------------------

    if signal_map is not None and len(signal_map) > 0:
        active_universe = list(signal_map.keys())
    else:
        active_universe = list(ETF_UNIVERSE)

    # Iterate only over the ETFs defined in ETF_UNIVERSE for portfolio construction
    for etf in active_universe:

        if etf not in price_data:
            continue

        df = price_data[etf].loc[start:end]

        # =========================================
        # PER-ETF SIGNAL SELECTION  (THE FIX)
        # =========================================
        if signal_map is not None and etf in signal_map:
            etf_signals = signal_map[etf]
        else:
            etf_signals = signal_functions
        # =========================================

        # sig_df = pd.concat(
        #     [fn(df) for fn in etf_signals],
        #     axis=1
        # )

        # signal_matrix[etf] = combine_signals(
        #     sig_df,
        #     mode=COMBINE_MODE,
        #     win=win
        # )

        # -----------------------------------------
        # SAFE signal construction
        # -----------------------------------------

        if len(etf_signals) == 0:
            # no signals → zero exposure
            zero = pd.Series(0.0, index=df.index)
            signal_matrix[etf] = zero
        else:
            sig_df = pd.concat(
                [fn(df) for fn in etf_signals],
                axis=1
            )

            signal_matrix[etf] = combine_signals(
                sig_df,
                mode=combine_mode,
                win=win
            )


        returns_matrix[etf] = df["Returns"]


    signal_df = pd.DataFrame(signal_matrix)
    returns_df = pd.DataFrame(returns_matrix)

    positions = build_long_short_portfolio(
        signal_df,
        returns_df=returns_df,
        portfolio_mode=portfolio_mode,
        win=win,
        long_leverage=long_leverage,
        short_leverage=short_leverage
    )

    # always use the same engine
    # =========================================

    pnl = compute_portfolio_pnl_with_costs(
        positions,
        returns_df,
        cost_bps=0
    )

    individual_etf_pnls = positions.shift(1) * returns_df

    return pnl, positions, returns_df, individual_etf_pnls

    # # ======================================
    # # NEW: ETF value-add diagnostics
    # # ======================================
    # value_add_scores = compute_value_add_scores(positions, returns_df)

    # print("\n=== ETF VALUE-ADD SCORES ===")
    # print(value_add_scores.round(4))

    # passed_etfs = value_add_scores[value_add_scores > 0].index.tolist()
    # print("ETF_UNIVERSE = " + str(passed_etfs) + "\n")

    # # keep = value_add_scores[value_add_scores > 0].index
    # # positions = positions[keep]
    # # returns_df = returns_df[keep]

    # return pnl, positions, individual_etf_pnls, value_add_scores




# =========================
# FULL CONTINUOUS BACKTEST (single run only)
# =========================

FULL_START = TRAIN_START
FULL_END   = BLIND_END

full_pnl_total, full_pos, full_returns_df, full_individual_pnl = run_period(
    FULL_START,
    FULL_END,
    price_data,
    _SIGNAL_REGISTRY,
    signal_map=SIGNAL_MAP
)

full_port = full_pnl_total.sort_index()

# =========================
# SLICE FROM FULL SERIES
# =========================

train_pnl_total = full_pnl_total.loc[TRAIN_START:TRAIN_END]
val_pnl_total   = full_pnl_total.loc[VAL_START:VAL_END]
blind_pnl_total = full_pnl_total.loc[BLIND_START:BLIND_END]
train_val_pnl_total = full_pnl_total.loc[TRAIN_START:VAL_END]

train_pos = full_pos.loc[TRAIN_START:TRAIN_END]
val_pos   = full_pos.loc[VAL_START:VAL_END]
blind_pos = full_pos.loc[BLIND_START:BLIND_END]

train_returns_df = full_returns_df.loc[TRAIN_START:TRAIN_END]
val_returns_df   = full_returns_df.loc[VAL_START:VAL_END]
blind_returns_df = full_returns_df.loc[BLIND_START:BLIND_END]

train_individual_pnl = full_individual_pnl.loc[TRAIN_START:TRAIN_END]
val_individual_pnl   = full_individual_pnl.loc[VAL_START:VAL_END]
blind_individual_pnl = full_individual_pnl.loc[BLIND_START:BLIND_END]

# =========================
# SLICE PERIODS FROM CONTINUOUS SERIES
# =========================

train_port = full_port.loc[TRAIN_START:TRAIN_END]
val_port   = full_port.loc[VAL_START:VAL_END]
blind_port = full_port.loc[BLIND_START:BLIND_END]

train_val_port = full_port.loc[TRAIN_START:VAL_END]

# =========================
# SHARPES
# =========================

print("\nTRAIN+VAL SHARPE:", sharpe(train_val_port))
print("\nTRAIN SHARPE:", sharpe(train_port))
print("VAL SHARPE:", sharpe(val_port))
print("BLIND SHARPE:", sharpe(blind_port))


# =========================
# FINAL PORTFOLIO (already continuous)
# =========================

portfolio = full_port

# train_scores, passed_etfs = select_etfs_by_value_add(
#     train_pos,
#     train_returns_df,
#     label="train"
# )

# val_scores, passed_etfs = select_etfs_by_value_add(
#     val_pos,
#     val_returns_df,
#     label="val"
# )

# blind_scores, passed_etfs = select_etfs_by_value_add(
#     blind_pos,
#     blind_returns_df,
#     label="blind"
# )

train_val_pos = full_pos.loc[TRAIN_START:VAL_END]
train_val_returns_df = full_returns_df.loc[TRAIN_START:VAL_END]

# tv_scores, passed_etfs = select_etfs_by_value_add(
#     train_val_pos,
#     train_val_returns_df,
#     label="train_val"
# )

# scores = compute_os_is_value_add(
#     train_val_pos,
#     train_val_returns_df,
#     TRAIN_START,
#     TRAIN_END,   # IS
#     VAL_START,
#     VAL_END      # OS
# )

# print("\n=== ETF OS/IS VALUE-ADD (TRAIN→VAL) ===")
# print(scores.round(4))

# scores = compute_train_val_value_add(
#     train_val_pos,
#     train_val_returns_df,
#     TRAIN_START,
#     TRAIN_END,   # IS
#     VAL_START,
#     VAL_END      # OS
# )

# scores = compute_train_full_value_add(train_val_pos, train_val_returns_df, TRAIN_START, TRAIN_END)

# scores = compute_trainval_blind_value_add(
#     full_pos,
#     full_returns_df,
#     TRAIN_START,
#     VAL_END,
#     BLIND_START,
#     BLIND_END
# )

# scores = compute_trainval_blind_value_add(
#     full_pos,
#     full_returns_df,
#     TRAIN_START,
#     TRAIN_END,
#     BLIND_START,
#     BLIND_END
# )

# scores = compute_train_val_blind_value_add(
#     full_pos,
#     full_returns_df,
#     TRAIN_START,
#     TRAIN_END,
#     VAL_START,
#     VAL_END,
#     BLIND_START,
#     BLIND_END
# )

scores = compute_train_val_weighted_value_add(
    full_pos,
    full_returns_df,
    TRAIN_START, TRAIN_END,
    VAL_START, VAL_END,
    w_train=0.8,
    w_val=0.2
)

print(scores.round(4))

passed_etfs = scores[scores > 0].index.tolist()
print("Positive:\nETF_UNIVERSE = " + str(passed_etfs) + "\n")

passed_etfs = scores[scores >= 0].index.tolist()
print("Nonnegative:\nETF_UNIVERSE = " + str(passed_etfs) + "\n")

# =========================
# SPY CONTINUOUS BACKTEST
# =========================

def run_spy_full(leverage_cap=1.0, signal_functions=_SIGNAL_REGISTRY):
    if "SPY" not in price_data:
        print("Warning: SPY data not available.")
        return pd.Series(dtype="float64")

    df = price_data["SPY"]  # FULL history (no slicing)

    sig_df = pd.concat([fn(df) for fn in signal_functions], axis=1)

    pos = combine_signals(sig_df, mode="equal")

    pnl = compute_pnl(pos, df["Returns"], leverage_cap)

    return pnl.sort_index()

spy_full_pnl = run_spy_full()

spy_train_pnl = spy_full_pnl.loc[TRAIN_START:TRAIN_END]
spy_val_pnl   = spy_full_pnl.loc[VAL_START:VAL_END]
spy_blind_pnl = spy_full_pnl.loc[BLIND_START:BLIND_END]
spy_train_val = spy_full_pnl.loc[TRAIN_START:VAL_END]


print("\nSPY SHARPE")
print("Train     :", sharpe(spy_train_pnl))
print("Val       :", sharpe(spy_val_pnl))
print("Blind     :", sharpe(spy_blind_pnl))
print("Train+Val :", sharpe(spy_train_val))


# =========================================================
# ROBUSTNESS — CONTINUOUS (NO RESTARTS, FULL-HISTORY ONLY)
# =========================================================

print("\n================ ROBUSTNESS TESTS (CONTINUOUS PORTFOLIO) ================")

FULL_START = TRAIN_START
FULL_END   = BLIND_END

original_registry = _SIGNAL_REGISTRY.copy()
original_map = SIGNAL_MAP.copy() if SIGNAL_MAP is not None else None

# ---------------------------------------------------------
# helper: rebuild signal_map
# ---------------------------------------------------------
def rebuild_signal_map(active):

    if original_map is None:
        return None

    first_key = next(iter(original_map.keys()))

    # ----------------------------------------
    # Mode 3 : signal → ETF
    # ----------------------------------------
    if callable(first_key):

        return {
            sig: etfs
            for sig, etfs in original_map.items()
            if sig in active
        }

    # ----------------------------------------
    # Mode 2 : ETF → signal
    # ----------------------------------------
    else:

        return {
            etf: [s for s in sigs if s in active]
            for etf, sigs in original_map.items()
        }

# ---------------------------------------------------------
# helper: slice pnl/pos into periods
# ---------------------------------------------------------
def slice_periods(series):

    return {
        "TRAIN": series.loc[TRAIN_START:TRAIN_END],
        "VAL":   series.loc[VAL_START:VAL_END],
        "TRAIN+VAL":  series.loc[TRAIN_START:VAL_END],
        "BLIND": series.loc[BLIND_START:BLIND_END]
    }

# =========================================================
# BUILD SIGNAL PNL MATRIX (compute ONCE)
# =========================================================

signal_pnls = {}

is_mode3 = (
    original_map is not None and
    len(original_map) > 0 and
    callable(next(iter(original_map.keys())))
)

for fn in original_registry:

    if is_mode3:
        # Mode 3 → single signal portfolio directly
        single_map = {fn: original_map[fn]}
    else:
        # Mode 1/2 → must rebuild
        single_map = rebuild_signal_map([fn])

    pnl, _, _, _ = run_period(
        FULL_START,
        FULL_END,
        price_data,
        [fn],
        signal_map=single_map
    )

    signal_pnls[fn.__name__] = pnl

signal_pnls = pd.DataFrame(signal_pnls)
# ⭐ CRITICAL
signal_pnls = signal_pnls.dropna(how="all")

# =========================================================
# INDIVIDUAL SIGNAL PERFORMANCE (continuous)
# =========================================================

print("\n================ INDIVIDUAL SIGNAL PERFORMANCE =================")

rows = []

for col in signal_pnls.columns:

    sliced = slice_periods(signal_pnls[col])

    rows.append([
        col,
        *(sharpe(sliced[k]) for k in ["TRAIN","VAL","TRAIN+VAL","BLIND"])
    ])

signal_perf = (
    pd.DataFrame(
        rows,
        columns=["Signal", "Train", "Val", "Train+Val", "Blind"]
    )
    .set_index("Signal")
    .sort_values("Train+Val", ascending=False)
)
display(signal_perf.round(3))

# =========================================================
# LEAVE-ONE-OUT  (continuous)
# =========================================================

print("\nLEAVE-ONE-OUT (continuous)")

is_mode3 = original_map is not None and callable(next(iter(original_map.keys())))
rows = []

for col in signal_pnls.columns:

    if is_mode3:
        pnl = signal_pnls.drop(columns=col).mean(axis=1)
    else:
        # fallback for Mode 1/2
        active = [s for s in original_registry if s.__name__ != col]
        active_map = rebuild_signal_map(active)

        pnl, _, _, _ = run_period(
            FULL_START,
            FULL_END,
            price_data,
            active,
            signal_map=active_map
        )

    sliced = slice_periods(pnl)

    # print(f"\nDrop {col}")
    # for k, v in sliced.items():
    #     print(f"{k}: {sharpe(v):.3f}")

    rows.append([
        col,
        *(sharpe(sliced[k]) for k in ["TRAIN","VAL","TRAIN+VAL","BLIND"])
    ])

loo_df = (
    pd.DataFrame(
        rows,
        columns=["Dropped","Train","Val","Train+Val","Blind"]
    )
    .set_index("Dropped")
    .sort_values("Train+Val", ascending=False)
)
display(loo_df.round(3))

# =========================================================
# SIGNAL CORRELATION (continuous)
# =========================================================

print("\nSIGNAL CORRELATION (continuous portfolio-level)")

for period_name, (s, e) in {
    "TRAIN": (TRAIN_START, TRAIN_END),
    "VAL":   (VAL_START, VAL_END),
    "BLIND": (BLIND_START, BLIND_END)
}.items():

    sub = signal_pnls.loc[s:e]

    print(f"\nCorrelation — {period_name}")
    if sub.shape[1] > 1:
        display(sub.corr().round(3))
    else:
        print("Not enough signals.")

# =========================================================
# COSTS + OPEN (already continuous since using full_pos)
# =========================================================

def cost_and_open_tests(pos_full):

    pos_slices = slice_periods(pos_full)

    for label, pos_slice in pos_slices.items():

        print(f"\nTRANSACTION COSTS — {label}")

        returns_df = pd.DataFrame({
            etf: price_data[etf]["Returns"].reindex(pos_slice.index)
            for etf in pos_slice.columns
        })

        for bps in [1,5,10,20]:
            pnl_tc = compute_portfolio_pnl_with_costs(pos_slice, returns_df, cost_bps=bps)
            print(f"{bps} bps:", sharpe(pnl_tc))

        print("NEXT-DAY OPEN")

        open_returns = {
            etf: price_data[etf]["Open"].pct_change().reindex(pos_slice.index)
            for etf in pos_slice.columns
        }

        open_df = pd.DataFrame(open_returns)
        open_pnl = (pos_slice.shift(1) * open_df).sum(axis=1)

        print("Open Sharpe:", sharpe(open_pnl))


# run costs/open using your already-computed full_pos
cost_and_open_tests(full_pos)





# =========================
# REGIME TABLE — Bull/Bear/Chop × VIX (3x2 + totals)
# =========================

if "SPY" not in price_data or 'vix' not in globals() or vix.empty:
    print("SPY or VIX missing — skipping regime table.")
else:

    # =========================================================
    # 1) FULL-HISTORY REGIME FILTERS (computed ONCE, continuous)
    # =========================================================

    spy_full = price_data["SPY"].sort_index()

    # ---------- Trend (Bull/Bear via SMA200) ----------
    sma200 = spy_full["Close"].rolling(200).mean()
    bull_full = spy_full["Close"] > sma200

    # ---------- Chop (ADX < threshold) ----------
    high = spy_full["High"]
    low  = spy_full["Low"]
    close = spy_full["Close"]

    tr1 = (high - low).abs()
    tr2 = (high - close.shift()).abs()
    tr3 = (low  - close.shift()).abs()
    tr = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)

    up_move   = high.diff()
    down_move = -low.diff()

    plus_dm  = np.where((up_move > down_move) & (up_move > 0), up_move, 0.0)
    minus_dm = np.where((down_move > up_move) & (down_move > 0), down_move, 0.0)

    atr = tr.rolling(14).mean()

    plus_di  = 100 * pd.Series(plus_dm,  index=spy_full.index).rolling(14).sum() / atr
    minus_di = 100 * pd.Series(minus_dm, index=spy_full.index).rolling(14).sum() / atr

    dx  = (plus_di - minus_di).abs() / (plus_di + minus_di) * 100
    adx = dx.rolling(14).mean()

    CHOP_THRESHOLD = 25
    chop_full = adx < CHOP_THRESHOLD

    # ---------- Final mutually-exclusive trend states ----------
    bull_full = bull_full & ~chop_full
    bear_full = (~bull_full) & ~chop_full

    # ---------- VIX ----------
    vix_full = vix.sort_index()

    HIGH_VOL_THRESHOLD = 25
    LOW_VOL_THRESHOLD  = 15


    # =========================================================
    # 2) TABLE BUILDER (portfolio-level)
    # =========================================================

    def regime_table(port_slice, label):

        if port_slice.empty:
            print(f"\n{label}: empty portfolio slice")
            return

        idx = port_slice.index

        # -------- SAFE ALIGNMENT (fixes your earlier IndexingError) --------
        bull = bull_full.reindex(idx).fillna(False)
        bear = bear_full.reindex(idx).fillna(False)
        chop = chop_full.reindex(idx).fillna(False)

        vix_aligned = vix_full.reindex(idx, method="ffill")

        high_vol = vix_aligned > HIGH_VOL_THRESHOLD
        low_vol  = vix_aligned < LOW_VOL_THRESHOLD
        mid_vol  = ~(high_vol | low_vol)   # everything else


        # ---------- helper ----------
        def S(mask):
            s = port_slice[mask]
            return np.nan if len(s) == 0 else round(sharpe(s), 2)


        # =====================================================
        # 3) 3 × 2 MATRIX + TOTALS (confusion-matrix style)
        # =====================================================

        # ----- intersections -----
        bull_low   = bull & low_vol
        bull_mid   = bull & mid_vol
        bull_high  = bull & high_vol

        bear_low   = bear & low_vol
        bear_mid   = bear & mid_vol
        bear_high  = bear & high_vol

        chop_low   = chop & low_vol
        chop_mid   = chop & mid_vol
        chop_high  = chop & high_vol

        # ---------- totals ----------
        row_bull = bull
        row_bear = bear
        row_chop = chop

        col_low  = low_vol
        col_mid  = mid_vol
        col_high = high_vol

        all_days = pd.Series(True, index=idx)


        table = pd.DataFrame(
            [
                [S(bull_low), S(bull_mid), S(bull_high), S(row_bull)],
                [S(bear_low), S(bear_mid), S(bear_high), S(row_bear)],
                [S(chop_low), S(chop_mid), S(chop_high), S(row_chop)],
                [S(col_low),  S(col_mid),  S(col_high),  S(all_days)],
            ],
            index=["Bull", "Bear", "Chop", "Total"],
            columns=["Low Vol", "Mid Vol", "High Vol", "Total"]
        )

        print(f"\nREGIME SHARPE TABLE — {label}")
        print(table)


    # =========================================================
    # 4) RUN FOR EACH PERIOD (NO REBUILDING, NO RESET)
    # =========================================================

    regime_table(train_port, "TRAIN")
    regime_table(val_port,   "VAL")
    regime_table(blind_port, "BLIND")


# =========================
# TURNOVER & MARGIN
# =========================

def portfolio_turnover_and_margin(pnl, positions):
    return {
        "Avg Turnover (%)": 100 * compute_turnover(positions).mean(),
        "Margin (bps)": compute_margin(pnl, positions)
    }

print("\n=== TURNOVER & MARGIN ===")

train_tm = portfolio_turnover_and_margin(train_pnl_total, train_pos)
val_tm   = portfolio_turnover_and_margin(val_pnl_total, val_pos)
bli_tm = portfolio_turnover_and_margin(blind_pnl_total, blind_pos)

print(f"TRAIN  | Turnover: {train_tm['Avg Turnover (%)']:.2f}% | Margin: {train_tm['Margin (bps)']:.2f} bps")
print(f"VAL    | Turnover: {val_tm['Avg Turnover (%)']:.2f}% | Margin: {val_tm['Margin (bps)']:.2f} bps")
print(f"BLIND  | Turnover: {bli_tm['Avg Turnover (%)']:.2f}% | Margin: {bli_tm['Margin (bps)']:.2f} bps")



# =========================
# LEVERAGE STRESS (ALL PERIODS)
# =========================

# FULL CONTINUOUS BACKTEST — L10 (leverage = 1.5)

full_pnl_total_L10, full_pos_L10, full_individual_pnl_L10, full_value_add_L10 = run_period(
    FULL_START,
    FULL_END,
    price_data,
    _SIGNAL_REGISTRY,
    signal_map=SIGNAL_MAP,
    long_leverage=1.5
)

full_port_L10 = full_pnl_total_L10.sort_index()


# SLICE FROM FULL SERIES — L10

train_pnl_total_L10 = full_pnl_total_L10.loc[TRAIN_START:TRAIN_END]
val_pnl_total_L10   = full_pnl_total_L10.loc[VAL_START:VAL_END]
blind_pnl_total_L10 = full_pnl_total_L10.loc[BLIND_START:BLIND_END]
train_val_pnl_total_L10 = full_pnl_total_L10.loc[TRAIN_START:VAL_END]

train_pos_L10 = full_pos_L10.loc[TRAIN_START:TRAIN_END]
val_pos_L10   = full_pos_L10.loc[VAL_START:VAL_END]
blind_pos_L10 = full_pos_L10.loc[BLIND_START:BLIND_END]

train_individual_pnl_L10 = full_individual_pnl_L10.loc[TRAIN_START:TRAIN_END]
val_individual_pnl_L10   = full_individual_pnl_L10.loc[VAL_START:VAL_END]
blind_individual_pnl_L10 = full_individual_pnl_L10.loc[BLIND_START:BLIND_END]


# PORT SERIES — L10

train_port_L10 = full_port_L10.loc[TRAIN_START:TRAIN_END]
val_port_L10   = full_port_L10.loc[VAL_START:VAL_END]
blind_port_L10 = full_port_L10.loc[BLIND_START:BLIND_END]

train_val_port_L10 = full_port_L10.loc[TRAIN_START:VAL_END]

# SHARPES — L10

print("\n[L10] TRAIN+VAL SHARPE:", sharpe(train_val_port_L10))
print("[L10] TRAIN SHARPE:", sharpe(train_port_L10))
print("[L10] VAL SHARPE:", sharpe(val_port_L10))
print("[L10] BLIND SHARPE:", sharpe(blind_port_L10))



# =========================
# CONTINUOUS PORTFOLIO SERIES
# =========================

# Concatenate in chronological order
portfolio = pd.concat([train_port, val_port, blind_port])
portfolio = portfolio[~portfolio.index.duplicated()].sort_index()

# =========================
# DYNAMIC BUY & HOLD BENCHMARK
# =========================

# Collect returns for all ETFs in the universe over the portfolio's active period
if not ETF_UNIVERSE:
    print("Warning: ETF_UNIVERSE is empty. Cannot create a Buy & Hold benchmark.")
    bh_benchmark = pd.Series(0, index=portfolio.index) # Create a zero series if no ETFs
else:
    benchmark_returns = pd.DataFrame({
        etf: price_data[etf]["Returns"].loc[portfolio.index.min():portfolio.index.max()]
        for etf in ETF_UNIVERSE if etf in price_data # Ensure ETF is in loaded data
    })

    # Create an equally-weighted buy & hold benchmark
    bh_benchmark = benchmark_returns.mean(axis=1).fillna(0)

print(f"\nPortfolio head:\n{portfolio.head(10)}")
print(f"\nBuy & Hold Benchmark head (before cumsum):\n{bh_benchmark.head(10)}")

plt.figure(figsize=(15,6))
plt.plot(portfolio.cumsum(), label="Strategy", linewidth=2)
plt.plot(bh_benchmark.cumsum(), "--", label="Equally-Weighted Buy & Hold", alpha=0.8)

plt.axvspan(pd.to_datetime(TRAIN_START), pd.to_datetime(TRAIN_END),
            color="green", alpha=0.08, label="Train")
plt.axvspan(pd.to_datetime(VAL_START), pd.to_datetime(VAL_END),
            color="blue", alpha=0.08, label="Validation")
plt.axvspan(pd.to_datetime(BLIND_START), pd.to_datetime(BLIND_END),
            color="red", alpha=0.08, label="Blind")

plt.legend()
plt.title("Continuous Equity Curve — Train / Validation / Blind")
plt.ylabel("Cumulative Return")
plt.grid(alpha=0.3)
plt.show()


# =========================
# PERFORMANCE BY ETF TABLE
# =========================

def cagr(returns, periods_per_year=252):
    returns = returns.dropna()
    if len(returns) == 0:
        return np.nan
    total = (1 + returns).prod()
    years = len(returns) / periods_per_year
    return total ** (1 / years) - 1

def max_drawdown(returns):
    cum = (1 + returns).cumprod()
    peak = cum.cummax()
    dd = cum / peak - 1
    return dd.min()

def perf_stats(pnl_df, pos_df, price_data):
    stats = {}
    for etf in pnl_df.columns:
        r = pnl_df[etf]
        p = pos_df[etf]
        df = price_data[etf]
        open_r = compute_open_pnl(p, df)
        bh_r = df["Returns"]
        bh_open_r = df["Open"].pct_change()
        stats[etf] = {
            "Sharpe": sharpe(r),
            "OpenSharpe": sharpe(open_r),
            "BHSharpe": sharpe(bh_r),
            "BHOpenSharpe": sharpe(bh_open_r),
            "CAGR": cagr(r),
            "BHCAGR": cagr(bh_r),
            "Vol": r.std() * np.sqrt(252),
            "MaxDD": max_drawdown(r),
            "Turnover": average_turnover(p),
            "Margin": compute_margin(r, p)
        }
    return pd.DataFrame(stats).T

# --- Compute stats ---
train_stats = perf_stats(train_individual_pnl, train_pos, price_data)
val_stats   = perf_stats(val_individual_pnl, val_pos, price_data)
blind_stats = perf_stats(blind_individual_pnl, blind_pos, price_data)

train_stats_L10 = perf_stats(train_individual_pnl_L10, train_pos_L10, price_data)
val_stats_L10   = perf_stats(val_individual_pnl_L10, val_pos_L10, price_data)
blind_stats_L10 = perf_stats(blind_individual_pnl_L10, blind_pos_L10, price_data)

# --- Combine into single table ---
perf_table = (
    train_stats.add_suffix("_Train")
    .join(val_stats.add_suffix("_Val"))
    .join(blind_stats.add_suffix("_Blind"))
    .join(train_stats_L10.add_suffix("_Train_L1.0"))
    .join(val_stats_L10.add_suffix("_Val_L1.0"))
    .join(blind_stats_L10.add_suffix("_Blind_L1.0"))
)

# --- Portfolio row ---
def portfolio_row(pnl_series, pos_df, start, end):
    r = pnl_series

    # ----- OPEN PNL (portfolio level, same semantics)
    open_returns = pd.DataFrame({
        etf: price_data[etf].loc[start:end]["Open"].pct_change()
        for etf in pos_df.columns
    })

    open_r = (pos_df.shift(1) * open_returns).sum(axis=1)

    # For portfolio-level turnover and margin, we need to consider all positions
    # Sum of absolute daily turnover for each asset
    portfolio_total_daily_turnover = pos_df.diff().abs().sum(axis=1)
    avg_portfolio_turnover = 100 * portfolio_total_daily_turnover.mean()

    portfolio_margin_val = compute_margin(r, pos_df)

    return pd.Series({
        "Sharpe": sharpe(r),
        "OpenSharpe": sharpe(open_r),
        "CAGR": cagr(r),
        "Vol": r.std() * np.sqrt(252),
        "MaxDD": max_drawdown(r),
        "Turnover": avg_portfolio_turnover,
        "Margin": portfolio_margin_val
    })

# --- Portfolio row (pandas 2.x safe) ---
portfolio_perf = pd.concat([
    portfolio_row(train_pnl_total, train_pos, TRAIN_START, TRAIN_END).add_suffix("_Train"),
    portfolio_row(val_pnl_total, val_pos, VAL_START, VAL_END).add_suffix("_Val"),
    portfolio_row(blind_pnl_total, blind_pos, BLIND_START, BLIND_END).add_suffix("_Blind")
])

# perf_table.loc["PORTFOLIO"] = portfolio_perf

portfolio_perf_L10 = pd.concat([
    portfolio_row(train_pnl_total_L10, train_pos_L10, TRAIN_START, TRAIN_END).add_suffix("_Train_L1.0"),
    portfolio_row(val_pnl_total_L10, val_pos_L10, VAL_START, VAL_END).add_suffix("_Val_L1.0"),
    portfolio_row(blind_pnl_total_L10, blind_pos_L10, BLIND_START, BLIND_END).add_suffix("_Blind_L1.0")
])

perf_table.loc["PORTFOLIO"] = pd.concat([portfolio_perf, portfolio_perf_L10])

# =========================
# BUY & HOLD ROW (equal weight, long only)
# =========================

def buy_hold_row(start, end, etfs):
    # close returns
    rets = pd.DataFrame({
        etf: price_data[etf].loc[start:end]["Returns"]
        for etf in etfs
    })

    r = rets.mean(axis=1)  # equal weight

    # synthetic constant positions for turnover/margin consistency
    pos = pd.DataFrame(
        1 / len(etfs),
        index=rets.index,
        columns=etfs
    )

    # open pnl (same semantics as portfolio)
    open_returns = pd.DataFrame({
        etf: price_data[etf].loc[start:end]["Open"].pct_change()
        for etf in etfs
    })

    open_r = (pos.shift(1) * open_returns).sum(axis=1)

    return pd.Series({
        "Sharpe": sharpe(r),
        "OpenSharpe": sharpe(open_r),
        "CAGR": cagr(r),
        "Vol": r.std() * np.sqrt(252),
        "MaxDD": max_drawdown(r),
        "Turnover": 0.0,              # no trading
        "Margin": np.nan              # no dollars traded
    })


bh_perf = pd.concat([
    buy_hold_row(TRAIN_START, TRAIN_END, train_pos.columns).add_suffix("_Train"),
    buy_hold_row(VAL_START, VAL_END, val_pos.columns).add_suffix("_Val"),
    buy_hold_row(BLIND_START, BLIND_END, blind_pos.columns).add_suffix("_Blind")
])

perf_table.loc["BUY&HOLD"] = bh_perf

# -------------------------------------------------
# Alpha Sharpe columns (NEW)
# -------------------------------------------------

for split in ["Train", "Val", "Blind"]:

    perf_table[f"AlphaSharpe_{split}"] = (
        perf_table[f"Sharpe_{split}"]
        - perf_table[f"BHSharpe_{split}"]
    )

    perf_table[f"AlphaOpenSharpe_{split}"] = (
        perf_table[f"OpenSharpe_{split}"]
        - perf_table[f"BHOpenSharpe_{split}"]
    )

    perf_table[f"AlphaSharpe_{split}_L1.0"] = (
        perf_table[f"Sharpe_{split}_L1.0"]
        - perf_table[f"BHSharpe_{split}"]
    )

    perf_table[f"AlphaOpenSharpe_{split}_L1.0"] = (
        perf_table[f"OpenSharpe_{split}_L1.0"]
        - perf_table[f"BHOpenSharpe_{split}"]
    )

# =========================
# DISPLAY
# =========================
print("\nPERFORMANCE COMPARISON BY ETF")
display(
    perf_table.round(3)
    .sort_values("Sharpe_Train", ascending=False)
)
# Out:
# Loading ETF data...
#
# ...

# %%
# =========================================================
# INTERACTIVE SIGNAL SELECTION + PERFORMANCE TABLE
# =========================================================

import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import pandas as pd


# ---------------------------------------------------------
# 1. UI
# ---------------------------------------------------------

selector = widgets.SelectMultiple(
    options=list(signal_pnls.columns),
    value=list(signal_pnls.columns[:5]),
    description="Signals",
    rows=15,
    layout=widgets.Layout(width="260px")
)

mode = widgets.ToggleButtons(
    options=["Equal Weight", "Sum"],
    description="Combine:"
)


# ---------------------------------------------------------
# 2. Performance helper
# ---------------------------------------------------------

def perf_table(series):

    periods = slice_periods(series)

    return pd.DataFrame({
        "Sharpe": {
            "Train": sharpe(periods["TRAIN"]),
            "Val": sharpe(periods["VAL"]),
            "Train+Val": sharpe(periods["TRAIN+VAL"]),
            "Blind": sharpe(periods["BLIND"]),
        }
    }).round(3)


# ---------------------------------------------------------
# 3. DRAW
# ---------------------------------------------------------

def draw(change=None):

    clear_output(wait=True)
    display(selector, mode)

    if len(selector.value) == 0:
        print("Select at least one signal")
        return

    selected = signal_pnls[list(selector.value)]

    # combine
    if mode.value == "Equal Weight":
        combined = selected.mean(axis=1)
    else:
        combined = selected.sum(axis=1)


    # ---------- PLOT ----------
    plt.figure(figsize=(15,6))
    plt.plot(combined.cumsum(), label="Combined Signals", linewidth=2)

    plt.axvspan(pd.to_datetime(TRAIN_START), pd.to_datetime(TRAIN_END),
                alpha=0.08, label="Train")

    plt.axvspan(pd.to_datetime(VAL_START), pd.to_datetime(VAL_END),
                alpha=0.08, label="Validation")

    plt.axvspan(pd.to_datetime(BLIND_START), pd.to_datetime(BLIND_END),
                alpha=0.08, label="Blind")

    plt.title("Signal Portfolio Equity Curve")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.show()


    # ---------- TABLE ----------
    display(perf_table(combined))


selector.observe(draw, names="value")
mode.observe(draw, names="value")

draw()
# 8, 9, convexity_gap, record_rate, return_iqr, burstiness, range_return, path_efficiency
# 1, 3, 8, 9, autocorr, entropy, convexity_gap_adjusted, run_length, record_rate, return_iqr, burstiness, signed_volume_agreement, range_return_conflict, path_efficiency
# Train	3.731
# Val	3.219
# Train+Val	3.568
# Blind	2.162
# 1, 3, 8, 9, autocorr, entropy, convexity_gap_adjusted, run_length, record_rate, return_iqr, burstiness, signed_volume_agreement, range_return_conflict, path_efficiency, vol_of_vol
# Train	3.740
# Val	3.525
# Train+Val	3.650
# Blind	2.332
# 1, 3, 8, 9, autocorr, entropy, convexity_gap_adjusted, run_length, record_rate, return_iqr, burstiness, signed_volume_agreement, range_return_conflict, path_efficiency, vol_of_vol, return_conviction, price_volume_phase
# Train	3.911
# Val	3.661
# Train+Val	3.804
# Blind	2.558
# 1, 3, 8, 9, autocorr, entropy, convexity_gap_adjusted, run_length, record_rate, return_iqr, burstiness, signed_volume_agreement, range_return_conflict, path_efficiency, vol_of_vol, return_conviction, price_volume_phase, vol_compression_ratio
# Train	3.935
# Val	3.857
# Train+Val	3.866
# Blind	2.644
# 1, 3, 8, 9, autocorr, entropy, convexity_gap_adjusted, run_length, record_rate, return_iqr, burstiness, signed_volume_agreement, range_return_conflict, path_efficiency, vol_of_vol, return_conviction, price_volume_phase, vol_compression_ratio, liquidity_persistence
# Train	3.933
# Val	3.919
# Train+Val	3.877
# Blind	2.697
# 1, 3, 8, 9, autocorr, entropy, convexity_gap_adjusted, run_length, record_rate, time_since_volume_spike, return_iqr, burstiness, signed_volume_agreement, range_return_conflict, path_efficiency, vol_of_vol, return_conviction, price_volume_phase, vol_compression_ratio, liquidity_persistence
# Train	3.991
# Val	4.017
# Train+Val	3.947
# Blind	2.689
# Out:
# SelectMultiple(description='Signals', index=(0, 1, 2, 3, 4), layout=Layout(width='260px'), options=('signal_1'…
# ToggleButtons(description='Combine:', options=('Equal Weight', 'Sum'), value='Equal Weight')
#            Sharpe
# Train       2.674
# Val         2.179
# Train+Val   2.521
# Blind       1.138

# %%
# 1. Sort the table
sorted_df = perf_table.sort_values("Sharpe_Train", ascending=False)

# 2. Keep columns that do NOT contain "CAGR"
# na=False handles cases where column names might be missing or non-strings
filtered_df = sorted_df.loc[:, sorted_df.columns.str.contains('Sharpe', na=False)]

filtered_df
# Out:
#            Sharpe_Train  OpenSharpe_Train  BHSharpe_Train  BHOpenSharpe_Train  \
# PORTFOLIO      3.731031          2.424344             NaN                 NaN
# SPMD           1.158755          0.831444        0.297591            0.301198
# DVY            0.933193          0.575684        0.363006            0.355537
# QQQ            0.930953          0.242532        0.889052            0.895034
# PZA            0.907466          0.399501        0.261689            0.257595
# ...                 ...               ...             ...                 ...
# FTC           -0.049547         -0.042374        0.548351            0.525703
# VCLT          -0.096707          0.126266        0.072582            0.072309
# ICF           -0.123191          0.056382        0.300217            0.295573
# FPX           -0.158503         -0.168860        0.578909            0.558099
# SPXL          -0.721541          0.212724        0.775105            0.782874
#
# ...

# %%
cols_to_show = [
    # base
    "Sharpe_Train", "Sharpe_Val", "Sharpe_Blind",
    "OpenSharpe_Train", "OpenSharpe_Val", "OpenSharpe_Blind",
    "AlphaSharpe_Train", "AlphaSharpe_Val", "AlphaSharpe_Blind",
    "Margin_Train", "Margin_Val", "Margin_Blind",

    # # L1.0
    # "Sharpe_Train_L1.0", "Sharpe_Val_L1.0", "Sharpe_Blind_L1.0",
    # "OpenSharpe_Train_L1.0", "OpenSharpe_Val_L1.0", "OpenSharpe_Blind_L1.0",
    # "AlphaSharpe_Train_L1.0", "AlphaSharpe_Val_L1.0", "AlphaSharpe_Blind_L1.0",
    # "Margin_Train_L1.0", "Margin_Val_L1.0", "Margin_Blind_L1.0",
]

perf_table[cols_to_show].sort_values("Sharpe_Train", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1139/3390426329.py in <cell line: 0>()
#      13 ]
#      14
# ---> 15 perf_table[cols_to_show].sort_values("Sharpe_Train", ascending=False)
#
# TypeError: 'function' object is not subscriptable

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_signal_underwater(pnl, title="Signal"):

    pnl = pnl.dropna()

    equity = pnl.cumsum()

    # drawdown (underwater)
    running_max = equity.cummax()
    drawdown = equity - running_max

    fig, ax = plt.subplots(2, 1, figsize=(14,7), sharex=True)

    # =========================
    # Equity curve
    # =========================
    ax[0].plot(equity)
    ax[0].set_title(f"{title} — Equity")
    ax[0].grid(alpha=0.3)

    # period shading (same as your other plots)
    ax[0].axvspan(TRAIN_START, TRAIN_END, alpha=0.08)
    ax[0].axvspan(VAL_START, VAL_END, alpha=0.08)
    ax[0].axvspan(BLIND_START, BLIND_END, alpha=0.08)

    # =========================
    # Underwater
    # =========================
    ax[1].fill_between(drawdown.index, drawdown, 0)
    ax[1].set_title("Underwater (Drawdown)")
    ax[1].grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

plot_signal_underwater(signal_pnls["signal_time_underwater"], "signal_time_underwater")

# %%
s = signal_pnls["signal_time_underwater"]

print("sum:", s.sum())
print("mean:", s.mean())
print("std:", s.std())
print("zeros:", (s==0).sum())
print("first 5:", s.head().values)
print("last 5:", s.tail().values)
# Out:
# sum: 3.3625535860616296
# mean: 0.0006129335738355139
# std: 0.013396262712120419
# zeros: 126
# first 5: [0. 0. 0. 0. 0.]
# last 5: [-0.03217315  0.00573781 -0.00806974 -0.02674633  0.01401172]

# %%
bad = []

for etf in ['AAXJ', 'TECL', 'VOX', 'SH', 'PHO', 'GLD', 'FNX', 'MGK', 'RPV', 'PXH', 'HYD', 'PPA', 'EWP', 'FXL', 'SLV', 'DEM', 'SHY', 'FXI', 'DBC', 'MUNI', 'HYG', 'EFV', 'VCIT', 'VCSH', 'VMBS']:
    px = price_data[etf]["Close"].loc[TRAIN_START:TRAIN_END]
    flat_ratio = (px.diff() == 0).mean()

    if flat_ratio > 0.05:   # >5% flat days is suspicious
        bad.append((etf, flat_ratio))

print(bad)
# Out:
# [('HYD', np.float64(0.056929269695227144)), ('SHY', np.float64(0.0935483870967742)), ('VMBS', np.float64(0.052734375))]

# %%
col = "signal_time_underwater"

p = slice_periods(signal_pnls[col])["TRAIN"]

print("len:", len(p))
print("start/end:", p.index.min(), p.index.max())
print("nans:", p.isna().sum())
print("sum:", p.sum())
print("std:", p.std())
# Out:
# len: 3100
# start/end: 2003-09-10 04:00:00 2015-12-31 05:00:00
# nans: 0
# sum: 2.3115240416488287
# std: 0.01274348268077883

# %%
col = "signal_time_underwater"

p = slice_periods(signal_pnls[col])["VAL"]

print("len:", len(p))
print("start/end:", p.index.min(), p.index.max())
print("nans:", p.isna().sum())
print("sum:", p.sum())
print("std:", p.std())
# Out:
# len: 1511
# start/end: 2016-01-04 05:00:00 2021-12-31 05:00:00
# nans: 0
# sum: 1.129015299648875
# std: 0.012063545881903746

# %%
print(price_data["SPY"]["Close"].head(10))
# Out:
# Date
# 2003-09-10 04:00:00    101.96
# 2003-09-11 04:00:00    102.26
# 2003-09-12 04:00:00    102.45
# 2003-09-15 04:00:00    102.09
# 2003-09-16 04:00:00    103.58
# 2003-09-17 04:00:00    103.38
# 2003-09-18 04:00:00    104.60
# 2003-09-19 04:00:00    103.67
# 2003-09-22 04:00:00    102.55
# 2003-09-23 04:00:00    102.94
# Name: Close, dtype: float64

# %%
import hashlib

def hash_series(s):
    return hashlib.md5(s.values.tobytes()).hexdigest()

print(hash_series(signal_pnls[col]))
# Out:
# f80971852e23d32ff30ceeade5756046

# %%
import numpy as np
np.__config__.show()
# Out:
# Build Dependencies:
#   blas:
#     detection method: pkgconfig
#     found: true
#     include directory: /opt/_internal/cpython-3.12.2/lib/python3.12/site-packages/scipy_openblas64/include
#     lib directory: /opt/_internal/cpython-3.12.2/lib/python3.12/site-packages/scipy_openblas64/lib
#     name: scipy-openblas
#     openblas configuration: OpenBLAS 0.3.27  USE64BITINT DYNAMIC_ARCH NO_AFFINITY
#       Zen MAX_THREADS=64
#     pc file directory: /project/.openblas
#     version: 0.3.27
#   lapack:
#     detection method: pkgconfig
#     found: true
#     include directory: /opt/_internal/cpython-3.12.2/lib/python3.12/site-packages/scipy_openblas64/include
#     lib directory: /opt/_internal/cpython-3.12.2/lib/python3.12/site-packages/scipy_openblas64/lib
#     name: scipy-openblas
#     openblas configuration: OpenBLAS 0.3.27  USE64BITINT DYNAMIC_ARCH NO_AFFINITY
#       Zen MAX_THREADS=64
#     pc file directory: /project/.openblas
#     version: 0.3.27
# Compilers:
#   c:
# ...

# %%
print([f.__name__ for f in _SIGNAL_REGISTRY])
# Out:
# ['signal_1', 'signal_8', 'signal_9', 'signal_autocorr', 'signal_entropy', 'signal_kurtosis', 'signal_convexity_gap_adjusted', 'signal_time_underwater', 'signal_run_length', 'signal_record_rate', 'signal_time_since_volume_spike', 'signal_return_iqr', 'signal_burstiness', 'signal_signed_volume_agreement', 'signal_range_return_conflict', 'signal_price_volume_elasticity', 'signal_volume_center_of_mass', 'signal_path_efficiency', 'signal_roughness']

# %%
import numpy as np
# a = np.array([1,1,1,1,1,2,2,2,2])
a = np.array([1,2,1,2,1,2,1,2,1])
print(np.argsort(a))
# Out:
# [0 2 6 4 8 3 5 1 7]

# %%
import pandas as pd, numpy as np
print(pd.__version__, np.__version__)
# Out:
# 2.2.2 2.0.2

# %%
print(signal_pnls.head(50).round(10))
# Out:
#                      signal_1  signal_8  signal_9  signal_autocorr  \
# Date
# 2003-09-10 04:00:00  0.000000  0.000000  0.000000         0.000000
# 2003-09-11 04:00:00  0.000000  0.000000  0.000000         0.000000
# 2003-09-12 04:00:00  0.000000  0.000000  0.000000         0.000000
# 2003-09-15 04:00:00  0.000000 -0.003160  0.000000         0.000000
# 2003-09-16 04:00:00  0.000000 -0.011815  0.000000         0.000000
# 2003-09-17 04:00:00  0.000737  0.006810  0.000000         0.000000
# 2003-09-18 04:00:00 -0.012465 -0.004733  0.000000         0.000000
# 2003-09-19 04:00:00  0.003207 -0.002738  0.000000         0.000000
# 2003-09-22 04:00:00 -0.019454 -0.014202  0.000000         0.000000
# 2003-09-23 04:00:00  0.010337  0.006638  0.000000         0.000000
# 2003-09-24 04:00:00  0.017770  0.023118  0.000000         0.000000
# 2003-09-25 04:00:00  0.006317 -0.000122  0.000000         0.000000
# 2003-09-26 04:00:00 -0.015368 -0.016261  0.000000         0.000000
# ...
